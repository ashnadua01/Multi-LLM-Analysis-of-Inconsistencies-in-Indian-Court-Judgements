# %%
import PyPDF2

# %%
def pdf_to_txt(pdf_file_path, txt_file_path):
    with open(pdf_file_path, 'rb') as pdf_file:
        pdf_reader = PyPDF2.PdfReader(pdf_file)
        
        text = ""
        for page_num in range(len(pdf_reader.pages)):
            page = pdf_reader.pages[page_num]
            text += page.extract_text().rstrip()

    with open(txt_file_path, 'w', encoding='utf-8') as txt_file:
        txt_file.write(text)

# %%
pdf_to_txt('/Users/ashnadua/Desktop/ACM CONFERENCE WORK/FINAL_LIST_DOCS/Smt_Sarla_Mudgal_President_Kalyani_vs_Union_Of_India_Ors_on_10_May_1995.PDF', 'sarla.txt')

# %%
import pandas as pd
import nltk
nltk.download('punkt')  # Download the required NLTK data
# Out:
# [nltk_data] Downloading package punkt to /Users/ashnadua/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
def find_related_sentences(sentences, keyword):
    related_sentences = []

    for i, sentence in enumerate(sentences):
        if keyword in sentence:
            prev_sentence = sentences[i - 1].strip() if i > 0 else None
            next_sentence = sentences[i + 1].strip() if i < len(sentences) - 1 else None
            related_sentences.append({
                "Sentence": sentence.strip(),
                "Previous": prev_sentence,
                "Next": next_sentence
            })

    return related_sentences

# %%
with open('/Users/ashnadua/Desktop/ACM CONFERENCE WORK/codes/Sarla Case/sarla.txt', "r") as file:
    text = file.read()

# Tokenize into sentences using nltk.sent_tokenize()
sentences = nltk.sent_tokenize(text)

keyword = "marriage"
result = []

related_sentences = find_related_sentences(sentences, keyword)
result.extend(related_sentences)

# Create a DataFrame with columns "Sentence," "Previous," and "Next"
output_df = pd.DataFrame(result, columns=["Sentence", "Previous", "Next"])

# Save results to a new CSV
output_df.to_csv("output_sentences_sarla.csv", index=False)

# %%
encodings_to_try = ['utf-8', 'latin1', 'utf-16', 'ISO-8859-1']

# Try reading the CSV file with different encodings
for encoding in encodings_to_try:
    try:
        output_df = pd.read_csv("output_sentences_sarla.csv", encoding=encoding)
        print("CSV file read successfully with encoding:", encoding)
        break  # Exit loop if successful
    except UnicodeDecodeError:
        print("Failed to read CSV file with encoding:", encoding)
        continue  # Try next encoding
# Out:
# CSV file read successfully with encoding: utf-8

# %%
output_df
# Out:
#                                              Sentence  \
# 0   Sarla Mudgal, President, Kalyani & ... vs Unio...
# 1   Whether such a\nmarriage without having the fi...
# 2   In early 1988, the petitioner was shocked to l...
# 3   The marriage was solemnised after they convert...
# 4   It is stated that\nthe conversion to Islam was...
# ..                                                ...
# 75  Bigamous marriage has been made punishable amo...
# 76  The 1772 Regulations followed by the Regulatio...
# 77  It would\nbe necessary to emphasise that the r...
# 78  Answering the questions posed by us in the beg...
# 79  The second marriage would\nbe void in terms of...
#
#                                              Previous  \
# 0   When more than 80% of the citizens have\nalrea...
# 1   Sarla Mudgal, President, Kalyani & ... vs Unio...
# 2   Three children (two sons and a daughter)\nwere...
# 3   In early 1988, the petitioner was shocked to l...
# 4   In December 1991, the petitioner learnt that P...
# ..                                                ...
# 75  It can be superseded by the State just as it c...
# 76  Sarla Mudgal, President, Kalyani & ... vs Unio...
# 77  Those who preferred to\nremain in India after ...
# 78  Sahai, J. in his short and crisp supporting op...
# 79  Answering the questions posed by us in the beg...
#
#                                                  Next
# 0   Whether such a\nmarriage without having the fi...
# 1   Whether the apostate husband\nwould be quilty ...
# 2   The marriage was solemnised after they convert...
# 3   According to the petitioner, conversion of her...
# 4   Sushmita Ghosh is another unfortunate lady who...
# ..                                                ...
# 75  Political history of India shows that during t...
# 76  So far as the criminal justice was concerned\n...
# 77  only under the Regulations of 1781 framed by\n...
# 78  The second marriage would\nbe void in terms of...
# 79  The question of law having been answered we di...
#
# [80 rows x 3 columns]

# %%
concatenated_sen = pd.DataFrame(output_df['Previous'].astype(str) + ' ' + output_df['Sentence'].astype(str) + ' ' + output_df['Next'].astype(str), columns=['concat'])

# %%
print(concatenated_sen['concat'].iloc[0])
# Out:
# When more than 80% of the citizens have
# already been brought under the codified personal law there is no justification
# whatsoever to keep in abeyance, any more, the introduction of "uniform civil code"
# for all citizens in the territory of India.Smt. Sarla Mudgal, President, Kalyani & ... vs Union Of India & Ors on 10 May, 1995
# Indian Kanoon - http://indiankanoon.org/doc/733037/ 2The questions for our consideration are whether a Hindu husband, married under
# Hindu law, by embracing Islam, can solemnise second marriage? Whether such a
# marriage without having the first marriage dissolved under law, would be a valid
# marriage qua the first wife who continue to be Hindu?

# %%
concatenated_sen.to_csv('sentences_final_concatenated_sarla.csv', index=False)

# %%
import csv

# %%
def create_person_id_map(file_path):
    person_id_map = {}

    with open(file_path, 'r') as csvfile:
        reader = csv.reader(csvfile)
        header = next(reader)
        
        for row in reader:
            person_id_list = row[0]
            person = person_id_list.strip()
            person_id = row[1].strip()
            person_id_map[person] = person_id

    return person_id_map

def create_location_id_map(file_path):
    location_id_map = {}

    with open(file_path, 'r') as csvfile:
        reader = csv.reader(csvfile)
        header = next(reader)
        
        for row in reader:
            location_id_list = row[0]
            location = location_id_list.strip()
            location_id = row[1].strip()
            location_id_map[location] = location_id

    return location_id_map

def create_time_id_map(file_path):
    time_id_map = {}

    with open(file_path, 'r') as csvfile:
        reader = csv.reader(csvfile)
        header = next(reader)
        
        for row in reader:
            time_id_list = row[0].split(',')
            time = time_id_list.strip()
            time_id = row[1].strip()
            time_id_map[time] = time_id

    return time_id_map

def create_event_id_map(file_path):
    event_id_map = {}

    with open(file_path, 'r') as csvfile:
        reader = csv.reader(csvfile)
        header = next(reader)
        
        for row in reader:
            event_id_list = row[0].split(',')
            event = event_id_list.strip()
            event_id = row[1].strip()
            event_id_map[event] = event_id

    return event_id_map

def create_other_id_map(file_path):
    other_id_map = {}

    with open(file_path, 'r') as csvfile:
        reader = csv.reader(csvfile)
        header = next(reader)
        
        for row in reader:
            other_id_list = row[0].split(',')
            other = other_id_list.strip()
            other_id = row[1].strip()
            other_id_map[other] = other_id

    return other_id_map

# %%
file_path_person = '/Users/ashnadua/Desktop/ACM CONFERENCE WORK/Entities/Sarla Case/person.csv'
file_path_location = '/Users/ashnadua/Desktop/ACM CONFERENCE WORK/Entities/Sarla Case/location.csv'
file_path_time = '/Users/ashnadua/Desktop/ACM CONFERENCE WORK/Entities/Sarla Case/time.csv'
file_path_event = '/Users/ashnadua/Desktop/ACM CONFERENCE WORK/Entities/Sarla Case/event.csv'
file_path_other = '/Users/ashnadua/Desktop/ACM CONFERENCE WORK/Entities/Sarla Case/activity.csv'
person_id_map = create_person_id_map(file_path_person)
location_id_map = create_location_id_map(file_path_location)
time_id_map = create_location_id_map(file_path_time)
event_id_map = create_location_id_map(file_path_event)
other_id_map = create_location_id_map(file_path_other)

# %%
def generate_ngrams(text, n=6):
    words = text.split()
    ngrams = []
    for j in range(n, 0, -1):
        for i in range(len(words)):
            if i + j <= len(words):
                ngrams.append(' '.join(words[i:i+j]))
    return ngrams

# %%
def preprocess_text(text):
    text = text.replace("'s", "")
    text = text.replace(".", "")
    text = text.replace(";", "")
#     text = text.replace("-", "")
    text = text.replace("!", "")
    text = text.replace("?", "")
#     text = text.replace("/", "")
    text = text.replace("@", "")
    text = text.replace("#", "")
    text = text.replace(",", "")
    return text

# %%
def replace_entities(text):
    text = text.lower()
    ngrams = generate_ngrams(text)
    replaced_text = text

    for ngram in ngrams:
        original = ngram.lower()
        
        if original in person_id_map:
            entity_id = person_id_map[original]
            replaced_text = replaced_text.replace(ngram, entity_id)
        else:
            preprocessed_ngram = preprocess_text(ngram.lower())
            if preprocessed_ngram in person_id_map:
                entity_id = person_id_map[preprocessed_ngram]
                replaced_text = replaced_text.replace(ngram, entity_id)
            else:
                if original in location_id_map:
                    entity_id = location_id_map[original]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif preprocessed_ngram in location_id_map:
                    entity_id = location_id_map[preprocessed_ngram]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif original in time_id_map:
                    entity_id = time_id_map[original]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif preprocessed_ngram in time_id_map:
                    entity_id = time_id_map[preprocessed_ngram]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif original in event_id_map:
                    entity_id = event_id_map[original]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif preprocessed_ngram in event_id_map:
                    entity_id = event_id_map[preprocessed_ngram]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif original in other_id_map:
                    entity_id = other_id_map[original]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif preprocessed_ngram in other_id_map:
                    entity_id = other_id_map[preprocessed_ngram]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                    
    return replaced_text

# %%
with open('sentences_final_concatenated_sarla.csv', 'r', encoding='latin-1') as csvfile:
     reader = csv.reader(csvfile)
     next(reader)
     ref_sen = []
     for row in reader:
         sentence = row[0]
         ref_sen.append(sentence)

# %%
final_sentences = []

for sen in ref_sen:
     s = replace_entities(sen)
     final_sentences.append(s)

# %%
with open('cleaned_sentences_sarla.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Sentences'])
#      for sen in final_sentences:
    for sen in final_sentences:
        writer.writerow([sen])

# %% [markdown]
# ## Matrix Creation

# %%
# with the sentences
import pandas as pd
import csv
import re

# Load the CSV files
time_df = pd.read_csv(file_path_time)
location_df = pd.read_csv(file_path_location)
event_df = pd.read_csv(file_path_event)
person_df = pd.read_csv(file_path_person)
activity_df = pd.read_csv(file_path_other)

location_ID = location_df['Id'].tolist()
location_df = location_df['Location'].tolist()

time_ID = time_df['Id'].tolist()
time_df = time_df['Time'].tolist()

# event_ID = event_df['ID'].tolist()
# event_df = event_df['Event'].tolist()

# person_ID = person_df['ID'].tolist()
# person_df = person_df['Person'].tolist()

# activity_ID = activity_df['ID'].tolist()
# activity_df = activity_df['Others'].tolist()

event_ID_map = dict(zip(event_df['Id'], event_df['Event']))
person_ID_map = dict(zip(person_df['Id'], person_df['Person']))
activity_ID_map = dict(zip(activity_df['Id'], activity_df['Activity']))

matrix = {}

# %%
sentences = []
with open('cleaned_sentences_sarla.csv', 'r', encoding='latin-1') as csvfile:
    reader = csv.reader(csvfile)
    next(reader)
    for row in reader:
        sentence = row[0]
        sentences.append(sentence)

# %%
for s in sentences:
    pattern = r'([PTLEA]\d+)'
    matches = re.findall(pattern, s)

    persons = []
    time = []
    location = []
    event = []
    activity = []

    for match in matches:
        if match[0] == 'P':
            persons.append(person_ID_map.get(match, 'Unknown Person'))
        elif match[0] == 'L':
             location.append(location_ID.index(match))
        elif match[0] == 'E':
            event.append(event_ID_map.get(match, 'Unknown Event'))
        elif match[0] == 'A':
            activity.append(activity_ID_map.get(match, 'Unknown Activity'))
        elif match[0] == 'T':
            time.append(time_ID.index(match))

    if location and time:
        for loc_index in location:
            loc_key = location_df[loc_index]
            for time_index in time:
                time_key = time_df[time_index]
                if time_key not in matrix:
                    matrix[time_key] = {}
                if loc_key not in matrix[time_key]:
                    matrix[time_key][loc_key] = []
                matrix[time_key][loc_key].extend([(entity, s) for entity in (persons + event + activity)])
    elif location:
        for loc_index in location:
            loc_key = location_df[loc_index]
            if loc_key not in matrix:
                matrix[loc_key] = {}
            if 'NULL' not in matrix:
                matrix['NULL'] = {}
            if loc_key not in matrix["NULL"]:
                matrix["NULL"][loc_key] = []
            matrix["NULL"][loc_key].extend([(entity, s) for entity in (persons + event + activity)])
    elif time:
        for time_index in time:
            time_key = time_df[time_index]
            if time_key not in matrix:
                matrix[time_key] = {}
            if 'NULL' not in matrix[time_key]:
                matrix[time_key]['NULL'] = []
            matrix[time_key]["NULL"].extend([(entity, s) for entity in (persons + event + activity)])
    else:
        if 'NULL' not in matrix:
            matrix['NULL'] = {}
        if 'NULL' not in matrix['NULL']:
            matrix['NULL']['NULL'] = []
        matrix["NULL"]["NULL"].extend([(entity, s) for entity in (persons + event + activity)])

matrix_df = pd.DataFrame.from_dict(matrix, orient='index')

# %%
matrix_df.to_csv('matrix_with_sen_sarla.csv')

# %%
import networkx as nx

# %%
df = pd.read_csv('matrix_with_sen_sarla.csv')

# %%
df.rename(columns={'Unnamed: 0': 'Time'}, inplace=True)

# %%
import ast
from tabulate import tabulate
import pandas as pd

def show_10x10_entity_matrix_as_sets(df):
    # Take first 10 rows and first 10 columns EXACTLY
    sub = df.iloc[:10, :10].copy()

    # Convert each cell to a STRING representation of a set of entity IDs, e.g. {P1, E2}
    def to_entity_set(cell):
        if pd.isnull(cell) or str(cell).strip() == "":
            return "{}"
        try:
            parsed = ast.literal_eval(cell)
            entities = [e for e, _ in parsed]
            unique = sorted(set(entities))  # sort for determinism
            if not unique:
                return "{}"
            return "{" + ", ".join(unique) + "}"
        except Exception:
            # If parsing fails, try to extract tokens and make a set
            tokens = [t.strip() for t in str(cell).split(",") if t.strip()]
            unique = sorted(set(tokens))
            return "{" + ", ".join(unique) + "}" if unique else "{}"

    # Apply to each column except 'Time'
    for col in sub.columns:
        if col != "Time":
            sub[col] = sub[col].apply(to_entity_set)

    # Print nicely
    print(tabulate(sub, headers="keys", tablefmt="github", showindex=False))
    return sub

# RUN IT
show_10x10_entity_matrix_as_sets(df)
# Out:
# | Time    | NULL                                                                                                              |
# |---------|-------------------------------------------------------------------------------------------------------------------|
# | nan     | {apostasy, bigamy, conversion, dissolution of the marriage, divorce, marriage, married, marrying again, ran away} |
# | 1988    | {conversion, marriage, solemnised second marriage}                                                                |
# | 1891    | {bigamy, conversion, marriage, married}                                                                           |
# | 1947    | {conversion, convicted for adultery, marriage, married}                                                           |
# | 1946    | {bigamy, divorce, marriage, married}                                                                              |
# | 1872    | {bigamy, divorce, marriage, married}                                                                              |
# | 1955    | {dissolution of the marriage, marriage}                                                                           |
# | 1955-56 | {marriage}                                                                                                        |
# | 1772    | {marriage}                                                                                                        |
# | 1781    | {marriage}                                                                                                        |
#       Time                                               NULL
# 0      NaN  {apostasy, bigamy, conversion, dissolution of ...
# 1     1988  {conversion, marriage, solemnised second marri...
# 2     1891            {bigamy, conversion, marriage, married}
# 3     1947  {conversion, convicted for adultery, marriage,...
# 4     1946               {bigamy, divorce, marriage, married}
# 5     1872               {bigamy, divorce, marriage, married}
# 6     1955            {dissolution of the marriage, marriage}
# 7  1955-56                                         {marriage}
# 8     1772                                         {marriage}
# 9     1781                                         {marriage}

# %%
G = nx.Graph()

for index, row in df.iterrows():
    time = row['Time']
    for location in df.columns:
        if location == 'Time':
            continue
        # Convert the tuple to a string and add it as a node
        G.add_node(f"{time}, {location}")

# %%
import ast

# %%
final = set()

# Update the final set with only the entities
for value in pd.unique(df.drop(columns='Time').values.ravel()):
    if pd.notnull(value):
        value_list = ast.literal_eval(value)
        entity_list = [entity for entity, sentence in value_list]
        final.update(entity_list)

# %%
G.add_nodes_from(final)

# %%
for index, row in df.iterrows():
    time = row['Time']
    for location in df.columns:
        if location == 'Time':
            continue
        if pd.notnull(row[location]):
            value_list = ast.literal_eval(row[location])
            entity_list = [entity for entity, sentence in value_list]
            for entity in entity_list:
                if entity in final:
                    # Convert the tuples to strings and add them as an edge
                    G.add_edge(f"{time}, {location}", entity)

# %%
for node in list(G.nodes):
    if not list(G.neighbors(node)):
        G.remove_node(node)

# %%
for node1 in G.nodes:
    # Check if node1 can be split into a pair
    if ', ' in node1:
        parts1 = node1.split(", ")
        if len(parts1) == 2:  # Ensure it splits into exactly two parts
            time1, location1 = parts1
            for node2 in G.nodes:
                # Check if node2 can be split into a pair
                if ', ' in node2:
                    parts2 = node2.split(", ")
                    if len(parts2) == 2:  # Ensure it splits into exactly two parts
                        time2, location2 = parts2
                        # Add edge if the time or location matches
                        if time1 == time2 or location1 == location2:
                            G.add_edge(node1, node2)

# %%
degree_dict = dict(G.degree(G.nodes()))
nx.set_node_attributes(G, degree_dict, 'degree')

# %%
# Create a dictionary to store the sentences for each node
sentences_dict = {}

# Create a dictionary to store the sentences for each edge i.e. between two nodes
edge_sentences_dict = {}

# Update the sentences_dict and edge_sentences_dict
for index, row in df.iterrows():
    time = row['Time']
    for location in df.columns:
        if location == 'Time':
            continue
        if pd.notnull(row[location]):
            value_list = ast.literal_eval(row[location])
            for entity, sentence in value_list:
                if entity in final:
                    # Add the sentence to the sentences_dict for the entity
                    if entity not in sentences_dict:
                        sentences_dict[entity] = set()
                    sentences_dict[entity].add(sentence)

                    # Add the sentence to the sentences_dict for the (time, location) node
                    time_location_node = f"{time}, {location}"
                    if time_location_node not in sentences_dict:
                        sentences_dict[time_location_node] = set()
                    sentences_dict[time_location_node].add(sentence)

                    # Add the sentence to the edge_sentences_dict for the edge
                    edge = (time_location_node, entity)
                    if edge not in edge_sentences_dict:
                        edge_sentences_dict[edge] = set()
                    edge_sentences_dict[edge].add(sentence)

# Convert the sets back to lists if needed
for node, sentences in sentences_dict.items():
    sentences_dict[node] = list(sentences)

for edge, sentences in edge_sentences_dict.items():
    edge_sentences_dict[edge] = list(sentences)

# %%
pip install node2vec
# Out:
# Requirement already satisfied: node2vec in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (0.5.0)
# Requirement already satisfied: gensim<5.0.0,>=4.3.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from node2vec) (4.4.0)
# Requirement already satisfied: joblib<2.0.0,>=1.4.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from node2vec) (1.4.2)
# Requirement already satisfied: networkx<4.0.0,>=3.1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from node2vec) (3.4.2)
# Requirement already satisfied: numpy<2.0.0,>=1.24.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from node2vec) (1.26.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from node2vec) (4.67.1)
# Requirement already satisfied: scipy>=1.7.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from gensim<5.0.0,>=4.3.0->node2vec) (1.15.1)
# Requirement already satisfied: smart_open>=1.8.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from gensim<5.0.0,>=4.3.0->node2vec) (7.5.0)
# Requirement already satisfied: wrapt in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from smart_open>=1.8.1->gensim<5.0.0,>=4.3.0->node2vec) (2.0.1)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from node2vec import Node2Vec

# Create a Node2Vec instance
node2vec = Node2Vec(G, dimensions=64, walk_length=30, num_walks=200, workers=4)

# Generate embeddings
model = node2vec.fit(window=10, min_count=1, batch_words=4)
# Out:
# Computing transition probabilities:   0%|          | 0/22 [00:00<?, ?it/s]
# Generating walks (CPU: 2): 100%|██████████| 50/50 [00:00<00:00, 368.99it/s]
# Generating walks (CPU: 1): 100%|██████████| 50/50 [00:00<00:00, 367.77it/s]
# Generating walks (CPU: 3): 100%|██████████| 50/50 [00:00<00:00, 363.99it/s]
# Generating walks (CPU: 4): 100%|██████████| 50/50 [00:00<00:00, 363.73it/s]

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Get the node embeddings
node_embeddings = {node: model.wv[node] for node in G.nodes}

# Compute cosine similarity matrix
similarity_matrix = cosine_similarity(list(node_embeddings.values()))

# %%
from sklearn.cluster import DBSCAN

# Initialize DBSCAN
dbscan = DBSCAN(eps=0.5, min_samples=3)  # Adjust parameters as needed

# Fit and predict clusters
labels = dbscan.fit_predict(similarity_matrix)

# %%
cluster_colors = [
    'rgb(31, 119, 180)',  # Blue
    'rgb(255, 127, 14)',  # Orange
    'rgb(44, 160, 44)',   # Green
    'rgb(214, 39, 40)',   # Red
    'rgb(148, 103, 189)', # Purple
    'rgb(140, 86, 75)',   # Brown
    'rgb(227, 119, 194)', # Pink
    'rgb(127, 127, 127)', # Gray
    'rgb(188, 189, 34)',  # Olive
    'rgb(23, 190, 207)',  # Teal
    'rgb(255, 187, 120)', # Peach
    'rgb(214, 39, 40)',   # Maroon
    'rgb(77, 175, 74)',   # Light Green
    'rgb(152, 78, 163)',  # Plum
    'rgb(255, 152, 150)'  # Salmon
]

# %%
import networkx as nx
import plotly.graph_objs as go

# Assuming 'G' is your graph and 'labels' is the list of labels
# Renumber clusters from 1 to 7 if needed, otherwise ensure you have clusters numbered 1 to 7
unique_labels = list(set(labels))
label_mapping = {label: idx+1 for idx, label in enumerate(unique_labels)}

def draw_subgraph_plotly(subgraph, cluster_id, cluster_color):
    pos = nx.spring_layout(subgraph, seed=42)  # Fixed seed for reproducibility
    
    # Extract the node positions
    x_nodes = [pos[node][0] for node in subgraph.nodes()]
    y_nodes = [pos[node][1] for node in subgraph.nodes()]

    # Extract the edges
    edge_x = []
    edge_y = []
    for edge in subgraph.edges():
        x0, y0 = pos[edge[0]]
        x1, y1 = pos[edge[1]]
        edge_x.extend([x0, x1, None])
        edge_y.extend([y0, y1, None])

    # Edge trace
    edge_trace = go.Scatter(
        x=edge_x, y=edge_y,
        line=dict(width=1, color='gray'),
        hoverinfo='none',
        mode='lines')

    # Node trace
    node_trace = go.Scatter(
        x=x_nodes, y=y_nodes,
        mode='markers+text',
        text=[f'{node}' for node in subgraph.nodes()],
        textposition="top center",
        marker=dict(
            showscale=False,
            color=cluster_color,  # Assign the cluster color
            size=20,
            line=dict(width=2, color='black')
        ),
        hoverinfo='text'
    )

    # Create figure
    fig = go.Figure(data=[edge_trace, node_trace],
                    layout=go.Layout(
                        title=f'Cluster {cluster_id}',
                        showlegend=False,
                        hovermode='closest',
                        margin=dict(b=20, l=5, r=5, t=40),
                        xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                        yaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                        height=600,
                        width=600,
                        paper_bgcolor='white',
                        plot_bgcolor='white'
                    ))

    fig.show()

# Iterate over each cluster and draw the subgraph
for original_cluster_id in set(labels):
    cluster_id = label_mapping[original_cluster_id]
    cluster_color = cluster_colors[cluster_id - 1]  # Assign a unique color to each cluster
    cluster_nodes = [node for node, label in zip(G.nodes, labels) if label == original_cluster_id]
    subgraph = G.subgraph(cluster_nodes)
    draw_subgraph_plotly(subgraph, cluster_id, cluster_color)

# %%
# # Initialize lists for nodes and links
# nodes = []
# links = []

# # Add nodes to the list
# for node, sentences in sentences_dict.items():
#     nodes.append({
#         "id": node,
#         "group": 1,  # Update this as needed
#         "size": len(sentences)  # The size could be based on the number of sentences
#     })

# # Add links to the list
# for edge, sentences in edge_sentences_dict.items():
#     source, target = edge
#     links.append({
#         "source": source,
#         "target": target,
#         "value": len(sentences)  # The value could be based on the number of sentences
#     })

# # Combine nodes and links into a single dictionary
# graph_data = {
#     "nodes": nodes,
#     "links": links
# }

# %%
# import os

# os.environ['METIS_DLL'] = '/Users/ashnadua/.local/lib/libmetis.dylib'

# %%
# import metis

# %%
# edgecuts, parts = metis.part_graph(G)

# %%
import json

# Create a mapping from nodes to integers
node_to_int = {node: i for i, node in enumerate(G.nodes)}

# %%
degree_dict = dict(G.degree(G.nodes()))
nx.set_node_attributes(G, degree_dict, 'degree')

data = nx.node_link_data(G)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/networkx/readwrite/json_graph/node_link.py:142: FutureWarning:
#
#
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.

# %%
import numpy as np

# %%
labels = labels.astype(np.int32)

# %%
graph_data = {
    "nodes": [{"name": str(node), "n": degree_dict[node], "grp": int(labels[i]), "id": str(node)} for i, node in enumerate(G.nodes())],
    "links": [{"source": str(link_data['source']), "target": str(link_data['target']), "value": 1} for link_data in data['links']]
}

# %%
json_data = json.dumps(graph_data)
with open('data_sarla.json', 'w') as f:
    f.write(json_data)

# %%
# from collections import defaultdict

# # Create a dictionary where keys are part numbers and values are lists of nodes
# part_dict = defaultdict(list)
# for node, part in enumerate(parts):
#     part_dict[part].append(node)

# # Print the number of parts
# print("Number of parts:", len(part_dict))

# # Print the nodes in each part
# for part, nodes in part_dict.items():
#     print("Part", part, ":", nodes)

# %%
# Assuming you have already created clusters using DBSCAN and have 'labels' and 'G' available

# Initialize an empty dictionary to store sentences for each cluster
cluster_sentences_dict = {}

# Iterate over each cluster
for original_cluster_id in set(labels):
    cluster_id = label_mapping[original_cluster_id]
    cluster_nodes = [node for node, label in zip(G.nodes, labels) if label == original_cluster_id]
    
    # Initialize a set to store sentences for this cluster
    cluster_sentences = set()
    
    # Iterate over nodes in the cluster
    for node in cluster_nodes:
        # Assuming 'node' contains the relevant information (e.g., entity, time, location)
        # Extract sentences associated with this node and add them to the cluster_sentences set
        if node in sentences_dict:
            cluster_sentences.update(sentences_dict[node])
    
    # Store the cluster_sentences set in the cluster_sentences_dict
    cluster_sentences_dict[cluster_id] = cluster_sentences

# %%
sentences_dict
# Out:
# {'married': ['if E20 of\none of the spouses leads to unhappiness, then the ground for dissolution of A30\nwould not be the E20 but the resultant unhappiness. under muslim law,\nE13 from islam of either party to a A30 operates as a complete and\nimmediate E14 but s.4 of the dissolution of muslim\nA30s act (viii of 1939) provides that the renulciation of islam by a A6\nmuslim woman or her E20 to a faith other than islam shall not by itself\noperate to dissolve her A30.',
#   'the second\nA30 of an apostate would, therefore, be illegal A30 qua his wife who A6 him under\nthe act and continues to be hindu. between the apostate and his hindu wife the second A30 is\nin violation of the provisions of the act and as such would be nonest. section 494 indian penal code\nis as under:-\n"marrying again during lifetime of husband or wife.',
#   'in december 1991, the petitioner learnt that pradeep kumar\nE6 with one deepa and after E20 to islam A6 her. it is stated that\nthe E20 to islam was only for the purpose of facilitating the second A30 sushmita ghosh is another unfortunate lady who is petitioner in civil writ petition\n509 of 1992.',
#   'this is a very clear and emphatic indication that the\nindian legislature has departed from; the rigor of the ancient muslim law and has\ntaken the more modern view that there is nothing to prevent a happy A30\nnotwithstanding the fact that the two parties to it professed different religious.. we\nmust also point out that the plaintiff and the defendant were A6 according to the\nzoroastrian rites. they entered into a solemn pact that the A30 would be\nmonogamous and could only be dissolved according to the tenets of the zoroastrian\nreligion. it would be patently contrary to justice and right that one party to a solemn\npact should be allowed to repudiate it by a unilateral act.',
#   'sarla mudgal, president, kalyani & ... vs union of india & ors on 10 may, 1995\nindian kanoon - http://indiankanoon.org/doc/733037/ 7A30. section 17 provides the only means for the dissolution of a A30 or a\ndeclaration of its nullity. consequently, where two persons A6 under the act subsequently become\nconverted to islam, the A30 can only be dissolved under the provisions of the\nA9 act and the same would apply even if only one of them becomes converted to\nislam.',
#   'a christian lady was A6 according to the christian rites. years later she\nembraced islamic faith and got A6 by the registrar of muslim marriages at colombo according\nto the statutory formalities prescribed for a muslim A30 the husband was charged and\nconvicted by the supreme court, ceylon of the offence of E11 under the ceylon penal code.',
#   'it would be tantamount to\npermitting the wife to force a A9 upon her husband although he may not want it\nand although the A30 vows which both of them have taken would not permit it. we might also point out that the shariat act (act xxvi of 1937) provides that the rule\nof decision in the various cases enumerated in s.2 which includes A30 and\ndissolution of A30 shall be the muslim personal law only where the parties are\nmuslims; it does not provide that the muslim personal law shall apply when only one\nof the parties is a muslim." (the single judge judgment and the division bench\njudgment are reported in T18 bombay law reporter 864) in andal vaidyanathan\nvs. abdul allam vaidya T18 madras, a division bench of the high court dealing\nwith a A30 under the special A30 act T32 held:\n"the special A30 act clearly only contemplates monogamy and a person\nA6 under the act cannot escape from its provisions by merely changing his\nreligion.',
#   'a\nsecond A30 by an apostate under the shelter of E20 to islam would nevertheless be a\nA30 in violation of the provisions of the act by which he would be continuing to be governed so\nfar as his first A30 under the act is concerned despite his E20 to islam. the second\nA30 of an apostate would, therefore, be illegal A30 qua his wife who A6 him under\nthe act and continues to be hindu. between the apostate and his hindu wife the second A30 is\nin violation of the provisions of the act and as such would be nonest.',
#   'we might also point out that the shariat act (act xxvi of 1937) provides that the rule\nof decision in the various cases enumerated in s.2 which includes A30 and\ndissolution of A30 shall be the muslim personal law only where the parties are\nmuslims; it does not provide that the muslim personal law shall apply when only one\nof the parties is a muslim." (the single judge judgment and the division bench\njudgment are reported in T18 bombay law reporter 864) in andal vaidyanathan\nvs. abdul allam vaidya T18 madras, a division bench of the high court dealing\nwith a A30 under the special A30 act T32 held:\n"the special A30 act clearly only contemplates monogamy and a person\nA6 under the act cannot escape from its provisions by merely changing his\nreligion. such a person commits E11 if he marries again during the lifetime of his\nspouse, and it matters not what religion he professes at the time of the secondsmt.',
#   'section 17 provides the only means for the dissolution of a A30 or a\ndeclaration of its nullity. consequently, where two persons A6 under the act subsequently become\nconverted to islam, the A30 can only be dissolved under the provisions of the\nA9 act and the same would apply even if only one of them becomes converted to\nislam. such a A30 is not a A30 in the mahomoden sense which can be\ndissolved in a mahomedan manner.',
#   'when more than 80% of the citizens have\nalready been brought under the codified personal law there is no justification\nwhatsoever to keep in abeyance, any more, the introduction of "uniform civil code"\nfor all citizens in the territory of india.smt. sarla mudgal, president, kalyani & ... vs union of india & ors on 10 may, 1995\nindian kanoon - http://indiankanoon.org/doc/733037/ 2the questions for our consideration are whether a hindu husband, A6 under\nhindu law, by embracing islam, can solemnise second A30 whether such a\nA30 without having the first A30 dissolved under law, would be a valid\nA30 qua the first wife who continue to be hindu?',
#   'but s.4 of the dissolution of muslim\nA30s act (viii of 1939) provides that the renulciation of islam by a A6\nmuslim woman or her E20 to a faith other than islam shall not by itself\noperate to dissolve her A30 this is a very clear and emphatic indication that the\nindian legislature has departed from; the rigor of the ancient muslim law and has\ntaken the more modern view that there is nothing to prevent a happy A30\nnotwithstanding the fact that the two parties to it professed different religious.. we\nmust also point out that the plaintiff and the defendant were A6 according to the\nzoroastrian rites. they entered into a solemn pact that the A30 would be\nmonogamous and could only be dissolved according to the tenets of the zoroastrian\nreligion.',
#   "consequently, where two persons A6 under the act subsequently become\nconverted to islam, the A30 can only be dissolved under the provisions of the\nA9 act and the same would apply even if only one of them becomes converted to\nislam. such a A30 is not a A30 in the mahomoden sense which can be\ndissolved in a mahomedan manner. it is a statutory A30 and can only be\ndissolved in accordance with the statute: ('41) 28 a.i.r.1941 cal.",
#   'sarla mudgal, president, kalyani & ... vs union of india & ors on 10 may, 1995\nindian kanoon - http://indiankanoon.org/doc/733037/ 2the questions for our consideration are whether a hindu husband, A6 under\nhindu law, by embracing islam, can solemnise second A30 whether such a\nA30 without having the first A30 dissolved under law, would be a valid\nA30 qua the first wife who continue to be hindu? whether the apostate husband\nwould be quilty of the offence under section 494 of the indian penal code (ipc)?',
#   'there are many other ties which make it possible for a husband and wife to\nlive happily and contentedly together. it would indeed be a startling proposition to\nlay down that although two persons may want to continue to live in a A6 state\nand disagree as to the religion they should profess, their A30 must be\nautomatically dissolved. mr. peerbhoy has urged that it is rarely possible for two\npersons of different communities to be happily united in wedlock.',
#   'it is obvious from the various provisions of the act that the modern hindu law strictly enforces\nmonogamy. a A30 performed under the act cannot be dissolved except on the grounds\navailable under section 13 of the act. in that situation parties who have solemnised the A30\nunder the act remain A6 even when the husband embraces islam in pursuit of other wife.',
#   'it would be useful to have a look at some of the old cases on the subject. in\nre ram kumari T13 calcutta 246 where a hindu wife became convert to the muslim\nfaith and then A6 a mohammedan, it was held that her earlier A30 with a\nhindu husband was not dissolved by her E20 she was charged and convicted\nof E11 under section 494 of the ipc.',
#   'the\nchristian wife renounced christianity and embraced islam and then A6 a\nmohomedan. it was held that according to the christian A30 law, which was the\nlaw applicable to the case, the first A30 was not dissolved and therefore thesmt. sarla mudgal, president, kalyani & ... vs union of india & ors on 10 may, 1995\nindian kanoon - http://indiankanoon.org/doc/733037/ 4subsequent A30 was bigamous.',
#   'under muslim law,\nE13 from islam of either party to a A30 operates as a complete and\nimmediate E14 but s.4 of the dissolution of muslim\nA30s act (viii of 1939) provides that the renulciation of islam by a A6\nmuslim woman or her E20 to a faith other than islam shall not by itself\noperate to dissolve her A30. this is a very clear and emphatic indication that the\nindian legislature has departed from; the rigor of the ancient muslim law and has\ntaken the more modern view that there is nothing to prevent a happy A30\nnotwithstanding the fact that the two parties to it professed different religious.. we\nmust also point out that the plaintiff and the defendant were A6 according to the\nzoroastrian rites.',
#   'in that situation parties who have solemnised the A30\nunder the act remain A6 even when the husband embraces islam in pursuit of other wife. a\nsecond A30 by an apostate under the shelter of E20 to islam would nevertheless be a\nA30 in violation of the provisions of the act by which he would be continuing to be governed so\nfar as his first A30 under the act is concerned despite his E20 to islam. the second\nA30 of an apostate would, therefore, be illegal A30 qua his wife who A6 him under\nthe act and continues to be hindu.',
#   'a A30 performed under the act cannot be dissolved except on the grounds\navailable under section 13 of the act. in that situation parties who have solemnised the A30\nunder the act remain A6 even when the husband embraces islam in pursuit of other wife. a\nsecond A30 by an apostate under the shelter of E20 to islam would nevertheless be a\nA30 in violation of the provisions of the act by which he would be continuing to be governed so\nfar as his first A30 under the act is concerned despite his E20 to islam.',
#   'in gul mohammed v. emperor air T15 nagpur 121 a hindu\nwife was fraudulently taken away by the accused a mohammedan who A6 her\naccording to muslim law after converting her to islam. it was held that the\nE20 of the hindu wife to mohammedan faith did not ipso facto dissolve the\nA30 and she could not during the life time of her former husband enter into a\nvalid contract of A30. accordingly the accused was A15 under\nsection 497 of the ipc.'],
#  'nan, NULL': ['if E20 of\none of the spouses leads to unhappiness, then the ground for dissolution of A30\nwould not be the E20 but the resultant unhappiness. under muslim law,\nE13 from islam of either party to a A30 operates as a complete and\nimmediate E14 but s.4 of the dissolution of muslim\nA30s act (viii of 1939) provides that the renulciation of islam by a A6\nmuslim woman or her E20 to a faith other than islam shall not by itself\noperate to dissolve her A30.',
#   'the doctrine of indissolubility of A30 under the traditional hindu law, did not\nrecognise that E20 would have the effect of dissolving a hindu A30 E20 to another religion by one or both the hindu spouses did not dissolve the\nA30 it would be useful to have a look at some of the old cases on the subject.',
#   'the second\nA30 of an apostate would, therefore, be illegal A30 qua his wife who A6 him under\nthe act and continues to be hindu. between the apostate and his hindu wife the second A30 is\nin violation of the provisions of the act and as such would be nonest. section 494 indian penal code\nis as under:-\n"marrying again during lifetime of husband or wife.',
#   'it may be that a A30 solemnised according to jesish\nrites may be dissolved by the proper authority under jewish law when one of the\nparties renounces the jewish faith. it may be that a A30 solemnised according\nto mahommedan law may be dissolved according to the mahommedan law when\none of the parties ceases to be a mahommedan. but i can find no authority for the\nview that a A30 solemnized according to one personal law can be dissolved\naccording to another personal law simply because one of the two parties has changed\nhis or her religion."',
#   'in december 1991, the petitioner learnt that pradeep kumar\nE6 with one deepa and after E20 to islam A6 her. it is stated that\nthe E20 to islam was only for the purpose of facilitating the second A30 sushmita ghosh is another unfortunate lady who is petitioner in civil writ petition\n509 of 1992.',
#   'this is a very clear and emphatic indication that the\nindian legislature has departed from; the rigor of the ancient muslim law and has\ntaken the more modern view that there is nothing to prevent a happy A30\nnotwithstanding the fact that the two parties to it professed different religious.. we\nmust also point out that the plaintiff and the defendant were A6 according to the\nzoroastrian rites. they entered into a solemn pact that the A30 would be\nmonogamous and could only be dissolved according to the tenets of the zoroastrian\nreligion. it would be patently contrary to justice and right that one party to a solemn\npact should be allowed to repudiate it by a unilateral act.',
#   'sarla mudgal, president, kalyani & ... vs union of india & ors on 10 may, 1995\nindian kanoon - http://indiankanoon.org/doc/733037/ 8of section 5." "A9d persons when may marry again.- when a A30 has been dissolved by a\ndecree of A9 and either there is no right of appeal against the decree or, of there\nis such a right of appeal the time for appealing has expired without an appeal having\nbeen presented or an appeal has been presented but has been dismissed, it shall be\nlawful for either party to the A30 to marry again." it is obvious from the various provisions of the act that the modern hindu law strictly enforces\nmonogamy.',
#   'sarla mudgal, president, kalyani & ... vs union of india & ors on 10 may, 1995\nindian kanoon - http://indiankanoon.org/doc/733037/ 9a hindu A30 solemnised under the act can only be dissolved on any of the grounds specified\nunder the act. till the time a hindu A30 is dissolved under the act none of the spouses can\ncontract second A30. E20 to islam and A7 would not, by itself, dissolve the\nhindu A30 under the act.',
#   'there is no general matrimonial law regarding mixed A30s other\nthan the statute law, and there is no suggestion that the statute law is applicable in\nthe present case.. it may be that a A30 solemnised according to jewish rites may\nbe dissolved by the proper authority under jewish law when one of the parties\nrenounces the jewish faith. it may be that a A30 solemnised according to jesish\nrites may be dissolved by the proper authority under jewish law when one of the\nparties renounces the jewish faith.',
#   'but there is no rule of english law which can be made applicable\nto a suit for A9 by a muslim wife against her zoroastrian husband. the english\nlaw only deals and can only deal with christian marriages and with grounds for\ndissolving a christian marriage.smt. sarla mudgal, president, kalyani & ... vs union of india & ors on 10 may, 1995\nindian kanoon - http://indiankanoon.org/doc/733037/ 6therefore we must decided according to justice and right, or equity and good\nconscience independently of any provisions of the english law.',
#   'sarla mudgal, president, kalyani & ... vs union of india & ors on 10 may, 1995\nindian kanoon - http://indiankanoon.org/doc/733037/ 7A30. section 17 provides the only means for the dissolution of a A30 or a\ndeclaration of its nullity. consequently, where two persons A6 under the act subsequently become\nconverted to islam, the A30 can only be dissolved under the provisions of the\nA9 act and the same would apply even if only one of them becomes converted to\nislam.',
#   'the bench upheld the judgment of blagden, j. and dismissed the appeal. chagla, j. chagla, j. elaborating the legal position held as under:-\n"we have here a muslim wife according to whose personal law E20 to islam, if\nthe other spouse does not embrace the same religion, automatically dissolves the\nA30 we have a zoroastrian husband according to whose personal law such\nE20 does not bring about the same result.',
#   'the necessary ingredients of the section are: (1) having a husband or wife living; (2)\nmarries in any case; (3) in which such A30 is void; (4) by reason of its taking\nplace during the life of such husband or wife. it is no doubt correct that the A30 solemnised by a hindu husband after embracing islam may\nnot be strictly a void A30 under the act because he is no longer a hindu, but the fact remains\nthat the said A30 would be in violation of the act which strictly professes monogamy. the expression "void" for the purpose of the act has been defined under section 11 of the act.',
#   'answering the questions posed by us in the beginning of the judgment, we hold that\nthe second A30 of a hindu- husband after E20 to islam, without having\nhis first A30 dissolved under law, would be invalid. the second A30 would\nbe void in terms of the provisions of section 494 ipc and the apostate-husband\nwould be guilty of the offence under section 494 ipc. the question of law having been answered we dispose of the writ petitions.',
#   'a christian lady was A6 according to the christian rites. years later she\nembraced islamic faith and got A6 by the registrar of muslim marriages at colombo according\nto the statutory formalities prescribed for a muslim A30 the husband was charged and\nconvicted by the supreme court, ceylon of the offence of E11 under the ceylon penal code.',
#   'she was charged with an offence under section 494\nof the indian penal code. it was held that the mere fact of her E20 to islam did\nnot dissolve the A30 which could only be dissolved by a decree of court. emperor vs. mt.',
#   'it is the foundation of the family and in turn of the society without which\nno civilisation can exist. till the time we achieve the goal - uniform civil code for all the citizens of india -\nthere is an open inducement to a hindu husband, who wants to enter into second\nA30 while the first A30 is subsisting, to become a muslim. since monogamy\nis the law for hindus and the muslim law permits as many as four wives in india,\nerrand hindu husband embraces islam to circumvent the provisions of the hindu\nlaw and to escape from penal consequences.',
#   'a\nsecond A30 by an apostate under the shelter of E20 to islam would nevertheless be a\nA30 in violation of the provisions of the act by which he would be continuing to be governed so\nfar as his first A30 under the act is concerned despite his E20 to islam. the second\nA30 of an apostate would, therefore, be illegal A30 qua his wife who A6 him under\nthe act and continues to be hindu. between the apostate and his hindu wife the second A30 is\nin violation of the provisions of the act and as such would be nonest.',
#   'looked from another angle, the second A30 of an apostate-husband would be in violation of\nthe rules of natural justice. assuming that a hindu husband has a right to embrace islam as his\nreligion, he has no right under the act to marry again without getting his A30 under the act\ndissolved. the second A30 after E20 to islam would, thus, be in violation of the rules of\nnatural justice and as such would be void.',
#   'it can be superseded by the state just as it can prohibit human sacrifice or the practice of\n"suttee" in the interest of public order. bigamous A30 has been made punishable amongst\nchristians by act (xv of 1872), parsis by act (iii of 1936) and hindus, buddhists, sikhs and jains by\nact (xxv of 1955). political history of india shows that during the muslim regime, justice was administered by the\nqazis who would obviously apply the muslim scriptural law to muslims, but there was no similar\nassurance so far litigations concerning hindus was concerned.',
#   'section 494 indian penal code\nis as under:-\n"marrying again during lifetime of husband or wife. whoever, having a husband or\nwife living, marries in any case in which such A30 is void by reason of its taking\nplace during the life of such husband or wife, shall be punished with imprisonment of\neither description for a term which may extend to seven years, and shall also be liable\nto fine. the necessary ingredients of the section are: (1) having a husband or wife living; (2)\nmarries in any case; (3) in which such A30 is void; (4) by reason of its taking\nplace during the life of such husband or wife.',
#   'the wife\nbecame muslim whereas the husband declined to do so. the wife claimed that her\nA30 stood dissolved because of her E20 to islam. the learned judge\ndismissed the suit.',
#   'save as otherwise expressly provided in this act,-\n(a) any text, rule or interpretation of hindu law or any custom or usage as part of that\nlaw in force immediately before the commencement of this act shall cease to have\neffect with respect to any matter for which provision is made in this act;\n(b) any other law in force immediately before the commencement of this act shall\ncease to have effect in so far as it is inconsistent with any of the provisions contained\nin this act." a A30 solemnised, whether before or after the commencement of the act, can only be dissolved\nby a decree of A9 on any of the grounds enumerated in section 13 of the act. one of the grounds\nunder section 13 (i) (ii) is that "the other party has ceased to be a hindu by E20 to another\nreligion".',
#   'i can see no reason why the mahommedan\nlaw should be preferred to the jewish law in a matrimonial dispute between a\nmahommdan and a jew particularly when the relationship, viz. : A30 was\ncreated under the jewish law.. as i stated in a previous case there is no matrimonial\nlaw of general application in india. there is a hindu law for hindus, a\nmahommedan law for mahommedans, a christian law for christians, and a jewish\nlaw for jews.',
#   'it may be that a A30 solemnised according to jewish rites may\nbe dissolved by the proper authority under jewish law when one of the parties\nrenounces the jewish faith. it may be that a A30 solemnised according to jesish\nrites may be dissolved by the proper authority under jewish law when one of the\nparties renounces the jewish faith. it may be that a A30 solemnised according\nto mahommedan law may be dissolved according to the mahommedan law when\none of the parties ceases to be a mahommedan.',
#   'a A30 which is\nin violation of any provisions of law would be void in terms of the expression used under section\n494, ipc.smt. sarla mudgal, president, kalyani & ... vs union of india & ors on 10 may, 1995\nindian kanoon - http://indiankanoon.org/doc/733037/ 9a hindu A30 solemnised under the act can only be dissolved on any of the grounds specified\nunder the act. till the time a hindu A30 is dissolved under the act none of the spouses can\ncontract second A30.',
#   'the said\nA30 is void by reason of its taking place during the life of the first wife.smt. sarla mudgal, president, kalyani & ... vs union of india & ors on 10 may, 1995\nindian kanoon - http://indiankanoon.org/doc/733037/ 10we, therefore, hold that the second A30 of a hindu husband after his E20 to islam is a\nvoid A30 in terms of section 494 ipc. we may at this stage notice the privy council judgment in attorney general ceylon vs. reid (1965\nal.',
#   'it such inherent right is to be abrogated, it must\nbe done by statute." despite there being an inherent right to change religion the applicability of penal laws would\ndepend upon the two personal laws governing the A30 the decision of privy council was on\nthe facts of the case, specially in the background of the two personal laws operating in ceylon.',
#   'section 17 provides the only means for the dissolution of a A30 or a\ndeclaration of its nullity. consequently, where two persons A6 under the act subsequently become\nconverted to islam, the A30 can only be dissolved under the provisions of the\nA9 act and the same would apply even if only one of them becomes converted to\nislam. such a A30 is not a A30 in the mahomoden sense which can be\ndissolved in a mahomedan manner.',
#   'when more than 80% of the citizens have\nalready been brought under the codified personal law there is no justification\nwhatsoever to keep in abeyance, any more, the introduction of "uniform civil code"\nfor all citizens in the territory of india.smt. sarla mudgal, president, kalyani & ... vs union of india & ors on 10 may, 1995\nindian kanoon - http://indiankanoon.org/doc/733037/ 2the questions for our consideration are whether a hindu husband, A6 under\nhindu law, by embracing islam, can solemnise second A30 whether such a\nA30 without having the first A30 dissolved under law, would be a valid\nA30 qua the first wife who continue to be hindu?',
#   'sarla mudgal, president, kalyani & ... vs union of india & ors on 10 may, 1995\nindian kanoon - http://indiankanoon.org/doc/733037/ 3embraced islam. in the writ petition, the petitioner has further prayed that her\nhusband be restrained from entering into second A30 with vinita gupta. A30 is the very foundation of the civilised society.',
#   'apart from\nstatute law a A30 was governed by the personal law of the parties. a A30\nsolemnised under a particular statute and according to personal law could not be\ndissolved according to another personal law, simply because one of the parties had\nchanged his or her religion. in sayeda khatoon @ a.m. obadiah vs. m. obadiah 49 cwn 745, lodge, j. speaking\nfor the court held as under:\n"the parties were originally jews bound by the jewish personal law...',
#   'in india there has never been a matrimonial law of general application. apart from\nstatute law a A30 was governed by the personal law of the parties. a A30\nsolemnised under a particular statute and according to personal law could not be\ndissolved according to another personal law, simply because one of the parties had\nchanged his or her religion.',
#   'the expression "void" under section 494, ipc has been used in the wider sense. a A30 which is\nin violation of any provisions of law would be void in terms of the expression used under section\n494, ipc.smt. sarla mudgal, president, kalyani & ... vs union of india & ors on 10 may, 1995\nindian kanoon - http://indiankanoon.org/doc/733037/ 9a hindu A30 solemnised under the act can only be dissolved on any of the grounds specified\nunder the act.',
#   'but s.4 of the dissolution of muslim\nA30s act (viii of 1939) provides that the renulciation of islam by a A6\nmuslim woman or her E20 to a faith other than islam shall not by itself\noperate to dissolve her A30 this is a very clear and emphatic indication that the\nindian legislature has departed from; the rigor of the ancient muslim law and has\ntaken the more modern view that there is nothing to prevent a happy A30\nnotwithstanding the fact that the two parties to it professed different religious.. we\nmust also point out that the plaintiff and the defendant were A6 according to the\nzoroastrian rites. they entered into a solemn pact that the A30 would be\nmonogamous and could only be dissolved according to the tenets of the zoroastrian\nreligion.',
#   "such a A30 is not a A30 in the mahomoden sense which can be\ndissolved in a mahomedan manner. it is a statutory A30 and can only be\ndissolved in accordance with the statute: ('41) 28 a.i.r.1941 cal. 582 and (1917) 1\nk.b.",
#   "consequently, where two persons A6 under the act subsequently become\nconverted to islam, the A30 can only be dissolved under the provisions of the\nA9 act and the same would apply even if only one of them becomes converted to\nislam. such a A30 is not a A30 in the mahomoden sense which can be\ndissolved in a mahomedan manner. it is a statutory A30 and can only be\ndissolved in accordance with the statute: ('41) 28 a.i.r.1941 cal.",
#   'any act which is in violation of mandatory\nprovisions of law is per-se void. the real reason for the voidness of the second A30 is the subsisting of the first A30 which\nis not dissolved even by the E20 of the husband. it would be giving a go-bye to the substance\nof the matter and acting against the spirit of the statute if the second A30 of the convert is held\nto be legal.',
#   'sahai, j. in his short and crisp supporting opinion has\nsuggested some of the measures which can be undertaken by the government in this\nrespect. answering the questions posed by us in the beginning of the judgment, we hold that\nthe second A30 of a hindu- husband after E20 to islam, without having\nhis first A30 dissolved under law, would be invalid. the second A30 would\nbe void in terms of the provisions of section 494 ipc and the apostate-husband\nwould be guilty of the offence under section 494 ipc.',
#   'it is difficult to see why the E20 of one\nparty to a A30 should necessarily afford a ground for its dissolution. the bond\nthat keeps a man and woman happy in A30 is not exclusively the bond of\nreligion. there are many other ties which make it possible for a husband and wife to\nlive happily and contentedly together.',
#   'such a person commits E11 if he marries again during the lifetime of his\nspouse, and it matters not what religion he professes at the time of the secondsmt. sarla mudgal, president, kalyani & ... vs union of india & ors on 10 may, 1995\nindian kanoon - http://indiankanoon.org/doc/733037/ 7A30. section 17 provides the only means for the dissolution of a A30 or a\ndeclaration of its nullity.',
#   'sarla mudgal, president, kalyani & ... vs union of india & ors on 10 may, 1995\nindian kanoon - http://indiankanoon.org/doc/733037/ 2the questions for our consideration are whether a hindu husband, A6 under\nhindu law, by embracing islam, can solemnise second A30 whether such a\nA30 without having the first A30 dissolved under law, would be a valid\nA30 qua the first wife who continue to be hindu? whether the apostate husband\nwould be quilty of the offence under section 494 of the indian penal code (ipc)?',
#   'the second A30 of a hindu husband\nafter embracing islam being violative of justice, equity and good conscience would be void on that\nground also and attract the provisions of section 494, ipc. looked from another angle, the second A30 of an apostate-husband would be in violation of\nthe rules of natural justice. assuming that a hindu husband has a right to embrace islam as his\nreligion, he has no right under the act to marry again without getting his A30 under the act\ndissolved.',
#   'there is a hindu law for hindus, a\nmahommedan law for mahommedans, a christian law for christians, and a jewish\nlaw for jews. there is no general matrimonial law regarding mixed A30s other\nthan the statute law, and there is no suggestion that the statute law is applicable in\nthe present case.. it may be that a A30 solemnised according to jewish rites may\nbe dissolved by the proper authority under jewish law when one of the parties\nrenounces the jewish faith.',
#   'he has a wife living, he marries again. the said\nA30 is void by reason of its taking place during the life of the first wife.smt. sarla mudgal, president, kalyani & ... vs union of india & ors on 10 may, 1995\nindian kanoon - http://indiankanoon.org/doc/733037/ 10we, therefore, hold that the second A30 of a hindu husband after his E20 to islam is a\nvoid A30 in terms of section 494 ipc.',
#   'E20 to islam and A7 would not, by itself, dissolve the\nhindu A30 under the act. the second A30 by a convert would therefore be in violation of\nthe act and as such void in terms of section 494, ipc. any act which is in violation of mandatory\nprovisions of law is per-se void.',
#   'one of the grounds\nunder section 13 (i) (ii) is that "the other party has ceased to be a hindu by E20 to another\nreligion". sections 11 and 15 of the act is as under:-\n"void A30s:- any A30 solemnized after the commencement of this act shall be null and\nvoid and may, on a petition presented by either party thereto against the other party, be so declared\nby a decree of nullity if it contravenes any one of the conditions specified in clauses (i), (iv) and (v)smt. sarla mudgal, president, kalyani & ... vs union of india & ors on 10 may, 1995\nindian kanoon - http://indiankanoon.org/doc/733037/ 8of section 5."',
#   'there are many other ties which make it possible for a husband and wife to\nlive happily and contentedly together. it would indeed be a startling proposition to\nlay down that although two persons may want to continue to live in a A6 state\nand disagree as to the religion they should profess, their A30 must be\nautomatically dissolved. mr. peerbhoy has urged that it is rarely possible for two\npersons of different communities to be happily united in wedlock.',
#   'it is obvious from the various provisions of the act that the modern hindu law strictly enforces\nmonogamy. a A30 performed under the act cannot be dissolved except on the grounds\navailable under section 13 of the act. in that situation parties who have solemnised the A30\nunder the act remain A6 even when the husband embraces islam in pursuit of other wife.',
#   'the\nchristian wife renounced christianity and embraced islam and then A6 a\nmohomedan. it was held that according to the christian A30 law, which was the\nlaw applicable to the case, the first A30 was not dissolved and therefore thesmt. sarla mudgal, president, kalyani & ... vs union of india & ors on 10 may, 1995\nindian kanoon - http://indiankanoon.org/doc/733037/ 4subsequent A30 was bigamous.',
#   'under muslim law,\nE13 from islam of either party to a A30 operates as a complete and\nimmediate E14 but s.4 of the dissolution of muslim\nA30s act (viii of 1939) provides that the renulciation of islam by a A6\nmuslim woman or her E20 to a faith other than islam shall not by itself\noperate to dissolve her A30. this is a very clear and emphatic indication that the\nindian legislature has departed from; the rigor of the ancient muslim law and has\ntaken the more modern view that there is nothing to prevent a happy A30\nnotwithstanding the fact that the two parties to it professed different religious.. we\nmust also point out that the plaintiff and the defendant were A6 according to the\nzoroastrian rites.',
#   'assuming that a hindu husband has a right to embrace islam as his\nreligion, he has no right under the act to marry again without getting his A30 under the act\ndissolved. the second A30 after E20 to islam would, thus, be in violation of the rules of\nnatural justice and as such would be void. the interpretation we have given to section 494 ipc would advance the interest of justice.',
#   'it was held that according to the christian A30 law, which was the\nlaw applicable to the case, the first A30 was not dissolved and therefore thesmt. sarla mudgal, president, kalyani & ... vs union of india & ors on 10 may, 1995\nindian kanoon - http://indiankanoon.org/doc/733037/ 4subsequent A30 was bigamous. in india there has never been a matrimonial law of general application.',
#   'in that situation parties who have solemnised the A30\nunder the act remain A6 even when the husband embraces islam in pursuit of other wife. a\nsecond A30 by an apostate under the shelter of E20 to islam would nevertheless be a\nA30 in violation of the provisions of the act by which he would be continuing to be governed so\nfar as his first A30 under the act is concerned despite his E20 to islam. the second\nA30 of an apostate would, therefore, be illegal A30 qua his wife who A6 him under\nthe act and continues to be hindu.',
#   'in\nan appeal before the privy council, the respondent was absolved from the offence of E11 it was\nheld by privy council as under :-\n"in their lordship\'s view, in such countries there must be an inherent right in the\ninhabitants domiciled there to change their religion and personal law and so to\ncontract a valid polygamous A30 if recognised by the laws of the country\nnotwithstanding an earlier A30. it such inherent right is to be abrogated, it must\nbe done by statute."',
#   'whoever, having a husband or\nwife living, marries in any case in which such A30 is void by reason of its taking\nplace during the life of such husband or wife, shall be punished with imprisonment of\neither description for a term which may extend to seven years, and shall also be liable\nto fine. the necessary ingredients of the section are: (1) having a husband or wife living; (2)\nmarries in any case; (3) in which such A30 is void; (4) by reason of its taking\nplace during the life of such husband or wife. it is no doubt correct that the A30 solemnised by a hindu husband after embracing islam may\nnot be strictly a void A30 under the act because he is no longer a hindu, but the fact remains\nthat the said A30 would be in violation of the act which strictly professes monogamy.',
#   'it is impossible to\naccept the contention of mr. peerbhoy that justice and right requires that we should\napply muslim law in dealing this case. it is difficult to see why the E20 of one\nparty to a A30 should necessarily afford a ground for its dissolution. the bond\nthat keeps a man and woman happy in A30 is not exclusively the bond of\nreligion.',
#   'since monogamy\nis the law for hindus and the muslim law permits as many as four wives in india,\nerrand hindu husband embraces islam to circumvent the provisions of the hindu\nlaw and to escape from penal consequences. the doctrine of indissolubility of A30 under the traditional hindu law, did not\nrecognise that E20 would have the effect of dissolving a hindu A30 E20 to another religion by one or both the hindu spouses did not dissolve the\nA30',
#   'it would be patently contrary to justice and right that one party to a solemn\npact should be allowed to repudiate it by a unilateral act. it would be tantamount to\npermitting the wife to force a A9 upon her husband although he may not want it\nand although the A30 vows which both of them have taken would not permit it. we might also point out that the shariat act (act xxvi of 1937) provides that the rule\nof decision in the various cases enumerated in s.2 which includes A30 and\ndissolution of A30 shall be the muslim personal law only where the parties are\nmuslims; it does not provide that the muslim personal law shall apply when only one\nof the parties is a muslim."',
#   '264, disting." it is, thus, obvious from the catena of case-low that a A30 celebrated under a particular\npersonal law cannot be dissolved by the application of another personal law to which one of the\nspouses converts and the other refuses to do so. where a A30 takes place under hindu law the\nparties acquire a status and certain rights by the A30 itself under the law governing the hindu\nA30 and if one of the parties is allowed to dissolve the A30 by adopting and enforcing a\nnew personal law, it would tantamount to destroying the existing rights of the other spouse who\ncontinues to be hindu.',
#   'a A30 performed under the act cannot be dissolved except on the grounds\navailable under section 13 of the act. in that situation parties who have solemnised the A30\nunder the act remain A6 even when the husband embraces islam in pursuit of other wife. a\nsecond A30 by an apostate under the shelter of E20 to islam would nevertheless be a\nA30 in violation of the provisions of the act by which he would be continuing to be governed so\nfar as his first A30 under the act is concerned despite his E20 to islam.',
#   "the real reason for the voidness of the second A30 is the subsisting of the first A30 which\nis not dissolved even by the E20 of the husband. it would be giving a go-bye to the substance\nof the matter and acting against the spirit of the statute if the second A30 of the convert is held\nto be legal. we also agree with the law laid down by chagla, j. in robasa khanum vs. khodabad irani's case\n(supra) wherein the learned judge has held that the conduct of a spouse who converts to islam has\nto be judged on the basis of the rule of justice and right or equity and good conscience.",
#   'till the time a hindu A30 is dissolved under the act none of the spouses can\ncontract second A30. E20 to islam and A7 would not, by itself, dissolve the\nhindu A30 under the act. the second A30 by a convert would therefore be in violation of\nthe act and as such void in terms of section 494, ipc.',
#   'result of the interpretation, we have given to section 494\nipc, would be that the hindu law on the one hand and the muslim law on the other hand would\noperate within their respective ambits without trespassing on the personal laws of each other. since\nit is not the object of islam nor is the intention of the enlighten muslim community that the hindu\nhusbands should be encouraged to become muslims merely for the purpose of evading their own\npersonal laws by A7 the courts can be persuaded to adopt a construction of the laws\nresulting in denying the hindu husband converted to islam the right to marry again without having\nhis existing A30 dissolved in accordance with law. all the four ingredients of section 494 ipc are satisfied in the case of a hindu husband who marries\nfor the second time after E20 to islam.',
#   'in such cases the court shall act and the judge shall\ndecide according to justice, equity and good conscience. the second A30 of a hindu husband\nafter embracing islam being violative of justice, equity and good conscience would be void on that\nground also and attract the provisions of section 494, ipc. looked from another angle, the second A30 of an apostate-husband would be in violation of\nthe rules of natural justice.',
#   'A30 succession and like matters of a\nsecular character cannot be brought within the guarantee enshrined under articles 25, 26 and 27. the personal law of the hindus, such as relating to A30 succession and the like have all a\nsacramental origin, in the same manner as in the case of the muslims or the christians. the hindus\nalongwith sikhs, buddhists and jains have forsaken their sentiments in the cause of the national\nunity and integration, some other communities would not, though the constitution enjoins the\nestablishment of a "common civil code" for the whole of india.',
#   'mr. peerbhoy has urged that it is rarely possible for two\npersons of different communities to be happily united in wedlock. if E20 of\none of the spouses leads to unhappiness, then the ground for dissolution of A30\nwould not be the E20 but the resultant unhappiness. under muslim law,\nE13 from islam of either party to a A30 operates as a complete and\nimmediate E14'],
#  'marriage': ['the doctrine of indissolubility of A30 under the traditional hindu law, did not\nrecognise that E20 would have the effect of dissolving a hindu A30 E20 to another religion by one or both the hindu spouses did not dissolve the\nA30 it would be useful to have a look at some of the old cases on the subject.',
#   'it may be that a A30 solemnised according to jesish\nrites may be dissolved by the proper authority under jewish law when one of the\nparties renounces the jewish faith. it may be that a A30 solemnised according\nto mahommedan law may be dissolved according to the mahommedan law when\none of the parties ceases to be a mahommedan. but i can find no authority for the\nview that a A30 solemnized according to one personal law can be dissolved\naccording to another personal law simply because one of the two parties has changed\nhis or her religion."',
#   'in december 1991, the petitioner learnt that pradeep kumar\nE6 with one deepa and after E20 to islam A6 her. it is stated that\nthe E20 to islam was only for the purpose of facilitating the second A30 sushmita ghosh is another unfortunate lady who is petitioner in civil writ petition\n509 of 1992.',
#   'there is no general matrimonial law regarding mixed A30s other\nthan the statute law, and there is no suggestion that the statute law is applicable in\nthe present case.. it may be that a A30 solemnised according to jewish rites may\nbe dissolved by the proper authority under jewish law when one of the parties\nrenounces the jewish faith. it may be that a A30 solemnised according to jesish\nrites may be dissolved by the proper authority under jewish law when one of the\nparties renounces the jewish faith.',
#   'it is the foundation of the family and in turn of the society without which\nno civilisation can exist. till the time we achieve the goal - uniform civil code for all the citizens of india -\nthere is an open inducement to a hindu husband, who wants to enter into second\nA30 while the first A30 is subsisting, to become a muslim. since monogamy\nis the law for hindus and the muslim law permits as many as four wives in india,\nerrand hindu husband embraces islam to circumvent the provisions of the hindu\nlaw and to escape from penal consequences.',
#   'a\nsecond A30 by an apostate under the shelter of E20 to islam would nevertheless be a\nA30 in violation of the provisions of the act by which he would be continuing to be governed so\nfar as his first A30 under the act is concerned despite his E20 to islam. the second\nA30 of an apostate would, therefore, be illegal A30 qua his wife who A6 him under\nthe act and continues to be hindu. between the apostate and his hindu wife the second A30 is\nin violation of the provisions of the act and as such would be nonest.',
#   'it may be that a A30 solemnised according to jewish rites may\nbe dissolved by the proper authority under jewish law when one of the parties\nrenounces the jewish faith. it may be that a A30 solemnised according to jesish\nrites may be dissolved by the proper authority under jewish law when one of the\nparties renounces the jewish faith. it may be that a A30 solemnised according\nto mahommedan law may be dissolved according to the mahommedan law when\none of the parties ceases to be a mahommedan.',
# ...
#  'bigamy': ['a christian lady was A6 according to the christian rites. years later she\nembraced islamic faith and got A6 by the registrar of muslim marriages at colombo according\nto the statutory formalities prescribed for a muslim A30 the husband was charged and\nconvicted by the supreme court, ceylon of the offence of E11 under the ceylon penal code.',
#   'in\nan appeal before the privy council, the respondent was absolved from the offence of E11 it was\nheld by privy council as under :-\n"in their lordship\'s view, in such countries there must be an inherent right in the\ninhabitants domiciled there to change their religion and personal law and so to\ncontract a valid polygamous A30 if recognised by the laws of the country\nnotwithstanding an earlier A30. it such inherent right is to be abrogated, it must\nbe done by statute."',
#   'such a person commits E11 if he marries again during the lifetime of his\nspouse, and it matters not what religion he professes at the time of the secondsmt. sarla mudgal, president, kalyani & ... vs union of india & ors on 10 may, 1995\nindian kanoon - http://indiankanoon.org/doc/733037/ 7A30. section 17 provides the only means for the dissolution of a A30 or a\ndeclaration of its nullity.',
#   'we might also point out that the shariat act (act xxvi of 1937) provides that the rule\nof decision in the various cases enumerated in s.2 which includes A30 and\ndissolution of A30 shall be the muslim personal law only where the parties are\nmuslims; it does not provide that the muslim personal law shall apply when only one\nof the parties is a muslim." (the single judge judgment and the division bench\njudgment are reported in T18 bombay law reporter 864) in andal vaidyanathan\nvs. abdul allam vaidya T18 madras, a division bench of the high court dealing\nwith a A30 under the special A30 act T32 held:\n"the special A30 act clearly only contemplates monogamy and a person\nA6 under the act cannot escape from its provisions by merely changing his\nreligion. such a person commits E11 if he marries again during the lifetime of his\nspouse, and it matters not what religion he professes at the time of the secondsmt.',
#   'it would be useful to have a look at some of the old cases on the subject. in\nre ram kumari T13 calcutta 246 where a hindu wife became convert to the muslim\nfaith and then A6 a mohammedan, it was held that her earlier A30 with a\nhindu husband was not dissolved by her E20 she was charged and convicted\nof E11 under section 494 of the ipc.'],
#  'marrying again': ['E20 to islam and A7 would not, by itself, dissolve the\nhindu A30 under the act. the second A30 by a convert would therefore be in violation of\nthe act and as such void in terms of section 494, ipc. any act which is in violation of mandatory\nprovisions of law is per-se void.',
#   'sarla mudgal, president, kalyani & ... vs union of india & ors on 10 may, 1995\nindian kanoon - http://indiankanoon.org/doc/733037/ 9a hindu A30 solemnised under the act can only be dissolved on any of the grounds specified\nunder the act. till the time a hindu A30 is dissolved under the act none of the spouses can\ncontract second A30. E20 to islam and A7 would not, by itself, dissolve the\nhindu A30 under the act.',
#   'result of the interpretation, we have given to section 494\nipc, would be that the hindu law on the one hand and the muslim law on the other hand would\noperate within their respective ambits without trespassing on the personal laws of each other. since\nit is not the object of islam nor is the intention of the enlighten muslim community that the hindu\nhusbands should be encouraged to become muslims merely for the purpose of evading their own\npersonal laws by A7 the courts can be persuaded to adopt a construction of the laws\nresulting in denying the hindu husband converted to islam the right to marry again without having\nhis existing A30 dissolved in accordance with law. all the four ingredients of section 494 ipc are satisfied in the case of a hindu husband who marries\nfor the second time after E20 to islam.',
#   'till the time a hindu A30 is dissolved under the act none of the spouses can\ncontract second A30. E20 to islam and A7 would not, by itself, dissolve the\nhindu A30 under the act. the second A30 by a convert would therefore be in violation of\nthe act and as such void in terms of section 494, ipc.'],
#  'solemnised second marriage': ['three children (two sons and a daughter)\nwere born out of the wed-lock. in early T5 the petitioner was shocked to learn that\nher husband had E1 with one sunita narula @ fathima. the A30 was solemnised after they converted themselves to islam and adopted\nmuslim religion.',
#   'in early T5 the petitioner was shocked to learn that\nher husband had E1 with one sunita narula @ fathima. the A30 was solemnised after they converted themselves to islam and adopted\nmuslim religion. according to the petitioner, E20 of her husband to islam was\nonly for the purpose of marrying sunita and circumventing the provisions of section\n494, ipc.'],
#  '1988, NULL': ['three children (two sons and a daughter)\nwere born out of the wed-lock. in early T5 the petitioner was shocked to learn that\nher husband had E1 with one sunita narula @ fathima. the A30 was solemnised after they converted themselves to islam and adopted\nmuslim religion.',
#   'in early T5 the petitioner was shocked to learn that\nher husband had E1 with one sunita narula @ fathima. the A30 was solemnised after they converted themselves to islam and adopted\nmuslim religion. according to the petitioner, E20 of her husband to islam was\nonly for the purpose of marrying sunita and circumventing the provisions of section\n494, ipc.'],
#  '1891, NULL': ['it would be useful to have a look at some of the old cases on the subject. in\nre ram kumari T13 calcutta 246 where a hindu wife became convert to the muslim\nfaith and then A6 a mohammedan, it was held that her earlier A30 with a\nhindu husband was not dissolved by her E20 she was charged and convicted\nof E11 under section 494 of the ipc.'],
#  '1947, NULL': ['in gul mohammed v. emperor air T15 nagpur 121 a hindu\nwife was fraudulently taken away by the accused a mohammedan who A6 her\naccording to muslim law after converting her to islam. it was held that the\nE20 of the hindu wife to mohammedan faith did not ipso facto dissolve the\nA30 and she could not during the life time of her former husband enter into a\nvalid contract of A30. accordingly the accused was A15 under\nsection 497 of the ipc.'],
#  'convicted for adultery': ['in gul mohammed v. emperor air T15 nagpur 121 a hindu\nwife was fraudulently taken away by the accused a mohammedan who A6 her\naccording to muslim law after converting her to islam. it was held that the\nE20 of the hindu wife to mohammedan faith did not ipso facto dissolve the\nA30 and she could not during the life time of her former husband enter into a\nvalid contract of A30. accordingly the accused was A15 under\nsection 497 of the ipc.'],
#  '1946, NULL': ['it would be tantamount to\npermitting the wife to force a A9 upon her husband although he may not want it\nand although the A30 vows which both of them have taken would not permit it. we might also point out that the shariat act (act xxvi of 1937) provides that the rule\nof decision in the various cases enumerated in s.2 which includes A30 and\ndissolution of A30 shall be the muslim personal law only where the parties are\nmuslims; it does not provide that the muslim personal law shall apply when only one\nof the parties is a muslim." (the single judge judgment and the division bench\njudgment are reported in T18 bombay law reporter 864) in andal vaidyanathan\nvs. abdul allam vaidya T18 madras, a division bench of the high court dealing\nwith a A30 under the special A30 act T32 held:\n"the special A30 act clearly only contemplates monogamy and a person\nA6 under the act cannot escape from its provisions by merely changing his\nreligion.',
#   'it may be that a A30 solemnised according\nto mahommedan law may be dissolved according to the mahommedan law when\none of the parties ceases to be a mahommedan. but i can find no authority for the\nview that a A30 solemnized according to one personal law can be dissolved\naccording to another personal law simply because one of the two parties has changed\nhis or her religion." sayeda khatoon\'s case was followed with approval by blagden, j. of the bombay high\ncourt in robasa khanum vs. khodadad bomanji irani T18 bombay law reporter\n864.',
#   'we might also point out that the shariat act (act xxvi of 1937) provides that the rule\nof decision in the various cases enumerated in s.2 which includes A30 and\ndissolution of A30 shall be the muslim personal law only where the parties are\nmuslims; it does not provide that the muslim personal law shall apply when only one\nof the parties is a muslim." (the single judge judgment and the division bench\njudgment are reported in T18 bombay law reporter 864) in andal vaidyanathan\nvs. abdul allam vaidya T18 madras, a division bench of the high court dealing\nwith a A30 under the special A30 act T32 held:\n"the special A30 act clearly only contemplates monogamy and a person\nA6 under the act cannot escape from its provisions by merely changing his\nreligion. such a person commits E11 if he marries again during the lifetime of his\nspouse, and it matters not what religion he professes at the time of the secondsmt.'],
#  '1872, NULL': ['it would be tantamount to\npermitting the wife to force a A9 upon her husband although he may not want it\nand although the A30 vows which both of them have taken would not permit it. we might also point out that the shariat act (act xxvi of 1937) provides that the rule\nof decision in the various cases enumerated in s.2 which includes A30 and\ndissolution of A30 shall be the muslim personal law only where the parties are\nmuslims; it does not provide that the muslim personal law shall apply when only one\nof the parties is a muslim." (the single judge judgment and the division bench\njudgment are reported in T18 bombay law reporter 864) in andal vaidyanathan\nvs. abdul allam vaidya T18 madras, a division bench of the high court dealing\nwith a A30 under the special A30 act T32 held:\n"the special A30 act clearly only contemplates monogamy and a person\nA6 under the act cannot escape from its provisions by merely changing his\nreligion.',
#   'we might also point out that the shariat act (act xxvi of 1937) provides that the rule\nof decision in the various cases enumerated in s.2 which includes A30 and\ndissolution of A30 shall be the muslim personal law only where the parties are\nmuslims; it does not provide that the muslim personal law shall apply when only one\nof the parties is a muslim." (the single judge judgment and the division bench\njudgment are reported in T18 bombay law reporter 864) in andal vaidyanathan\nvs. abdul allam vaidya T18 madras, a division bench of the high court dealing\nwith a A30 under the special A30 act T32 held:\n"the special A30 act clearly only contemplates monogamy and a person\nA6 under the act cannot escape from its provisions by merely changing his\nreligion. such a person commits E11 if he marries again during the lifetime of his\nspouse, and it matters not what religion he professes at the time of the secondsmt.'],
#  '1955, NULL': ['we, therefore, hold that under the hindu personal law as it existed prior to\nits codification in T22 a hindu A30 continued to subsist even after one of the spouses\nconverted to islam. there was no automatic E14 the position has not changed after coming into force of the hindu A30 act, T22 (the act)\nrather it has become worse for the apostate.',
#   'it is, thus, obvious from the catena of case-low that a A30 celebrated under a particular\npersonal law cannot be dissolved by the application of another personal law to which one of the\nspouses converts and the other refuses to do so. where a A30 takes place under hindu law the\nparties acquire a status and certain rights by the A30 itself under the law governing the hindu\nA30 and if one of the parties is allowed to dissolve the A30 by adopting and enforcing a\nnew personal law, it would tantamount to destroying the existing rights of the other spouse who\ncontinues to be hindu. we, therefore, hold that under the hindu personal law as it existed prior to\nits codification in T22 a hindu A30 continued to subsist even after one of the spouses\nconverted to islam.',
#   'where a A30 takes place under hindu law the\nparties acquire a status and certain rights by the A30 itself under the law governing the hindu\nA30 and if one of the parties is allowed to dissolve the A30 by adopting and enforcing a\nnew personal law, it would tantamount to destroying the existing rights of the other spouse who\ncontinues to be hindu. we, therefore, hold that under the hindu personal law as it existed prior to\nits codification in T22 a hindu A30 continued to subsist even after one of the spouses\nconverted to islam. there was no automatic E14'],
#  '1955-56, NULL': ['one wonders how long will it take for the government of the day to implement the mandate of the\nframers of the constitution under article 44 of the constitution of india. the traditional hindu law -\npersonal law of the hindus - governing inheritance, succession and A30 was given go- bye as\nback as T26 by codifying the same. there is no justification whatsoever in delaying indefinitely\nthe introduction of a uniform personal law in the country.'],
#  '1772, NULL': ['sarla mudgal, president, kalyani & ... vs union of india & ors on 10 may, 1995\nindian kanoon - http://indiankanoon.org/doc/733037/ 12the administration of civil justice for the native population, without discrimination between hindus\nand mahomedans. the T28 regulations followed by the regulations of T29 whereunder it was\nprescribed that either community was to be governed by its "personal" law in matters relating to\ninheritance, A30 religious usage and institutions. so far as the criminal justice was concerned\nthe british gradually superseded the muslim law in T30 and criminal justice was governed by the\nenglish common law.'],
#  '1781, NULL': ['sarla mudgal, president, kalyani & ... vs union of india & ors on 10 may, 1995\nindian kanoon - http://indiankanoon.org/doc/733037/ 12the administration of civil justice for the native population, without discrimination between hindus\nand mahomedans. the T28 regulations followed by the regulations of T29 whereunder it was\nprescribed that either community was to be governed by its "personal" law in matters relating to\ninheritance, A30 religious usage and institutions. so far as the criminal justice was concerned\nthe british gradually superseded the muslim law in T30 and criminal justice was governed by the\nenglish common law.'],
#  '1832, NULL': ['sarla mudgal, president, kalyani & ... vs union of india & ors on 10 may, 1995\nindian kanoon - http://indiankanoon.org/doc/733037/ 12the administration of civil justice for the native population, without discrimination between hindus\nand mahomedans. the T28 regulations followed by the regulations of T29 whereunder it was\nprescribed that either community was to be governed by its "personal" law in matters relating to\ninheritance, A30 religious usage and institutions. so far as the criminal justice was concerned\nthe british gradually superseded the muslim law in T30 and criminal justice was governed by the\nenglish common law.']}

# %%
with open("output.txt", "w") as f:
    f.write(str(sentences_dict))
