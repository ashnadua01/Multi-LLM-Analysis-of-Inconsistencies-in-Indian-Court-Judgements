# %%
import PyPDF2

# %%
def pdf_to_txt(pdf_file_path, txt_file_path):
    with open(pdf_file_path, 'rb') as pdf_file:
        pdf_reader = PyPDF2.PdfReader(pdf_file)
        
        text = ""
        for page_num in range(len(pdf_reader.pages)):
            page = pdf_reader.pages[page_num]
            text += page.extract_text().rstrip()

    with open(txt_file_path, 'w', encoding='utf-8') as txt_file:
        txt_file.write(text)

# %%
pdf_to_txt('/Users/ashnadua/Desktop/ACM CONFERENCE WORK/FINAL_LIST_DOCS/Association_For_Democratics_Reforms_vs_Union_Of_India_on_15_February_2024.PDF', 'democratics.txt')

# %%
import pandas as pd
import nltk
nltk.download('punkt')  # Download the required NLTK data
# Out:
# [nltk_data] Downloading package punkt to /Users/ashnadua/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
def find_related_sentences(sentences, keyword):
    related_sentences = []

    for i, sentence in enumerate(sentences):
        if keyword in sentence:
            prev_sentence = sentences[i - 1].strip() if i > 0 else None
            next_sentence = sentences[i + 1].strip() if i < len(sentences) - 1 else None
            related_sentences.append({
                "Sentence": sentence.strip(),
                "Previous": prev_sentence,
                "Next": next_sentence
            })

    return related_sentences

# %%
with open('/Users/ashnadua/Desktop/ACM CONFERENCE WORK/codes/Democratics Case/democratics.txt', "r") as file:
    text = file.read()

# Tokenize into sentences using nltk.sent_tokenize()
sentences = nltk.sent_tokenize(text)

keyword = "Electoral Bond Scheme"
result = []

related_sentences = find_related_sentences(sentences, keyword)
result.extend(related_sentences)

# Create a DataFrame with columns "Sentence," "Previous," and "Next"
output_df = pd.DataFrame(result, columns=["Sentence", "Previous", "Next"])

# Save results to a new CSV
output_df.to_csv("output_sentences_democratics.csv", index=False)

# %%
encodings_to_try = ['utf-8', 'latin1', 'utf-16', 'ISO-8859-1']

# Try reading the CSV file with different encodings
for encoding in encodings_to_try:
    try:
        output_df = pd.read_csv("output_sentences_democratics.csv", encoding=encoding)
        print("CSV file read successfully with encoding:", encoding)
        break  # Exit loop if successful
    except UnicodeDecodeError:
        print("Failed to read CSV file with encoding:", encoding)
        continue  # Try next encoding
# Out:
# CSV file read successfully with encoding: utf-8

# %%
output_df
# Out:
#                                              Sentence  \
# 0   Objections of RBI and ECI to the Electoral Bon...
# 1   Balancing the right to information and the rig...
# 2   The law relating to financial\n       contribu...
# 3   Objections of RBI and ECI to the Electoral Bon...
# 4   The draft of the Electoral Bond Scheme was cir...
# ..                                                ...
# 56  However, as explained above, the\n    anonymit...
# 57  Thus, the Electoral Bond Scheme 2018 will also...
# 58  The\n    amendment to Section 182(3) of the Co...
# 59  The Electoral Bond Scheme, the proviso to Sect...
# 60  We direct the disclosure of information on con...
#
#                                              Previous  \
# 0   Transparency ....................................
# 1   Privacy vis-à-vis political party ...............
# 2   To understand the context in which the legisla...
# 3                                                 iv.
# 4                                                 20.
# ..                                                ...
# 56  The question is whether\n    this Court should...
# 57  The\n    Electoral Bond is not distinguishable...
# 58  The only purpose of amending Section 182(3) wa...
# 59  In view of the discussion above, the following...
# 60                                               217.
#
#                                                  Next
# 0   Issues ..........................................
# 1   The application of the principle of non-arbitr...
# 2                                                  i.
# 3   On 2 January 2017, the RBI wrote a letter to t...
# 4   The draft conferred notified scheduled commerc...
# ..                                                ...
# 56  The\n    Electoral Bond is not distinguishable...
# 57  c.   Validity of Section 154 of the Finance Ac...
# 58                                               174.
# 59  The deletion of the proviso to Section 182(1) ...
# 60  On 12 April 2019, this Court issued an interim...
#
# [61 rows x 3 columns]

# %%
concatenated_sen = pd.DataFrame(output_df['Previous'].astype(str) + ' ' + output_df['Sentence'].astype(str) + ' ' + output_df['Next'].astype(str), columns=['concat'])

# %%
print(concatenated_sen['concat'].iloc[0])
# Out:
# Transparency ........................................................................................... 11
#      iv. Objections of RBI and ECI to the Electoral Bond Scheme .................. 13
#      v.         Electoral Bond Scheme .......................................................................... 18
# B. Issues ........................................................................................................... 23
# C. Submissions................................................................................................ 24
#      i.         Submissions of petitioners .................................................................... 24
#      ii.

# %%
concatenated_sen.to_csv('sentences_final_concatenated_democratics.csv', index=False)

# %%
import csv

# %%
def create_person_id_map(file_path):
    person_id_map = {}

    with open(file_path, 'r') as csvfile:
        reader = csv.reader(csvfile)
        header = next(reader)
        
        for row in reader:
            person_id_list = row[0]
            person = person_id_list.strip()
            person_id = row[1].strip()
            person_id_map[person] = person_id

    return person_id_map

def create_location_id_map(file_path):
    location_id_map = {}

    with open(file_path, 'r') as csvfile:
        reader = csv.reader(csvfile)
        header = next(reader)
        
        for row in reader:
            location_id_list = row[0]
            location = location_id_list.strip()
            location_id = row[1].strip()
            location_id_map[location] = location_id

    return location_id_map

def create_time_id_map(file_path):
    time_id_map = {}

    with open(file_path, 'r') as csvfile:
        reader = csv.reader(csvfile)
        header = next(reader)
        
        for row in reader:
            time_id_list = row[0].split(',')
            time = time_id_list.strip()
            time_id = row[1].strip()
            time_id_map[time] = time_id

    return time_id_map

def create_event_id_map(file_path):
    event_id_map = {}

    with open(file_path, 'r') as csvfile:
        reader = csv.reader(csvfile)
        header = next(reader)
        
        for row in reader:
            event_id_list = row[0].split(',')
            event = event_id_list.strip()
            event_id = row[1].strip()
            event_id_map[event] = event_id

    return event_id_map

def create_other_id_map(file_path):
    other_id_map = {}

    with open(file_path, 'r') as csvfile:
        reader = csv.reader(csvfile)
        header = next(reader)
        
        for row in reader:
            other_id_list = row[0].split(',')
            other = other_id_list.strip()
            other_id = row[1].strip()
            other_id_map[other] = other_id

    return other_id_map

# %%
file_path_person = '/Users/ashnadua/Desktop/ACM CONFERENCE WORK/Entities/Democratics Case/person.csv'
file_path_location = '/Users/ashnadua/Desktop/ACM CONFERENCE WORK/Entities/Democratics Case/location.csv'
file_path_time = '/Users/ashnadua/Desktop/ACM CONFERENCE WORK/Entities/Democratics Case/time.csv'
file_path_event = '/Users/ashnadua/Desktop/ACM CONFERENCE WORK/Entities/Democratics Case/event.csv'
file_path_other = '/Users/ashnadua/Desktop/ACM CONFERENCE WORK/Entities/Democratics Case/activity.csv'
person_id_map = create_person_id_map(file_path_person)
location_id_map = create_location_id_map(file_path_location)
time_id_map = create_location_id_map(file_path_time)
event_id_map = create_location_id_map(file_path_event)
other_id_map = create_location_id_map(file_path_other)

# %%
def generate_ngrams(text, n=6):
    words = text.split()
    ngrams = []
    for j in range(n, 0, -1):
        for i in range(len(words)):
            if i + j <= len(words):
                ngrams.append(' '.join(words[i:i+j]))
    return ngrams

# %%
def preprocess_text(text):
    text = text.replace("'s", "")
    text = text.replace(".", "")
    text = text.replace(";", "")
#     text = text.replace("-", "")
    text = text.replace("!", "")
    text = text.replace("?", "")
#     text = text.replace("/", "")
    text = text.replace("@", "")
    text = text.replace("#", "")
    text = text.replace(",", "")
    return text

# %%
def replace_entities(text):
    text = text.lower()
    ngrams = generate_ngrams(text)
    replaced_text = text

    for ngram in ngrams:
        original = ngram.lower()
        
        if original in person_id_map:
            entity_id = person_id_map[original]
            replaced_text = replaced_text.replace(ngram, entity_id)
        else:
            preprocessed_ngram = preprocess_text(ngram.lower())
            if preprocessed_ngram in person_id_map:
                entity_id = person_id_map[preprocessed_ngram]
                replaced_text = replaced_text.replace(ngram, entity_id)
            else:
                if original in location_id_map:
                    entity_id = location_id_map[original]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif preprocessed_ngram in location_id_map:
                    entity_id = location_id_map[preprocessed_ngram]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif original in time_id_map:
                    entity_id = time_id_map[original]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif preprocessed_ngram in time_id_map:
                    entity_id = time_id_map[preprocessed_ngram]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif original in event_id_map:
                    entity_id = event_id_map[original]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif preprocessed_ngram in event_id_map:
                    entity_id = event_id_map[preprocessed_ngram]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif original in other_id_map:
                    entity_id = other_id_map[original]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif preprocessed_ngram in other_id_map:
                    entity_id = other_id_map[preprocessed_ngram]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                    
    return replaced_text

# %%
with open('sentences_final_concatenated_democratics.csv', 'r', encoding='latin-1') as csvfile:
     reader = csv.reader(csvfile)
     next(reader)
     ref_sen = []
     for row in reader:
         sentence = row[0]
         ref_sen.append(sentence)

# %%
final_sentences = []

for sen in ref_sen:
     s = replace_entities(sen)
     final_sentences.append(s)

# %%
with open('cleaned_sentences_democratics.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Sentences'])
#      for sen in final_sentences:
    for sen in final_sentences:
        writer.writerow([sen])

# %% [markdown]
# ## Matrix Creation

# %%
# with the sentences
import pandas as pd
import csv
import re

# Load the CSV files
time_df = pd.read_csv(file_path_time)
location_df = pd.read_csv(file_path_location)
event_df = pd.read_csv(file_path_event)
person_df = pd.read_csv(file_path_person)
activity_df = pd.read_csv(file_path_other)

location_ID = location_df['Id'].tolist()
location_df = location_df['Location'].tolist()

time_ID = time_df['Id'].tolist()
time_df = time_df['Time'].tolist()

# event_ID = event_df['ID'].tolist()
# event_df = event_df['Event'].tolist()

# person_ID = person_df['ID'].tolist()
# person_df = person_df['Person'].tolist()

# activity_ID = activity_df['ID'].tolist()
# activity_df = activity_df['Others'].tolist()

event_ID_map = dict(zip(event_df['Id'], event_df['Event']))
person_ID_map = dict(zip(person_df['Id'], person_df['Person']))
activity_ID_map = dict(zip(activity_df['Id'], activity_df['Activity']))

matrix = {}

# %%
sentences = []
with open('cleaned_sentences_democratics.csv', 'r', encoding='latin-1') as csvfile:
    reader = csv.reader(csvfile)
    next(reader)
    for row in reader:
        sentence = row[0]
        sentences.append(sentence)

# %%
for s in sentences:
    pattern = r'([PTLEA]\d+)'
    matches = re.findall(pattern, s)

    persons = []
    time = []
    location = []
    event = []
    activity = []

    for match in matches:
        if match[0] == 'P':
            persons.append(person_ID_map.get(match, 'Unknown Person'))
        elif match[0] == 'L':
             location.append(location_ID.index(match))
        elif match[0] == 'E':
            event.append(event_ID_map.get(match, 'Unknown Event'))
        elif match[0] == 'A':
            activity.append(activity_ID_map.get(match, 'Unknown Activity'))
        elif match[0] == 'T':
            time.append(time_ID.index(match))

    if location and time:
        for loc_index in location:
            loc_key = location_df[loc_index]
            for time_index in time:
                time_key = time_df[time_index]
                if time_key not in matrix:
                    matrix[time_key] = {}
                if loc_key not in matrix[time_key]:
                    matrix[time_key][loc_key] = []
                matrix[time_key][loc_key].extend([(entity, s) for entity in (persons + event + activity)])
    elif location:
        for loc_index in location:
            loc_key = location_df[loc_index]
            if loc_key not in matrix:
                matrix[loc_key] = {}
            if 'NULL' not in matrix:
                matrix['NULL'] = {}
            if loc_key not in matrix["NULL"]:
                matrix["NULL"][loc_key] = []
            matrix["NULL"][loc_key].extend([(entity, s) for entity in (persons + event + activity)])
    elif time:
        for time_index in time:
            time_key = time_df[time_index]
            if time_key not in matrix:
                matrix[time_key] = {}
            if 'NULL' not in matrix[time_key]:
                matrix[time_key]['NULL'] = []
            matrix[time_key]["NULL"].extend([(entity, s) for entity in (persons + event + activity)])
    else:
        if 'NULL' not in matrix:
            matrix['NULL'] = {}
        if 'NULL' not in matrix['NULL']:
            matrix['NULL']['NULL'] = []
        matrix["NULL"]["NULL"].extend([(entity, s) for entity in (persons + event + activity)])

matrix_df = pd.DataFrame.from_dict(matrix, orient='index')

# %%
matrix_df.to_csv('matrix_with_sen_democratics.csv')

# %%
import networkx as nx

# %%
df = pd.read_csv('matrix_with_sen_democratics.csv')

# %%
df.rename(columns={'Unnamed: 0': 'Time'}, inplace=True)

# %%
G = nx.Graph()

for index, row in df.iterrows():
    time = row['Time']
    for location in df.columns:
        if location == 'Time':
            continue
        # Convert the tuple to a string and add it as a node
        G.add_node(f"{time}, {location}")

# %%
import ast

# %%
final = set()

# Update the final set with only the entities
for value in pd.unique(df.drop(columns='Time').values.ravel()):
    if pd.notnull(value):
        value_list = ast.literal_eval(value)
        entity_list = [entity for entity, sentence in value_list]
        final.update(entity_list)

# %%
G.add_nodes_from(final)

# %%
for index, row in df.iterrows():
    time = row['Time']
    for location in df.columns:
        if location == 'Time':
            continue
        if pd.notnull(row[location]):
            value_list = ast.literal_eval(row[location])
            entity_list = [entity for entity, sentence in value_list]
            for entity in entity_list:
                if entity in final:
                    # Convert the tuples to strings and add them as an edge
                    G.add_edge(f"{time}, {location}", entity)

# %%
for node in list(G.nodes):
    if not list(G.neighbors(node)):
        G.remove_node(node)

# %%
for node1 in G.nodes:
    # Check if node1 can be split into a pair
    if ', ' in node1:
        parts1 = node1.split(", ")
        if len(parts1) == 2:  # Ensure it splits into exactly two parts
            time1, location1 = parts1
            for node2 in G.nodes:
                # Check if node2 can be split into a pair
                if ', ' in node2:
                    parts2 = node2.split(", ")
                    if len(parts2) == 2:  # Ensure it splits into exactly two parts
                        time2, location2 = parts2
                        # Add edge if the time or location matches
                        if time1 == time2 or location1 == location2:
                            G.add_edge(node1, node2)

# %%
degree_dict = dict(G.degree(G.nodes()))
nx.set_node_attributes(G, degree_dict, 'degree')

# %%
# Create a dictionary to store the sentences for each node
sentences_dict = {}

# Create a dictionary to store the sentences for each edge i.e. between two nodes
edge_sentences_dict = {}

# Update the sentences_dict and edge_sentences_dict
for index, row in df.iterrows():
    time = row['Time']
    for location in df.columns:
        if location == 'Time':
            continue
        if pd.notnull(row[location]):
            value_list = ast.literal_eval(row[location])
            for entity, sentence in value_list:
                if entity in final:
                    # Add the sentence to the sentences_dict for the entity
                    if entity not in sentences_dict:
                        sentences_dict[entity] = set()
                    sentences_dict[entity].add(sentence)

                    # Add the sentence to the sentences_dict for the (time, location) node
                    time_location_node = f"{time}, {location}"
                    if time_location_node not in sentences_dict:
                        sentences_dict[time_location_node] = set()
                    sentences_dict[time_location_node].add(sentence)

                    # Add the sentence to the edge_sentences_dict for the edge
                    edge = (time_location_node, entity)
                    if edge not in edge_sentences_dict:
                        edge_sentences_dict[edge] = set()
                    edge_sentences_dict[edge].add(sentence)

# Convert the sets back to lists if needed
for node, sentences in sentences_dict.items():
    sentences_dict[node] = list(sentences)

for edge, sentences in edge_sentences_dict.items():
    edge_sentences_dict[edge] = list(sentences)

# %%
pip install node2vec
# Out:
# Requirement already satisfied: node2vec in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (0.5.0)
# Requirement already satisfied: gensim<5.0.0,>=4.3.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from node2vec) (4.4.0)
# Requirement already satisfied: joblib<2.0.0,>=1.4.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from node2vec) (1.4.2)
# Requirement already satisfied: networkx<4.0.0,>=3.1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from node2vec) (3.4.2)
# Requirement already satisfied: numpy<2.0.0,>=1.24.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from node2vec) (1.26.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from node2vec) (4.67.1)
# Requirement already satisfied: scipy>=1.7.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from gensim<5.0.0,>=4.3.0->node2vec) (1.15.1)
# Requirement already satisfied: smart_open>=1.8.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from gensim<5.0.0,>=4.3.0->node2vec) (7.5.0)
# Requirement already satisfied: wrapt in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from smart_open>=1.8.1->gensim<5.0.0,>=4.3.0->node2vec) (2.0.1)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from node2vec import Node2Vec

# Create a Node2Vec instance
node2vec = Node2Vec(G, dimensions=64, walk_length=30, num_walks=200, workers=4)

# Generate embeddings
model = node2vec.fit(window=10, min_count=1, batch_words=4)
# Out:
# Computing transition probabilities:   0%|          | 0/8 [00:00<?, ?it/s]
# Generating walks (CPU: 2): 100%|██████████| 50/50 [00:00<00:00, 1127.33it/s]
# Generating walks (CPU: 1): 100%|██████████| 50/50 [00:00<00:00, 1106.50it/s]
# Generating walks (CPU: 3): 100%|██████████| 50/50 [00:00<00:00, 1101.32it/s]
# Generating walks (CPU: 4): 100%|██████████| 50/50 [00:00<00:00, 1199.08it/s]

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Get the node embeddings
node_embeddings = {node: model.wv[node] for node in G.nodes}

# Compute cosine similarity matrix
similarity_matrix = cosine_similarity(list(node_embeddings.values()))

# %%
from sklearn.cluster import DBSCAN

# Initialize DBSCAN
dbscan = DBSCAN(eps=0.5, min_samples=3)  # Adjust parameters as needed

# Fit and predict clusters
labels = dbscan.fit_predict(similarity_matrix)

# %%
cluster_colors = [
    'rgb(31, 119, 180)',  # Blue
    'rgb(255, 127, 14)',  # Orange
    'rgb(44, 160, 44)',   # Green
    'rgb(214, 39, 40)',   # Red
    'rgb(148, 103, 189)', # Purple
    'rgb(140, 86, 75)',   # Brown
    'rgb(227, 119, 194)', # Pink
    'rgb(127, 127, 127)', # Gray
    'rgb(188, 189, 34)',  # Olive
    'rgb(23, 190, 207)',  # Teal
    'rgb(255, 187, 120)', # Peach
    'rgb(214, 39, 40)',   # Maroon
    'rgb(77, 175, 74)',   # Light Green
    'rgb(152, 78, 163)',  # Plum
    'rgb(255, 152, 150)'  # Salmon
]

# %%
import networkx as nx
import plotly.graph_objs as go

# Assuming 'G' is your graph and 'labels' is the list of labels
# Renumber clusters from 1 to 7 if needed, otherwise ensure you have clusters numbered 1 to 7
unique_labels = list(set(labels))
label_mapping = {label: idx+1 for idx, label in enumerate(unique_labels)}

def draw_subgraph_plotly(subgraph, cluster_id, cluster_color):
    pos = nx.spring_layout(subgraph, seed=42)  # Fixed seed for reproducibility
    
    # Extract the node positions
    x_nodes = [pos[node][0] for node in subgraph.nodes()]
    y_nodes = [pos[node][1] for node in subgraph.nodes()]

    # Extract the edges
    edge_x = []
    edge_y = []
    for edge in subgraph.edges():
        x0, y0 = pos[edge[0]]
        x1, y1 = pos[edge[1]]
        edge_x.extend([x0, x1, None])
        edge_y.extend([y0, y1, None])

    # Edge trace
    edge_trace = go.Scatter(
        x=edge_x, y=edge_y,
        line=dict(width=1, color='gray'),
        hoverinfo='none',
        mode='lines')

    # Node trace
    node_trace = go.Scatter(
        x=x_nodes, y=y_nodes,
        mode='markers+text',
        text=[f'{node}' for node in subgraph.nodes()],
        textposition="top center",
        marker=dict(
            showscale=False,
            color=cluster_color,  # Assign the cluster color
            size=20,
            line=dict(width=2, color='black')
        ),
        hoverinfo='text'
    )

    # Create figure
    fig = go.Figure(data=[edge_trace, node_trace],
                    layout=go.Layout(
                        title=f'Cluster {cluster_id}',
                        showlegend=False,
                        hovermode='closest',
                        margin=dict(b=20, l=5, r=5, t=40),
                        xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                        yaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                        height=600,
                        width=600,
                        paper_bgcolor='white',
                        plot_bgcolor='white'
                    ))

    fig.show()

# Iterate over each cluster and draw the subgraph
for original_cluster_id in set(labels):
    cluster_id = label_mapping[original_cluster_id]
    cluster_color = cluster_colors[cluster_id - 1]  # Assign a unique color to each cluster
    cluster_nodes = [node for node, label in zip(G.nodes, labels) if label == original_cluster_id]
    subgraph = G.subgraph(cluster_nodes)
    draw_subgraph_plotly(subgraph, cluster_id, cluster_color)

# %%
# # Initialize lists for nodes and links
# nodes = []
# links = []

# # Add nodes to the list
# for node, sentences in sentences_dict.items():
#     nodes.append({
#         "id": node,
#         "group": 1,  # Update this as needed
#         "size": len(sentences)  # The size could be based on the number of sentences
#     })

# # Add links to the list
# for edge, sentences in edge_sentences_dict.items():
#     source, target = edge
#     links.append({
#         "source": source,
#         "target": target,
#         "value": len(sentences)  # The value could be based on the number of sentences
#     })

# # Combine nodes and links into a single dictionary
# graph_data = {
#     "nodes": nodes,
#     "links": links
# }

# %%
# import os

# os.environ['METIS_DLL'] = '/Users/ashnadua/.local/lib/libmetis.dylib'

# %%
# import metis

# %%
# edgecuts, parts = metis.part_graph(G)

# %%
import json

# Create a mapping from nodes to integers
node_to_int = {node: i for i, node in enumerate(G.nodes)}

# %%
degree_dict = dict(G.degree(G.nodes()))
nx.set_node_attributes(G, degree_dict, 'degree')

data = nx.node_link_data(G)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/networkx/readwrite/json_graph/node_link.py:142: FutureWarning:
#
#
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.

# %%
import numpy as np

# %%
labels = labels.astype(np.int32)

# %%
graph_data = {
    "nodes": [{"name": str(node), "n": degree_dict[node], "grp": int(labels[i]), "id": str(node)} for i, node in enumerate(G.nodes())],
    "links": [{"source": str(link_data['source']), "target": str(link_data['target']), "value": 1} for link_data in data['links']]
}

# %%
json_data = json.dumps(graph_data)
with open('data_democratics.json', 'w') as f:
    f.write(json_data)

# %%
# from collections import defaultdict

# # Create a dictionary where keys are part numbers and values are lists of nodes
# part_dict = defaultdict(list)
# for node, part in enumerate(parts):
#     part_dict[part].append(node)

# # Print the number of parts
# print("Number of parts:", len(part_dict))

# # Print the nodes in each part
# for part, nodes in part_dict.items():
#     print("Part", part, ":", nodes)

# %%
# Assuming you have already created clusters using DBSCAN and have 'labels' and 'G' available

# Initialize an empty dictionary to store sentences for each cluster
cluster_sentences_dict = {}

# Iterate over each cluster
for original_cluster_id in set(labels):
    cluster_id = label_mapping[original_cluster_id]
    cluster_nodes = [node for node, label in zip(G.nodes, labels) if label == original_cluster_id]
    
    # Initialize a set to store sentences for this cluster
    cluster_sentences = set()
    
    # Iterate over nodes in the cluster
    for node in cluster_nodes:
        # Assuming 'node' contains the relevant information (e.g., entity, time, location)
        # Extract sentences associated with this node and add them to the cluster_sentences set
        if node in sentences_dict:
            cluster_sentences.update(sentences_dict[node])
    
    # Store the cluster_sentences set in the cluster_sentences_dict
    cluster_sentences_dict[cluster_id] = cluster_sentences

# %%
sentences_dict
# Out:
# {'credit received against each bond': ['in its order dated 13 april 2019, this court observed that the amendments\n      which have been challenged give rise to weighty issues which have a bearing\n      on the sanctity of the electoral process. this court directed all political parties,\n      in the interim to submit details of contributions received through electoral\n      bonds (with particulars of the A54 date of credit,\n      and particulars of the bank account to which the amount has been credited)\n45 electoral bond scheme, clause 13\n46 electoral bond scheme, clause 14\n                                             21\n\x0c                                                                                            part a\n      to the eci in a sealed cover. the prayer for interim relief was rejected by\n      observing that the operations under the scheme are not placed behind Ã¢Â\x80Â\x9ciron\n      curtains incapable of being piercedÃ¢Â\x80Â\x9d:\n                   "25.'],
#  'nan, NULL': ['according to the data, the political\n             party at the center has received fifty seven percent of the total\n             contributions made through electoral bonds;\n50 relied on subash chandra v. delhi subordinate services selection board, (2009) 15 scc 458\n                                                    27\n\x0c                                                                         part c\ni. the electoral bond scheme skews the principle of one person, one vote\n     because it gives the corporates a greater opportunity to influence\n     political parties and electoral outcomes;\nj. the amendment to section 182(3) permits: (i) loss making companies to\n     A10 (ii) unlimited contributions to political\n     parties enabling significant policy influence; and (iii) non-disclosure of\n     information on political funding to shareholders;\nk.   the amendments permitting non-disclosure of information on political\n     funding are violative of the right to information under article 19(1)(a).',
#   'the principle underlying\n         the presumption of constitutionality is that the legislature represents the\n         will of the people and that it is validly constituted through free and fair\n         E8 it would be paradoxical to accord a presumption of\n                                         26\n\x0c                                                                                               part c\n             constitutionality to the very laws or rules that set the conditions under\n             which the legislature comes into being50;\n      e.     corporate funding per se is violative of the constitution because\n             corporate entities are not citizens and thus, are not entitled to rights\n             under article 19(1)(a);\n      f.     the funds contributed to the electoral bond scheme can be used in any\n             manner and their use is not restricted to electoral campaigns;\n      g.     the electoral bond scheme severs the link between E8 and\n             representative democracy because those elected are inclined to fulfill\n             the wishes of the contributors and not the voters. this could be through\n             direct quid pro quo where an express promise is made to enact a policy\n             in favour of the donor and indirect quid pro quo where there is an\n             influence through access to policy makers;association for democratics reforms vs union of india on 15 february, 2024\nindian kanoon - http://indiankanoon.org/doc/121499464/ 27      h.     the scheme promotes information asymmetry where the information\n             about political donations is not disclosed to voters but the central\n             government is privy to such information through the state bank of india\n             which is the authorized bank under the scheme.',
#   'having concluded that the constitution guarantees a right to informational\n     privacy of political affiliation, it needs to be decided if the right can be extended\n     to the contributions to political parties. the electoral bond scheme has two\n     manifestations of privacy: first, informational privacy by prescribing\n     confidentiality vis-Ã£Â\xa0-vis the political party; and second, informational privacy\n     by prescribing non-disclosure of the information of political contributions to\n     the public. the union of india submitted that contributions made to political\n     parties must be protected both from the political party itself and the public\n     because donor privacy is an extension of the principle of secret ballot and is\n     a facet of free and fair E8',
#   'mr kapil sibal, learned senior counsel made the following submissions:\n    a. the amendments and the electoral bond scheme skew free and fair\n         E8 by permitting unlimited contributions to political parties by\n         corporate entities and removing the requirement of disclosure of\n         information about political funding;\n    b. freedom of a voter in the negative connotation refers to the freedom to\n         A36 without interference and intimidation.',
#   'this indicates that bonds are\n                       purchased by corporates and not individuals. the limited disclosure\n                       clause in the electoral bond scheme prevents investigating\n                       agencies such as the central bureau of investigation and\n                       enforcement directorate from identifying corruption; andassociation for democratics reforms vs union of india on 15 february, 2024\nindian kanoon - http://indiankanoon.org/doc/121499464/ 25      d.          they violate the rights of shareholders of companies who are donating\n                  money to political parties by preventing disclosure of information to\n                  them; and\n      e.          the statutory amendments and the electoral bond scheme subvert\n                  democracy and interfere with free and fair E8 because the huge\n                  difference in the funds received by ruling parties in the states and centre\n48 relied on pucl v. union of india, (2003) 4 scc 399; adr v. union of india, (2002) 5 scc 294; anjali bhardwaj\nv. union of india, (2019) 18 scc 246\n49 relied on kanwar lal gupta v. amar nath chawla, 1975 scc (3) 646\n                                                      25\n\x0c                                                                           part c\n         vitiates a level playing field between different parties and between\n         parties and independent candidates. 31.',
#   'in its order dated 13 april 2019, this court observed that the amendments\n      which have been challenged give rise to weighty issues which have a bearing\n      on the sanctity of the electoral process. this court directed all political parties,\n      in the interim to submit details of contributions received through electoral\n      bonds (with particulars of the A54 date of credit,\n      and particulars of the bank account to which the amount has been credited)\n45 electoral bond scheme, clause 13\n46 electoral bond scheme, clause 14\n                                             21\n\x0c                                                                                            part a\n      to the eci in a sealed cover. the prayer for interim relief was rejected by\n      observing that the operations under the scheme are not placed behind Ã¢Â\x80Â\x9ciron\n      curtains incapable of being piercedÃ¢Â\x80Â\x9d:\n                   "25.',
#   'whether unlimited corporate funding to political parties, as envisaged by theassociation for democratics reforms vs union of india on 15 february, 2024\nindian kanoon - http://indiankanoon.org/doc/121499464/ 23     amendment to section 182(1) of the companies act infringes the principle of\n     free and fair E8 and violates article 14 of the constitution; and\nb. whether the non-disclosure of information on voluntary contributions to\n     political parties under the electoral bond scheme and the amendments to\n     section 29c of the rpa, section 182(3) of the companies act and section\n     13a(b) of the it act are violative of the right to information of citizens under\narticle 19(1)(a) of the constitution. 23\n\x0c                                                                                       part c\n     c.   submissions\ni.        submissions of petitioners\n     30.'],
#  'elections': ['the bond shall be available for purchase for a period of T17 on a\n             quarterly basis, in the months of january, april, july, and october asassociation for democratics reforms vs union of india on 15 february, 2024\nindian kanoon - http://indiankanoon.org/doc/121499464/ 20             specified by the central government.41 bonds will be available for an\n             additional period of T5 as specified by the central government\n             in a year when general E8 to the house of people are to be held;42\n      k.     no interest is payable on the bond.43 no commission, brokerage, or any\n             other charges for issue of a bond shall be payable by the buyer against\n             purchase of the bond;44\n      l.     the value of the bonds shall be considered as income by way of\n             voluntary contributions received by an eligible political party for the\n37 electoral bond scheme, clause 7(3)\n38 electoral bond scheme, clause 7(4)\n39 electoral bond scheme, clause 7(6)\n40 electoral bond scheme, clause 7(4)\n41 electoral bond scheme, clause 8(1)\n42 electoral bond scheme, clause 8(2)\n43 electoral bond scheme, clause 9\n44 electoral bond scheme,   clause 10\n                                            20\n\x0c                                                                                 part a\n             purpose of exemption from income tax under section 13a of the it act;45\n             and\n      m.     the bonds are not eligible for trading.46\n25. the petitioners instituted proceedings under article 32 seeking a declaration\n      that electoral bond scheme and the following provisions be declared\n      unconstitutional:\n      a. section 135 of the finance act T36 and the corresponding amendment\n             in section 31 of the rbi act;association for democratics reforms vs union of india on 15 february, 2024\nindian kanoon - http://indiankanoon.org/doc/121499464/ 21      b.',
#   'the principle underlying\n         the presumption of constitutionality is that the legislature represents the\n         will of the people and that it is validly constituted through free and fair\n         E8 it would be paradoxical to accord a presumption of\n                                         26\n\x0c                                                                                               part c\n             constitutionality to the very laws or rules that set the conditions under\n             which the legislature comes into being50;\n      e.     corporate funding per se is violative of the constitution because\n             corporate entities are not citizens and thus, are not entitled to rights\n             under article 19(1)(a);\n      f.     the funds contributed to the electoral bond scheme can be used in any\n             manner and their use is not restricted to electoral campaigns;\n      g.     the electoral bond scheme severs the link between E8 and\n             representative democracy because those elected are inclined to fulfill\n             the wishes of the contributors and not the voters. this could be through\n             direct quid pro quo where an express promise is made to enact a policy\n             in favour of the donor and indirect quid pro quo where there is an\n             influence through access to policy makers;association for democratics reforms vs union of india on 15 february, 2024\nindian kanoon - http://indiankanoon.org/doc/121499464/ 27      h.     the scheme promotes information asymmetry where the information\n             about political donations is not disclosed to voters but the central\n             government is privy to such information through the state bank of india\n             which is the authorized bank under the scheme.',
#   'having concluded that the constitution guarantees a right to informational\n     privacy of political affiliation, it needs to be decided if the right can be extended\n     to the contributions to political parties. the electoral bond scheme has two\n     manifestations of privacy: first, informational privacy by prescribing\n     confidentiality vis-Ã£Â\xa0-vis the political party; and second, informational privacy\n     by prescribing non-disclosure of the information of political contributions to\n     the public. the union of india submitted that contributions made to political\n     parties must be protected both from the political party itself and the public\n     because donor privacy is an extension of the principle of secret ballot and is\n     a facet of free and fair E8',
#   'mr kapil sibal, learned senior counsel made the following submissions:\n    a. the amendments and the electoral bond scheme skew free and fair\n         E8 by permitting unlimited contributions to political parties by\n         corporate entities and removing the requirement of disclosure of\n         information about political funding;\n    b. freedom of a voter in the negative connotation refers to the freedom to\n         A36 without interference and intimidation.',
#   'this indicates that bonds are\n                       purchased by corporates and not individuals. the limited disclosure\n                       clause in the electoral bond scheme prevents investigating\n                       agencies such as the central bureau of investigation and\n                       enforcement directorate from identifying corruption; andassociation for democratics reforms vs union of india on 15 february, 2024\nindian kanoon - http://indiankanoon.org/doc/121499464/ 25      d.          they violate the rights of shareholders of companies who are donating\n                  money to political parties by preventing disclosure of information to\n                  them; and\n      e.          the statutory amendments and the electoral bond scheme subvert\n                  democracy and interfere with free and fair E8 because the huge\n                  difference in the funds received by ruling parties in the states and centre\n48 relied on pucl v. union of india, (2003) 4 scc 399; adr v. union of india, (2002) 5 scc 294; anjali bhardwaj\nv. union of india, (2019) 18 scc 246\n49 relied on kanwar lal gupta v. amar nath chawla, 1975 scc (3) 646\n                                                      25\n\x0c                                                                           part c\n         vitiates a level playing field between different parties and between\n         parties and independent candidates. 31.',
#   'it shall be disclosed only when demanded by a\n             competent court or upon the registration of criminal case by any law\n             enforcement agency;40\n      j. the bond shall be available for purchase for a period of T17 on a\n             quarterly basis, in the months of january, april, july, and october asassociation for democratics reforms vs union of india on 15 february, 2024\nindian kanoon - http://indiankanoon.org/doc/121499464/ 20             specified by the central government.41 bonds will be available for an\n             additional period of T5 as specified by the central government\n             in a year when general E8 to the house of people are to be held;42\n      k.     no interest is payable on the bond.43 no commission, brokerage, or any\n             other charges for issue of a bond shall be payable by the buyer against\n             purchase of the bond;44\n      l.     the value of the bonds shall be considered as income by way of\n             voluntary contributions received by an eligible political party for the\n37 electoral bond scheme, clause 7(3)\n38 electoral bond scheme, clause 7(4)\n39 electoral bond scheme, clause 7(6)\n40 electoral bond scheme, clause 7(4)\n41 electoral bond scheme, clause 8(1)\n42 electoral bond scheme, clause 8(2)\n43 electoral bond scheme, clause 9\n44 electoral bond scheme,   clause 10\n                                            20\n\x0c                                                                                 part a\n             purpose of exemption from income tax under section 13a of the it act;45\n             and\n      m.     the bonds are not eligible for trading.46\n25. the petitioners instituted proceedings under article 32 seeking a declaration\n      that electoral bond scheme and the following provisions be declared\n      unconstitutional:\n      a.',
#   'whether unlimited corporate funding to political parties, as envisaged by theassociation for democratics reforms vs union of india on 15 february, 2024\nindian kanoon - http://indiankanoon.org/doc/121499464/ 23     amendment to section 182(1) of the companies act infringes the principle of\n     free and fair E8 and violates article 14 of the constitution; and\nb. whether the non-disclosure of information on voluntary contributions to\n     political parties under the electoral bond scheme and the amendments to\n     section 29c of the rpa, section 182(3) of the companies act and section\n     13a(b) of the it act are violative of the right to information of citizens under\narticle 19(1)(a) of the constitution. 23\n\x0c                                                                                       part c\n     c.   submissions\ni.        submissions of petitioners\n     30.'],
#  'cast their vote': ['mr kapil sibal, learned senior counsel made the following submissions:\n    a. the amendments and the electoral bond scheme skew free and fair\n         E8 by permitting unlimited contributions to political parties by\n         corporate entities and removing the requirement of disclosure of\n         information about political funding;\n    b. freedom of a voter in the negative connotation refers to the freedom to\n         A36 without interference and intimidation.'],
#  'contribute to political parties': ['according to the data, the political\n             party at the center has received fifty seven percent of the total\n             contributions made through electoral bonds;\n50 relied on subash chandra v. delhi subordinate services selection board, (2009) 15 scc 458\n                                                    27\n\x0c                                                                         part c\ni. the electoral bond scheme skews the principle of one person, one vote\n     because it gives the corporates a greater opportunity to influence\n     political parties and electoral outcomes;\nj. the amendment to section 182(3) permits: (i) loss making companies to\n     A10 (ii) unlimited contributions to political\n     parties enabling significant policy influence; and (iii) non-disclosure of\n     information on political funding to shareholders;\nk.   the amendments permitting non-disclosure of information on political\n     funding are violative of the right to information under article 19(1)(a).'],
#  '2017, NULL': ['the bond shall be available for purchase for a period of T17 on a\n             quarterly basis, in the months of january, april, july, and october asassociation for democratics reforms vs union of india on 15 february, 2024\nindian kanoon - http://indiankanoon.org/doc/121499464/ 20             specified by the central government.41 bonds will be available for an\n             additional period of T5 as specified by the central government\n             in a year when general E8 to the house of people are to be held;42\n      k.     no interest is payable on the bond.43 no commission, brokerage, or any\n             other charges for issue of a bond shall be payable by the buyer against\n             purchase of the bond;44\n      l.     the value of the bonds shall be considered as income by way of\n             voluntary contributions received by an eligible political party for the\n37 electoral bond scheme, clause 7(3)\n38 electoral bond scheme, clause 7(4)\n39 electoral bond scheme, clause 7(6)\n40 electoral bond scheme, clause 7(4)\n41 electoral bond scheme, clause 8(1)\n42 electoral bond scheme, clause 8(2)\n43 electoral bond scheme, clause 9\n44 electoral bond scheme,   clause 10\n                                            20\n\x0c                                                                                 part a\n             purpose of exemption from income tax under section 13a of the it act;45\n             and\n      m.     the bonds are not eligible for trading.46\n25. the petitioners instituted proceedings under article 32 seeking a declaration\n      that electoral bond scheme and the following provisions be declared\n      unconstitutional:\n      a. section 135 of the finance act T36 and the corresponding amendment\n             in section 31 of the rbi act;association for democratics reforms vs union of india on 15 february, 2024\nindian kanoon - http://indiankanoon.org/doc/121499464/ 21      b.'],
#  'ten days, NULL': ['the bond shall be available for purchase for a period of T17 on a\n             quarterly basis, in the months of january, april, july, and october asassociation for democratics reforms vs union of india on 15 february, 2024\nindian kanoon - http://indiankanoon.org/doc/121499464/ 20             specified by the central government.41 bonds will be available for an\n             additional period of T5 as specified by the central government\n             in a year when general E8 to the house of people are to be held;42\n      k.     no interest is payable on the bond.43 no commission, brokerage, or any\n             other charges for issue of a bond shall be payable by the buyer against\n             purchase of the bond;44\n      l.     the value of the bonds shall be considered as income by way of\n             voluntary contributions received by an eligible political party for the\n37 electoral bond scheme, clause 7(3)\n38 electoral bond scheme, clause 7(4)\n39 electoral bond scheme, clause 7(6)\n40 electoral bond scheme, clause 7(4)\n41 electoral bond scheme, clause 8(1)\n42 electoral bond scheme, clause 8(2)\n43 electoral bond scheme, clause 9\n44 electoral bond scheme,   clause 10\n                                            20\n\x0c                                                                                 part a\n             purpose of exemption from income tax under section 13a of the it act;45\n             and\n      m.     the bonds are not eligible for trading.46\n25. the petitioners instituted proceedings under article 32 seeking a declaration\n      that electoral bond scheme and the following provisions be declared\n      unconstitutional:\n      a. section 135 of the finance act T36 and the corresponding amendment\n             in section 31 of the rbi act;association for democratics reforms vs union of india on 15 february, 2024\nindian kanoon - http://indiankanoon.org/doc/121499464/ 21      b.',
#   'it shall be disclosed only when demanded by a\n             competent court or upon the registration of criminal case by any law\n             enforcement agency;40\n      j. the bond shall be available for purchase for a period of T17 on a\n             quarterly basis, in the months of january, april, july, and october asassociation for democratics reforms vs union of india on 15 february, 2024\nindian kanoon - http://indiankanoon.org/doc/121499464/ 20             specified by the central government.41 bonds will be available for an\n             additional period of T5 as specified by the central government\n             in a year when general E8 to the house of people are to be held;42\n      k.     no interest is payable on the bond.43 no commission, brokerage, or any\n             other charges for issue of a bond shall be payable by the buyer against\n             purchase of the bond;44\n      l.     the value of the bonds shall be considered as income by way of\n             voluntary contributions received by an eligible political party for the\n37 electoral bond scheme, clause 7(3)\n38 electoral bond scheme, clause 7(4)\n39 electoral bond scheme, clause 7(6)\n40 electoral bond scheme, clause 7(4)\n41 electoral bond scheme, clause 8(1)\n42 electoral bond scheme, clause 8(2)\n43 electoral bond scheme, clause 9\n44 electoral bond scheme,   clause 10\n                                            20\n\x0c                                                                                 part a\n             purpose of exemption from income tax under section 13a of the it act;45\n             and\n      m.     the bonds are not eligible for trading.46\n25. the petitioners instituted proceedings under article 32 seeking a declaration\n      that electoral bond scheme and the following provisions be declared\n      unconstitutional:\n      a.'],
#  'thirty days, NULL': ['the bond shall be available for purchase for a period of T17 on a\n             quarterly basis, in the months of january, april, july, and october asassociation for democratics reforms vs union of india on 15 february, 2024\nindian kanoon - http://indiankanoon.org/doc/121499464/ 20             specified by the central government.41 bonds will be available for an\n             additional period of T5 as specified by the central government\n             in a year when general E8 to the house of people are to be held;42\n      k.     no interest is payable on the bond.43 no commission, brokerage, or any\n             other charges for issue of a bond shall be payable by the buyer against\n             purchase of the bond;44\n      l.     the value of the bonds shall be considered as income by way of\n             voluntary contributions received by an eligible political party for the\n37 electoral bond scheme, clause 7(3)\n38 electoral bond scheme, clause 7(4)\n39 electoral bond scheme, clause 7(6)\n40 electoral bond scheme, clause 7(4)\n41 electoral bond scheme, clause 8(1)\n42 electoral bond scheme, clause 8(2)\n43 electoral bond scheme, clause 9\n44 electoral bond scheme,   clause 10\n                                            20\n\x0c                                                                                 part a\n             purpose of exemption from income tax under section 13a of the it act;45\n             and\n      m.     the bonds are not eligible for trading.46\n25. the petitioners instituted proceedings under article 32 seeking a declaration\n      that electoral bond scheme and the following provisions be declared\n      unconstitutional:\n      a. section 135 of the finance act T36 and the corresponding amendment\n             in section 31 of the rbi act;association for democratics reforms vs union of india on 15 february, 2024\nindian kanoon - http://indiankanoon.org/doc/121499464/ 21      b.',
#   'it shall be disclosed only when demanded by a\n             competent court or upon the registration of criminal case by any law\n             enforcement agency;40\n      j. the bond shall be available for purchase for a period of T17 on a\n             quarterly basis, in the months of january, april, july, and october asassociation for democratics reforms vs union of india on 15 february, 2024\nindian kanoon - http://indiankanoon.org/doc/121499464/ 20             specified by the central government.41 bonds will be available for an\n             additional period of T5 as specified by the central government\n             in a year when general E8 to the house of people are to be held;42\n      k.     no interest is payable on the bond.43 no commission, brokerage, or any\n             other charges for issue of a bond shall be payable by the buyer against\n             purchase of the bond;44\n      l.     the value of the bonds shall be considered as income by way of\n             voluntary contributions received by an eligible political party for the\n37 electoral bond scheme, clause 7(3)\n38 electoral bond scheme, clause 7(4)\n39 electoral bond scheme, clause 7(6)\n40 electoral bond scheme, clause 7(4)\n41 electoral bond scheme, clause 8(1)\n42 electoral bond scheme, clause 8(2)\n43 electoral bond scheme, clause 9\n44 electoral bond scheme,   clause 10\n                                            20\n\x0c                                                                                 part a\n             purpose of exemption from income tax under section 13a of the it act;45\n             and\n      m.     the bonds are not eligible for trading.46\n25. the petitioners instituted proceedings under article 32 seeking a declaration\n      that electoral bond scheme and the following provisions be declared\n      unconstitutional:\n      a.']}

# %%
with open("output.txt", "w") as f:
    f.write(str(sentences_dict))
