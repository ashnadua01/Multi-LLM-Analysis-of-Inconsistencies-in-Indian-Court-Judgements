# %%
import PyPDF2

# %%
def pdf_to_txt(pdf_file_path, txt_file_path):
    with open(pdf_file_path, 'rb') as pdf_file:
        pdf_reader = PyPDF2.PdfReader(pdf_file)
        
        text = ""
        for page_num in range(len(pdf_reader.pages)):
            page = pdf_reader.pages[page_num]
            text += page.extract_text().rstrip()

    with open(txt_file_path, 'w', encoding='utf-8') as txt_file:
        txt_file.write(text)

# %%
pdf_to_txt('/Users/Desktop/ACM CONFERENCE WORK/FINAL_LIST_DOCS/Bandhua_Mukti_Morcha_vs_Union_Of_India_Others_on_16_December_1983.PDF', 'bandhua_mukti.txt')

# %%
import pandas as pd
import nltk
nltk.download('punkt')  # Download the required NLTK data
# Out:
# [nltk_data] Downloading package punkt to /Users/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
def find_related_sentences(sentences, keyword):
    related_sentences = []

    for i, sentence in enumerate(sentences):
        if keyword in sentence:
            prev_sentence = sentences[i - 1].strip() if i > 0 else None
            next_sentence = sentences[i + 1].strip() if i < len(sentences) - 1 else None
            related_sentences.append({
                "Sentence": sentence.strip(),
                "Previous": prev_sentence,
                "Next": next_sentence
            })

    return related_sentences

# %%
with open('/Users/Desktop/ACM CONFERENCE WORK/codes/Bandhua Mukti/bandhua_mukti.txt', "r") as file:
    text = file.read()

# Tokenize into sentences using nltk.sent_tokenize()
sentences = nltk.sent_tokenize(text)

keyword = "Bandhua Mukti"
result = []

related_sentences = find_related_sentences(sentences, keyword)
result.extend(related_sentences)

# Create a DataFrame with columns "Sentence," "Previous," and "Next"
output_df = pd.DataFrame(result, columns=["Sentence", "Previous", "Next"])

# Save results to a new CSV
output_df.to_csv("output_sentences_bandhua_mukti.csv", index=False)

# %%
encodings_to_try = ['utf-8', 'latin1', 'utf-16', 'ISO-8859-1']

# Try reading the CSV file with different encodings
for encoding in encodings_to_try:
    try:
        output_df = pd.read_csv("output_sentences_bandhua_mukti.csv", encoding=encoding)
        print("CSV file read successfully with encoding:", encoding)
        break  # Exit loop if successful
    except UnicodeDecodeError:
        print("Failed to read CSV file with encoding:", encoding)
        continue  # Try next encoding
# Out:
# CSV file read successfully with encoding: utf-8

# %%
output_df
# Out:
#                                              Sentence  \
# 0   Bandhua Mukti Morcha vs Union Of India & Other...
# 1   SEN, AMARENDRA NATH (J)\nCITATION:\n 1984 AIR ...
# 2   HEADNOTE:\n     The petitioner,  an organisati...
# 3   32, this Court\nis  not   empowered  to   appo...
# 4   This right to\nlive with  human dignity enshri...
# ..                                                ...
# 88  They, however, do not and cannot have the effe...
# 89  The Petitioner which claims to be a Social Wel...
# 90  The power to appoint a commission or an invest...
# 91  Apart from the principal grievance\nmade that ...
# 92  S. R.                                  Petitio...
#
#                                              Previous  \
# 0                                                 NaN
# 1                                        PATHAK, R.S.
# 2   Minimum Wages  Act, Workmen's  Compensation Ac...
# 3   The  respondents  contended:  (1)  Article  32...
# 4   It is  the fundamental  right of  every one in...
# ..                                                ...
# 88                            32 of the Constitution.
# 89  In the present case, the unfortunate workers w...
# 90  When this Court is approached on behalf of thi...
# 91  On the merits of the case my learned brother B...
# 92  As I am in\nagreement with the views expressed...
#
#                                                  Next
# 0   I. C. 560, 1984 SCC (L&S) 389, (1984) 2 LAB LN...
# 1   Constitution of  India, Article  32 (2)-Appoin...
# 2   The\npetitioner also  mentioned in  the letter...
# 3   Rejecting all  the contentions  and allowing  ...
# 4   These  are  the  minimum\nrequirements which m...
# ..                                                ...
# 88  32 of the Constitution, if made,\nonly in the ...
# 89  I shall now consider the third and the last ob...
# 90  32 for enforcement of the fundamental rights g...
# 91  The grievance of denial of other just rights t...
# 92                                                NaN
#
# [93 rows x 3 columns]

# %%
concatenated_sen = pd.DataFrame(output_df['Previous'].astype(str) + ' ' + output_df['Sentence'].astype(str) + ' ' + output_df['Next'].astype(str), columns=['concat'])

# %%
print(concatenated_sen['concat'].iloc[0])
# Out:
# nan Bandhua Mukti Morcha vs Union Of India & Others on 16
# December, 1983
# Equivalent citations: 1984 AIR 802, 1984 SCR (2) 67, AIR 1984 SUPREME
# COURT 802, 1984 LAB. I. C. 560, 1984 SCC (L&S) 389, (1984) 2 LAB LN 60,
# 1984 (3) SCC 161
# Author: P.N.

# %%
concatenated_sen.to_csv('sentences_final_concatenated_bandhua_mukti.csv', index=False)

# %%
import csv

# %%
def create_person_id_map(file_path):
    person_id_map = {}

    with open(file_path, 'r') as csvfile:
        reader = csv.reader(csvfile)
        header = next(reader)
        
        for row in reader:
            person_id_list = row[0]
            person = person_id_list.strip()
            person_id = row[1].strip()
            person_id_map[person] = person_id

    return person_id_map

def create_location_id_map(file_path):
    location_id_map = {}

    with open(file_path, 'r') as csvfile:
        reader = csv.reader(csvfile)
        header = next(reader)
        
        for row in reader:
            location_id_list = row[0]
            location = location_id_list.strip()
            location_id = row[1].strip()
            location_id_map[location] = location_id

    return location_id_map

def create_time_id_map(file_path):
    time_id_map = {}

    with open(file_path, 'r') as csvfile:
        reader = csv.reader(csvfile)
        header = next(reader)
        
        for row in reader:
            time_id_list = row[0].split(',')
            time = time_id_list.strip()
            time_id = row[1].strip()
            time_id_map[time] = time_id

    return time_id_map

def create_event_id_map(file_path):
    event_id_map = {}

    with open(file_path, 'r') as csvfile:
        reader = csv.reader(csvfile)
        header = next(reader)
        
        for row in reader:
            event_id_list = row[0].split(',')
            event = event_id_list.strip()
            event_id = row[1].strip()
            event_id_map[event] = event_id

    return event_id_map

def create_other_id_map(file_path):
    other_id_map = {}

    with open(file_path, 'r') as csvfile:
        reader = csv.reader(csvfile)
        header = next(reader)
        
        for row in reader:
            other_id_list = row[0].split(',')
            other = other_id_list.strip()
            other_id = row[1].strip()
            other_id_map[other] = other_id

    return other_id_map

# %%
file_path_person = '/Users/Desktop/ACM CONFERENCE WORK/Entities/Bandhua Mukti Case/person.csv'
file_path_location = '/Users/Desktop/ACM CONFERENCE WORK/Entities/Bandhua Mukti Case/location.csv'
file_path_time = '/Users/Desktop/ACM CONFERENCE WORK/Entities/Bandhua Mukti Case/time.csv'
file_path_event = '/Users/Desktop/ACM CONFERENCE WORK/Entities/Bandhua Mukti Case/event.csv'
file_path_other = '/Users/Desktop/ACM CONFERENCE WORK/Entities/Bandhua Mukti Case/activity.csv'
person_id_map = create_person_id_map(file_path_person)
location_id_map = create_location_id_map(file_path_location)
time_id_map = create_location_id_map(file_path_time)
event_id_map = create_location_id_map(file_path_event)
other_id_map = create_location_id_map(file_path_other)

# %%
def generate_ngrams(text, n=6):
    words = text.split()
    ngrams = []
    for j in range(n, 0, -1):
        for i in range(len(words)):
            if i + j <= len(words):
                ngrams.append(' '.join(words[i:i+j]))
    return ngrams

# %%
def preprocess_text(text):
    text = text.replace("'s", "")
    text = text.replace(".", "")
    text = text.replace(";", "")
#     text = text.replace("-", "")
    text = text.replace("!", "")
    text = text.replace("?", "")
#     text = text.replace("/", "")
    text = text.replace("@", "")
    text = text.replace("#", "")
    text = text.replace(",", "")
    return text

# %%
def replace_entities(text):
    text = text.lower()
    ngrams = generate_ngrams(text)
    replaced_text = text

    for ngram in ngrams:
        original = ngram.lower()
        
        if original in person_id_map:
            entity_id = person_id_map[original]
            replaced_text = replaced_text.replace(ngram, entity_id)
        else:
            preprocessed_ngram = preprocess_text(ngram.lower())
            if preprocessed_ngram in person_id_map:
                entity_id = person_id_map[preprocessed_ngram]
                replaced_text = replaced_text.replace(ngram, entity_id)
            else:
                if original in location_id_map:
                    entity_id = location_id_map[original]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif preprocessed_ngram in location_id_map:
                    entity_id = location_id_map[preprocessed_ngram]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif original in time_id_map:
                    entity_id = time_id_map[original]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif preprocessed_ngram in time_id_map:
                    entity_id = time_id_map[preprocessed_ngram]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif original in event_id_map:
                    entity_id = event_id_map[original]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif preprocessed_ngram in event_id_map:
                    entity_id = event_id_map[preprocessed_ngram]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif original in other_id_map:
                    entity_id = other_id_map[original]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif preprocessed_ngram in other_id_map:
                    entity_id = other_id_map[preprocessed_ngram]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                    
    return replaced_text

# %%
with open('sentences_final_concatenated_bandhua_mukti.csv', 'r', encoding='latin-1') as csvfile:
     reader = csv.reader(csvfile)
     next(reader)
     ref_sen = []
     for row in reader:
         sentence = row[0]
         ref_sen.append(sentence)

# %%
final_sentences = []

for sen in ref_sen:
     s = replace_entities(sen)
     final_sentences.append(s)

# %%
with open('cleaned_sentences_bandhua_mukti.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Sentences'])
#      for sen in final_sentences:
    for sen in final_sentences:
        writer.writerow([sen])

# %% [markdown]
# ## Matrix Creation

# %%
# with the sentences
import pandas as pd
import csv
import re

# Load the CSV files
time_df = pd.read_csv(file_path_time)
location_df = pd.read_csv(file_path_location)
event_df = pd.read_csv(file_path_event)
person_df = pd.read_csv(file_path_person)
activity_df = pd.read_csv(file_path_other)

location_ID = location_df['ID'].tolist()
location_df = location_df['Location'].tolist()

time_ID = time_df['ID'].tolist()
time_df = time_df['Time'].tolist()

# event_ID = event_df['ID'].tolist()
# event_df = event_df['Event'].tolist()

# person_ID = person_df['ID'].tolist()
# person_df = person_df['Person'].tolist()

# activity_ID = activity_df['ID'].tolist()
# activity_df = activity_df['Others'].tolist()

event_ID_map = dict(zip(event_df['ID'], event_df['Event']))
person_ID_map = dict(zip(person_df['ID'], person_df['Person']))
activity_ID_map = dict(zip(activity_df['ID'], activity_df['Activity']))

matrix = {}

# %%
sentences = []
with open('cleaned_sentences_bandhua_mukti.csv', 'r', encoding='latin-1') as csvfile:
    reader = csv.reader(csvfile)
    next(reader)
    for row in reader:
        sentence = row[0]
        sentences.append(sentence)

# %%
for s in sentences:
    pattern = r'([PTLEA]\d+)'
    matches = re.findall(pattern, s)

    persons = []
    time = []
    location = []
    event = []
    activity = []

    for match in matches:
        if match[0] == 'P':
            persons.append(person_ID_map.get(match, 'Unknown Person'))
        elif match[0] == 'L':
             location.append(location_ID.index(match))
        elif match[0] == 'E':
            event.append(event_ID_map.get(match, 'Unknown Event'))
        elif match[0] == 'A':
            activity.append(activity_ID_map.get(match, 'Unknown Activity'))
        elif match[0] == 'T':
            time.append(time_ID.index(match))

    if location and time:
        for loc_index in location:
            loc_key = location_df[loc_index]
            for time_index in time:
                time_key = time_df[time_index]
                if time_key not in matrix:
                    matrix[time_key] = {}
                if loc_key not in matrix[time_key]:
                    matrix[time_key][loc_key] = []
                matrix[time_key][loc_key].extend([(entity, s) for entity in (persons + event + activity)])
    elif location:
        for loc_index in location:
            loc_key = location_df[loc_index]
            if loc_key not in matrix:
                matrix[loc_key] = {}
            if 'NULL' not in matrix:
                matrix['NULL'] = {}
            if loc_key not in matrix["NULL"]:
                matrix["NULL"][loc_key] = []
            matrix["NULL"][loc_key].extend([(entity, s) for entity in (persons + event + activity)])
    elif time:
        for time_index in time:
            time_key = time_df[time_index]
            if time_key not in matrix:
                matrix[time_key] = {}
            if 'NULL' not in matrix[time_key]:
                matrix[time_key]['NULL'] = []
            matrix[time_key]["NULL"].extend([(entity, s) for entity in (persons + event + activity)])
    else:
        if 'NULL' not in matrix:
            matrix['NULL'] = {}
        if 'NULL' not in matrix['NULL']:
            matrix['NULL']['NULL'] = []
        matrix["NULL"]["NULL"].extend([(entity, s) for entity in (persons + event + activity)])

matrix_df = pd.DataFrame.from_dict(matrix, orient='index')

# %%
matrix_df.to_csv('matrix_with_sen_bandhua_mukti.csv')

# %%
import networkx as nx

# %%
df = pd.read_csv('matrix_with_sen_bandhua_mukti.csv')

# %%
df.rename(columns={'Unnamed: 0': 'Time'}, inplace=True)

# %%
G = nx.Graph()

for index, row in df.iterrows():
    time = row['Time']
    for location in df.columns:
        if location == 'Time':
            continue
        # Convert the tuple to a string and add it as a node
        G.add_node(f"{time}, {location}")

# %%
import ast

# %%
final = set()

# Update the final set with only the entities
for value in pd.unique(df.drop(columns='Time').values.ravel()):
    if pd.notnull(value):
        value_list = ast.literal_eval(value)
        entity_list = [entity for entity, sentence in value_list]
        final.update(entity_list)

# %%
G.add_nodes_from(final)

# %%
for index, row in df.iterrows():
    time = row['Time']
    for location in df.columns:
        if location == 'Time':
            continue
        if pd.notnull(row[location]):
            value_list = ast.literal_eval(row[location])
            entity_list = [entity for entity, sentence in value_list]
            for entity in entity_list:
                if entity in final:
                    # Convert the tuples to strings and add them as an edge
                    G.add_edge(f"{time}, {location}", entity)

# %%
for node in list(G.nodes):
    if not list(G.neighbors(node)):
        G.remove_node(node)

# %%
for node1 in G.nodes:
    # Check if node1 can be split into a pair
    if ', ' in node1:
        parts1 = node1.split(", ")
        if len(parts1) == 2:  # Ensure it splits into exactly two parts
            time1, location1 = parts1
            for node2 in G.nodes:
                # Check if node2 can be split into a pair
                if ', ' in node2:
                    parts2 = node2.split(", ")
                    if len(parts2) == 2:  # Ensure it splits into exactly two parts
                        time2, location2 = parts2
                        # Add edge if the time or location matches
                        if time1 == time2 or location1 == location2:
                            G.add_edge(node1, node2)

# %%
degree_dict = dict(G.degree(G.nodes()))
nx.set_node_attributes(G, degree_dict, 'degree')

# %%
# Create a dictionary to store the sentences for each node
sentences_dict = {}

# Create a dictionary to store the sentences for each edge i.e. between two nodes
edge_sentences_dict = {}

# Update the sentences_dict and edge_sentences_dict
for index, row in df.iterrows():
    time = row['Time']
    for location in df.columns:
        if location == 'Time':
            continue
        if pd.notnull(row[location]):
            value_list = ast.literal_eval(row[location])
            for entity, sentence in value_list:
                if entity in final:
                    # Add the sentence to the sentences_dict for the entity
                    if entity not in sentences_dict:
                        sentences_dict[entity] = set()
                    sentences_dict[entity].add(sentence)

                    # Add the sentence to the sentences_dict for the (time, location) node
                    time_location_node = f"{time}, {location}"
                    if time_location_node not in sentences_dict:
                        sentences_dict[time_location_node] = set()
                    sentences_dict[time_location_node].add(sentence)

                    # Add the sentence to the edge_sentences_dict for the edge
                    edge = (time_location_node, entity)
                    if edge not in edge_sentences_dict:
                        edge_sentences_dict[edge] = set()
                    edge_sentences_dict[edge].add(sentence)

# Convert the sets back to lists if needed
for node, sentences in sentences_dict.items():
    sentences_dict[node] = list(sentences)

for edge, sentences in edge_sentences_dict.items():
    edge_sentences_dict[edge] = list(sentences)

# %%
pip install node2vec
# Out:
# Requirement already satisfied: node2vec in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (0.5.0)
# Requirement already satisfied: gensim<5.0.0,>=4.3.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from node2vec) (4.4.0)
# Requirement already satisfied: joblib<2.0.0,>=1.4.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from node2vec) (1.4.2)
# Requirement already satisfied: networkx<4.0.0,>=3.1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from node2vec) (3.4.2)
# Requirement already satisfied: numpy<2.0.0,>=1.24.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from node2vec) (1.26.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from node2vec) (4.67.1)
# Requirement already satisfied: scipy>=1.7.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from gensim<5.0.0,>=4.3.0->node2vec) (1.15.1)
# Requirement already satisfied: smart_open>=1.8.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from gensim<5.0.0,>=4.3.0->node2vec) (7.5.0)
# Requirement already satisfied: wrapt in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from smart_open>=1.8.1->gensim<5.0.0,>=4.3.0->node2vec) (2.0.1)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from node2vec import Node2Vec

# Create a Node2Vec instance
node2vec = Node2Vec(G, dimensions=64, walk_length=30, num_walks=200, workers=4)

# Generate embeddings
model = node2vec.fit(window=10, min_count=1, batch_words=4)
# Out:
# Computing transition probabilities:   0%|          | 0/17 [00:00<?, ?it/s]
# Generating walks (CPU: 3): 100%|██████████| 50/50 [00:00<00:00, 334.89it/s]
# Generating walks (CPU: 2): 100%|██████████| 50/50 [00:00<00:00, 330.10it/s]
# Generating walks (CPU: 4): 100%|██████████| 50/50 [00:00<00:00, 337.61it/s]
# Generating walks (CPU: 1): 100%|██████████| 50/50 [00:00<00:00, 331.13it/s]

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Get the node embeddings
node_embeddings = {node: model.wv[node] for node in G.nodes}

# Compute cosine similarity matrix
similarity_matrix = cosine_similarity(list(node_embeddings.values()))

# %%
from sklearn.cluster import DBSCAN

# Initialize DBSCAN
dbscan = DBSCAN(eps=0.5, min_samples=3)  # Adjust parameters as needed

# Fit and predict clusters
labels = dbscan.fit_predict(similarity_matrix)

# %%
cluster_colors = [
    'rgb(31, 119, 180)',  # Blue
    'rgb(255, 127, 14)',  # Orange
    'rgb(44, 160, 44)',   # Green
    'rgb(214, 39, 40)',   # Red
    'rgb(148, 103, 189)', # Purple
    'rgb(140, 86, 75)',   # Brown
    'rgb(227, 119, 194)', # Pink
    'rgb(127, 127, 127)', # Gray
    'rgb(188, 189, 34)',  # Olive
    'rgb(23, 190, 207)',  # Teal
    'rgb(255, 187, 120)', # Peach
    'rgb(214, 39, 40)',   # Maroon
    'rgb(77, 175, 74)',   # Light Green
    'rgb(152, 78, 163)',  # Plum
    'rgb(255, 152, 150)'  # Salmon
]

# %%
import networkx as nx
import plotly.graph_objs as go

# Assuming 'G' is your graph and 'labels' is the list of labels
# Renumber clusters from 1 to 7 if needed, otherwise ensure you have clusters numbered 1 to 7
unique_labels = list(set(labels))
label_mapping = {label: idx+1 for idx, label in enumerate(unique_labels)}

def draw_subgraph_plotly(subgraph, cluster_id, cluster_color):
    pos = nx.spring_layout(subgraph, seed=42)  # Fixed seed for reproducibility
    
    # Extract the node positions
    x_nodes = [pos[node][0] for node in subgraph.nodes()]
    y_nodes = [pos[node][1] for node in subgraph.nodes()]

    # Extract the edges
    edge_x = []
    edge_y = []
    for edge in subgraph.edges():
        x0, y0 = pos[edge[0]]
        x1, y1 = pos[edge[1]]
        edge_x.extend([x0, x1, None])
        edge_y.extend([y0, y1, None])

    # Edge trace
    edge_trace = go.Scatter(
        x=edge_x, y=edge_y,
        line=dict(width=1, color='gray'),
        hoverinfo='none',
        mode='lines')

    # Node trace
    node_trace = go.Scatter(
        x=x_nodes, y=y_nodes,
        mode='markers+text',
        text=[f'{node}' for node in subgraph.nodes()],
        textposition="top center",
        marker=dict(
            showscale=False,
            color=cluster_color,  # Assign the cluster color
            size=20,
            line=dict(width=2, color='black')
        ),
        hoverinfo='text'
    )

    # Create figure
    fig = go.Figure(data=[edge_trace, node_trace],
                    layout=go.Layout(
                        title=f'Cluster {cluster_id}',
                        showlegend=False,
                        hovermode='closest',
                        margin=dict(b=20, l=5, r=5, t=40),
                        xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                        yaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                        height=600,
                        width=600,
                        paper_bgcolor='white',
                        plot_bgcolor='white'
                    ))

    fig.show()

# Iterate over each cluster and draw the subgraph
for original_cluster_id in set(labels):
    cluster_id = label_mapping[original_cluster_id]
    cluster_color = cluster_colors[cluster_id - 1]  # Assign a unique color to each cluster
    cluster_nodes = [node for node, label in zip(G.nodes, labels) if label == original_cluster_id]
    subgraph = G.subgraph(cluster_nodes)
    draw_subgraph_plotly(subgraph, cluster_id, cluster_color)

# %%
# # Initialize lists for nodes and links
# nodes = []
# links = []

# # Add nodes to the list
# for node, sentences in sentences_dict.items():
#     nodes.append({
#         "id": node,
#         "group": 1,  # Update this as needed
#         "size": len(sentences)  # The size could be based on the number of sentences
#     })

# # Add links to the list
# for edge, sentences in edge_sentences_dict.items():
#     source, target = edge
#     links.append({
#         "source": source,
#         "target": target,
#         "value": len(sentences)  # The value could be based on the number of sentences
#     })

# # Combine nodes and links into a single dictionary
# graph_data = {
#     "nodes": nodes,
#     "links": links
# }

# %%
# import os

# os.environ['METIS_DLL'] = '/Users/.local/lib/libmetis.dylib'

# %%
# import metis

# %%
# edgecuts, parts = metis.part_graph(G)

# %%
import json

# Create a mapping from nodes to integers
node_to_int = {node: i for i, node in enumerate(G.nodes)}

# %%
degree_dict = dict(G.degree(G.nodes()))
nx.set_node_attributes(G, degree_dict, 'degree')

data = nx.node_link_data(G)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/networkx/readwrite/json_graph/node_link.py:142: FutureWarning:
#
#
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.

# %%
import numpy as np

# %%
labels = labels.astype(np.int32)

# %%
graph_data = {
    "nodes": [{"name": str(node), "n": degree_dict[node], "grp": int(labels[i]), "id": str(node)} for i, node in enumerate(G.nodes())],
    "links": [{"source": str(link_data['source']), "target": str(link_data['target']), "value": 1} for link_data in data['links']]
}

# %%
json_data = json.dumps(graph_data)
with open('data_air_india.json', 'w') as f:
    f.write(json_data)

# %%
# from collections import defaultdict

# # Create a dictionary where keys are part numbers and values are lists of nodes
# part_dict = defaultdict(list)
# for node, part in enumerate(parts):
#     part_dict[part].append(node)

# # Print the number of parts
# print("Number of parts:", len(part_dict))

# # Print the nodes in each part
# for part, nodes in part_dict.items():
#     print("Part", part, ":", nodes)

# %%
# Assuming you have already created clusters using DBSCAN and have 'labels' and 'G' available

# Initialize an empty dictionary to store sentences for each cluster
cluster_sentences_dict = {}

# Iterate over each cluster
for original_cluster_id in set(labels):
    cluster_id = label_mapping[original_cluster_id]
    cluster_nodes = [node for node, label in zip(G.nodes, labels) if label == original_cluster_id]
    
    # Initialize a set to store sentences for this cluster
    cluster_sentences = set()
    
    # Iterate over nodes in the cluster
    for node in cluster_nodes:
        # Assuming 'node' contains the relevant information (e.g., entity, time, location)
        # Extract sentences associated with this node and add them to the cluster_sentences set
        if node in sentences_dict:
            cluster_sentences.update(sentences_dict[node])
    
    # Store the cluster_sentences set in the cluster_sentences_dict
    cluster_sentences_dict[cluster_id] = cluster_sentences

# %%
sentences_dict
# Out:
# {'bonded labour': ['it was contended by the learned additional solicitor general on behalf of the state of haryana that\nin the stone quarries and stone crushers there might be E1ers but they were not bonded\nlabourers within the meaning of that expression as used in the act, since a labourer would be a\nE2er only if he has or is presumed to have incurred a bonded debt and there was nothing\nin the present case to show that the workmen employed in the stone quarries and stone crushers\nhad incurred or could be presumed to have incurred any bonded debt. it was not enough, contended\nthe learned additional solicitor general the petitioner merely to show that the workmen werebandhua mukti morcha vs union of india & others on 16 december, 1983\nindian kanoon - http://indiankanoon.org/doc/595099/ 59providing E1 in that they were not allowed to leave the premises of the establishment, but\nit was further necessary to show that they were working under the E2 system. the\nlearned additional solicitor general also submitted that in any event, even if the workmen filed\naffidavits to the effect that they had taken advances from thekedar or jamadar and or mine lessees\nand/or stone crusher owners and they were not allowed to leave the premises of the establishment\nuntil the advances were paid of, that would not be enough evidence for the court to hold that they\nwere E2ers, because the mine-lessees and stone crusher owners had no opportunity to\ncross-examine the workmen making such affidavits.',
#   'we would therefore strongly impress upon the magistrates and judicial officers to\ntake a strict view of violation of labour laws and to impose adequate punishment on the erring\nemployers so that they may realise that it does not pay to commit a breach of such laws and to deny\nthe benefit of such laws to the workmen. we accordingly allow this writ petition and issue the above directions to the central government\nand the state of haryana and the various authorities mentioned in the preceding paragraphs of this\njudgment so that these poor unfortunate workmen who lead a miserable existence in small hovels,\nexposed to the vagaries of weather, drinking foul water, breathing heavily dust-laden polluted airbandhua mukti morcha vs union of india & others on 16 december, 1983\nindian kanoon - http://indiankanoon.org/doc/595099/ 70and breaking and blasting stone all their life, may one day be able to realise that freedom is not only\nthe monopoly of a few but belongs to them all and that they are also equally entitled along with\nothers to participate in the fruits of freedom and development. these directions may be summarized\nas follows (1) the government of haryana will, without any delay and at any rate within \nfrom  constitute vigilance committee in each sub- division of a district in compliance with the\nrequirements of section 13 of the E2 system (abolition) act 1976 keeping in view the\nguidelines given by us in this judgment.',
#   'ashok srivastava and ashok panda\nshould be supplied to all the minelesses and stone crushers who are respondents to the writ\npetitions so that they may have an opportunity to file their reply to the facts found in the report. the court also appointed dr. patwardhan of indian institute of technology to carry out a socio-legal\ninvestigation in the following terms:\n"it is necessary that a socio-legal investigation should be carried out for the purpose\nof determining what are the conditions prevailing in the various quarries in\nfaridabad district and whether there are any workmen in those quarries against their\nwill or without their consent and what are the conditions in which they are living and\nwhether any of the provisions of the E2 system (abolition) act andbandhua mukti morcha vs union of india & others on 16 december, 1983\nindian kanoon - http://indiankanoon.org/doc/595099/ 38inter- state migrant workmen (regulation of employment & conditions of service)\nact is being violated. we may make it clear that when we are directing a socio-legal\ninvestigation of these matters it is not in a spirit to criticise the state government or\nany of its officers but with a view to find out the correctness of the state of affairs so\nthat the state government and its officers could take necessary steps for remedying\nthe situation if a state of affairs exists which is contrary to the provisions of law and\nthe basic human norms.',
#   'it is therefore necessary to impress upon the\nadministration that it does not help to ostrich-like bury its head in the sand and ignore the\nprevalence of E2 for it is not the existence of E2 that is a slur on the\nadministration but its failure to eradicate it and moreover not taking the necessary steps for the\npurpose of wiping out this blot on the fair name of the state is a breach of its constitutional\nobligation. we would therefore direct the government of haryana and also suggest to the other\nstate governments, to take steps to sensitise the officers concerned with the implementation of thebandhua mukti morcha vs union of india & others on 16 december, 1983\nindian kanoon - http://indiankanoon.org/doc/595099/ 61act to this acute human problems and its socioeconomic parameters. moreover it may be noted that\nthe district magistrates have a central role to play under the provisions of the act and the state\ngovernments would therefore do well to instruct the district magistrates to take up the work of\nidentification of E2 as one of their top priority tasks.',
#   '[130 f-h, 131 a]\n     it would  be cruel  to insist  that a  E2 in\norder  to   derive  the  benefits  of  this  social  welfare\nlegislation, should  have to  go through a formal process of\ntrial with  the normal  procedure for recording of evidence. that would be a totally futile process because it is obvious\nthat a  E2ers  can never stand up to the regidity\nand formalism  of the  legal process  due  to  his  poverty,\nilliteracy and  social and economic backwardness and if suchbandhua mukti morcha vs union of india & others on 16 december, 1983\nindian kanoon - http://indiankanoon.org/doc/595099/ 16a  procedure   were  required  to  be  followed,  the  state\ngovernment might  as  well  obliterate  this  act  from  the\nstatute book. it is now statistically established that most\nof bonded  labourers are  members of  scheduled  castes  and\nscheduled tribes  or other  backward  classes  and  ordinary\ncourse of  human affairs  would show, indeed judicial notice\ncan be  taken of  it, that  there would be no occasion for a\nlabourer to be placed in a situation where he is required to\nsupply E1 for no wage or for nominal wage, unless\nhe has received some advance of other economic consideration\nfrom the  employer and  under  the  consideration  from  the\nemployer and  under the  pretext of not having returned such\nadvance or  other economic  consideration, he is required to\nrender service to the employer or is deprived of his freedom\nof employment  or of  the right  to move  freely wherever he\nwants.',
#   'it was on the basis of this\ndefinitional requirement that the learned additional solicitor general on behalf of the state of\nharyana put forward the argument that even if the workmen employed in the stone quarries and\nstone crushers were being compelled to provide E1 they were not E2ers,\nsince it as not shown by them or by the petitioner that they were doing so in consideration of an\nadvance or other economic consideration received from the mine-lessees and owners of stone\ncrushers. now if this contention of the learned additional solicitor general were well-founded, it\nwould become almost impossible to enforce the provisions of the E2 system (abolition)\nact 1976 because in every case where E2ers are sought to be identified for the purpose of\nrelease and rehabilitation under the provisions of the act, the state authorities as also the employer\nwould be entitled to insist that the E2ers must first prove that they are providing forced\nlabour in consideration of an advance or other economic consideration received by them and then\nonly they would be eligible of the benefits provided under the act and this would make it extremely\ndifficult, if not impossible, for the labourers to establish that they are E2ers because they\nwould have no evidence at all to prove that any advance or economic consideration was provided to\nthem by the employer and since employment of E2ers is a penal offence under the actbandhua mukti morcha vs union of india & others on 16 december, 1983\nindian kanoon - http://indiankanoon.org/doc/595099/ 60the employer would immediately, without any hesitation, disown having given any advance or\neconomic consideration to the E2ers. it is indeed difficult to understand how the state\ngovernment which is constitutionally mandated to bring about change in the life conditions of the\npoor and the down-trodden and to ensure social justice to them, could possibly take up the stand\nthat the labourers must prove that they are made to provide E1 in consideration of an\nadvance or other economic consideration received from the employer and are therefore bonded\nlabourers.',
#   'we cannot ignore this material which has\nbeen placed before us and unquestioningly accept the statement made on behalf of the state of\nharyana that there is no E2 in the stone quarries and stone crushers. but at the same\ntime, we do not think that it would be right for us on the basis of this material to come to a definitebandhua mukti morcha vs union of india & others on 16 december, 1983\nindian kanoon - http://indiankanoon.org/doc/595099/ 63finding that these workers whose names are given in the report of m/s ashok srivastava and ashok\npanda or who have filed affidavits are providing E1 or are E2ers. it is\nnecessary to direct a further inquiry for the purpose of ascertaining whether any of the labourers\nworking in the stone quarries and stone crushers in faridabad district are E2ers in the\nlight of the law laid down by us in this judgment.',
#   "the  respondents  contended:  (1)  article  32  of  the\nconstitution is  not attracted  to the  instant case  as  no\nfundamental right  of  the  petitioner  or  of  the  workmen\nreferred to  in the  petition is  infringed;  (2)  a  letter\naddressed by  a party  to this  court cannot be treated as a\nwrit petition; (3) in a proceeding under art. 32, this court\nis  not   empowered  to   appoint  any   commission  or   an\ninvestigating body  to enquire  into the allegations made in\nthe writ  petition; (4) reports made by such commissions are\nbased only on ex-parte statements which have not been testedbandhua mukti morcha vs union of india & others on 16 december, 1983\nindian kanoon - http://indiankanoon.org/doc/595099/ 3by cross-examination  and therefore they have no evidentiary\nvalue; and  (5) there might be forced labourers in the stone\nquarries and stone crushers in the state of haryana but they\nwere  not  bonded  labourers  within  the  meaning  of  that\nexpression as  used in  the E2 system (abolition)\nact, 1976. rejecting all  the contentions  and allowing  the  writ\npetition on merits, the court\n^\n     held:  the  state  government's  objection  as  to  the\nmaintainability of the writ petition under article 32 of the\nconstitution by  the petitioners  is reprehensible.",
#   'section 5 invalidates any custom or tradition or any contract agreement or other instrument by\nvirtue of which any person or any member of the family or dependent of such person is required to\ndo any work or render any service as a E2er. section 6 provides inter alia that on the\ncommencement of the act, every obligation of a E2er to repay and bonded debt or such\npart of any bonded debt as remains unsatisfied immediately before such commencement, shall be\ndeemed to have been extinguished.bandhua mukti morcha vs union of india & others on 16 december, 1983\nindian kanoon - http://indiankanoon.org/doc/595099/ 58there are certain other consequential provisions in section 7 to 9 but it is not necessary to refer to\nthem. sections 10 to 12 impose a duty on every district magistrate and every officer to whom power\nmay be delegated by him, to inquire whether, after the commencement of the act, any bonded\nlabour system or any other form of E1 is being enforced by or on behalf of, any person\nresident within the local limits of his jurisdiction and if, as a result of such inquiry, any person is\nfound to be enforcing the E2 system or any other system of E1, he is required\nforthwith to take the necessary action to eradicate the enforcement of such E1.',
#   'we can appreciate the anxiety of\nthe mine lessees to resist the writ petition on any ground available to them, be it hyper-technical or\neven frivolous, but we find it incomprehensible that the state government should urge such a\npreliminary objection with a view to stifling at the thresh-hold an inquiry by the court as to whether\nthe workmen are living in bondage and under inhuman conditions. we should have thought that if\nany citizen brings before the court a complaint that a large number of peasants or workers are\nbonded serfs or are being subjected to exploitation by a few mine lessees or contractors or\nemployers or are being denied the benefits of social welfare laws, the state government, which is,\nunder our constitutional scheme, charged with the mission of bringing about a new socioeconomic\norder where there will be social and economic justice for every one and equality of status andbandhua mukti morcha vs union of india & others on 16 december, 1983\nindian kanoon - http://indiankanoon.org/doc/595099/ 40opportunity for all, would welcome an inquiry by the court, so that if it is found that there are in fact\nE2ers or even if the workers are not bonded in the strict sense of the term as defined in\nthe E2 system (abolition) act 1976 but they are made to provide E1 or are\nconsigned to a life of utter deprivation and degradation such a situation can be set right by the state\ngovernment. even if the state government is on its own inquiry satisfied that the workmen are not\nbonded and are not compelled to provide E1 and are living and working in decent\nconditions with all the basic necessities of life provided to them, the state government should not\nbaulk an inquiry by the court when a complaint is brought by a citizen, but it should be anxious to\nsatisfy the court and through the court the people of the country, that it is discharging its\nconstitutional obligation fairly and adequately and the workmen are being ensured social and\neconomic justice.',
#   'minimum wages  act, workmen\'s  compensation act,  1983,\npayment  of   wages  act,  employees  state  insurance  act,\nemployees provident  fund and  miscellaneous provisions act,\nmaternity benefits  act, 1957-benefits  accruing under these\nacts-whether available to mine workers. headnote:\n     the petitioner,  an organisation dedicated to the cause\nof release  of bonded  labourers in the country, addressed a\nletter to hon\'ble bhagwati, j. alleging: (1) that there were\na large  number of  labourers from  different parts  of  the\ncountry who  were working  in some  of  the  stone  quarriesbandhua mukti morcha vs union of india & others on 16 december, 1983\nindian kanoon - http://indiankanoon.org/doc/595099/
andhua mukti morcha vs union of india & others on 16 december, 1983\nindian kanoon - http://indiankanoon.org/doc/595099/ 34some states is not willing to admit the existence of E2 even though it exists in their\nterritory and there is incontrovertible evidence that it does so exist. we fail to see why the\nadministration should feel shy in admitting the existence of E2 because it is not the\nexistence of E2 that is a slur on the administration but its failure to take note of it and to\ntake all necessary steps for the purpose of putting an end to the E2 system by quickly\nidentifying, releasing and permanently rehabilitating E2ers.',
#   'but, it appears that though the constitution was enacted as far back as 26th\njanuary, 1950 and many years passed since then, no serious effort was made to give\neffect to article 23 and to stamp out the shocking practice of to E2 it wasbandhua mukti morcha vs union of india & others on 16 december, 1983\nindian kanoon - http://indiankanoon.org/doc/595099/ 33only in 1976 that parliament enacted the E2 system (abolition) act,\n1976 providing for the abolition of E2 system with a view to preventing\nthe economic and physical exploitation of the weaker sections of the people. but,\nunfortunately, as subsequent events have shown and that is borne out also by the\nreport made by the centre for rural development administration, indian institute\nof public administration to the ministry of labour government of india on\n"rehabilitation of E2 in monghyr district, bihar", the report made by\nthe public policy and planning division of the indian institute of public\nadministration to the ministry of labour, government of india on "evaluation study\nof E2 rehabilitation scheme in tehri garhwal, u.p.',
#   'ashok srivastava and ashok panda\nshould be supplied to all the minelesses and stone crushers who are respondents to the writ\npetitions so that they may have an opportunity to file their reply to the facts found in the report. the court also appointed dr. patwardhan of indian institute of technology to carry out a socio-legal\ninvestigation in the following terms:\n"it is necessary that a socio-legal investigation should be carried out for the purpose\nof determining what are the conditions prevailing in the various quarries in\nfaridabad district and whether there are any workmen in those quarries against their\nwill or without their consent and what are the conditions in which they are living and\nwhether any of the provisions of the E2 system (abolition) act andbandhua mukti morcha vs union of india & others on 16 december, 1983\nindian kanoon - http://indiankanoon.org/doc/595099/ 38inter- state migrant workmen (regulation of employment & conditions of service)\nact is being violated. we may make it clear that when we are directing a socio-legal\ninvestigation of these matters it is not in a spirit to criticise the state government or\nany of its officers but with a view to find out the correctness of the state of affairs so\nthat the state government and its officers could take necessary steps for remedying\nthe situation if a state of affairs exists which is contrary to the provisions of law and\nthe basic human norms.',
#   'it is therefore necessary to impress upon the\nadministration that it does not help to ostrich-like bury its head in the sand and ignore the\nprevalence of E2 for it is not the existence of E2 that is a slur on the\nadministration but its failure to eradicate it and moreover not taking the necessary steps for the\npurpose of wiping out this blot on the fair name of the state is a breach of its constitutional\nobligation. we would therefore direct the government of haryana and also suggest to the other\nstate governments, to take steps to sensitise the officers concerned with the implementation of thebandhua mukti morcha vs union of india & others on 16 december, 1983\nindian kanoon - http://indiankanoon.org/doc/595099/ 61act to this acute human problems and its socioeconomic parameters. moreover it may be noted that\nthe district magistrates have a central role to play under the provisions of the act and the state\ngovernments would therefore do well to instruct the district magistrates to take up the work of\nidentification of E2 as one of their top priority tasks.',
#   "the  respondents  contended:  (1)  article  32  of  the\nconstitution is  not attracted  to the  instant case  as  no\nfundamental right  of  the  petitioner  or  of  the  workmen\nreferred to  in the  petition is  infringed;  (2)  a  letter\naddressed by  a party  to this  court cannot be treated as a\nwrit petition; (3) in a proceeding under art. 32, this court\nis  not   empowered  to   appoint  any   commission  or   an\ninvestigating body  to enquire  into the allegations made in\nthe writ  petition; (4) reports made by such commissions are\nbased only on ex-parte statements which have not been testedbandhua mukti morcha vs union of india & others on 16 december, 1983\nindian kanoon - http://indiankanoon.org/doc/595099/
andhua mukti morcha vs union of india & others on 16 december, 1983\nindian kanoon - http://indiankanoon.org/doc/595099/ 35intolerable conditions" and many of whom were bonded labourers. the petitioner therefore\naddressed a letter to one of us on 25th february, 1982 pointing out that in the mines of shri s.l.',
# ...
#   'but we do not wish to\nanitcipate the discussion in regard to this argument and at the present stage we content ourselves by\nmerely observing that it is unfortunate that any state government should take up the plea that\npersons who are forced to provided labour may be forced labourers but unless it is shown by them\nby proper evidence tested by cross-examination that they are E14 against a\nbonded debt, they cannot be said to be bonded labourers and the state government cannot be held\nto be under any obligation to rehabilitate them. the petitioner made a survey of some of the stone quarries in faridabad district near the city of\ndelhi and found that there were a large number of labourers from maharashtra, madhya pradesh,\nuttar pradesh and rajasthan who were working in these stone quarries under "inhuman andbandhua mukti morcha vs union of india & others on 16 december, 1983\nindian kanoon - http://indiankanoon.org/doc/595099/ 35intolerable conditions" and many of whom were bonded labourers. the petitioner therefore\naddressed a letter to one of us on 25th february, 1982 pointing out that in the mines of shri s.l.'],
#  'addressed by the petitioner': ['the petitioner also set out the various provisions of the constitution and the statutes which were not\nbeing implemented or observed in regard to the labourers working in these stone quarries. thebandhua mukti morcha vs union of india & others on 16 december, 1983\nindian kanoon - http://indiankanoon.org/doc/595099/ 36petitioner in the end prayed that a writ be issued for proper implementation of these provisions of\nthe constitution and statutes with a view to ending the misery, suffering and helplessness of "these\nvictims of most inhuman exploitation". the letter dated 25th february 1982 A60 was A61 and\nby an order dated 26th february 1982 this court A62 and appointed\ntwo advocates, namely, m/s.'],
#  'treated as a writ petition': ['the petitioner also set out the various provisions of the constitution and the statutes which were not\nbeing implemented or observed in regard to the labourers working in these stone quarries. thebandhua mukti morcha vs union of india & others on 16 december, 1983\nindian kanoon - http://indiankanoon.org/doc/595099/ 36petitioner in the end prayed that a writ be issued for proper implementation of these provisions of\nthe constitution and statutes with a view to ending the misery, suffering and helplessness of "these\nvictims of most inhuman exploitation". the letter dated 25th february 1982 A60 was A61 and\nby an order dated 26th february 1982 this court A62 and appointed\ntwo advocates, namely, m/s.'],
#  'issued notice on the writ petition': ['the petitioner also set out the various provisions of the constitution and the statutes which were not\nbeing implemented or observed in regard to the labourers working in these stone quarries. thebandhua mukti morcha vs union of india & others on 16 december, 1983\nindian kanoon - http://indiankanoon.org/doc/595099/ 36petitioner in the end prayed that a writ be issued for proper implementation of these provisions of\nthe constitution and statutes with a view to ending the misery, suffering and helplessness of "these\nvictims of most inhuman exploitation". the letter dated 25th february 1982 A60 was A61 and\nby an order dated 26th february 1982 this court A62 and appointed\ntwo advocates, namely, m/s.'],
#  'provide pure drinking water': ['if shri laxmi dhar misra finds as a result of his inquiry that the contract labour act\nand/or the inter-state migrant workmen act is applicable, he will make a report to that effect to the\ncourt on or before 15th february 1984. we may make it clear that this inquiry by shri laxmi dhar\nmisra is not directed for the purpose of fastening any liability on the mine-lessees and stone crusher\nowners or the jamadars and thekedars proprio vigore on the basis of such report, but merely for the\npurpose of considering whether a prima facie case exists on the basis of which action can be initiated\nby the central government, in which the mine- lessees and stone crusher owners and/or the\njamadars or thekedars would have an opportunity of contesting the allegation that the contract\nlabour act and/or the inter- state migrant workmen act applies to their stone quarry or stone\ncrusher and defending such action.bandhua mukti morcha vs union of india & others on 16 december, 1983\nindian kanoon - http://indiankanoon.org/doc/595099/ 66we may now take up a few specific complaints urged on behalf of the workmen. the first complaint\nrelates to the failure to A39 to the workmen in most of the stone quarries\nand stone crushers.'],
#  'injury': ["it is also necessary to point out that\nwhenever any workman suffers any E6 or contracts any E7 in the course of employment, he\nis entitled to compensation under the workmens' compensation act 1923, but unfortunately he is\nvery often not in a position to approach the appropriate court or authority for enforcing his claim to\ncompensation and even if he files such a claim, it takes a long time before such claim is disposed of\nby the court or authority. we would therefore direct that as soon as any workman employed in a\nstone quarry or stone crusher receives E6 or contracts E7 in the course of his employment,\nthe concerned mine-lessee or stone crusher owner shall immediately report this fact to the chiefbandhua mukti morcha vs union of india & others on 16 december, 1983\nindian kanoon - http://indiankanoon.org/doc/595099/