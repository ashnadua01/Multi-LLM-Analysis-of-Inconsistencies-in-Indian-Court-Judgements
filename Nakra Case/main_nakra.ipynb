# %%
import PyPDF2

# %%
def pdf_to_txt(pdf_file_path, txt_file_path):
    with open(pdf_file_path, 'rb') as pdf_file:
        pdf_reader = PyPDF2.PdfReader(pdf_file)
        
        text = ""
        for page_num in range(len(pdf_reader.pages)):
            page = pdf_reader.pages[page_num]
            text += page.extract_text().rstrip()

    with open(txt_file_path, 'w', encoding='utf-8') as txt_file:
        txt_file.write(text)

# %%
pdf_to_txt('/Users/ashnadua/Desktop/ACM CONFERENCE WORK/FINAL_LIST_DOCS/D_S_Nakara_Others_vs_Union_Of_India_on_17_December_1982.PDF', 'nakara.txt')

# %%
import pandas as pd
import nltk
nltk.download('punkt')  # Download the required NLTK data
# Out:
# [nltk_data] Downloading package punkt to /Users/ashnadua/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
def find_related_sentences(sentences, keyword):
    related_sentences = []

    for i, sentence in enumerate(sentences):
        if keyword in sentence:
            prev_sentence = sentences[i - 1].strip() if i > 0 else None
            next_sentence = sentences[i + 1].strip() if i < len(sentences) - 1 else None
            related_sentences.append({
                "Sentence": sentence.strip(),
                "Previous": prev_sentence,
                "Next": next_sentence
            })

    return related_sentences

# %%
with open('/Users/ashnadua/Desktop/ACM CONFERENCE WORK/codes/Nakra Case/nakara.txt', "r") as file:
    text = file.read()

# Tokenize into sentences using nltk.sent_tokenize()
sentences = nltk.sent_tokenize(text)

keyword = "pension"
result = []

related_sentences = find_related_sentences(sentences, keyword)
result.extend(related_sentences)

# Create a DataFrame with columns "Sentence," "Previous," and "Next"
output_df = pd.DataFrame(result, columns=["Sentence", "Previous", "Next"])

# Save results to a new CSV
output_df.to_csv("output_sentences_nakara.csv", index=False)

# %%
encodings_to_try = ['utf-8', 'latin1', 'utf-16', 'ISO-8859-1']

# Try reading the CSV file with different encodings
for encoding in encodings_to_try:
    try:
        output_df = pd.read_csv("output_sentences_nakara.csv", encoding=encoding)
        print("CSV file read successfully with encoding:", encoding)
        break  # Exit loop if successful
    except UnicodeDecodeError:
        print("Failed to read CSV file with encoding:", encoding)
        continue  # Try next encoding
# Out:
# CSV file read successfully with encoding: utf-8

# %%
output_df
# Out:
#                                               Sentence  \
# 0    14-Central Civil Services\n(Pension) Rules,  1...
# 1    Rules  and  Regulations  governing  grant  of ...
# 2    HEADNOTE:\n     By a  Memorandum dated  May 25...
# 3    3, a  registered  society\nespousing the  caus...
# 4    Counsel for  petitioners contended  that all p...
# ..                                                 ...
# 206  With the expanding horizons of socio-economic ...
# 207  Both the memoranda shall be enforced and imple...
# 208  are unconstitutional and are struck down with ...
# 209  Omitting the\nunconstitutional part it is decl...
# 210  Arrears of pension prior to the\nspecified dat...
#
#                                               Previous  \
# 0    Nakara & Others vs Union Of India on 17 Decemb...
# 1    14-Doctrine    of\nseverability-Severance may ...
# 2    Rules  and  Regulations  governing  grant  of ...
# 3    Petitioners 1  and 2  who had  retired in the ...
# 4    Nakara & Others vs Union Of India on 17 Decemb...
# ..                                                 ...
# 206  Nakara & Others vs Union Of India on 17 Decemb...
# 207    14 and is\nunconstitutional and is struck down.
# 208  Both the memoranda shall be enforced and imple...
# 209  are unconstitutional and are struck down with ...
# 210  Omitting the\nunconstitutional part it is decl...
#
#                                                   Next
# 0          14\n     Constitution   of    India,   Art.
# 1    HEADNOTE:\n     By a  Memorandum dated  May 25...
# 2    By another\nMemorandum issued  on September  2...
# 3    Nakara & Others vs Union Of India on 17 Decemb...
# 4    14\nas the  choice of specified date is wholly...
# ..                                                 ...
# 206    14 and is\nunconstitutional and is struck down.
# 207  are unconstitutional and are struck down with ...
# 208  Omitting the\nunconstitutional part it is decl...
# 209  Arrears of pension prior to the\nspecified dat...
# 210               Let a writ to that effect be issued.
#
# [211 rows x 3 columns]

# %%
concatenated_sen = pd.DataFrame(output_df['Previous'].astype(str) + ' ' + output_df['Sentence'].astype(str) + ' ' + output_df['Next'].astype(str), columns=['concat'])

# %%
print(concatenated_sen['concat'].iloc[0])
# Out:
# Nakara & Others vs Union Of India on 17 December, 1982
# Indian Kanoon - http://indiankanoon.org/doc/1416283/ 1 R          1987 SC 943  (8)
#  RF         1987 SC2359  (17)
#  D          1988 SC 501  (3,4,6,7)
#  RF         1988 SC 740  (13)
#  D          1988 SC1291  (9)
#  R          1988 SC1645  (8)
#  D          1989 SC 665  (7)
#  F          1989 SC2088  (7)
#  R          1990 SC 334  (104)
#  RF         1990 SC 883  (6)
#  E          1990 SC1760  (9)
#  RF         1990 SC1923  (3)
#  D          1990 SC2043  (2,7)
#  E          1991 SC1182  (6 TO 16,18,19,23)
#  RF         1991 SC1743  (1,2,4)
#  R          1992 SC  96  (11)
#  R          1992 SC 767  (2,4,TO 8,10)
# ACT:
#      Constitution of  India, Art. 14-Central Civil Services
# (Pension) Rules,  1972 and Regulations governing pension for
# Armed  Forces  Personnel-Liberalisation  in  computation  of
# pension effective  from specified date-Divides pensioners so
# as to  confer benefit  on some  while denying  it to others-
# Classification arbitrary, devoid of rational nexus to object
# of liberalisation and violative of Art. 14
#      Constitution   of    India,   Art.

# %%
concatenated_sen.to_csv('sentences_final_concatenated_nakara.csv', index=False)

# %%
import csv

# %%
def create_person_id_map(file_path):
    person_id_map = {}

    with open(file_path, 'r') as csvfile:
        reader = csv.reader(csvfile)
        header = next(reader)
        
        for row in reader:
            person_id_list = row[0]
            person = person_id_list.strip()
            person_id = row[1].strip()
            person_id_map[person] = person_id

    return person_id_map

def create_location_id_map(file_path):
    location_id_map = {}

    with open(file_path, 'r') as csvfile:
        reader = csv.reader(csvfile)
        header = next(reader)
        
        for row in reader:
            location_id_list = row[0]
            location = location_id_list.strip()
            location_id = row[1].strip()
            location_id_map[location] = location_id

    return location_id_map

def create_time_id_map(file_path):
    time_id_map = {}

    with open(file_path, 'r') as csvfile:
        reader = csv.reader(csvfile)
        header = next(reader)
        
        for row in reader:
            time_id_list = row[0].split(',')
            time = time_id_list.strip()
            time_id = row[1].strip()
            time_id_map[time] = time_id

    return time_id_map

def create_event_id_map(file_path):
    event_id_map = {}

    with open(file_path, 'r') as csvfile:
        reader = csv.reader(csvfile)
        header = next(reader)
        
        for row in reader:
            event_id_list = row[0].split(',')
            event = event_id_list.strip()
            event_id = row[1].strip()
            event_id_map[event] = event_id

    return event_id_map

def create_other_id_map(file_path):
    other_id_map = {}

    with open(file_path, 'r') as csvfile:
        reader = csv.reader(csvfile)
        header = next(reader)
        
        for row in reader:
            other_id_list = row[0].split(',')
            other = other_id_list.strip()
            other_id = row[1].strip()
            other_id_map[other] = other_id

    return other_id_map

# %%
file_path_person = '/Users/ashnadua/Desktop/ACM CONFERENCE WORK/Entities/Nakra Case/person.csv'
file_path_location = '/Users/ashnadua/Desktop/ACM CONFERENCE WORK/Entities/Nakra Case/location.csv'
file_path_time = '/Users/ashnadua/Desktop/ACM CONFERENCE WORK/Entities/Nakra Case/time.csv'
file_path_event = '/Users/ashnadua/Desktop/ACM CONFERENCE WORK/Entities/Nakra Case/event.csv'
file_path_other = '/Users/ashnadua/Desktop/ACM CONFERENCE WORK/Entities/Nakra Case/activity.csv'
person_id_map = create_person_id_map(file_path_person)
location_id_map = create_location_id_map(file_path_location)
time_id_map = create_location_id_map(file_path_time)
event_id_map = create_location_id_map(file_path_event)
other_id_map = create_location_id_map(file_path_other)

# %%
def generate_ngrams(text, n=6):
    words = text.split()
    ngrams = []
    for j in range(n, 0, -1):
        for i in range(len(words)):
            if i + j <= len(words):
                ngrams.append(' '.join(words[i:i+j]))
    return ngrams

# %%
def preprocess_text(text):
    text = text.replace("'s", "")
    text = text.replace(".", "")
    text = text.replace(";", "")
#     text = text.replace("-", "")
    text = text.replace("!", "")
    text = text.replace("?", "")
#     text = text.replace("/", "")
    text = text.replace("@", "")
    text = text.replace("#", "")
    text = text.replace(",", "")
    return text

# %%
def replace_entities(text):
    text = text.lower()
    ngrams = generate_ngrams(text)
    replaced_text = text

    for ngram in ngrams:
        original = ngram.lower()
        
        if original in person_id_map:
            entity_id = person_id_map[original]
            replaced_text = replaced_text.replace(ngram, entity_id)
        else:
            preprocessed_ngram = preprocess_text(ngram.lower())
            if preprocessed_ngram in person_id_map:
                entity_id = person_id_map[preprocessed_ngram]
                replaced_text = replaced_text.replace(ngram, entity_id)
            else:
                if original in location_id_map:
                    entity_id = location_id_map[original]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif preprocessed_ngram in location_id_map:
                    entity_id = location_id_map[preprocessed_ngram]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif original in time_id_map:
                    entity_id = time_id_map[original]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif preprocessed_ngram in time_id_map:
                    entity_id = time_id_map[preprocessed_ngram]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif original in event_id_map:
                    entity_id = event_id_map[original]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif preprocessed_ngram in event_id_map:
                    entity_id = event_id_map[preprocessed_ngram]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif original in other_id_map:
                    entity_id = other_id_map[original]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif preprocessed_ngram in other_id_map:
                    entity_id = other_id_map[preprocessed_ngram]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                    
    return replaced_text

# %%
with open('sentences_final_concatenated_nakara.csv', 'r', encoding='latin-1') as csvfile:
     reader = csv.reader(csvfile)
     next(reader)
     ref_sen = []
     for row in reader:
         sentence = row[0]
         ref_sen.append(sentence)

# %%
final_sentences = []

for sen in ref_sen:
     s = replace_entities(sen)
     final_sentences.append(s)

# %%
with open('cleaned_sentences_nakara.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Sentences'])
#      for sen in final_sentences:
    for sen in final_sentences:
        writer.writerow([sen])

# %% [markdown]
# ## Matrix Creation

# %%
# with the sentences
import pandas as pd
import csv
import re

# Load the CSV files
time_df = pd.read_csv(file_path_time)
location_df = pd.read_csv(file_path_location)
event_df = pd.read_csv(file_path_event)
person_df = pd.read_csv(file_path_person)
activity_df = pd.read_csv(file_path_other)

location_ID = location_df['ID'].tolist()
location_df = location_df['Location'].tolist()

time_ID = time_df['ID'].tolist()
time_df = time_df['Time'].tolist()

# event_ID = event_df['ID'].tolist()
# event_df = event_df['Event'].tolist()

# person_ID = person_df['ID'].tolist()
# person_df = person_df['Person'].tolist()

# activity_ID = activity_df['ID'].tolist()
# activity_df = activity_df['Others'].tolist()

event_ID_map = dict(zip(event_df['ID'], event_df['Event']))
person_ID_map = dict(zip(person_df['ID'], person_df['Person']))
activity_ID_map = dict(zip(activity_df['ID'], activity_df['Activity']))

matrix = {}

# %%
sentences = []
with open('cleaned_sentences_nakara.csv', 'r', encoding='latin-1') as csvfile:
    reader = csv.reader(csvfile)
    next(reader)
    for row in reader:
        sentence = row[0]
        sentences.append(sentence)

# %%
for s in sentences:
    pattern = r'([PTLEA]\d+)'
    matches = re.findall(pattern, s)

    persons = []
    time = []
    location = []
    event = []
    activity = []

    for match in matches:
        if match[0] == 'P':
            persons.append(person_ID_map.get(match, 'Unknown Person'))
        elif match[0] == 'L':
             location.append(location_ID.index(match))
        elif match[0] == 'E':
            event.append(event_ID_map.get(match, 'Unknown Event'))
        elif match[0] == 'A':
            activity.append(activity_ID_map.get(match, 'Unknown Activity'))
        elif match[0] == 'T':
            time.append(time_ID.index(match))

    if location and time:
        for loc_index in location:
            loc_key = location_df[loc_index]
            for time_index in time:
                time_key = time_df[time_index]
                if time_key not in matrix:
                    matrix[time_key] = {}
                if loc_key not in matrix[time_key]:
                    matrix[time_key][loc_key] = []
                matrix[time_key][loc_key].extend([(entity, s) for entity in (persons + event + activity)])
    elif location:
        for loc_index in location:
            loc_key = location_df[loc_index]
            if loc_key not in matrix:
                matrix[loc_key] = {}
            if 'NULL' not in matrix:
                matrix['NULL'] = {}
            if loc_key not in matrix["NULL"]:
                matrix["NULL"][loc_key] = []
            matrix["NULL"][loc_key].extend([(entity, s) for entity in (persons + event + activity)])
    elif time:
        for time_index in time:
            time_key = time_df[time_index]
            if time_key not in matrix:
                matrix[time_key] = {}
            if 'NULL' not in matrix[time_key]:
                matrix[time_key]['NULL'] = []
            matrix[time_key]["NULL"].extend([(entity, s) for entity in (persons + event + activity)])
    else:
        if 'NULL' not in matrix:
            matrix['NULL'] = {}
        if 'NULL' not in matrix['NULL']:
            matrix['NULL']['NULL'] = []
        matrix["NULL"]["NULL"].extend([(entity, s) for entity in (persons + event + activity)])

matrix_df = pd.DataFrame.from_dict(matrix, orient='index')

# %%
matrix_df.to_csv('matrix_with_sen_nakara.csv')

# %%
import networkx as nx

# %%
df = pd.read_csv('matrix_with_sen_nakara.csv')

# %%
df.rename(columns={'Unnamed: 0': 'Time'}, inplace=True)

# %%
G = nx.Graph()

for index, row in df.iterrows():
    time = row['Time']
    for location in df.columns:
        if location == 'Time':
            continue
        # Convert the tuple to a string and add it as a node
        G.add_node(f"{time}, {location}")

# %%
import ast

# %%
final = set()

# Update the final set with only the entities
for value in pd.unique(df.drop(columns='Time').values.ravel()):
    if pd.notnull(value):
        value_list = ast.literal_eval(value)
        entity_list = [entity for entity, sentence in value_list]
        final.update(entity_list)

# %%
G.add_nodes_from(final)

# %%
for index, row in df.iterrows():
    time = row['Time']
    for location in df.columns:
        if location == 'Time':
            continue
        if pd.notnull(row[location]):
            value_list = ast.literal_eval(row[location])
            entity_list = [entity for entity, sentence in value_list]
            for entity in entity_list:
                if entity in final:
                    # Convert the tuples to strings and add them as an edge
                    G.add_edge(f"{time}, {location}", entity)

# %%
for node in list(G.nodes):
    if not list(G.neighbors(node)):
        G.remove_node(node)

# %%
for node1 in G.nodes:
    # Check if node1 can be split into a pair
    if ', ' in node1:
        parts1 = node1.split(", ")
        if len(parts1) == 2:  # Ensure it splits into exactly two parts
            time1, location1 = parts1
            for node2 in G.nodes:
                # Check if node2 can be split into a pair
                if ', ' in node2:
                    parts2 = node2.split(", ")
                    if len(parts2) == 2:  # Ensure it splits into exactly two parts
                        time2, location2 = parts2
                        # Add edge if the time or location matches
                        if time1 == time2 or location1 == location2:
                            G.add_edge(node1, node2)

# %%
degree_dict = dict(G.degree(G.nodes()))
nx.set_node_attributes(G, degree_dict, 'degree')

# %%
# Create a dictionary to store the sentences for each node
sentences_dict = {}

# Create a dictionary to store the sentences for each edge i.e. between two nodes
edge_sentences_dict = {}

# Update the sentences_dict and edge_sentences_dict
for index, row in df.iterrows():
    time = row['Time']
    for location in df.columns:
        if location == 'Time':
            continue
        if pd.notnull(row[location]):
            value_list = ast.literal_eval(row[location])
            for entity, sentence in value_list:
                if entity in final:
                    # Add the sentence to the sentences_dict for the entity
                    if entity not in sentences_dict:
                        sentences_dict[entity] = set()
                    sentences_dict[entity].add(sentence)

                    # Add the sentence to the sentences_dict for the (time, location) node
                    time_location_node = f"{time}, {location}"
                    if time_location_node not in sentences_dict:
                        sentences_dict[time_location_node] = set()
                    sentences_dict[time_location_node].add(sentence)

                    # Add the sentence to the edge_sentences_dict for the edge
                    edge = (time_location_node, entity)
                    if edge not in edge_sentences_dict:
                        edge_sentences_dict[edge] = set()
                    edge_sentences_dict[edge].add(sentence)

# Convert the sets back to lists if needed
for node, sentences in sentences_dict.items():
    sentences_dict[node] = list(sentences)

for edge, sentences in edge_sentences_dict.items():
    edge_sentences_dict[edge] = list(sentences)

# %%
pip install node2vec
# Out:
# Requirement already satisfied: node2vec in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (0.5.0)
# Requirement already satisfied: gensim<5.0.0,>=4.3.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from node2vec) (4.4.0)
# Requirement already satisfied: joblib<2.0.0,>=1.4.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from node2vec) (1.4.2)
# Requirement already satisfied: networkx<4.0.0,>=3.1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from node2vec) (3.4.2)
# Requirement already satisfied: numpy<2.0.0,>=1.24.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from node2vec) (1.26.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from node2vec) (4.67.1)
# Requirement already satisfied: scipy>=1.7.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from gensim<5.0.0,>=4.3.0->node2vec) (1.15.1)
# Requirement already satisfied: smart_open>=1.8.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from gensim<5.0.0,>=4.3.0->node2vec) (7.5.0)
# Requirement already satisfied: wrapt in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from smart_open>=1.8.1->gensim<5.0.0,>=4.3.0->node2vec) (2.0.1)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from node2vec import Node2Vec

# Create a Node2Vec instance
node2vec = Node2Vec(G, dimensions=64, walk_length=30, num_walks=200, workers=4)

# Generate embeddings
model = node2vec.fit(window=10, min_count=1, batch_words=4)
# Out:
# Computing transition probabilities:   0%|          | 0/19 [00:00<?, ?it/s]
# Generating walks (CPU: 2): 100%|██████████| 50/50 [00:00<00:00, 462.63it/s]
# Generating walks (CPU: 3): 100%|██████████| 50/50 [00:00<00:00, 461.85it/s]
# Generating walks (CPU: 1): 100%|██████████| 50/50 [00:00<00:00, 458.54it/s]
# Generating walks (CPU: 4): 100%|██████████| 50/50 [00:00<00:00, 457.76it/s]

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Get the node embeddings
node_embeddings = {node: model.wv[node] for node in G.nodes}

# Compute cosine similarity matrix
similarity_matrix = cosine_similarity(list(node_embeddings.values()))

# %%
from sklearn.cluster import DBSCAN

# Initialize DBSCAN
dbscan = DBSCAN(eps=0.5, min_samples=3)  # Adjust parameters as needed

# Fit and predict clusters
labels = dbscan.fit_predict(similarity_matrix)

# %%
cluster_colors = [
    'rgb(31, 119, 180)',  # Blue
    'rgb(255, 127, 14)',  # Orange
    'rgb(44, 160, 44)',   # Green
    'rgb(214, 39, 40)',   # Red
    'rgb(148, 103, 189)', # Purple
    'rgb(140, 86, 75)',   # Brown
    'rgb(227, 119, 194)', # Pink
    'rgb(127, 127, 127)', # Gray
    'rgb(188, 189, 34)',  # Olive
    'rgb(23, 190, 207)',  # Teal
    'rgb(255, 187, 120)', # Peach
    'rgb(214, 39, 40)',   # Maroon
    'rgb(77, 175, 74)',   # Light Green
    'rgb(152, 78, 163)',  # Plum
    'rgb(255, 152, 150)'  # Salmon
]

# %%
import networkx as nx
import plotly.graph_objs as go

# Assuming 'G' is your graph and 'labels' is the list of labels
# Renumber clusters from 1 to 7 if needed, otherwise ensure you have clusters numbered 1 to 7
unique_labels = list(set(labels))
label_mapping = {label: idx+1 for idx, label in enumerate(unique_labels)}

def draw_subgraph_plotly(subgraph, cluster_id, cluster_color):
    pos = nx.spring_layout(subgraph, seed=42)  # Fixed seed for reproducibility
    
    # Extract the node positions
    x_nodes = [pos[node][0] for node in subgraph.nodes()]
    y_nodes = [pos[node][1] for node in subgraph.nodes()]

    # Extract the edges
    edge_x = []
    edge_y = []
    for edge in subgraph.edges():
        x0, y0 = pos[edge[0]]
        x1, y1 = pos[edge[1]]
        edge_x.extend([x0, x1, None])
        edge_y.extend([y0, y1, None])

    # Edge trace
    edge_trace = go.Scatter(
        x=edge_x, y=edge_y,
        line=dict(width=1, color='gray'),
        hoverinfo='none',
        mode='lines')

    # Node trace
    node_trace = go.Scatter(
        x=x_nodes, y=y_nodes,
        mode='markers+text',
        text=[f'{node}' for node in subgraph.nodes()],
        textposition="top center",
        marker=dict(
            showscale=False,
            color=cluster_color,  # Assign the cluster color
            size=20,
            line=dict(width=2, color='black')
        ),
        hoverinfo='text'
    )

    # Create figure
    fig = go.Figure(data=[edge_trace, node_trace],
                    layout=go.Layout(
                        title=f'Cluster {cluster_id}',
                        showlegend=False,
                        hovermode='closest',
                        margin=dict(b=20, l=5, r=5, t=40),
                        xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                        yaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                        height=600,
                        width=600,
                        paper_bgcolor='white',
                        plot_bgcolor='white'
                    ))

    fig.show()

# Iterate over each cluster and draw the subgraph
for original_cluster_id in set(labels):
    cluster_id = label_mapping[original_cluster_id]
    cluster_color = cluster_colors[cluster_id - 1]  # Assign a unique color to each cluster
    cluster_nodes = [node for node, label in zip(G.nodes, labels) if label == original_cluster_id]
    subgraph = G.subgraph(cluster_nodes)
    draw_subgraph_plotly(subgraph, cluster_id, cluster_color)

# %%
# # Initialize lists for nodes and links
# nodes = []
# links = []

# # Add nodes to the list
# for node, sentences in sentences_dict.items():
#     nodes.append({
#         "id": node,
#         "group": 1,  # Update this as needed
#         "size": len(sentences)  # The size could be based on the number of sentences
#     })

# # Add links to the list
# for edge, sentences in edge_sentences_dict.items():
#     source, target = edge
#     links.append({
#         "source": source,
#         "target": target,
#         "value": len(sentences)  # The value could be based on the number of sentences
#     })

# # Combine nodes and links into a single dictionary
# graph_data = {
#     "nodes": nodes,
#     "links": links
# }

# %%
# import os

# os.environ['METIS_DLL'] = '/Users/ashnadua/.local/lib/libmetis.dylib'

# %%
# import metis

# %%
# edgecuts, parts = metis.part_graph(G)

# %%
import json

# Create a mapping from nodes to integers
node_to_int = {node: i for i, node in enumerate(G.nodes)}

# %%
degree_dict = dict(G.degree(G.nodes()))
nx.set_node_attributes(G, degree_dict, 'degree')

data = nx.node_link_data(G)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/networkx/readwrite/json_graph/node_link.py:142: FutureWarning:
#
#
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.

# %%
import numpy as np

# %%
labels = labels.astype(np.int32)

# %%
graph_data = {
    "nodes": [{"name": str(node), "n": degree_dict[node], "grp": int(labels[i]), "id": str(node)} for i, node in enumerate(G.nodes())],
    "links": [{"source": str(link_data['source']), "target": str(link_data['target']), "value": 1} for link_data in data['links']]
}

# %%
json_data = json.dumps(graph_data)
with open('data_nakara.json', 'w') as f:
    f.write(json_data)

# %%
# from collections import defaultdict

# # Create a dictionary where keys are part numbers and values are lists of nodes
# part_dict = defaultdict(list)
# for node, part in enumerate(parts):
#     part_dict[part].append(node)

# # Print the number of parts
# print("Number of parts:", len(part_dict))

# # Print the nodes in each part
# for part, nodes in part_dict.items():
#     print("Part", part, ":", nodes)

# %%
# Assuming you have already created clusters using DBSCAN and have 'labels' and 'G' available

# Initialize an empty dictionary to store sentences for each cluster
cluster_sentences_dict = {}

# Iterate over each cluster
for original_cluster_id in set(labels):
    cluster_id = label_mapping[original_cluster_id]
    cluster_nodes = [node for node, label in zip(G.nodes, labels) if label == original_cluster_id]
    
    # Initialize a set to store sentences for this cluster
    cluster_sentences = set()
    
    # Iterate over nodes in the cluster
    for node in cluster_nodes:
        # Assuming 'node' contains the relevant information (e.g., entity, time, location)
        # Extract sentences associated with this node and add them to the cluster_sentences set
        if node in sentences_dict:
            cluster_sentences.update(sentences_dict[node])
    
    # Store the cluster_sentences set in the cluster_sentences_dict
    cluster_sentences_dict[cluster_id] = cluster_sentences

# %%
sentences_dict
# Out:
# {'retirement': ['the average emoluments have\nto be worked out keeping in view the emoluments drawn by him before E1 but in accordance\nwith the principles of the liberalised pension scheme. the two features which make the liberalised\npension scheme more attractive is the redefining of average emoluments in rule 34, and\nintroduction of slab system simultaneously A46 within these parameters, the pension\nwill have to be recomputed with effect from the date from which the liberalised pension scheme\ncame into force i.e.',
#   'nakara & others vs union of india on 17 december, 1982\nindian kanoon - http://indiankanoon.org/doc/1416283/ 15respondents, pensioners who retire from central government service and are governed by the\nrelevant pension rules all do not form a class but pensioners who retire prior to a certain date and\nthose who retire subsequent to a certain date form distinct and separate classes. it may be made\nclear that the date of E1 of each individual pensioner is not suggested as a criterion for\nclassification as that would lead to an absurd result, because in that event every pensioner relevant\nto his date of E1 will form a class unto himself. what is suggested is that when a pension\nscheme undergoes a revision and is enforced effective form a certain date, the date so specified\nbecomes a sort of a rubicon and those who retire prior to that date form one class and those who\nretire on a subsequent date form a distinct and separate class and no one can cross the rubicon.',
#   "government servants in service, in other words, those who have not retired, are entitled to\nsalary and other allowances. those who retire and are designated as 'pensioners' are entitled to\nreceive pension under the relevant rules. therefore, this would clearly indicate that those who\nA11 and A12 or any other mode of E1 and are in receipt of\npension are comprehended in the expression 'pensioners'.",
#   'in reply to this contention set out in para 19 of the petition, mr. s.n. mathur, director, ministry of finance in part 17 of his affidavit-in-opposition on\nbehalf of the respondents has averred as under:\n"the contentions in part 18 and 19 that all pensioners form one class is not correct\nand the petitioners have not shown how they form one class. classification of\npensioners on the basis of their date of E1 is a valid classification for the\npurpose of pensionary benefits."',
#   'the date of E1 of each employee remains as it is. the average emoluments have\nto be worked out keeping in view the emoluments drawn by him before E1 but in accordance\nwith the principles of the liberalised pension scheme. the two features which make the liberalised\npension scheme more attractive is the redefining of average emoluments in rule 34, and\nintroduction of slab system simultaneously A46',
#   'some landmark changes may be noticed. the first central pay commission (1946-47) recommended that the age of E1 in future\nshould be uniformly T17 for all services and the scale of pension should be 1/80 of the\nemoluments for each year of service, subject to a limit of 35/80 with a ceiling of rs. 8,000 per year\nfor 35 years of service, which the government of india while accepting the recommendation raised\nto rs.',
#   'thus according to thed.s. nakara & others vs union of india on 17 december, 1982\nindian kanoon - http://indiankanoon.org/doc/1416283/ 15respondents, pensioners who retire from central government service and are governed by the\nrelevant pension rules all do not form a class but pensioners who retire prior to a certain date and\nthose who retire subsequent to a certain date form distinct and separate classes. it may be made\nclear that the date of E1 of each individual pensioner is not suggested as a criterion for\nclassification as that would lead to an absurd result, because in that event every pensioner relevant\nto his date of E1 will form a class unto himself.',
#   "if that can't be done when they are in service, can that be done\nduring their E1 expanding this principle, one can confidently say that if pensioners form a\nclass, their computation cannot be by different formula affording unequal treatment solely on the\nground that some retired earlier and some retired later. art.",
#   'omitting the unconstitutional part\nit is  declared that  all pensioners  governed by  the  T7\nrules and  army pension  regulations shall  be  entitled  to\npension as  computed under  the liberalised  pension  scheme\nfrom  the  specified  date,  irrespective  of  the  date  of\nE1 arrears  of pension  prior to the specified date\nas per  fresh computation is not admissible. [190a-c, 198 g,\n198 e-f, 205 f-h, 209 f-h, 210 a-d]\n     d.r.',
#   'the\nreport of the commission is known as "northcote-trevelyan report". the report was pungent in its\ncriticism when it says that: "in civil services comparable to lightness of work and the certainty of\nprovision in case of E1 owing to bodily incapacity, furnish strong inducements to the\nparents and friends of sickly youths to endeavour to obtain for them employment in the service of\nthe government, and the extent to which the public are consequently burdened; first with the\nsalaries of officers who are obliged to absent themselves from their duties on account of ill health,\nand afterwards with their pensions when they retire on the same plea, would hardly be credited by\nthose who have not had opportunities of observing the operation of the system" (see gerald rhodes,\npublic sector pensions, pp. 18-19).',
#   "this is liberalisation. now, if the pensioners who retired prior to the\nspecified date and had to earn pension on the average emoluments of 36 months' salary just\npreceding the date of E1 naturally the average would be lower and they will be doubly hit\nbecause the slab system as now introduced was not available and the ceiling was at a lower level. thus they suffer triple jeopardy, viz., lower average emoluments, absence of slab system and lower\nceiling.d.s.",
#   'classification of\npensioners on the basis of their date of E1 is a valid classification for the\npurpose of pensionary benefits." these averments would show at a glance that the state action is sought to be sustained on the\ndoctrine of classification and the criterion on which the classification is sought to be sustained is the\ndate of E1 of the government servant which entitled him to pension. thus according to thed.s.',
#   "the\nadministrative reforms commission ('arc' for short) set up by the government of india in T19\ntook note of the fact that the cost of living has shot up and correspondingly the possibility of savings\nhas gone down and consequently the drop in wages on E1 is in reality much steeper than\nwhat the quantum of pension would indicate, and accordingly the arc recommended that thed.s. nakara & others vs union of india on 17 december, 1982\nindian kanoon - http://indiankanoon.org/doc/1416283/ 10quantum of pension admissible may be raised to 3/6 of the emoluments of the last T20 of\nservice as against the existing 3/8 and the ceiling should be raised from rs. 675 p.m. to rs.",
#   'are unconstitutional and are struck down with this specification that the date mentioned therein will\nbe relevant as being one from which the liberalised pension scheme becomes operative to all\npensioners governed by T7 rules irrespective of the date of E1 omitting the\nunconstitutional part it is declared that all pensioners governed by the T7 rules and army\npension regulations shall be entitled to pension as computed under the liberalised pension scheme\nfrom the specified date, irrespective of the date of E1 arrears of pension prior to the\nspecified date as per fresh computation is not admissible.',
#   "unquestionably pension is\nlinked to length of service and the last pay drawn but the last pay does not imply the pay on the last\nday of E1 but average emoluments as defined in the scheme. earlier average emoluments of\n36 months' service provided the measure of pension because the pension was related to the average\nemoluments during 36 months just preceding E1. by the liberalised scheme it is now\nreduced to average emoluments of 10 months preceding the date.",
#   'the present enquiry is limited to non-contributory superannuation or E1\npension paid by government to its erstwhile employee and the purpose and object underlying it. initially this class of pension appears to have been introduced as a reward for loyal service. probably\nthe alien rulers who recruited employees in lower echelons of service from the colony and exported\nhigher level employees from the seat of empire, wanted to ensure in the case of former continued\nloyalty till death to the alien rulers and in the case of latter, an assured decent living standard in old\nage ensuring economic security at the cost of the colony.d.s.',
#   'at  any given\npoint of  time there  is no  fixed or pre-determined pension\nfund which is divided amongst eligible pensioners. [195 c-g]\n     (ix) the  date of E1 of each employee remaining\nas it  is, there  is no  question of  fresh  commutation  of\npension of  the pensioners  who retired  prior to 31st march\nT40 and have already availed of the benefit of commutation. it is not open to them to get that benefit at this late date\nbecause  commutation   has  to  be  availed  of  within  the\nspecified time  limit from  the date  of actual  E1.',
#   'this is just and fair. now if pension as we view it, is some kind of\nE1 wages for past service, can it be denied to those who retired earlier, revised E1\nbenefits being available to future retirees only ? therefore, there is no substance in the contention\nthat the court by its approach would be making the scheme retroactive, because it is implicit in\ntheory of wages.',
#   'the state cannot be burdened with arrears\ncommencing from the date of E1 of each pensioner. but effective from the\nspecified date future pension of earlier retired government servants can be computed\nand paid on the analogy of fitments in revised pay-scales becoming prospectively\noperative. that removes the nefarious unconstitutional part and retains the beneficial\nportion.',
#   "old age, ebbing mental and physical prowess, atrophy of both muscle\nand brain powers permeating these petitions, the petitioners in the fall of life yearn for equality of\ntreatment which is being meted out to those who are soon going to join and swell their own ranks,\ndo pensioners entitled to receive superannuation or retiring pension under central civil services\n(pension) rules, T7 ('T7 rules' for short) form a class as a whole ? is the date of E1 a\nrelevant consideration for eligibility when a revised formula for computation of pension is ushered\nin and made effective from a specified date ? would differential treatment to pensioners related to\nthe date of E1 qua the revised formula for computation of pension attract article 14 of the\nconstitution and the element of discrimination liable to be declared unconstitutional as being\nviolative of art.",
#   'the date of E1 is irrelevant. but the revised scheme would be operative from the\ndate mentioned in the scheme and would bring under its umbrella all existing pensioners and those\nwho retired subsequent to that date. in case of pensioners who retired prior to the specified date,\ntheir pension would be computed afresh and would be payable in future commencing from the\nspecified date.',
#   '[185 d-\ne, 186 b-c]\n     (iv) pension  as a  E1 benefit is in consonance\nwith and  in furtherance  of the  goals of the constitution. the goals for which pension is\n171\npaid themselves  give a  fillip and  push to  the policy  of\nsetting up a welfare state. the preamble to the constitution\nenvisages the  establishment of  a socialist  republic.',
#   "those who retire and are designated as 'pensioners' are entitled to\nreceive pension under the relevant rules. therefore, this would clearly indicate that those who\nA11 and A12 or any other mode of E1 and are in receipt of\npension are comprehended in the expression 'pensioners'. is this class of pensioners further divisible for the purpose of 'entitlement' and 'payment' of pension\ninto those who retired by certain date and those who retired after that date ?",
#   'v. iqbal singh (1). there are various kinds of pensions and there are equally various methods of funding pension\nprogrammes. the present enquiry is limited to non-contributory superannuation or E1\npension paid by government to its erstwhile employee and the purpose and object underlying it.',
#   'and in exhibit p-2, the words:\n          "the new  rates of  pension are effective from ist\n     april T40  and  will  be  applicable  to  all  service\n     officers who  became/become noneffective  on  or  after\n     that date"\nare  unconstitutional   and  are   struck  down   with   the\nspecification  that  the  date  mentioned  therein  will  be\nrelevant as  being one  from which  the liberalised  pension\nscheme becomes operative. omitting the unconstitutional part\nit is  declared that  all pensioners  governed by  the  T7\nrules and  army pension  regulations shall  be  entitled  to\npension as  computed under  the liberalised  pension  scheme\nfrom  the  specified  date,  irrespective  of  the  date  of\nE1 arrears  of pension  prior to the specified date\nas per  fresh computation is not admissible.',
#   'counsel for  petitioners contended  that all pensioners\nentitled to  receive pension under the relevant rules form a\nclass irrespective  of the  dates of  their  E1  and\nthere cannot  be a  mini-classification within  this  class;\nthat the  differential treatment  accorded to  those who had\nretired prior  to the specified date is violative of art. 14\nas the  choice of specified date is wholly arbitrary and the\nclassification  based  on  the  fortuitous  circumstance  of\nE1 before  or subsequent  to the  specified date  is\ninvalid;  and   that  the   scheme  of   liberalisation   in\ncomputation of  pension  must  be  uniformly  enforced  with\nregard to all pensioners. 166\n     counsel for respondents contended that a classification\nbased on  the date of E1 is valid for the purpose of\ngranting pensionary  benefits; that the specified date is an\nintegral part  of  the  scheme  of  liberalisation  and  the\ngovernment would  never have  enforced the  scheme devoid of\nthe date;  that  the  doctrine  of  severability  cannot  be\ninvoked to  sever the  specified date  from the scheme as it\nwould have  the effect  of enlarging the class of pensioners\ncovered by the scheme and when the legislature has expressly\ndefined the  class to which the legislation applies it would\nbe outside  the judicial function to enlarge the class; that\nthere is not a single case where the court has included some\ncategory within the scope of provisions of a law to maintain\nits   constitutionality;    that   since   the   scheme   of\nliberalisation has  financial implications, the court cannot\nmake it  retroactive;  that  if  more  persons  divided  the\navailable cake  the residue  falling to  the share  of each,\nespecially to  the share  of those  who are  not before  the\ncourt would become far less and therefore no relief could be\ngiven to  the petitioners  that pension is always correlated\nto the  date of  E1 and  the court cannot change the\ndate of  E1 and  impose  fresh  commutation  benefit\nwhich may  burden the  exchequer to  the  tune  of  rs.',
#   'the judgment of the court was delivered by desai,j.with a slight variation to suit the context\nwoolesey\'s prayer : "had i served my god as reverently as i did my king, i would not have fallen on\nthese days of penury" is chanted by petitioners in this group of petitions in the shellian tune : \'i fall\non the thorns of life i bleed.\' old age, ebbing mental and physical prowess, atrophy of both muscle\nand brain powers permeating these petitions, the petitioners in the fall of life yearn for equality of\ntreatment which is being meted out to those who are soon going to join and swell their own ranks,\ndo pensioners entitled to receive superannuation or retiring pension under central civil services\n(pension) rules, T7 (\'T7 rules\' for short) form a class as a whole ? is the date of E1 a\nrelevant consideration for eligibility when a revised formula for computation of pension is ushered\nin and made effective from a specified date ?',
#   'mathur, director, ministry of finance in part 17 of his affidavit-in-opposition on\nbehalf of the respondents has averred as under:\n"the contentions in part 18 and 19 that all pensioners form one class is not correct\nand the petitioners have not shown how they form one class. classification of\npensioners on the basis of their date of E1 is a valid classification for the\npurpose of pensionary benefits." these averments would show at a glance that the state action is sought to be sustained on the\ndoctrine of classification and the criterion on which the classification is sought to be sustained is the\ndate of E1 of the government servant which entitled him to pension.',
#   '14 and is\nunconstitutional and is struck down. both the memoranda shall be enforced and implemented as\nread down as under: in other words, in exhibit p-1, the words:\n"that in respect of the government servants who were in service on the 31st march,\nT40 and A13 on or after that date"\nand in exhibit p-2, the words:\n"the new rates of pension are effective from 1st april T40 and will be applicable to all\nservice officers who became/become non-effective on or after that date." are unconstitutional and are struck down with this specification that the date mentioned therein will\nbe relevant as being one from which the liberalised pension scheme becomes operative to all\npensioners governed by T7 rules irrespective of the date of E1',
#   'if such be the goals of pension, if such be the welfare state which we propose to set up, if such be the\ngoals of socialism and conceding that any welfare measure may consistent with economic capacity of\nthe state be progressively augmented with wider width and a longer canvass yet when the economic\nmeans permit the augmentation, should some be left out for the sole reason that while in the\nformative years of the nascent state they contributed their mite but when the fruits of their labour\nled to the flowering of economic development and higher gross national produce bringing in larger\nrevenue and therefore larger cake is available, they would be denied any share of it ? indisputably,\nviewed from any angle pensioners for E4 form a class. unquestionably pension is\nlinked to length of service and the last pay drawn but the last pay does not imply the pay on the last\nday of E1 but average emoluments as defined in the scheme.',
#   'nakara & others vs union of india on 17 december, 1982\nindian kanoon - http://indiankanoon.org/doc/1416283/ 27payment of arrears which may impose a heavy burden. if the date is wholly removed,\nrevised pensions will have to be paid from the actual date of E1 of each\npensioner. that is impermissible.',
#   "consequently\nthose who retired prior to the specified date would not be entitled to the benefits of the liberalised\npension formula. petitioners accordingly contend that this court may consider the raison d'etre for payment of\npension. if the pension is paid for past satisfactory service rendered, and to avoid destitution in old\nage as well as a social welfare or socio-economic justice measure, the differential treatment for those\nretiring prior to a certain date and those retiring subsequently, the choice of the date being wholly\narbitrary, would be according differential treatment to pensioners who form a class irrespective of\nthe date of E1 and, therefore, would be violative of art.",
#   'it may be made\nclear that the date of E1 of each individual pensioner is not suggested as a criterion for\nclassification as that would lead to an absurd result, because in that event every pensioner relevant\nto his date of E1 will form a class unto himself. what is suggested is that when a pension\nscheme undergoes a revision and is enforced effective form a certain date, the date so specified\nbecomes a sort of a rubicon and those who retire prior to that date form one class and those who\nretire on a subsequent date form a distinct and separate class and no one can cross the rubicon. and the learned attorney general contended that this differentiation is grounded on a rational\nprinciple and it has a direct correlation to the object sought to be achieved by liberalised pension\nformula.',
#   'there are various kinds of pensions and there are equally various methods of funding pension\nprogrammes. the present enquiry is limited to non-contributory superannuation or E1\npension paid by government to its erstwhile employee and the purpose and object underlying it. initially this class of pension appears to have been introduced as a reward for loyal service.',
#   'but we make it abundantly clear that arrears are not required to be made because to that extent the\nscheme is prospective. all pensioners whenever they retired would be covered by the liberalised\npension scheme, because the scheme is a scheme for E4 to a pensioner governed by\nT7 rules. the date of E1 is irrelevant.',
#   'viewed in the light of the present day notions pension is a term applied to periodic money payments\nto a person who retires at a certain age considered age of disability; payments usually continue for\nthe rest of the natural life of the recipient. the reasons underlying the grant of pension vary from\ncountry to country and from scheme to scheme. but broadly stated they are (i) as compensation to\nformer members of the armed forces or their dependents for old age, disability, or death (usually\nfrom service causes),\n(ii) as old age E1 or disability benefits for civilian employees, and (iii) as social security\npayments for the aged, disabled, or deceased citizens made in accordance with the rules governing\nsocial service programmes of the country.',
#   "one of the terms of reference of the third pay commission was\n'death-cum- E1 benefits of central government employees'. the third pay commission did\nnot examine the question of relief to pensioners because in its view unless the terms of reference\nwere suitably amended it would not be within their jurisdiction to examine this question and on a\nreference by them, the government of india decided not to amend the terms of reference. with\nregard to the future pensioners the third pay commission while reiterating that the age of\nsuperannuation should continue to be T17 further recommended that no change in the existing\nformula for computing pension is considered necessary.",
#   "petitioners accordingly contend that this court may consider the raison d'etre for payment of\npension. if the pension is paid for past satisfactory service rendered, and to avoid destitution in old\nage as well as a social welfare or socio-economic justice measure, the differential treatment for those\nretiring prior to a certain date and those retiring subsequently, the choice of the date being wholly\narbitrary, would be according differential treatment to pensioners who form a class irrespective of\nthe date of E1 and, therefore, would be violative of art. 14.",
#   '(see E1 systems for public employees by bleakney, page 33.) as\nthe present case is concerned with superannuation pension, a brief history of its initial introduction\nin early stages and continued existence till today may be illuminating. superannuation is the most\ndescriptive word of all but has become obsolescent because it seems ponderous.',
#   'undoubtedly when an upward revision is introduced, a date from\nwhich it becomes effective has to be provided. it is the event of E1 subsequent to the\nspecified date which introduces discrimination in one otherwise homogeneous class of pensioners. this arbitrary selection of the happening of event subsequent to specified date denies equality of\ntreatment to persons belonging to the same class, some preferred and some omitted.',
#   'nakara & others vs union of india on 17 december, 1982\nindian kanoon - http://indiankanoon.org/doc/1416283/ 5          "that in  respect of  the government  servants who\n     were in  service on  the 31st  march, T40 and retiring\n     from service on or after that date. and in exhibit p-2, the words:\n          "the new  rates of  pension are effective from ist\n     april T40  and  will  be  applicable  to  all  service\n     officers who  became/become noneffective  on  or  after\n     that date"\nare  unconstitutional   and  are   struck  down   with   the\nspecification  that  the  date  mentioned  therein  will  be\nrelevant as  being one  from which  the liberalised  pension\nscheme becomes operative. omitting the unconstitutional part\nit is  declared that  all pensioners  governed by  the  T7\nrules and  army pension  regulations shall  be  entitled  to\npension as  computed under  the liberalised  pension  scheme\nfrom  the  specified  date,  irrespective  of  the  date  of\nE1',
#   'both the memoranda shall be enforced and implemented as\nread down as under: in other words, in exhibit p-1, the words:\n"that in respect of the government servants who were in service on the 31st march,\nT40 and A13 on or after that date"\nand in exhibit p-2, the words:\n"the new rates of pension are effective from 1st april T40 and will be applicable to all\nservice officers who became/become non-effective on or after that date." are unconstitutional and are struck down with this specification that the date mentioned therein will\nbe relevant as being one from which the liberalised pension scheme becomes operative to all\npensioners governed by T7 rules irrespective of the date of E1 omitting the\nunconstitutional part it is declared that all pensioners governed by the T7 rules and army\npension regulations shall be entitled to pension as computed under the liberalised pension scheme\nfrom the specified date, irrespective of the date of E1',
#   'that is impermissible. the state cannot be burdened with arrears\ncommencing from the date of E1 of each pensioner. but effective from the\nspecified date future pension of earlier retired government servants can be computed\nand paid on the analogy of fitments in revised pay-scales becoming prospectively\noperative.',
#   'nakara & others vs union of india on 17 december, 1982\nindian kanoon - http://indiankanoon.org/doc/1416283/ 2to all those who had retired earlier. counsel for  petitioners contended  that all pensioners\nentitled to  receive pension under the relevant rules form a\nclass irrespective  of the  dates of  their  E1  and\nthere cannot  be a  mini-classification within  this  class;\nthat the  differential treatment  accorded to  those who had\nretired prior  to the specified date is violative of art. 14\nas the  choice of specified date is wholly arbitrary and the\nclassification  based  on  the  fortuitous  circumstance  of\nE1 before  or subsequent  to the  specified date  is\ninvalid;  and   that  the   scheme  of   liberalisation   in\ncomputation of  pension  must  be  uniformly  enforced  with\nregard to all pensioners.',
#   "the second\ncentral pay commission (1957-58) re-affirmed that the age of superannuation should be T17\nfor all classes of public servants but did not recommend any increase in the non- contributory\nE1 benefits and recommended that if in future any improvement is to be made, it was the\nconsidered view of the commission that these benefits should be on a contributory basis. the\nadministrative reforms commission ('arc' for short) set up by the government of india in T19\ntook note of the fact that the cost of living has shot up and correspondingly the possibility of savings\nhas gone down and consequently the drop in wages on E1 is in reality much steeper than\nwhat the quantum of pension would indicate, and accordingly the arc recommended that thed.s. nakara & others vs union of india on 17 december, 1982\nindian kanoon - http://indiankanoon.org/doc/1416283/ 10quantum of pension admissible may be raised to 3/6 of the emoluments of the last T20 of\nservice as against the existing 3/8 and the ceiling should be raised from rs.",
#   'is the date of E1 a\nrelevant consideration for eligibility when a revised formula for computation of pension is ushered\nin and made effective from a specified date ? would differential treatment to pensioners related to\nthe date of E1 qua the revised formula for computation of pension attract article 14 of the\nconstitution and the element of discrimination liable to be declared unconstitutional as being\nviolative of art. 14 ?',
#   '14\nas the  choice of specified date is wholly arbitrary and the\nclassification  based  on  the  fortuitous  circumstance  of\nE1 before  or subsequent  to the  specified date  is\ninvalid;  and   that  the   scheme  of   liberalisation   in\ncomputation of  pension  must  be  uniformly  enforced  with\nregard to all pensioners. 166\n     counsel for respondents contended that a classification\nbased on  the date of E1 is valid for the purpose of\ngranting pensionary  benefits; that the specified date is an\nintegral part  of  the  scheme  of  liberalisation  and  the\ngovernment would  never have  enforced the  scheme devoid of\nthe date;  that  the  doctrine  of  severability  cannot  be\ninvoked to  sever the  specified date  from the scheme as it\nwould have  the effect  of enlarging the class of pensioners\ncovered by the scheme and when the legislature has expressly\ndefined the  class to which the legislation applies it would\nbe outside  the judicial function to enlarge the class; that\nthere is not a single case where the court has included some\ncategory within the scope of provisions of a law to maintain\nits   constitutionality;    that   since   the   scheme   of\nliberalisation has  financial implications, the court cannot\nmake it  retroactive;  that  if  more  persons  divided  the\navailable cake  the residue  falling to  the share  of each,\nespecially to  the share  of those  who are  not before  the\ncourt would become far less and therefore no relief could be\ngiven to  the petitioners  that pension is always correlated\nto the  date of  E1 and  the court cannot change the\ndate of  E1 and  impose  fresh  commutation  benefit\nwhich may  burden the  exchequer to  the  tune  of  rs. 233\ncrores; and that the third petitioner has no locus standi in\nthe case.',
#   "indisputably,\nviewed from any angle pensioners for E4 form a class. unquestionably pension is\nlinked to length of service and the last pay drawn but the last pay does not imply the pay on the last\nday of E1 but average emoluments as defined in the scheme. earlier average emoluments of\n36 months' service provided the measure of pension because the pension was related to the average\nemoluments during 36 months just preceding E1.",
#   'the equal treatment guaranteed in art. 14 is\nwholly violated inasmuch as the pension rules being statutory in character, since the specified date,\nthe rules accord differential and discriminatory treatment to equals in the matter of commutation of\npension. a 48 hours difference in matter of E1 would have a traumatic effect.',
#   'omitting the\nunconstitutional part it is declared that all pensioners governed by the T7 rules and army\npension regulations shall be entitled to pension as computed under the liberalised pension scheme\nfrom the specified date, irrespective of the date of E1 arrears of pension prior to the\nspecified date as per fresh computation is not admissible. let a writ to that effect be issued.',
#   'march 31, T40 there is no question of fresh E21 of the\npensioners who retired prior to 31st march, T40 and have already availed of the benefit of\ncommutation. it is not open to them to get that benefit at this late date because commutation has to\nbe availed of within specified time limit from the date of actual E1',
#   "therefore, this would clearly indicate that those who\nA11 and A12 or any other mode of E1 and are in receipt of\npension are comprehended in the expression 'pensioners'. is this class of pensioners further divisible for the purpose of 'entitlement' and 'payment' of pension\ninto those who retired by certain date and those who retired after that date ? if date of E1\ncan be accepted as a valid criterion for classification, on E1 each individual government\nservant would form a class by himself because the date of E1 of each is correlated to his\nbirth date and on attaining a certain age he had to retire.",
#   'no doubt, the benefit of the scheme will be available from the\nspecified date, irrespective of the fact when the concerned government servant actually retired from\nservice. having set out clearly the society which we propose to set up, the direction in which the state action\nmust move, the welfare state which we propose to build up, the constitutional goal of setting up a\nsocialist state and the assurance in the directive principles of state policy especially of security in\nold age at least to those who have A14 during their active years, it is indisputable,\nnor was it questioned, that pension as a E1 benefit is in consonance with and furtherance of\nthe goals of the constitution. the goals for which pension is paid themselves give a fillip and push to\nthe policy of setting up a welfare state because by pension the socialist goal of security of cradle to\ngrave is assured at least when it is mostly needed and least available, namely, in the fall of life.',
#   'whatever  becomes  due  and\npayable on  account of  pension is  recognised as an item of\nexpenditure and  is budgeted  for every  year. at  any given\npoint of  time there  is no  fixed or pre-determined pension\nfund which is divided amongst eligible pensioners. [195 c-g]\n     (ix) the  date of E1 of each employee remaining\nas it  is, there  is no  question of  fresh  commutation  of\npension of  the pensioners  who retired  prior to 31st march\nT40 and have already availed of the benefit of commutation.',
#   'having set out clearly the society which we propose to set up, the direction in which the state action\nmust move, the welfare state which we propose to build up, the constitutional goal of setting up a\nsocialist state and the assurance in the directive principles of state policy especially of security in\nold age at least to those who have A14 during their active years, it is indisputable,\nnor was it questioned, that pension as a E1 benefit is in consonance with and furtherance of\nthe goals of the constitution. the goals for which pension is paid themselves give a fillip and push to\nthe policy of setting up a welfare state because by pension the socialist goal of security of cradle to\ngrave is assured at least when it is mostly needed and least available, namely, in the fall of life. if such be the goals of pension, if such be the welfare state which we propose to set up, if such be the\ngoals of socialism and conceding that any welfare measure may consistent with economic capacity of\nthe state be progressively augmented with wider width and a longer canvass yet when the economic\nmeans permit the augmentation, should some be left out for the sole reason that while in the\nformative years of the nascent state they contributed their mite but when the fruits of their labour\nled to the flowering of economic development and higher gross national produce bringing in larger\nrevenue and therefore larger cake is available, they would be denied any share of it ?',
#   'no arrears for the period prior to 31st march, T40 in\naccordance with revised computation need be paid. in this context the last submission of the learned attorney general was that as the pension is always\ncorrelated to the date of E1 the court cannot change the date of E1 and impose\nfresh commutation benefit. we are doing nothing of this kind.'],
#  '1972, NULL': ["old age, ebbing mental and physical prowess, atrophy of both muscle\nand brain powers permeating these petitions, the petitioners in the fall of life yearn for equality of\ntreatment which is being meted out to those who are soon going to join and swell their own ranks,\ndo pensioners entitled to receive superannuation or retiring pension under central civil services\n(pension) rules, T7 ('T7 rules' for short) form a class as a whole ? is the date of E1 a\nrelevant consideration for eligibility when a revised formula for computation of pension is ushered\nin and made effective from a specified date ? would differential treatment to pensioners related to\nthe date of E1 qua the revised formula for computation of pension attract article 14 of the\nconstitution and the element of discrimination liable to be declared unconstitutional as being\nviolative of art.",
#   'omitting the\nunconstitutional part it is declared that all pensioners governed by the T7 rules and army\npension regulations shall be entitled to pension as computed under the liberalised pension scheme\nfrom the specified date, irrespective of the date of E1 arrears of pension prior to the\nspecified date as per fresh computation is not admissible. let a writ to that effect be issued.',
#   'but we make it abundantly clear that arrears are not required to be made because to that extent the\nscheme is prospective. all pensioners whenever they retired would be covered by the liberalised\npension scheme, because the scheme is a scheme for E4 to a pensioner governed by\nT7 rules. the date of E1 is irrelevant.',
#   'and in exhibit p-2, the words:\n          "the new  rates of  pension are effective from ist\n     april T40  and  will  be  applicable  to  all  service\n     officers who  became/become noneffective  on  or  after\n     that date"\nare  unconstitutional   and  are   struck  down   with   the\nspecification  that  the  date  mentioned  therein  will  be\nrelevant as  being one  from which  the liberalised  pension\nscheme becomes operative. omitting the unconstitutional part\nit is  declared that  all pensioners  governed by  the  T7\nrules and  army pension  regulations shall  be  entitled  to\npension as  computed under  the liberalised  pension  scheme\nfrom  the  specified  date,  irrespective  of  the  date  of\nE1 arrears  of pension  prior to the specified date\nas per  fresh computation is not admissible.',
#   'nakara & others vs union of india on 17 december, 1982\nindian kanoon - http://indiankanoon.org/doc/1416283/ 5          "that in  respect of  the government  servants who\n     were in  service on  the 31st  march, T40 and retiring\n     from service on or after that date. and in exhibit p-2, the words:\n          "the new  rates of  pension are effective from ist\n     april T40  and  will  be  applicable  to  all  service\n     officers who  became/become noneffective  on  or  after\n     that date"\nare  unconstitutional   and  are   struck  down   with   the\nspecification  that  the  date  mentioned  therein  will  be\nrelevant as  being one  from which  the liberalised  pension\nscheme becomes operative. omitting the unconstitutional part\nit is  declared that  all pensioners  governed by  the  T7\nrules and  army pension  regulations shall  be  entitled  to\npension as  computed under  the liberalised  pension  scheme\nfrom  the  specified  date,  irrespective  of  the  date  of\nE1',
#   'both the memoranda shall be enforced and implemented as\nread down as under: in other words, in exhibit p-1, the words:\n"that in respect of the government servants who were in service on the 31st march,\nT40 and A13 on or after that date"\nand in exhibit p-2, the words:\n"the new rates of pension are effective from 1st april T40 and will be applicable to all\nservice officers who became/become non-effective on or after that date." are unconstitutional and are struck down with this specification that the date mentioned therein will\nbe relevant as being one from which the liberalised pension scheme becomes operative to all\npensioners governed by T7 rules irrespective of the date of E1 omitting the\nunconstitutional part it is declared that all pensioners governed by the T7 rules and army\npension regulations shall be entitled to pension as computed under the liberalised pension scheme\nfrom the specified date, irrespective of the date of E1',
#   'omitting the unconstitutional part\nit is  declared that  all pensioners  governed by  the  T7\nrules and  army pension  regulations shall  be  entitled  to\npension as  computed under  the liberalised  pension  scheme\nfrom  the  specified  date,  irrespective  of  the  date  of\nE1 arrears  of pension  prior to the specified date\nas per  fresh computation is not admissible. [190a-c, 198 g,\n198 e-f, 205 f-h, 209 f-h, 210 a-d]\n     d.r.',
#   'are unconstitutional and are struck down with this specification that the date mentioned therein will\nbe relevant as being one from which the liberalised pension scheme becomes operative to all\npensioners governed by T7 rules irrespective of the date of E1 omitting the\nunconstitutional part it is declared that all pensioners governed by the T7 rules and army\npension regulations shall be entitled to pension as computed under the liberalised pension scheme\nfrom the specified date, irrespective of the date of E1 arrears of pension prior to the\nspecified date as per fresh computation is not admissible.',
#   'the judgment of the court was delivered by desai,j.with a slight variation to suit the context\nwoolesey\'s prayer : "had i served my god as reverently as i did my king, i would not have fallen on\nthese days of penury" is chanted by petitioners in this group of petitions in the shellian tune : \'i fall\non the thorns of life i bleed.\' old age, ebbing mental and physical prowess, atrophy of both muscle\nand brain powers permeating these petitions, the petitioners in the fall of life yearn for equality of\ntreatment which is being meted out to those who are soon going to join and swell their own ranks,\ndo pensioners entitled to receive superannuation or retiring pension under central civil services\n(pension) rules, T7 (\'T7 rules\' for short) form a class as a whole ? is the date of E1 a\nrelevant consideration for eligibility when a revised formula for computation of pension is ushered\nin and made effective from a specified date ?',
#   '14 and is\nunconstitutional and is struck down. both the memoranda shall be enforced and implemented as\nread down as under: in other words, in exhibit p-1, the words:\n"that in respect of the government servants who were in service on the 31st march,\nT40 and A13 on or after that date"\nand in exhibit p-2, the words:\n"the new rates of pension are effective from 1st april T40 and will be applicable to all\nservice officers who became/become non-effective on or after that date." are unconstitutional and are struck down with this specification that the date mentioned therein will\nbe relevant as being one from which the liberalised pension scheme becomes operative to all\npensioners governed by T7 rules irrespective of the date of E1',
#   "it\nwould be just and proper that the provision in the memoranda while retaining the date for its\nimplementation, but providing 'that in respect of government servants who were in service on the\n31st march, T40 but A13 in or after that date' can be legally and validly severed and\nmust be struck down. the date is retained without qualification as the effective date for\nimplementation of scheme, it being made abundantly clear that in respect of all pensioners\ngoverned by T7 rules, the pension of each may be recomputed as on april 1, T40 and future\npayments be made in accordance with fresh computation under the liberalised pension scheme as\nenacted in the impugned memoranda. no arrears for the period prior to 31st march, T40 in\naccordance with revised computation need be paid."],
#  'payment of pension': ['but we make it abundantly clear that arrears are not required to be made because to that extent the\nscheme is prospective. all pensioners whenever they retired would be covered by the liberalised\npension scheme, because the scheme is a scheme for E4 to a pensioner governed by\nT7 rules. the date of E1 is irrelevant.',
#   'we have set out the objects underlying the E4 if the state considered it necessary\nto liberalise the pension scheme, we find no rational principle behind it for granting these benefits\nonly to those who retired subsequent to that date simultaneously denying the same to those who\nretired prior to that date. if the liberalisation was considered necessary for augmenting social\nsecurity in old age to government servants then those who retired earlier cannot be worst off than\nthose who retire later.',
#   '167\n     in the  instant case,  looking to  the  goals  for  the\nattainment of  which pension  is paid  and the welfare state\nproposed to  be  set  up  in  the  light  of  the  directive\nprinciples of  state policy and preamble to the constitution\nit indisputable  that pensioners for E4 from\na  class. when  the   state  considered  it  necessary  to\nliberalise the  pension scheme  in order  to augment  social\nsecurity in  old age  to government  servants it  could  not\ngrant the  benefits of  liberalisation  only  to  those  who\nretired subsequent  to the  specified date and deny the same\nto those  who had  retired prior  to that date. the division\nwhich classified  the pensioners  into two  classes  on  the\nbasis of  the specified  date was  devoid  of  any  rational\nprinciple and  was both  arbitrary  and  unprincipled  being\nunrelated to  the object  sought to  be achieved by grant of\nliberalised pension  and the  guarantee of  equal  treatment\ncontained in  art.',
#   '1014, referred to. 167\n     in the  instant case,  looking to  the  goals  for  the\nattainment of  which pension  is paid  and the welfare state\nproposed to  be  set  up  in  the  light  of  the  directive\nprinciples of  state policy and preamble to the constitution\nit indisputable  that pensioners for E4 from\na  class. when  the   state  considered  it  necessary  to\nliberalise the  pension scheme  in order  to augment  social\nsecurity in  old age  to government  servants it  could  not\ngrant the  benefits of  liberalisation  only  to  those  who\nretired subsequent  to the  specified date and deny the same\nto those  who had  retired prior  to that date.',
#   'the classification has to be based, as is well settled, on some\nrational principle and the rational principle must have nexus to the objects sought to be achieved. we have set out the objects underlying the E4 if the state considered it necessary\nto liberalise the pension scheme, we find no rational principle behind it for granting these benefits\nonly to those who retired subsequent to that date simultaneously denying the same to those who\nretired prior to that date.',
#   'the E4 is a statutory liability undertaken by the government and\nwhatever becomes due and payable is budgeted for. one could have appreciated this line of\nreasoning where there is a contributory scheme and a pension fund from which alone pension is\ndisbursed. that being not the case, there is no question of pensioners dividing the pension fund\nwhich, if more persons are admitted to the scheme, would pro rata affect the share.',
#   "indisputably,\nviewed from any angle pensioners for E4 form a class. unquestionably pension is\nlinked to length of service and the last pay drawn but the last pay does not imply the pay on the last\nday of E1 but average emoluments as defined in the scheme. earlier average emoluments of\n36 months' service provided the measure of pension because the pension was related to the average\nemoluments during 36 months just preceding E1.",
# ...
#  'interpretative process': ['[206 c-d]\n     3. the  discernible  purpose  underlying  the  pension\nscheme must  inform the A31 and it should\nreceive a liberal construction. [185 g-h]\n     (i) pension  is a  right; not  a bounty  or  gratuitous\npayment.',
#   'one\nmay live and avoid unemployment but not senility and penury if there is nothing to fall back upon. the discernible purpose thus underlying pension scheme or a statute introducing the pension\nscheme must inform A31 and accordingly it should receive a liberal construction\nand the courts may not so interpret such statute as to render them inane (see american\njurisprudence 2d. 881).'],
#  'espousing the cause of the pensioners': ['factual matrix has little relevance to the issues raised and canvassed at the hearing. petitioners 1\nand 2 are retired pensioners of the central government, the first being a civil servant and the\nsecond being a member of the service personnel of the armed forces. the third petitioner is a\nsociety registered under the societies registration act, 1860, formed to ventilate the legitimate\npublic problems and consistent with its objective it is A38 all over\nthe country.',
#   'petitioners 1\nand 2 are retired pensioners of the central government, the first being a civil servant and the\nsecond being a member of the service personnel of the armed forces. the third petitioner is a\nsociety registered under the societies registration act, 1860, formed to ventilate the legitimate\npublic problems and consistent with its objective it is A38 all over\nthe country. its locus standi is in question but that is a different matter.'],
#  'render service': ["therefore, this would clearly indicate that those who\nA11 and A12 or any other mode of E1 and are in receipt of\npension are comprehended in the expression 'pensioners'. is this class of pensioners further divisible for the purpose of 'entitlement' and 'payment' of pension\ninto those who retired by certain date and those who retired after that date ? if date of E1\ncan be accepted as a valid criterion for classification, on E1 each individual government\nservant would form a class by himself because the date of E1 of each is correlated to his\nbirth date and on attaining a certain age he had to retire.",
#   "those who retire and are designated as 'pensioners' are entitled to\nreceive pension under the relevant rules. therefore, this would clearly indicate that those who\nA11 and A12 or any other mode of E1 and are in receipt of\npension are comprehended in the expression 'pensioners'. is this class of pensioners further divisible for the purpose of 'entitlement' and 'payment' of pension\ninto those who retired by certain date and those who retired after that date ?",
#   "government servants in service, in other words, those who have not retired, are entitled to\nsalary and other allowances. those who retire and are designated as 'pensioners' are entitled to\nreceive pension under the relevant rules. therefore, this would clearly indicate that those who\nA11 and A12 or any other mode of E1 and are in receipt of\npension are comprehended in the expression 'pensioners'.",
#   'and why was it required to be liberalised ? is the employer, which expression will\ninclude even the state, bound to pay pension ? is there any obligation on the employer to provide for\nthe erstwhile employee even after the contract of employment has come to an end and the employee\nhas ceased to A11 ?',
#   'is there any obligation on the employer to provide for\nthe erstwhile employee even after the contract of employment has come to an end and the employee\nhas ceased to A11 ? what is a pension ? what are the goals of pension ?'],
#  'retire on superannuation': ["government servants in service, in other words, those who have not retired, are entitled to\nsalary and other allowances. those who retire and are designated as 'pensioners' are entitled to\nreceive pension under the relevant rules. therefore, this would clearly indicate that those who\nA11 and A12 or any other mode of E1 and are in receipt of\npension are comprehended in the expression 'pensioners'.",
#   "therefore, this would clearly indicate that those who\nA11 and A12 or any other mode of E1 and are in receipt of\npension are comprehended in the expression 'pensioners'. is this class of pensioners further divisible for the purpose of 'entitlement' and 'payment' of pension\ninto those who retired by certain date and those who retired after that date ? if date of E1\ncan be accepted as a valid criterion for classification, on E1 each individual government\nservant would form a class by himself because the date of E1 of each is correlated to his\nbirth date and on attaining a certain age he had to retire.",
#   "those who retire and are designated as 'pensioners' are entitled to\nreceive pension under the relevant rules. therefore, this would clearly indicate that those who\nA11 and A12 or any other mode of E1 and are in receipt of\npension are comprehended in the expression 'pensioners'. is this class of pensioners further divisible for the purpose of 'entitlement' and 'payment' of pension\ninto those who retired by certain date and those who retired after that date ?"],
#  'rendered useful service': ['having set out clearly the society which we propose to set up, the direction in which the state action\nmust move, the welfare state which we propose to build up, the constitutional goal of setting up a\nsocialist state and the assurance in the directive principles of state policy especially of security in\nold age at least to those who have A14 during their active years, it is indisputable,\nnor was it questioned, that pension as a E1 benefit is in consonance with and furtherance of\nthe goals of the constitution. the goals for which pension is paid themselves give a fillip and push to\nthe policy of setting up a welfare state because by pension the socialist goal of security of cradle to\ngrave is assured at least when it is mostly needed and least available, namely, in the fall of life. if such be the goals of pension, if such be the welfare state which we propose to set up, if such be the\ngoals of socialism and conceding that any welfare measure may consistent with economic capacity of\nthe state be progressively augmented with wider width and a longer canvass yet when the economic\nmeans permit the augmentation, should some be left out for the sole reason that while in the\nformative years of the nascent state they contributed their mite but when the fruits of their labour\nled to the flowering of economic development and higher gross national produce bringing in larger\nrevenue and therefore larger cake is available, they would be denied any share of it ?',
#   'no doubt, the benefit of the scheme will be available from the\nspecified date, irrespective of the fact when the concerned government servant actually retired from\nservice. having set out clearly the society which we propose to set up, the direction in which the state action\nmust move, the welfare state which we propose to build up, the constitutional goal of setting up a\nsocialist state and the assurance in the directive principles of state policy especially of security in\nold age at least to those who have A14 during their active years, it is indisputable,\nnor was it questioned, that pension as a E1 benefit is in consonance with and furtherance of\nthe goals of the constitution. the goals for which pension is paid themselves give a fillip and push to\nthe policy of setting up a welfare state because by pension the socialist goal of security of cradle to\ngrave is assured at least when it is mostly needed and least available, namely, in the fall of life.'],
#  'implementing the scheme': ['we find no difficulty in A50 omitting the event happening\nafter the specified date retaining the more humane formula for computation of pension. it would\napply to all existing pensioners and future pensioners. in the case of existing pensioners, the\npension will have to be recomputed by applying the rule of average emoluments as set out in rule 34\nand introducing the slab system and the amount worked out within the floor and the ceiling.',
#   'nakara & others vs union of india on 17 december, 1982\nindian kanoon - http://indiankanoon.org/doc/1416283/ 26it was very seriously contended, remove the event correlated to date and examine whether the\nscheme is workable. we find no difficulty in A50 omitting the event happening\nafter the specified date retaining the more humane formula for computation of pension. it would\napply to all existing pensioners and future pensioners.'],
#  'severing the objectionable portion': ['the pension\nwill have to be recomputed in accordance with the provisions of the liberalised pension scheme as\nsalaries were required to be recomputed in accordance with the recommendation of the third pay\ncommission but becoming operative from the specified date. it does therefore appear that the\nreading down of impugned memoranda by E8 would not render the\nliberalised pension scheme vague, unenforceable or unworkable. in reading down the memoranda, is this court legislating ?',
#   'if from the impugned memoranda the event of being in service and retiring subsequent to specified\ndate is severed, all pensioners would be governed by the liberalised pension scheme. the pension\nwill have to be recomputed in accordance with the provisions of the liberalised pension scheme as\nsalaries were required to be recomputed in accordance with the recommendation of the third pay\ncommission but becoming operative from the specified date. it does therefore appear that the\nreading down of impugned memoranda by E8 would not render the\nliberalised pension scheme vague, unenforceable or unworkable.'],
#  '58 years, NULL': ["the second\ncentral pay commission (1957-58) re-affirmed that the age of superannuation should be T17\nfor all classes of public servants but did not recommend any increase in the non- contributory\nE1 benefits and recommended that if in future any improvement is to be made, it was the\nconsidered view of the commission that these benefits should be on a contributory basis. the\nadministrative reforms commission ('arc' for short) set up by the government of india in T19\ntook note of the fact that the cost of living has shot up and correspondingly the possibility of savings\nhas gone down and consequently the drop in wages on E1 is in reality much steeper than\nwhat the quantum of pension would indicate, and accordingly the arc recommended that thed.s. nakara & others vs union of india on 17 december, 1982\nindian kanoon - http://indiankanoon.org/doc/1416283/ 10quantum of pension admissible may be raised to 3/6 of the emoluments of the last T20 of\nservice as against the existing 3/8 and the ceiling should be raised from rs.",
#   "one of the terms of reference of the third pay commission was\n'death-cum- E1 benefits of central government employees'. the third pay commission did\nnot examine the question of relief to pensioners because in its view unless the terms of reference\nwere suitably amended it would not be within their jurisdiction to examine this question and on a\nreference by them, the government of india decided not to amend the terms of reference. with\nregard to the future pensioners the third pay commission while reiterating that the age of\nsuperannuation should continue to be T17 further recommended that no change in the existing\nformula for computing pension is considered necessary.",
#   'some landmark changes may be noticed. the first central pay commission (1946-47) recommended that the age of E1 in future\nshould be uniformly T17 for all services and the scale of pension should be 1/80 of the\nemoluments for each year of service, subject to a limit of 35/80 with a ceiling of rs. 8,000 per year\nfor 35 years of service, which the government of india while accepting the recommendation raised\nto rs.'],
#  '1956, NULL': ["the second\ncentral pay commission (1957-58) re-affirmed that the age of superannuation should be T17\nfor all classes of public servants but did not recommend any increase in the non- contributory\nE1 benefits and recommended that if in future any improvement is to be made, it was the\nconsidered view of the commission that these benefits should be on a contributory basis. the\nadministrative reforms commission ('arc' for short) set up by the government of india in T19\ntook note of the fact that the cost of living has shot up and correspondingly the possibility of savings\nhas gone down and consequently the drop in wages on E1 is in reality much steeper than\nwhat the quantum of pension would indicate, and accordingly the arc recommended that thed.s. nakara & others vs union of india on 17 december, 1982\nindian kanoon - http://indiankanoon.org/doc/1416283/ 10quantum of pension admissible may be raised to 3/6 of the emoluments of the last T20 of\nservice as against the existing 3/8 and the ceiling should be raised from rs.",
#   "the\nadministrative reforms commission ('arc' for short) set up by the government of india in T19\ntook note of the fact that the cost of living has shot up and correspondingly the possibility of savings\nhas gone down and consequently the drop in wages on E1 is in reality much steeper than\nwhat the quantum of pension would indicate, and accordingly the arc recommended that thed.s. nakara & others vs union of india on 17 december, 1982\nindian kanoon - http://indiankanoon.org/doc/1416283/ 10quantum of pension admissible may be raised to 3/6 of the emoluments of the last T20 of\nservice as against the existing 3/8 and the ceiling should be raised from rs. 675 p.m. to rs."],
#  'three years, NULL': ["the second\ncentral pay commission (1957-58) re-affirmed that the age of superannuation should be T17\nfor all classes of public servants but did not recommend any increase in the non- contributory\nE1 benefits and recommended that if in future any improvement is to be made, it was the\nconsidered view of the commission that these benefits should be on a contributory basis. the\nadministrative reforms commission ('arc' for short) set up by the government of india in T19\ntook note of the fact that the cost of living has shot up and correspondingly the possibility of savings\nhas gone down and consequently the drop in wages on E1 is in reality much steeper than\nwhat the quantum of pension would indicate, and accordingly the arc recommended that thed.s. nakara & others vs union of india on 17 december, 1982\nindian kanoon - http://indiankanoon.org/doc/1416283/ 10quantum of pension admissible may be raised to 3/6 of the emoluments of the last T20 of\nservice as against the existing 3/8 and the ceiling should be raised from rs.",
#   "the\nadministrative reforms commission ('arc' for short) set up by the government of india in T19\ntook note of the fact that the cost of living has shot up and correspondingly the possibility of savings\nhas gone down and consequently the drop in wages on E1 is in reality much steeper than\nwhat the quantum of pension would indicate, and accordingly the arc recommended that thed.s. nakara & others vs union of india on 17 december, 1982\nindian kanoon - http://indiankanoon.org/doc/1416283/ 10quantum of pension admissible may be raised to 3/6 of the emoluments of the last T20 of\nservice as against the existing 3/8 and the ceiling should be raised from rs. 675 p.m. to rs."]}

# %%
with open("output.txt", "w") as f:
    f.write(str(sentences_dict))
