# %%
import PyPDF2

# %%
def pdf_to_txt(pdf_file_path, txt_file_path):
    with open(pdf_file_path, 'rb') as pdf_file:
        pdf_reader = PyPDF2.PdfReader(pdf_file)
        
        text = ""
        for page_num in range(len(pdf_reader.pages)):
            page = pdf_reader.pages[page_num]
            text += page.extract_text().rstrip()

    with open(txt_file_path, 'w', encoding='utf-8') as txt_file:
        txt_file.write(text)

# %%
pdf_to_txt('/Users/Desktop/ACM CONFERENCE WORK/FINAL_LIST_DOCS/Maneka_Gandhi_vs_Union_Of_India_on_25_January_1978.PDF', 'maneka.txt')

# %%
import pandas as pd
import nltk
nltk.download('punkt')  # Download the required NLTK data
# Out:
# [nltk_data] Downloading package punkt to /Users/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
def find_related_sentences(sentences, keyword):
    related_sentences = []

    for i, sentence in enumerate(sentences):
        if keyword in sentence:
            prev_sentence = sentences[i - 1].strip() if i > 0 else None
            next_sentence = sentences[i + 1].strip() if i < len(sentences) - 1 else None
            related_sentences.append({
                "Sentence": sentence.strip(),
                "Previous": prev_sentence,
                "Next": next_sentence
            })

    return related_sentences

# %%
with open('/Users/Desktop/ACM CONFERENCE WORK/codes/Maneka Gandhi Case/maneka.txt', "r") as file:
    text = file.read()

# Tokenize into sentences using nltk.sent_tokenize()
sentences = nltk.sent_tokenize(text)

keyword = "passport"
result = []

related_sentences = find_related_sentences(sentences, keyword)
result.extend(related_sentences)

# Create a DataFrame with columns "Sentence," "Previous," and "Next"
output_df = pd.DataFrame(result, columns=["Sentence", "Previous", "Next"])

# Save results to a new CSV
output_df.to_csv("output_sentences_maneka.csv", index=False)

# %%
encodings_to_try = ['utf-8', 'latin1', 'utf-16', 'ISO-8859-1']

# Try reading the CSV file with different encodings
for encoding in encodings_to_try:
    try:
        output_df = pd.read_csv("output_sentences_maneka.csv", encoding=encoding)
        print("CSV file read successfully with encoding:", encoding)
        break  # Exit loop if successful
    except UnicodeDecodeError:
        print("Failed to read CSV file with encoding:", encoding)
        continue  # Try next encoding
# Out:
# CSV file read successfully with encoding: utf-8

# %%
output_df
# Out:
#                                               Sentence  \
# 0    3,5,6,10(3)(c),   10(5)--Whether\ns.10(3)(c)  ...
# 1    HEADNOTE:\nThe  petitioner was issued a passpo...
# 2    On the 4th  of  July  1977,  the\npetitioner r...
# 3    The petitioner was required to surrender her p...
# 4    The petitioner thereupon  filed  the\npresent ...
# ..                                                 ...
# 352  Pending the consideration of the petitioner's ...
# 353  This will be without prejudice to the power of...
# 354  In view of the statement that the petitioner m...
# 355  I construe section 10(3)(c) as providing a rig...
# 356  The passport will remain in the custody of the...
#
#                                               Previous  \
# 0                           Passports   Act,  1967-Ss.
# 1    Principles of Natural Justice--Whether applies...
# 2    HEADNOTE:\nThe  petitioner was issued a passpo...
# 3    On the 4th  of  July  1977,  the\npetitioner r...
# 4    A reply\nwas  sent by the Government of India,...
# ..                                                 ...
# 352                                                 4.
# 353  Pending the consideration of the petitioner's ...
# 354  This will be without prejudice to the power of...
# 355  21 of the Constitution and is in accordance\nw...
# 356  We, accordingly, dispose of the Writ\nPetition...
#
#                                                   Next
# 0    Principles of Natural Justice--Whether applies...
# 1    On the 4th  of  July  1977,  the\npetitioner r...
# 2    The petitioner was required to surrender her p...
# 3    The  petitioner\nimmediately  addressed  a let...
# 4    The Act was enacted on 24-4-67 in view of the\...
# ..                                                 ...
# 352  This will be without prejudice to the power of...
# 353  In view of the statement that the petitioner m...
# 354  The Attorney General assured us that all the g...
# 355  In view of the statement made by the learned A...
# 356                There will be no order as to costs.
#
# [357 rows x 3 columns]

# %%
concatenated_sen = pd.DataFrame(output_df['Previous'].astype(str) + ' ' + output_df['Sentence'].astype(str) + ' ' + output_df['Next'].astype(str), columns=['concat'])

# %%
print(concatenated_sen['concat'].iloc[0])
# Out:
# Passports   Act,  1967-Ss. 3,5,6,10(3)(c),   10(5)--Whether
# s.10(3)(c)  is  violative of Articles 14, 19(1)  (a)  (b) &
# 21--Grounds  for  refusing to  grant  passport--Whether  the
# power  to  impound passport  arbitrary--"in  general  public
# interest" if vague. Principles of Natural Justice--Whether applies only to quasi
# judicial   orders  or  applies  to   administrative   orders
# affecting  rights of citizens--When statute  silent  whether
# can be implied--Duty to act judicially whether can be  spelt
# out--In  urgent cases whether principles of natural  justice
# can apply.

# %%
concatenated_sen.to_csv('sentences_final_concatenated_maneka.csv', index=False)

# %%
import csv

# %%
def create_person_id_map(file_path):
    person_id_map = {}

    with open(file_path, 'r') as csvfile:
        reader = csv.reader(csvfile)
        header = next(reader)
        
        for row in reader:
            person_id_list = row[0]
            person = person_id_list.strip()
            person_id = row[1].strip()
            person_id_map[person] = person_id

    return person_id_map

def create_location_id_map(file_path):
    location_id_map = {}

    with open(file_path, 'r') as csvfile:
        reader = csv.reader(csvfile)
        header = next(reader)
        
        for row in reader:
            location_id_list = row[0]
            location = location_id_list.strip()
            location_id = row[1].strip()
            location_id_map[location] = location_id

    return location_id_map

def create_time_id_map(file_path):
    time_id_map = {}

    with open(file_path, 'r') as csvfile:
        reader = csv.reader(csvfile)
        header = next(reader)
        
        for row in reader:
            time_id_list = row[0].split(',')
            time = time_id_list.strip()
            time_id = row[1].strip()
            time_id_map[time] = time_id

    return time_id_map

def create_event_id_map(file_path):
    event_id_map = {}

    with open(file_path, 'r') as csvfile:
        reader = csv.reader(csvfile)
        header = next(reader)
        
        for row in reader:
            event_id_list = row[0].split(',')
            event = event_id_list.strip()
            event_id = row[1].strip()
            event_id_map[event] = event_id

    return event_id_map

def create_other_id_map(file_path):
    other_id_map = {}

    with open(file_path, 'r') as csvfile:
        reader = csv.reader(csvfile)
        header = next(reader)
        
        for row in reader:
            other_id_list = row[0].split(',')
            other = other_id_list.strip()
            other_id = row[1].strip()
            other_id_map[other] = other_id

    return other_id_map

# %%
file_path_person = '/Users/Desktop/ACM CONFERENCE WORK/Entities/Maneka Gandhi case/person.csv'
file_path_location = '/Users/Desktop/ACM CONFERENCE WORK/Entities/Maneka Gandhi case/location.csv'
file_path_time = '/Users/Desktop/ACM CONFERENCE WORK/Entities/Maneka Gandhi case/time.csv'
file_path_event = '/Users/Desktop/ACM CONFERENCE WORK/Entities/Maneka Gandhi case/event.csv'
file_path_other = '/Users/Desktop/ACM CONFERENCE WORK/Entities/Maneka Gandhi case/activity.csv'
person_id_map = create_person_id_map(file_path_person)
location_id_map = create_location_id_map(file_path_location)
time_id_map = create_location_id_map(file_path_time)
event_id_map = create_location_id_map(file_path_event)
other_id_map = create_location_id_map(file_path_other)

# %%
def generate_ngrams(text, n=6):
    words = text.split()
    ngrams = []
    for j in range(n, 0, -1):
        for i in range(len(words)):
            if i + j <= len(words):
                ngrams.append(' '.join(words[i:i+j]))
    return ngrams

# %%
def preprocess_text(text):
    text = text.replace("'s", "")
    text = text.replace(".", "")
    text = text.replace(";", "")
#     text = text.replace("-", "")
    text = text.replace("!", "")
    text = text.replace("?", "")
#     text = text.replace("/", "")
    text = text.replace("@", "")
    text = text.replace("#", "")
    text = text.replace(",", "")
    return text

# %%
def replace_entities(text):
    text = text.lower()
    ngrams = generate_ngrams(text)
    replaced_text = text

    for ngram in ngrams:
        original = ngram.lower()
        
        if original in person_id_map:
            entity_id = person_id_map[original]
            replaced_text = replaced_text.replace(ngram, entity_id)
        else:
            preprocessed_ngram = preprocess_text(ngram.lower())
            if preprocessed_ngram in person_id_map:
                entity_id = person_id_map[preprocessed_ngram]
                replaced_text = replaced_text.replace(ngram, entity_id)
            else:
                if original in location_id_map:
                    entity_id = location_id_map[original]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif preprocessed_ngram in location_id_map:
                    entity_id = location_id_map[preprocessed_ngram]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif original in time_id_map:
                    entity_id = time_id_map[original]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif preprocessed_ngram in time_id_map:
                    entity_id = time_id_map[preprocessed_ngram]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif original in event_id_map:
                    entity_id = event_id_map[original]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif preprocessed_ngram in event_id_map:
                    entity_id = event_id_map[preprocessed_ngram]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif original in other_id_map:
                    entity_id = other_id_map[original]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif preprocessed_ngram in other_id_map:
                    entity_id = other_id_map[preprocessed_ngram]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                    
    return replaced_text

# %%
with open('sentences_final_concatenated_maneka.csv', 'r', encoding='latin-1') as csvfile:
     reader = csv.reader(csvfile)
     next(reader)
     ref_sen = []
     for row in reader:
         sentence = row[0]
         ref_sen.append(sentence)

# %%
final_sentences = []

for sen in ref_sen:
     s = replace_entities(sen)
     final_sentences.append(s)

# %%
with open('cleaned_sentences_maneka.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Sentences'])
#      for sen in final_sentences:
    for sen in final_sentences:
        writer.writerow([sen])

# %% [markdown]
# ## Matrix Creation

# %%
# with the sentences
import pandas as pd
import csv
import re

# Load the CSV files
time_df = pd.read_csv(file_path_time)
location_df = pd.read_csv(file_path_location)
event_df = pd.read_csv(file_path_event)
person_df = pd.read_csv(file_path_person)
activity_df = pd.read_csv(file_path_other)

location_ID = location_df['Id'].tolist()
location_df = location_df['Location'].tolist()

time_ID = time_df['Id'].tolist()
time_df = time_df['Time'].tolist()

# event_ID = event_df['ID'].tolist()
# event_df = event_df['Event'].tolist()

# person_ID = person_df['ID'].tolist()
# person_df = person_df['Person'].tolist()

# activity_ID = activity_df['ID'].tolist()
# activity_df = activity_df['Others'].tolist()

event_ID_map = dict(zip(event_df['Id'], event_df['Event']))
person_ID_map = dict(zip(person_df['Id'], person_df['Person']))
activity_ID_map = dict(zip(activity_df['Id'], activity_df['Activity']))

matrix = {}

# %%
sentences = []
with open('cleaned_sentences_maneka.csv', 'r', encoding='latin-1') as csvfile:
    reader = csv.reader(csvfile)
    next(reader)
    for row in reader:
        sentence = row[0]
        sentences.append(sentence)

# %%
for s in sentences:
    pattern = r'([PTLEA]\d+)'
    matches = re.findall(pattern, s)

    persons = []
    time = []
    location = []
    event = []
    activity = []

    for match in matches:
        if match[0] == 'P':
            persons.append(person_ID_map.get(match, 'Unknown Person'))
        elif match[0] == 'L':
             location.append(location_ID.index(match))
        elif match[0] == 'E':
            event.append(event_ID_map.get(match, 'Unknown Event'))
        elif match[0] == 'A':
            activity.append(activity_ID_map.get(match, 'Unknown Activity'))
        elif match[0] == 'T':
            time.append(time_ID.index(match))

    if location and time:
        for loc_index in location:
            loc_key = location_df[loc_index]
            for time_index in time:
                time_key = time_df[time_index]
                if time_key not in matrix:
                    matrix[time_key] = {}
                if loc_key not in matrix[time_key]:
                    matrix[time_key][loc_key] = []
                matrix[time_key][loc_key].extend([(entity, s) for entity in (persons + event + activity)])
    elif location:
        for loc_index in location:
            loc_key = location_df[loc_index]
            if loc_key not in matrix:
                matrix[loc_key] = {}
            if 'NULL' not in matrix:
                matrix['NULL'] = {}
            if loc_key not in matrix["NULL"]:
                matrix["NULL"][loc_key] = []
            matrix["NULL"][loc_key].extend([(entity, s) for entity in (persons + event + activity)])
    elif time:
        for time_index in time:
            time_key = time_df[time_index]
            if time_key not in matrix:
                matrix[time_key] = {}
            if 'NULL' not in matrix[time_key]:
                matrix[time_key]['NULL'] = []
            matrix[time_key]["NULL"].extend([(entity, s) for entity in (persons + event + activity)])
    else:
        if 'NULL' not in matrix:
            matrix['NULL'] = {}
        if 'NULL' not in matrix['NULL']:
            matrix['NULL']['NULL'] = []
        matrix["NULL"]["NULL"].extend([(entity, s) for entity in (persons + event + activity)])

matrix_df = pd.DataFrame.from_dict(matrix, orient='index')

# %%
matrix_df.to_csv('matrix_with_sen_maneka.csv')

# %%
import networkx as nx

# %%
df = pd.read_csv('matrix_with_sen_maneka.csv')

# %%
df.rename(columns={'Unnamed: 0': 'Time'}, inplace=True)

# %%
G = nx.Graph()

for index, row in df.iterrows():
    time = row['Time']
    for location in df.columns:
        if location == 'Time':
            continue
        # Convert the tuple to a string and add it as a node
        G.add_node(f"{time}, {location}")

# %%
import ast

# %%
final = set()

# Update the final set with only the entities
for value in pd.unique(df.drop(columns='Time').values.ravel()):
    if pd.notnull(value):
        value_list = ast.literal_eval(value)
        entity_list = [entity for entity, sentence in value_list]
        final.update(entity_list)

# %%
G.add_nodes_from(final)

# %%
for index, row in df.iterrows():
    time = row['Time']
    for location in df.columns:
        if location == 'Time':
            continue
        if pd.notnull(row[location]):
            value_list = ast.literal_eval(row[location])
            entity_list = [entity for entity, sentence in value_list]
            for entity in entity_list:
                if entity in final:
                    # Convert the tuples to strings and add them as an edge
                    G.add_edge(f"{time}, {location}", entity)

# %%
for node in list(G.nodes):
    if not list(G.neighbors(node)):
        G.remove_node(node)

# %%
for node1 in G.nodes:
    # Check if node1 can be split into a pair
    if ', ' in node1:
        parts1 = node1.split(", ")
        if len(parts1) == 2:  # Ensure it splits into exactly two parts
            time1, location1 = parts1
            for node2 in G.nodes:
                # Check if node2 can be split into a pair
                if ', ' in node2:
                    parts2 = node2.split(", ")
                    if len(parts2) == 2:  # Ensure it splits into exactly two parts
                        time2, location2 = parts2
                        # Add edge if the time or location matches
                        if time1 == time2 or location1 == location2:
                            G.add_edge(node1, node2)

# %%
degree_dict = dict(G.degree(G.nodes()))
nx.set_node_attributes(G, degree_dict, 'degree')

# %%
# Create a dictionary to store the sentences for each node
sentences_dict = {}

# Create a dictionary to store the sentences for each edge i.e. between two nodes
edge_sentences_dict = {}

# Update the sentences_dict and edge_sentences_dict
for index, row in df.iterrows():
    time = row['Time']
    for location in df.columns:
        if location == 'Time':
            continue
        if pd.notnull(row[location]):
            value_list = ast.literal_eval(row[location])
            for entity, sentence in value_list:
                if entity in final:
                    # Add the sentence to the sentences_dict for the entity
                    if entity not in sentences_dict:
                        sentences_dict[entity] = set()
                    sentences_dict[entity].add(sentence)

                    # Add the sentence to the sentences_dict for the (time, location) node
                    time_location_node = f"{time}, {location}"
                    if time_location_node not in sentences_dict:
                        sentences_dict[time_location_node] = set()
                    sentences_dict[time_location_node].add(sentence)

                    # Add the sentence to the edge_sentences_dict for the edge
                    edge = (time_location_node, entity)
                    if edge not in edge_sentences_dict:
                        edge_sentences_dict[edge] = set()
                    edge_sentences_dict[edge].add(sentence)

# Convert the sets back to lists if needed
for node, sentences in sentences_dict.items():
    sentences_dict[node] = list(sentences)

for edge, sentences in edge_sentences_dict.items():
    edge_sentences_dict[edge] = list(sentences)

# %%
pip install node2vec
# Out:
# Requirement already satisfied: node2vec in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (0.5.0)
# Requirement already satisfied: gensim<5.0.0,>=4.3.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from node2vec) (4.4.0)
# Requirement already satisfied: joblib<2.0.0,>=1.4.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from node2vec) (1.4.2)
# Requirement already satisfied: networkx<4.0.0,>=3.1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from node2vec) (3.4.2)
# Requirement already satisfied: numpy<2.0.0,>=1.24.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from node2vec) (1.26.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from node2vec) (4.67.1)
# Requirement already satisfied: scipy>=1.7.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from gensim<5.0.0,>=4.3.0->node2vec) (1.15.1)
# Requirement already satisfied: smart_open>=1.8.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from gensim<5.0.0,>=4.3.0->node2vec) (7.5.0)
# Requirement already satisfied: wrapt in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from smart_open>=1.8.1->gensim<5.0.0,>=4.3.0->node2vec) (2.0.1)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from node2vec import Node2Vec

# Create a Node2Vec instance
node2vec = Node2Vec(G, dimensions=64, walk_length=30, num_walks=200, workers=4)

# Generate embeddings
model = node2vec.fit(window=10, min_count=1, batch_words=4)
# Out:
# Computing transition probabilities:   0%|          | 0/12 [00:00<?, ?it/s]
# Generating walks (CPU: 1): 100%|██████████| 50/50 [00:00<00:00, 660.52it/s]
# Generating walks (CPU: 3): 100%|██████████| 50/50 [00:00<00:00, 658.74it/s]
# Generating walks (CPU: 2): 100%|██████████| 50/50 [00:00<00:00, 652.85it/s]
# Generating walks (CPU: 4): 100%|██████████| 50/50 [00:00<00:00, 640.16it/s]

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Get the node embeddings
node_embeddings = {node: model.wv[node] for node in G.nodes}

# Compute cosine similarity matrix
similarity_matrix = cosine_similarity(list(node_embeddings.values()))

# %%
from sklearn.cluster import DBSCAN

# Initialize DBSCAN
dbscan = DBSCAN(eps=0.5, min_samples=3)  # Adjust parameters as needed

# Fit and predict clusters
labels = dbscan.fit_predict(similarity_matrix)

# %%
cluster_colors = [
    'rgb(31, 119, 180)',  # Blue
    'rgb(255, 127, 14)',  # Orange
    'rgb(44, 160, 44)',   # Green
    'rgb(214, 39, 40)',   # Red
    'rgb(148, 103, 189)', # Purple
    'rgb(140, 86, 75)',   # Brown
    'rgb(227, 119, 194)', # Pink
    'rgb(127, 127, 127)', # Gray
    'rgb(188, 189, 34)',  # Olive
    'rgb(23, 190, 207)',  # Teal
    'rgb(255, 187, 120)', # Peach
    'rgb(214, 39, 40)',   # Maroon
    'rgb(77, 175, 74)',   # Light Green
    'rgb(152, 78, 163)',  # Plum
    'rgb(255, 152, 150)'  # Salmon
]

# %%
import networkx as nx
import plotly.graph_objs as go

# Assuming 'G' is your graph and 'labels' is the list of labels
# Renumber clusters from 1 to 7 if needed, otherwise ensure you have clusters numbered 1 to 7
unique_labels = list(set(labels))
label_mapping = {label: idx+1 for idx, label in enumerate(unique_labels)}

def draw_subgraph_plotly(subgraph, cluster_id, cluster_color):
    pos = nx.spring_layout(subgraph, seed=42)  # Fixed seed for reproducibility
    
    # Extract the node positions
    x_nodes = [pos[node][0] for node in subgraph.nodes()]
    y_nodes = [pos[node][1] for node in subgraph.nodes()]

    # Extract the edges
    edge_x = []
    edge_y = []
    for edge in subgraph.edges():
        x0, y0 = pos[edge[0]]
        x1, y1 = pos[edge[1]]
        edge_x.extend([x0, x1, None])
        edge_y.extend([y0, y1, None])

    # Edge trace
    edge_trace = go.Scatter(
        x=edge_x, y=edge_y,
        line=dict(width=1, color='gray'),
        hoverinfo='none',
        mode='lines')

    # Node trace
    node_trace = go.Scatter(
        x=x_nodes, y=y_nodes,
        mode='markers+text',
        text=[f'{node}' for node in subgraph.nodes()],
        textposition="top center",
        marker=dict(
            showscale=False,
            color=cluster_color,  # Assign the cluster color
            size=20,
            line=dict(width=2, color='black')
        ),
        hoverinfo='text'
    )

    # Create figure
    fig = go.Figure(data=[edge_trace, node_trace],
                    layout=go.Layout(
                        title=f'Cluster {cluster_id}',
                        showlegend=False,
                        hovermode='closest',
                        margin=dict(b=20, l=5, r=5, t=40),
                        xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                        yaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                        height=600,
                        width=600,
                        paper_bgcolor='white',
                        plot_bgcolor='white'
                    ))

    fig.show()

# Iterate over each cluster and draw the subgraph
for original_cluster_id in set(labels):
    cluster_id = label_mapping[original_cluster_id]
    cluster_color = cluster_colors[cluster_id - 1]  # Assign a unique color to each cluster
    cluster_nodes = [node for node, label in zip(G.nodes, labels) if label == original_cluster_id]
    subgraph = G.subgraph(cluster_nodes)
    draw_subgraph_plotly(subgraph, cluster_id, cluster_color)

# %%
# # Initialize lists for nodes and links
# nodes = []
# links = []

# # Add nodes to the list
# for node, sentences in sentences_dict.items():
#     nodes.append({
#         "id": node,
#         "group": 1,  # Update this as needed
#         "size": len(sentences)  # The size could be based on the number of sentences
#     })

# # Add links to the list
# for edge, sentences in edge_sentences_dict.items():
#     source, target = edge
#     links.append({
#         "source": source,
#         "target": target,
#         "value": len(sentences)  # The value could be based on the number of sentences
#     })

# # Combine nodes and links into a single dictionary
# graph_data = {
#     "nodes": nodes,
#     "links": links
# }

# %%
# import os

# os.environ['METIS_DLL'] = '/Users/.local/lib/libmetis.dylib'

# %%
# import metis

# %%
# edgecuts, parts = metis.part_graph(G)

# %%
import json

# Create a mapping from nodes to integers
node_to_int = {node: i for i, node in enumerate(G.nodes)}

# %%
degree_dict = dict(G.degree(G.nodes()))
nx.set_node_attributes(G, degree_dict, 'degree')

data = nx.node_link_data(G)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/networkx/readwrite/json_graph/node_link.py:142: FutureWarning:
#
#
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.

# %%
import numpy as np

# %%
labels = labels.astype(np.int32)

# %%
graph_data = {
    "nodes": [{"name": str(node), "n": degree_dict[node], "grp": int(labels[i]), "id": str(node)} for i, node in enumerate(G.nodes())],
    "links": [{"source": str(link_data['source']), "target": str(link_data['target']), "value": 1} for link_data in data['links']]
}

# %%
json_data = json.dumps(graph_data)
with open('data_maneka.json', 'w') as f:
    f.write(json_data)

# %%
# from collections import defaultdict

# # Create a dictionary where keys are part numbers and values are lists of nodes
# part_dict = defaultdict(list)
# for node, part in enumerate(parts):
#     part_dict[part].append(node)

# # Print the number of parts
# print("Number of parts:", len(part_dict))

# # Print the nodes in each part
# for part, nodes in part_dict.items():
#     print("Part", part, ":", nodes)

# %%
# Assuming you have already created clusters using DBSCAN and have 'labels' and 'G' available

# Initialize an empty dictionary to store sentences for each cluster
cluster_sentences_dict = {}

# Iterate over each cluster
for original_cluster_id in set(labels):
    cluster_id = label_mapping[original_cluster_id]
    cluster_nodes = [node for node, label in zip(G.nodes, labels) if label == original_cluster_id]
    
    # Initialize a set to store sentences for this cluster
    cluster_sentences = set()
    
    # Iterate over nodes in the cluster
    for node in cluster_nodes:
        # Assuming 'node' contains the relevant information (e.g., entity, time, location)
        # Extract sentences associated with this node and add them to the cluster_sentences set
        if node in sentences_dict:
            cluster_sentences.update(sentences_dict[node])
    
    # Store the cluster_sentences set in the cluster_sentences_dict
    cluster_sentences_dict[cluster_id] = cluster_sentences

# %%
sentences_dict
# Out:
# {'surrender her passport': ['on the 4th  of  july  1977,  the\npetitioner received a letter dated 2nd july, 1977, from  the\nregional  passport officer delhi intimating to her  that  it\nwas  decided  by  the government of  india  to  impound  her\npassport under s. 10(3)(c) of the act "in public  interest". the petitioner was required to E2 within\n7  days  from the receipt of that  letter. the  petitioner\nimmediately  addressed  a letter to  the  regional  passport\nofficer requesting him to furnish a copy of the statement of\nreasons for making the order as provided in s.10(5).',
#   'headnote:\nthe  petitioner was issued a passport on june 1, 1976  under\nthe  passport  act,  1967. on the 4th  of  july  1977,  the\npetitioner received a letter dated 2nd july, 1977, from  the\nregional  passport officer delhi intimating to her  that  it\nwas  decided  by  the government of  india  to  impound  her\npassport under s. 10(3)(c) of the act "in public  interest". the petitioner was required to E2 within\n7  days  from the receipt of that  letter.'],
#  'nan, NULL': ["hence the question\nwhether the state could impose such restraint does not arise in this case. as the\ncontention was that by E6 the petitioner's fundamental right\nof freedom of speech etc. outside the country was infringed, it became necessary to\nconsider whether the citizen had any such right.",
#   'that would be a matter within the judgment of the\ncommission of inquiry and it would be entirely for the commission of inquiry to\ndecide whether or, not her presence is necessary in the proceeding before it. the\nimpugned order E6 of the petitioner on the basis of a mere\nopinion by the central government that the petitioner is likely to be required in\nconnection with the proceeding before the commission of inquiry was, in the\ncircumstances, clearly unreasonable and hence violative of article 19(1) (a) and (g). this ground of challenge was vehemently pressed on behalf of the petitioner and\nsupplemented on behalf of adil sahariar who intervened at the hearing of the writ\npetition, but we do not think there is any substance in it.',
#   'the petitioner\nimmediately addressed a letter to the regional passport officer requesting him to furnish a copy of\nthe statement of reasons for making the order as provided in section 10(5) to which a reply was sent\nby the government of india, ministry of external affairs on 6th july, 1977 stating inter alia that the\ngovernment has decided "in the interest of the general public" not to furnish her a copy of the\nstatement of reasons, for making of the order. the petitioner thereupon filed the present petition\nchallenging the action of the government in E4 and declining to give reasons\nfor doing so. the action of the government was impugned inter alia on the ground that it was mala\nfide, but this challenge was not pressed before us at the time of the hearing of the arguments and\nhence it is not necessary to state any facts hearing on that question.',
#   "the disclosure made under the\nstress of the writ petition that the petitioner's passport was impounded because, her presence was\nlikely to be required in connection with the proceedings before a commission of inquiry, could\neasily have been made when the petitioner called upon the government to let her know the reasons\nwhy her passport was impounded. the power to refuse to disclose the reasons for impounding a\npassport is of an exceptional nature and it ought to be exercised fairly, sparingly and only when fully\njustified by the exigencies of an uncommon situation. the reasons, if disclosed being open to judicial\nscrutiny for ascertaining their nexus with the order E6 the refusal to disclose\nthe reasons would equally be open to the scrutiny of the court; or else, the wholesome power of amaneka gandhi vs union of india on 25 january, 1978\nindian kanoon - http://indiankanoon.org/doc/1766147/ 43dispassionate judicial examination of executive orders could with impunity be set at naught by an\nobdurate determination to suppress the reasons.",
#   'we may observe that if the impugned order E6 of the petitioner were\nviolative, of her right to freedom of speech and expression or her right to carry on her profession as\na journalist, it would not be saved by article 19(2) or article 19(6), because the impounding of the\npassport for an indefinite length of time would clearly constitute an unreasonable restriction. the\nunion contended that though the period for which the impugned order was to operate was not\nspecified in so many terms, it was clear that it was intended to be co-terminous with the duration of\nthe commission of inquiry, since the reason for impounding was that the presence of the petitioner\nwas likely to be required in connection with the proceedings before the com- mission of inquiry and\nthe term of the commission of inquiry being limited upto 31st december, 1977, the impoundig of\nthe passport could not continue beyond that date and hence it would not be said that the impugned\norder was to operate for an indefinite period of time. now, it is true that the passport of the\npetitioner was impounded on the ground that her presence was likely to be required in connection\nwith the proceeding before the commission of inquiry and the initial time limit fixed for the\ncommission of inquiry to submit its report was 31st december, 1977, but the time limit could always\nbe extended by the government and the experience of several commissions of inquiry set up in this\ncountry over the last twenty-five years shows that hardly any commission of inquiry has been able\nto complete its report within the originally appointed time.',
#   "the authority is also required by s. 10(5) to\nrecord  in  writing  a brief statement of  the  reasons  for\nmaking  the order impounding a passport and save in  certain\nexceptional situations, the authority is obliged to' furnish\na  copy  of the statement of reasons to the  holder  of  the\npassport. where the passport authority which has  impounded\na  passport is other than the central government a right  of\nappeal against the order E6 is given by\nsection  11. thus,  the power conferred  on  the  passport\nauthority  to impound a passport is a  quasijudicial  power.",
#   'on the 4th  of  july  1977,  the\npetitioner received a letter dated 2nd july, 1977, from  the\nregional  passport officer delhi intimating to her  that  it\nwas  decided  by  the government of  india  to  impound  her\npassport under s. 10(3)(c) of the act "in public  interest". the petitioner was required to E2 within\n7  days  from the receipt of that  letter. the  petitioner\nimmediately  addressed  a letter to  the  regional  passport\nofficer requesting him to furnish a copy of the statement of\nreasons for making the order as provided in s.10(5).',
#   "if such a provision were held to be incorporated in the\npassports, act, 1967 by necessary implication, as we hold it must be, the procedure prescribed by the\nact for impounding a passport would be fight, fair and just and it would not suffer from the vice of\narbitrariness or unreasonableness. we must, therefore, hold that the procedure 'established' by the\npassports act, 1967 for impounding a passport is in conformity with the requirement of article 21\nand does not fall foul of that article. but the question then immediately arises whether the central government has complied with this\nprocedure in E6 of the petitioner.",
#   'moreover, it must be remembered that the exercise of this\npower is not made dependent on the subjective opinion of the passport authority as\nregards the necessity of exercising it on one or more of the grounds stated in the\nsection, but the passport authority is required to record in writing a brief statement\nof reasons for E6 and, save in cer-\ntain exceptional circumstances, to supply a copy of such statement to the person\naffected, so that the person concerned can challenge the decision of the passport\nauthority in appeal and the appellate authority can examine whether the reasons\ngiven by the passport authority are correct, and if so, whether they justify the making\nof the order E6. it is true that when the order impounding a\npassport is made by the central government, there is no appeal against it, but it must\nbe remembered that in such a case the power is exercised by the central government\nitself and it can safely be assumed that the central government will exercise the\npower in a reasonable and responsible manner. when power is vested in a high\nauthority like the central government, abuse of power cannot be lightly assumed.',
#   'sub-section (1) of that section\nempowers the passport authority to A5 of a passport or travel document\nor to vary or cancel the conditions subject to which a passport or travel document has been issued,\nhaving regard, inter alia, to the provisions of sub-section (1) of section 6 or any notification. under\nsection 19, sub-section (2) confers powers on the passport authority to vary or cancel the conditions\nof the passport or travel document on application of the holder of the passport or travel document\nand with the previous approval of the central government. sub-section (3) provides that the\npassport authority may impound or cause to be impounded or revoke a passport or travel document\non the grounds set out in clauses (a) to\n(h), the order E6 in the present case was made by the central government\nunder clause (c) which reads as follows:--maneka gandhi vs union of india on 25 january, 1978\nindian kanoon - http://indiankanoon.org/doc/1766147/ 50"(c) if the passport authority deems it necessary so to do in the interest of the\nsovereignty and integrity of india, the security of india, friendly relations of india\nwith any foreign country, or in the interests of the general public;"\nthe particular ground relied upon for making the order was that set out in the last part of clause (c),\nnamely, that the central government deems it necessary to impound the passport "in the interests\nof the general public."',
#   'if the order cannot be shown to have been made in the interests of public order,\ndecency or morality, it would not only contravene article 19 (1) (a), but would also be outside the\nauthority conferred by section 10(3) (c). constitutional validity of the impugned order:maneka gandhi vs union of india on 25 january, 1978\nindian kanoon - http://indiankanoon.org/doc/1766147/ 85we may now consider, in the light of this discussion, whether the impugned order\nmade by the central government E6 of the petitioner under\nsection 10(3) (c) suffers from any constitutional or legal infirmity. the first ground of\nattack against the validity of the impugned order was that it was made in\ncontravention of the rule of natural justice embodied in the maxim audi alteram\npartem and was, therefore, null and void.',
#   'i feel that in the\ncircumstances there is no justification for holding that s. 10(5) of the act is ultra vires of the powers\nof the legislature. we have taken note of the fact that in the present case there is no reason in\ndeclining to furnish to the petitioner the statement of reasons for E6 but such\na lapse by the authority would not make sec. 10(5) ultra vires of the powers of the legislature.',
#   'it would not, therefore, be right to conclude that the audi alteram\npartem rule is excluded merely because the power to impound a passport might be frustrated, if\nprior notice and hearing were to be given to the person concerned before impounding his passport.maneka gandhi vs union of india on 25 january, 1978\nindian kanoon - http://indiankanoon.org/doc/1766147/ 65the passport authority may proceed to impound the passport without giving any prior opportunity\nto the person concerned to be heard, but as soon as the order E6 is made, and\nopportunity of hearing, remedial in aim, should be given to him so that he may present his case and\ncontrovert that of the passport authority and point out why his passport should not be impounded\nand the order impounding it recalled. this should not only be possible but also quite appropriate,\nbecause the reasons for E6 are required to be supplied by the passport\nauthority after the making of the order and the person affected would, therefore, be in a position to\nA13 setting forth his case and plead for setting aside the action impounding his\npassport. a fair opportunity of being heard following immediately upon the order impounding the\npassport would satisfy the mandate of natural justice and a provision requiring giving of such\nopportunity to the person concerned can and should be read by (1) [1949] 1 all eng.',
#   'sub-section (3) provides that the\npassport authority may impound or cause to be impounded or revoke a passport or travel document\non the grounds set out in clauses (a) to\n(h), the order E6 in the present case was made by the central government\nunder clause (c) which reads as follows:--maneka gandhi vs union of india on 25 january, 1978\nindian kanoon - http://indiankanoon.org/doc/1766147/ 50"(c) if the passport authority deems it necessary so to do in the interest of the\nsovereignty and integrity of india, the security of india, friendly relations of india\nwith any foreign country, or in the interests of the general public;"\nthe particular ground relied upon for making the order was that set out in the last part of clause (c),\nnamely, that the central government deems it necessary to impound the passport "in the interests\nof the general public." then follows sub-section (5) which requires the passport authority\nimpounding or E7 or varying or canceling an endorsement\nmade upon it to "record in writing a brief statement of the reasons for making such order and\nfurnish to the holder of the passport or travel document on demand a copy of the same unless, in\nany case, the passport authority is of the opinion that it will not be in the interests of the soveriegnty\nand integrity of india, the security of india, friendly relations of india with my foreign country or in\nthe interests of the general public to furnish such a copy." it was in virtue of the provision contained\nin the latter part of this sub-section that the central government declined to furnish a copy of the\nstatement of reasons for E6 of the petitioner on the ground that it was not in\nthe interests of the general public to furnish such copy to the petitioner.',
#   'the order E6 of the petitioner was, therefore, clearly in violation of\nthe rule of natural justice embodied in the maxim audi alteram partem and it was not in conformity\nwith the procedure prescribed by the passports act, 1967. realising that this was a fatal defect which\nwould void the order E6, the learned attomey-general made a statement on\nbehalf of the government of india to the following effect :\n"1. the government is agreeable to considering any representation that may be made\nby the petitioner in respect of the E1 and giving her an\nopportunity in the matter.',
#   'section 10(1) enables the passport authority to A5 on a\npassport or travel document or may with the previous approval of the central government, vary or\ncancel the conditions subject to which a passport or travel document has been issued, and require-\nthe holder of a passport or a travel document by notice in writing, to deliver up the passport or\ntravel document to it within such time as may be specified in the notice. sub-section (2) enables the\nbolder of a passport or a travel document to vary or cancel the conditions of the passport. section 10(3) with which we are concerned runs as follows 10(3).-the passport authority may\nimpound or cause to be impounded or revoke a passport or travel document,-\n(a) if the passport authority is satisfied that the holder of the passport or travel document is in\nwrongful possession of;\n(b) if the passport or travel document was obtained by the suppression of material information or\non the basis of wrong information provided by the holder of the passpot or travel document or any\nother person on his behalf;\n(c) if the passport authority deems it necessary so to do in the interests of the sovereignity and\nintegrity of india, the security of india, friendly relations of india with any foreign country, or in the\ninterests of the general public;\n(d) if the holder of the passpot or travel document has, at any time after the issue of the passort or\ntravel document, been convicted by a court in india for any offence involving moral turpitude and\nsentenced in respect thereof to imprisonment for not less than two years;\n(c) if proceedings in respect of an offence alleged to have been committed by the holder of the\npassport or travel document are pending before a criminal court in india;\n(f) if any of the conditions of the passport or travel document has been contravened;maneka gandhi vs union of india on 25 january, 1978\nindian kanoon - http://indiankanoon.org/doc/1766147/ 141(g) if the holder of the passport or travel document has failed to comply with a notice under\nsub-section (1)requiring him to deliver up the same.',
#   'be deprived of this right except according to the procedure\nprescribed by law. there is no procedure prescribed by the passport act, 1967 for impounding or\nrevoking a passport and thereby preventing the holder of the passport from going abroad and in any\nevent, even if some procedure can be traced in the relevant provisions of the act, it is unreasonable\nand arbitrary, inasmuch as it does not provide for giving an opportunity to the holder of the\npassport to be heard against the making of the order and hence the action of the central government\nin E6 of the petitioner is in violation of article 21. this contention of the\npetitioner raises a question as to the true interpretation of article 21, what is the nature and extent\nof the protection afforded by this article ?',
#   'in the present case, there is no reason in declining to furnish to\nthe petitioner statement of reasons for E6 [772 h, 773 a-d, h, 774 a] in view\nof the statement of the attorney general that the petitioner might A13 in respect\nof the impounding of passport and that the representations would be dealt with expeditiously and\nthat even if the imounding of the passport is confirmed it will not exceed a period of 6 months, it is\nnot necessary to go into the merits of the case any further. [776 b-c] & original jurisdiction :\nwrit petition no.',
#   'moreover, a passport can be impounded by the passport authority only on certain specified grounds\nset out in sub-section (3) of section 10 and the passport authority would have to apply its mind to\nthe facts and circumstances of a given case and decide whether any of the specified grounds exists\nwhich would justify impounding of the passport. the passport authority is also required by\nsub-section (5) of section 10 to record in writing a brief statement of the reasons for making an\norder impounding a passport and, save in certain exceptional situations, the passport authority is\nobliged to furnish a copy of the statement of reasons to the bolder of the passport.maneka gandhi vs union of india on 25 january, 1978\nindian kanoon - http://indiankanoon.org/doc/1766147/ 63where the passport authority which has im- pounded a passport is other than the central\ngovernment, a right of appeal against the order E6 is given by section 11, and\nin the appeal, the validity of the reasons given by the passport authority for impounding the\npassport can be canvassed before the appellate authority. it is clear on a consideration of these\ncircumstances that the test laid down in the decisions of this court for distinguishing between a\nquasi-judicial power and an administrative power is satisfied and the power conferred on the\npassport authority to impound a passport is quasi-judicial power.',
#   "but there is a proviso to this section which says\nthat if the order impounding or E7 is passed by the central\ngovernment, there shall be no right to appeal. these are the relevant provisions of the act in the\nlight of which we have to consider the constitutionality of sub- section (3) (c) of section 10 and the\nvalidity of the order E6 of the petitioner. meaning and content of personal\nliberty in article 21 the first contention urged on behalf of the petitioner in support of the petition\nwas that the right to go abroad is part of 'personal liberty within the meaning of that expression as\nused in article 21 and no one can.",
#   'under\nsection 19, sub-section (2) confers powers on the passport authority to vary or cancel the conditions\nof the passport or travel document on application of the holder of the passport or travel document\nand with the previous approval of the central government. sub-section (3) provides that the\npassport authority may impound or cause to be impounded or revoke a passport or travel document\non the grounds set out in clauses (a) to\n(h), the order E6 in the present case was made by the central government\nunder clause (c) which reads as follows:--maneka gandhi vs union of india on 25 january, 1978\nindian kanoon - http://indiankanoon.org/doc/1766147/ 50"(c) if the passport authority deems it necessary so to do in the interest of the\nsovereignty and integrity of india, the security of india, friendly relations of india\nwith any foreign country, or in the interests of the general public;"\nthe particular ground relied upon for making the order was that set out in the last part of clause (c),\nnamely, that the central government deems it necessary to impound the passport "in the interests\nof the general public." then follows sub-section (5) which requires the passport authority\nimpounding or E7 or varying or canceling an endorsement\nmade upon it to "record in writing a brief statement of the reasons for making such order and\nfurnish to the holder of the passport or travel document on demand a copy of the same unless, in\nany case, the passport authority is of the opinion that it will not be in the interests of the soveriegnty\nand integrity of india, the security of india, friendly relations of india with my foreign country or in\nthe interests of the general public to furnish such a copy."',
#   '[681 g-h, 682 a-c, e-h, 683 a-b]\nin  the  present case, however, the central  government  not\nonly  did  not  give  an  opportunity  of  hearing  of   the\npetitioner  after making the impugned order  impounding  her\npassport but even declined to furnish to the petitioner  the\nreasons for E4 despite requests made by\nher. the  central  government was  wholly  unjustified  in\nwithholding the reasons for E6 and this\nwas  not only in breach of the statutory provisions  but  it\nalso  amounted  to denial of opportunity of hearing  to  the\npetitioner. the  order  impounding  the  passport  of  the\npetitioner was, therefore, clearly in violation of the  rule\nof natural justice embodied in the maxim audi alteram partem\nand  was not in conformity with the procedure prescribed  by\nthe  act.',
#   'as the undertaking given by\nthe attorney general amounts to an offer to deal with it justly and fairly after informing the\npetitioner of any ground that may exist for E4 it seems that no further action\nby this court may be necessary. in view, however, of what is practically an admission that the order\nactually passed on 7th july, 1977, is neither fair nor procedurally proper, i would, speaking for\nmyself, quash this order and direct the return of the impounded passport to the petitioner. i also\nthink that the petitioner is entitled to her costs.',
#   'now, it is obvious and indeed this could not\nbe controverted that the central government not only did not give an opporgive an opportunity of\nhearing to the petitioner after making the impugned order im- pounding her passport but even\ndeclined to furnish to the petitioner the reasons for E4 despite request made\nby her. we have already pointed out that the central government was wholly unjustified in\nwithholding the reasons for E6 from the petitioner and this was not only in\nbreach of the statutory provision, but it also amounted to denial of opportunity of hearing to the\npetitioner. the order E6 of the petitioner was, therefore, clearly in violation of\nthe rule of natural justice embodied in the maxim audi alteram partem and it was not in conformity\nwith the procedure prescribed by the passports act, 1967.',
#   "the passport can be impounded only on certain\nspecified grounds set out in section 10(3) and the  passport\nauthority  would  have to apply its mind to  the  facts  and\ncircumstances of a given case and decide whether any of  the\nspecified  grounds exists which would justify impounding  of\nthe passport. the authority is also required by s. 10(5) to\nrecord  in  writing  a brief statement of  the  reasons  for\nmaking  the order impounding a passport and save in  certain\nexceptional situations, the authority is obliged to' furnish\na  copy  of the statement of reasons to the  holder  of  the\npassport. where the passport authority which has  impounded\na  passport is other than the central government a right  of\nappeal against the order E6 is given by\nsection  11.",
#   '14 of the constitution, since the\ncondition denoted by the words "in the interests of the general public" limiting the\nexercise of the power is vague and undefined and the power conferred by this\nprovision is, therefore, excessive and suffers from the vice of "over-breath." the,\npetition also contained a challenge that an order under section 10(3) (c) impounding\na passport could not be made by the passport authority without giving an\nopportunity to the holder of the passportto be heard in defence and since in the\npresent case, the passport was impounded by the government without affording an\napportunity of hearingto the petitioner, the order was null and void, and in the\nalternativeif section 10(3) (c) were read in such a manner as to exclude the right of\nhearing, the section would be infected with the vice ofarbitrariness and it would be\nvoid as offending article 14. these were the only grounds taken in the petition as\noriginally filed and on 20th july, 1977 the petition was E8 by\nthis court and an interim order was made directing that the passport of the petitioner\nshould continue to remain deposited with the registrar of this court pending the\nhearing and final disposal of the petition.',
#   "section 10\nenables the passport authority to A5 on a passport. section 10(3)\nprovides the reasons for which a passport may be impounded. again reason', are required to be\nfurnished to the person concerned on demand except if the, passport authority is of the opinion that\nit will not be in the interest of sovereignty and integrity of india, security of india, 'friendly relations\nof india with any.",
#   'headnote:\nthe  petitioner was issued a passport on june 1, 1976  under\nthe  passport  act,  1967. on the 4th  of  july  1977,  the\npetitioner received a letter dated 2nd july, 1977, from  the\nregional  passport officer delhi intimating to her  that  it\nwas  decided  by  the government of  india  to  impound  her\npassport under s. 10(3)(c) of the act "in public  interest". the petitioner was required to E2 within\n7  days  from the receipt of that  letter.',
#   'how can section 10(3) (c) be said tomaneka gandhi vs union of india on 25 january, 1978\nindian kanoon - http://indiankanoon.org/doc/1766147/ 67incur any constitutional infirmity on account of these words when they are no wider\nthan the constitutional provision in article 19(5) and adhere loyally to the verbal\nformula adopted in the constitution ? we are clearly of the view that sufficient\nguidelines are provided by the, words "in the interests of the general public" and the\npower conferred on the passport authority to impound a passport cannot be said to\nbe unguided or unfettered. moreover, it must be remembered that the exercise of this\npower is not made dependent on the subjective opinion of the passport authority as\nregards the necessity of exercising it on one or more of the grounds stated in the\nsection, but the passport authority is required to record in writing a brief statement\nof reasons for E6 and, save in cer-\ntain exceptional circumstances, to supply a copy of such statement to the person\naffected, so that the person concerned can challenge the decision of the passport\nauthority in appeal and the appellate authority can examine whether the reasons\ngiven by the passport authority are correct, and if so, whether they justify the making\nof the order E6.',
#   'section 10 is most important as the impounding of the passport ,of the petitioner was ordered under\nsection 10(3)\n(c) of the act. section 10(1) enables the passport authority to A5 on a\npassport or travel document or may with the previous approval of the central government, vary or\ncancel the conditions subject to which a passport or travel document has been issued, and require-\nthe holder of a passport or a travel document by notice in writing, to deliver up the passport or\ntravel document to it within such time as may be specified in the notice. sub-section (2) enables the\nbolder of a passport or a travel document to vary or cancel the conditions of the passport.',
#   'section 8 provides that every passport shall be\nrenewable for the same period for which the passport was originally issued unless the passport\nauthority for reasons to be recorded in witing otherwise determines. section 10 is most important as the impounding of the passport ,of the petitioner was ordered under\nsection 10(3)\n(c) of the act. section 10(1) enables the passport authority to A5 on a\npassport or travel document or may with the previous approval of the central government, vary or\ncancel the conditions subject to which a passport or travel document has been issued, and require-\nthe holder of a passport or a travel document by notice in writing, to deliver up the passport or\ntravel document to it within such time as may be specified in the notice.',
#   'then we come to\nsection 10 which is the material section which falls for consideration. sub-section (1) of that section\nempowers the passport authority to A5 of a passport or travel document\nor to vary or cancel the conditions subject to which a passport or travel document has been issued,\nhaving regard, inter alia, to the provisions of sub-section (1) of section 6 or any notification. under\nsection 19, sub-section (2) confers powers on the passport authority to vary or cancel the conditions\nof the passport or travel document on application of the holder of the passport or travel document\nand with the previous approval of the central government.',
#   'kailasam, j.-this petition is filed by mrs. maneka gandhi under article 32 of the constitution of\nindia against the union of india and the regional pass port officer for a writ of certiorari for calling\nfor the records of the case including in particular the order dated july 2, 1977 made by the union of\nindia under section 10(3) (c) of the passports act, act 15 of 1967, E6 of the\npetitioner and for quashing the said order. the petitioner received a letter dated july 2, 1977 on july 4, 1977 informing her that it had been\ndecided by the government of india to impound her passport. the letter read as follows "you may\nrecall that a passport no.',
#   "the passport authority is also required by\nsub-section (5) of section 10 to record in writing a brief statement of the reasons for making an\norder impounding a passport and, save in certain exceptional situations, the passport authority is\nobliged to furnish a copy of the statement of reasons to the bolder of the passport.maneka gandhi vs union of india on 25 january, 1978\nindian kanoon - http://indiankanoon.org/doc/1766147/ 63where the passport authority which has im- pounded a passport is other than the central\ngovernment, a right of appeal against the order E6 is given by section 11, and\nin the appeal, the validity of the reasons given by the passport authority for impounding the\npassport can be canvassed before the appellate authority. it is clear on a consideration of these\ncircumstances that the test laid down in the decisions of this court for distinguishing between a\nquasi-judicial power and an administrative power is satisfied and the power conferred on the\npassport authority to impound a passport is quasi-judicial power. the rules of natural justice would,\nin the circumstances, be applicable in the exercise of the power of impounding a passport even on\nthe orthodox view which prevailed prior to a. k. kraipak's case.",
#   'the power to refuse to disclose the reasons for impounding a\npassport is of an exceptional nature and it ought to be exercised fairly, sparingly and only when fully\njustified by the exigencies of an uncommon situation. the reasons, if disclosed being open to judicial\nscrutiny for ascertaining their nexus with the order E6 the refusal to disclose\nthe reasons would equally be open to the scrutiny of the court; or else, the wholesome power of amaneka gandhi vs union of india on 25 january, 1978\nindian kanoon - http://indiankanoon.org/doc/1766147/ 43dispassionate judicial examination of executive orders could with impunity be set at naught by an\nobdurate determination to suppress the reasons. law cannot permit the exercise of a power to keep\nthe reasons undisclosed if the sole reason for doing so is to keep the reasons away from judicial\nscrutiny.',
#   'what he urged was a very limited contention, namely that having\nregard to the nature of the action involved in the impounding of a passport, the audi alteram partem\nrule must be held to, be excluded, because if notice were to be given to the hol- der of the passport\nand reasonable opportunity afforded to him to show cause why his passport should not be\nimpounded, he might immediately, on the strength of the passport, make good his exit from the\ncountry and the object of E6 would be frustrated. the argument was that if\nthe audi alteram partem rule were applied, its effect would be to stultify the power of impounding\nthe passport and it would defeat and paralyse the administration of the law and hence the audi\nalteram partem rule cannot in fairness be applied while exercising the power to impound a passport. this, argument was sought to be supported by reference to the statement of the law in a.s. de smith,\njudicial review of administrative action, 2nd ed., where the learned author says at page 174 that "in\nadministrative, law a prima facie right to prior notice and opportunity to be heard may be held to be\nexcluded by implication-where an obligation to give notice and opportunity to be heard would\nobstruct the taking of prompt action, especially action of a preventive or remedial nature".',
#   'the petitioner then contended that the requirement that she should be available for giving evidence\nbefore the commissions of inquiry did not warrant the making of the impugned order "in the\ninterests of the general public". section 10(3),according to the petitioner, contained clauses\n(e) and (h) dealing specifically with cases where a person is required in connection with a legal\nproceeding and the enactment of these two specific provisions clearly indicated the legislative intent\nthat the general power in section 10(3) (c) under the ground "interests of the general public"\nwas not meant to be exercised for impounding a passport in cases where a person is\nrequired in connection with a legal proceeding. the central government was,\ntherefore, not entitled to resort to this general power under section 10(3)\n(c) for the purpose of E6 of the petitioner on the ground that\nshe was (1) 1969] 3 s.c.r.',
#   'the learned attorney general,  however,  made  a\nstatement  on  behalf of the government of  india  that  the\ngovernment  was agreeable to considering any  representation\nthat  may  be  made  by the petitioner  in  respect  of  the\nE1 and giving her an opportunity  in\nthe matter, and that the representation would be dealt  with\nexpeditiously  in  accordance  with  law. this   statement\nremoves the vice from the order E6  and\nit can no longer be assailed on the ground that it does  not\ncomply with the audi alteram partem rule or is not in accord\nwith the procedure prescribed by the act. [683 c-g]\nthe  law is well settled that when a statute vests  unguided\nand unrestricted power in an authority to affect the  rights\nof  a  person without laying down any  policy  or  principle\nwhich is to guide the authority,, in exercise of the  power,\nit would be affected by the vice of discrimination since  it\nwould leave it open to the authority to discriminate between\npersons  and  things  similarly situated.',
#   'that is, however, not\nthe question before us at present. we may observe that if the impugned order E6 of the petitioner were\nviolative, of her right to freedom of speech and expression or her right to carry on her profession as\na journalist, it would not be saved by article 19(2) or article 19(6), because the impounding of the\npassport for an indefinite length of time would clearly constitute an unreasonable restriction. the\nunion contended that though the period for which the impugned order was to operate was not\nspecified in so many terms, it was clear that it was intended to be co-terminous with the duration of\nthe commission of inquiry, since the reason for impounding was that the presence of the petitioner\nwas likely to be required in connection with the proceedings before the com- mission of inquiry and\nthe term of the commission of inquiry being limited upto 31st december, 1977, the impoundig of\nthe passport could not continue beyond that date and hence it would not be said that the impugned\norder was to operate for an indefinite period of time.',
#   'the,\npetition also contained a challenge that an order under section 10(3) (c) impounding\na passport could not be made by the passport authority without giving an\nopportunity to the holder of the passportto be heard in defence and since in the\npresent case, the passport was impounded by the government without affording an\napportunity of hearingto the petitioner, the order was null and void, and in the\nalternativeif section 10(3) (c) were read in such a manner as to exclude the right of\nhearing, the section would be infected with the vice ofarbitrariness and it would be\nvoid as offending article 14. these were the only grounds taken in the petition as\noriginally filed and on 20th july, 1977 the petition was E8 by\nthis court and an interim order was made directing that the passport of the petitioner\nshould continue to remain deposited with the registrar of this court pending the\nhearing and final disposal of the petition. the hearing of the petition was fixed on\n30th august 1977, but before that, the petitioner filed an application for urging\nadditional grounds and by this application, two further grounds were sought to be\nurged by her.',
#   'the  central  government was  wholly  unjustified  in\nwithholding the reasons for E6 and this\nwas  not only in breach of the statutory provisions  but  it\nalso  amounted  to denial of opportunity of hearing  to  the\npetitioner. the  order  impounding  the  passport  of  the\npetitioner was, therefore, clearly in violation of the  rule\nof natural justice embodied in the maxim audi alteram partem\nand  was not in conformity with the procedure prescribed  by\nthe  act. the learned attorney general,  however,  made  a\nstatement  on  behalf of the government of  india  that  the\ngovernment  was agreeable to considering any  representation\nthat  may  be  made  by the petitioner  in  respect  of  the\nE1 and giving her an opportunity  in\nthe matter, and that the representation would be dealt  with\nexpeditiously  in  accordance  with  law.',
#   'then follows sub-section (5) which requires the passport authority\nimpounding or E7 or varying or canceling an endorsement\nmade upon it to "record in writing a brief statement of the reasons for making such order and\nfurnish to the holder of the passport or travel document on demand a copy of the same unless, in\nany case, the passport authority is of the opinion that it will not be in the interests of the soveriegnty\nand integrity of india, the security of india, friendly relations of india with my foreign country or in\nthe interests of the general public to furnish such a copy." it was in virtue of the provision contained\nin the latter part of this sub-section that the central government declined to furnish a copy of the\nstatement of reasons for E6 of the petitioner on the ground that it was not in\nthe interests of the general public to furnish such copy to the petitioner. it is indeed a matter of\nregret that the central government should have taken up this attitude in reply to the request of the\npetitioner to be supplied a copy of the statement of reasons, because ultimately, when the petition\ncame to be filed, the central government did disclose the reasons in the affidavit in reply to the\npetition which shows that it was not really contrary to public interest and if we look at the reasons\ngiven in the affidavit in reply, it will be clear that no reasonable person could possibly have taken the\nview that the interests of the general public would be prejudiced by the disclosure of the reasons.',
#   'these  words are in fact borrowed ipsissima verba  from  art\n19(5) and it would be nothing short of heresay to accuse the\nconstitution makers of vague and loose thinking. sufficient\nguidelines  are  provided by the act itself  and  the  power\nconferred  on the passport authority to impound  a  passport\ncannot  be said to be unguided or unfettered. moreover  the\nexercise  of  this  power  is  not  made  dependent  on  the\nsubjective opinion of the passport authority as regards  the\nnecessity of exercising it on one or more grounds stated  in\ns.10(3)(c), but the passport authority is required to record\nin  writing a brief statement of reasons for impounding  the\npassport  and  save in  certain  exceptional  circumstances,\nsupply  a  copy of such statement of reasons to  the  person\naffected  so  that the person concerned  can  challenge  the\ndecision of the passport authority in appeal and the  appel-\nlate authority can examine whether the reasons given by  the\npassport autho-\n632\nrity  are correct and if so whether they justify the  making\nof the order E6.',
#   "we must, therefore, hold that the procedure 'established' by the\npassports act, 1967 for impounding a passport is in conformity with the requirement of article 21\nand does not fall foul of that article. but the question then immediately arises whether the central government has complied with this\nprocedure in E6 of the petitioner. now, it is obvious and indeed this could not\nbe controverted that the central government not only did not give an opporgive an opportunity of\nhearing to the petitioner after making the impugned order im- pounding her passport but even\ndeclined to furnish to the petitioner the reasons for E4 despite request made\nby her.",
#   'section 6(2)  specifies  the\ngrounds on which alone and on no other grounds the  passport\nauthority  shall  refuse  to issue the  passport  or  travel\ndocument  for  visiting  any  foreign  country  and  amongst\nvarious  grounds  set  out there the last  is  that  in  the\nopinion  of the central government the issue of passport  or\ntravel  document to the applicant will not be in the  public\ninterest. sub-section  (1)  of  section  10  empowers  the\npassport  authority to A5  on  a\npassport  or travel document or to vary or cancel it on  the\nconditions  subject to which a passport or  travel  document\nhas been issued having regard to, inter alia, the provisionsmaneka gandhi vs union of india on 25 january, 1978\nindian kanoon - http://indiankanoon.org/doc/1766147/ 4of s. 6(1) or any notification under s. 19. sub-section  (2)\nconfers  powers on the passport authority to vary or  cancel\nthe  conditions  of the passport or travel document  on  the\napplication of the holder of the passport or travel document\nand  with the previous approval of the  central  government.',
#   'the  order  impounding  the  passport  of  the\npetitioner was, therefore, clearly in violation of the  rule\nof natural justice embodied in the maxim audi alteram partem\nand  was not in conformity with the procedure prescribed  by\nthe  act. the learned attorney general,  however,  made  a\nstatement  on  behalf of the government of  india  that  the\ngovernment  was agreeable to considering any  representation\nthat  may  be  made  by the petitioner  in  respect  of  the\nE1 and giving her an opportunity  in\nthe matter, and that the representation would be dealt  with\nexpeditiously  in  accordance  with  law. this   statement\nremoves the vice from the order E6  and\nit can no longer be assailed on the ground that it does  not\ncomply with the audi alteram partem rule or is not in accord\nwith the procedure prescribed by the act.',
#   'the ordermaneka gandhi vs union of india on 25 january, 1978\nindian kanoon - http://indiankanoon.org/doc/1766147/ 9should  be quashed and the respondent should be directed  to\ngive an opportunity to the petitioner to show cause  against\nany proposed action on such grounds as may be available. [656 e-g]\nthere were no pressing grounds with regard to the petitioner\nthat  the  immediate action of impounding her  passport  was\ncalled  for. the  rather cavalier  fashion  in  which  the\ndisclosure of any reason for E1  was\ndenied  to  the petitioner despite the fact  that  the  only\nreason said to exist is the possibility of her being  called\nto  give  evidence before a commission of inquiry.',
#   'rule is excluded merely because the power to\nimpound a passport might be frustrated, if prior notice  and\nhearing  were  to be given to the  person  concerned  before\nimpounding his passport. the passport authority may proceed\nto impound the passport without giving any prior opportunity\nto  the  person concerned to be heard, but as  soon  as  the\norder impounding\n631\nthe passport is made, an opportunity of hearing, remedial in\naim, should be given to him so that he may present his  case\nand controvert that of the\npassport authority and point out why his passport should notmaneka gandhi vs union of india on 25 january, 1978\nindian kanoon - http://indiankanoon.org/doc/1766147/ 17be  impounded  and the order impounding it  recalled. this\nshould  not  only be possible but  also  quite  appropriate,\nbecause the reasons for E6 are required\nto be supplied by the passport authority after the making of\nthe order and the person affected would, therefore, be in  a\nposition to A13 setting forth his case and\nplead for setting aside the action impounding his  passport.',
#   'we cannot disable article 14 or 19 from so\nfunctioning and hold those executive and legislative actions to which they could apply\nas unquestionable even when there is no emergency to shield actions of doubtful\nlegality. these tests are, in my opinion, available to us now to determine the\nconstitutional validity of section 10 (3) (c) of the act as well as of the impugned order\nof 7th july, 1977, passed against the petitioner E4 "in the\ninterest of general public" and stating that the government bad decided not to\nfurnish her with a copy of reasons and claiming immunity from such disclosure\nunder section 10(5) of the act. i have already mentioned some of the authorities relied upon by me in a. d. m.\njabalpur v. s. shukla (supra), while discussing the scope of article 21 of the\nconstitution, to hold that its ambit is very wide.',
# ...
#   'the petitioner\nimmediately addressed a letter to the regional passport officer requesting him to furnish a copy of\nthe statement of reasons for making the order as provided in section 10(5) to which a reply was sent\nby the government of india, ministry of external affairs on 6th july, 1977 stating inter alia that the\ngovernment has decided "in the interest of the general public" not to furnish her a copy of the\nstatement of reasons, for making of the order. the petitioner thereupon filed the present petition\nchallenging the action of the government in E4 and declining to give reasons\nfor doing so. the action of the government was impugned inter alia on the ground that it was mala\nfide, but this challenge was not pressed before us at the time of the hearing of the arguments and\nhence it is not necessary to state any facts hearing on that question.'],
#  'admitted and rule issued': ['14 of the constitution, since the\ncondition denoted by the words "in the interests of the general public" limiting the\nexercise of the power is vague and undefined and the power conferred by this\nprovision is, therefore, excessive and suffers from the vice of "over-breath." the,\npetition also contained a challenge that an order under section 10(3) (c) impounding\na passport could not be made by the passport authority without giving an\nopportunity to the holder of the passportto be heard in defence and since in the\npresent case, the passport was impounded by the government without affording an\napportunity of hearingto the petitioner, the order was null and void, and in the\nalternativeif section 10(3) (c) were read in such a manner as to exclude the right of\nhearing, the section would be infected with the vice ofarbitrariness and it would be\nvoid as offending article 14. these were the only grounds taken in the petition as\noriginally filed and on 20th july, 1977 the petition was E8 by\nthis court and an interim order was made directing that the passport of the petitioner\nshould continue to remain deposited with the registrar of this court pending the\nhearing and final disposal of the petition.',
#   'the,\npetition also contained a challenge that an order under section 10(3) (c) impounding\na passport could not be made by the passport authority without giving an\nopportunity to the holder of the passportto be heard in defence and since in the\npresent case, the passport was impounded by the government without affording an\napportunity of hearingto the petitioner, the order was null and void, and in the\nalternativeif section 10(3) (c) were read in such a manner as to exclude the right of\nhearing, the section would be infected with the vice ofarbitrariness and it would be\nvoid as offending article 14. these were the only grounds taken in the petition as\noriginally filed and on 20th july, 1977 the petition was E8 by\nthis court and an interim order was made directing that the passport of the petitioner\nshould continue to remain deposited with the registrar of this court pending the\nhearing and final disposal of the petition. the hearing of the petition was fixed on\n30th august 1977, but before that, the petitioner filed an application for urging\nadditional grounds and by this application, two further grounds were sought to be\nurged by her.'],
#  'revoking a passport or travel document': ['the passport authority would have to satisfy the court by placing proper material that\nthe giving of reasons would be clearly and indubitably against the interests of the general public and\nif the court is not so satisfied, the court may require the passport authority to disclose the reasons,\nsubject to any valid and lawful claim for privilege which may be set up on behalf of the government. here in the present case, as we have already pointed out, the central government did initially claim\nthat it would be against the interests of the general public to disclose the reasons for impounding the\npassport, but when it, came to filing the affidavit in reply, the central government very properly\nabandoned this unsustainable claim and disclosed the reasons the question whether these reasons\nhave any nexus with the interests of the general public or they are extraneous and irrelevant is a\nmatter which we shall examine when we deal with the arguments of the parties, ,meanwhile,maneka gandhi vs union of india on 25 january, 1978\nindian kanoon - http://indiankanoon.org/doc/1766147/ 51proceeding further with the resume of the relevant provisions, reference may be made to section 11\nwhich provides for an appeal inter alia against the order impounding or revoking a passport or\ntravel document under sub-section (3) of section 10. but there is a proviso to this section which says\nthat if the order impounding or E7 is passed by the central\ngovernment, there shall be no right to appeal.',
#   "but there is a proviso to this section which says\nthat if the order impounding or E7 is passed by the central\ngovernment, there shall be no right to appeal. these are the relevant provisions of the act in the\nlight of which we have to consider the constitutionality of sub- section (3) (c) of section 10 and the\nvalidity of the order E6 of the petitioner. meaning and content of personal\nliberty in article 21 the first contention urged on behalf of the petitioner in support of the petition\nwas that the right to go abroad is part of 'personal liberty within the meaning of that expression as\nused in article 21 and no one can.",
#   'sub-section (3) provides that the\npassport authority may impound or cause to be impounded or revoke a passport or travel document\non the grounds set out in clauses (a) to\n(h), the order E6 in the present case was made by the central government\nunder clause (c) which reads as follows:--maneka gandhi vs union of india on 25 january, 1978\nindian kanoon - http://indiankanoon.org/doc/1766147/ 50"(c) if the passport authority deems it necessary so to do in the interest of the\nsovereignty and integrity of india, the security of india, friendly relations of india\nwith any foreign country, or in the interests of the general public;"\nthe particular ground relied upon for making the order was that set out in the last part of clause (c),\nnamely, that the central government deems it necessary to impound the passport "in the interests\nof the general public." then follows sub-section (5) which requires the passport authority\nimpounding or E7 or varying or canceling an endorsement\nmade upon it to "record in writing a brief statement of the reasons for making such order and\nfurnish to the holder of the passport or travel document on demand a copy of the same unless, in\nany case, the passport authority is of the opinion that it will not be in the interests of the soveriegnty\nand integrity of india, the security of india, friendly relations of india with my foreign country or in\nthe interests of the general public to furnish such a copy." it was in virtue of the provision contained\nin the latter part of this sub-section that the central government declined to furnish a copy of the\nstatement of reasons for E6 of the petitioner on the ground that it was not in\nthe interests of the general public to furnish such copy to the petitioner.',
#   'under\nsection 19, sub-section (2) confers powers on the passport authority to vary or cancel the conditions\nof the passport or travel document on application of the holder of the passport or travel document\nand with the previous approval of the central government. sub-section (3) provides that the\npassport authority may impound or cause to be impounded or revoke a passport or travel document\non the grounds set out in clauses (a) to\n(h), the order E6 in the present case was made by the central government\nunder clause (c) which reads as follows:--maneka gandhi vs union of india on 25 january, 1978\nindian kanoon - http://indiankanoon.org/doc/1766147/ 50"(c) if the passport authority deems it necessary so to do in the interest of the\nsovereignty and integrity of india, the security of india, friendly relations of india\nwith any foreign country, or in the interests of the general public;"\nthe particular ground relied upon for making the order was that set out in the last part of clause (c),\nnamely, that the central government deems it necessary to impound the passport "in the interests\nof the general public." then follows sub-section (5) which requires the passport authority\nimpounding or E7 or varying or canceling an endorsement\nmade upon it to "record in writing a brief statement of the reasons for making such order and\nfurnish to the holder of the passport or travel document on demand a copy of the same unless, in\nany case, the passport authority is of the opinion that it will not be in the interests of the soveriegnty\nand integrity of india, the security of india, friendly relations of india with my foreign country or in\nthe interests of the general public to furnish such a copy."',
#   'then follows sub-section (5) which requires the passport authority\nimpounding or E7 or varying or canceling an endorsement\nmade upon it to "record in writing a brief statement of the reasons for making such order and\nfurnish to the holder of the passport or travel document on demand a copy of the same unless, in\nany case, the passport authority is of the opinion that it will not be in the interests of the soveriegnty\nand integrity of india, the security of india, friendly relations of india with my foreign country or in\nthe interests of the general public to furnish such a copy." it was in virtue of the provision contained\nin the latter part of this sub-section that the central government declined to furnish a copy of the\nstatement of reasons for E6 of the petitioner on the ground that it was not in\nthe interests of the general public to furnish such copy to the petitioner. it is indeed a matter of\nregret that the central government should have taken up this attitude in reply to the request of the\npetitioner to be supplied a copy of the statement of reasons, because ultimately, when the petition\ncame to be filed, the central government did disclose the reasons in the affidavit in reply to the\npetition which shows that it was not really contrary to public interest and if we look at the reasons\ngiven in the affidavit in reply, it will be clear that no reasonable person could possibly have taken the\nview that the interests of the general public would be prejudiced by the disclosure of the reasons.',
#   'here in the present case, as we have already pointed out, the central government did initially claim\nthat it would be against the interests of the general public to disclose the reasons for impounding the\npassport, but when it, came to filing the affidavit in reply, the central government very properly\nabandoned this unsustainable claim and disclosed the reasons the question whether these reasons\nhave any nexus with the interests of the general public or they are extraneous and irrelevant is a\nmatter which we shall examine when we deal with the arguments of the parties, ,meanwhile,maneka gandhi vs union of india on 25 january, 1978\nindian kanoon - http://indiankanoon.org/doc/1766147/ 51proceeding further with the resume of the relevant provisions, reference may be made to section 11\nwhich provides for an appeal inter alia against the order impounding or revoking a passport or\ntravel document under sub-section (3) of section 10. but there is a proviso to this section which says\nthat if the order impounding or E7 is passed by the central\ngovernment, there shall be no right to appeal. these are the relevant provisions of the act in the\nlight of which we have to consider the constitutionality of sub- section (3) (c) of section 10 and the\nvalidity of the order E6 of the petitioner.'],
#  '24-4-67, NULL': ['a reply\nwas  sent by the government of india, ministry  of  external\naffairs  on  6th  july  1977 stating  inter  alia  that  the\ngovernment  decided "in the interest of the general  public"\nnot to furnish her copy of the statement of reasons for  themaneka gandhi vs union of india on 25 january, 1978\nindian kanoon - http://indiankanoon.org/doc/1766147/ 3making  of  the order. the petitioner thereupon  filed  the\npresent  writ petition challenging action of the  government\nin-  E4 and declining to  give  reasons\nfor doing so. the act was enacted on T9 in view of the\ndecision of this court in satwant singg sawhney\'s case.'],
#  'six months, NULL': ['pending the consideration of the petitioner\'s represen- tation and until the decision of the\ngovernment of india thereon, the petitioner\'s passport shall remain in custody of this honourable\ncourt.maneka gandhi vs union of india on 25 january, 1978\nindian kanoon - http://indiankanoon.org/doc/1766147/ 1495. this will be without prejudice to the power of the government of india to take such action as it\nmay be advised in accordance with the provisions of the passport act in respect of the petitioner\'s\npassport." in view of the statement that the petitioner may A13 in respect of impounding of\npassport and that the representations will be dealt with expeditiously and that even if the\nimpounding of the passport is confirmed it will not exceed a period of T13 from the date, of\nthe decision that may be taken on the petitioner\'s repre- sentation, it is not necessary for me to go\ninto the merits of the case any further.',
#   'this will be without prejudice to the power of the government of india to take such action as it\nmay be advised in accordance with the provisions of the passport act in respect of the petitioner\'s\npassport." in view of the statement that the petitioner may A13 in respect of impounding of\npassport and that the representations will be dealt with expeditiously and that even if the\nimpounding of the passport is confirmed it will not exceed a period of T13 from the date, of\nthe decision that may be taken on the petitioner\'s repre- sentation, it is not necessary for me to go\ninto the merits of the case any further. the attorney general assured us that all the grounds urged\nbefore us by the petitioner and the grounds that may be urged before the authority will be properly\nconsidered by the authority and appropriate orders passed.'],
#  'two weeks, NULL': ['the opportunity will be, given within T12 of the\nreceipt of the representation. it is clarified that in the present case the grounds for\nE6 are those mentioned in the affidavit in reply dated 18th\naugust, 1977 of shri ghosh except those mentioned in para 2 (xi). 2.the representation of the petitioner will be dealt with expeditiously in accordance\nwith law.maneka gandhi vs union of india on 25 january, 1978\nindian kanoon - http://indiankanoon.org/doc/1766147/ 66this statement removes the voice from the order E6 and it can\nno longer be assailed on the ground that it does not comply with the audi alteram\npartem rule or is.',
#   'realising that this was a fatal defect which\nwould void the order E6 the learned attomey-general made a statement on\nbehalf of the government of india to the following effect :\n"1. the government is agreeable to considering any representation that may be made\nby the petitioner in respect of the E1 and giving her an\nopportunity in the matter. the opportunity will be, given within T12 of the\nreceipt of the representation.']}

# %%
with open("output.txt", "w") as f:
    f.write(str(sentences_dict))
