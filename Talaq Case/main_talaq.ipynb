# %%
import PyPDF2

# %%
def pdf_to_txt(pdf_file_path, txt_file_path):
    with open(pdf_file_path, 'rb') as pdf_file:
        pdf_reader = PyPDF2.PdfReader(pdf_file)
        
        text = ""
        for page_num in range(len(pdf_reader.pages)):
            page = pdf_reader.pages[page_num]
            text += page.extract_text().rstrip()

    with open(txt_file_path, 'w', encoding='utf-8') as txt_file:
        txt_file.write(text)

# %%
pdf_to_txt('/Users/Desktop/ACM CONFERENCE WORK/FINAL_LIST_DOCS/Supreme-Court-of-India-Judgment-WPC-No.118-of-2016-Triple-Talaq.pdf', 'talaq.txt')

# %%
import pandas as pd
import nltk
nltk.download('punkt')  # Download the required NLTK data

# %%
def find_related_sentences(sentences, keyword):
    related_sentences = []

    for i, sentence in enumerate(sentences):
        if keyword in sentence:
            prev_sentence = sentences[i - 1].strip() if i > 0 else None
            next_sentence = sentences[i + 1].strip() if i < len(sentences) - 1 else None
            related_sentences.append({
                "Sentence": sentence.strip(),
                "Previous": prev_sentence,
                "Next": next_sentence
            })

    return related_sentences

# %%
with open('/Users/Desktop/ACM CONFERENCE WORK/codes/Talaq Case/talaq.txt', "r") as file:
    text = file.read()

# Tokenize into sentences using nltk.sent_tokenize()
sentences = nltk.sent_tokenize(text)

keyword = "Law"
result = []

related_sentences = find_related_sentences(sentences, keyword)
result.extend(related_sentences)

# Create a DataFrame with columns "Sentence," "Previous," and "Next"
output_df = pd.DataFrame(result, columns=["Sentence", "Previous", "Next"])

# Save results to a new CSV
output_df.to_csv("output_sentences_talaq.csv", index=False)

# %%
encodings_to_try = ['utf-8', 'latin1', 'utf-16', 'ISO-8859-1']

# Try reading the CSV file with different encodings
for encoding in encodings_to_try:
    try:
        output_df = pd.read_csv("output_sentences_talaq.csv", encoding=encoding)
        print("CSV file read successfully with encoding:", encoding)
        break  # Exit loop if successful
    except UnicodeDecodeError:
        print("Failed to read CSV file with encoding:", encoding)
        continue  # Try next encoding
# Out:
# CSV file read successfully with encoding: utf-8

# %%
output_df
# Out:
#                                               Sentence  \
# 0               Laws of Arab States  (i) – (xiii) \nB.
# 1    Laws of Southeast Asian States  (i) – (iii) \n...
# 2    140 -14 5 \nV.  Did the Muslim Personal Law (S...
# 3    It is also her contention, that such a divorce...
# 4    It is \ntherefore, that the Muslim Personal La...
# ..                                                 ...
# 157  (See Dicey — “Law of the \nConstitution” — 10t...
# 158  “Law has reached its finest moments”, \nstated...
# 159  Dicey, the great \nexpounder of the rule of la...
# 160  [See Wade and Phillips: \nConstitutional Law (...
# 161  ‘Law’ is reasonable \nlaw, not any enacted piece.
#
#                                               Previous  \
# 0    Part -5 Abrogation of the practice of ‘talaq -...
# 1               Laws of Arab States  (i) – (xiii) \nB.
# 2    If yes, whether it is a \nconstituent of their...
# 3    The petitioner has sought a declaration , that...
# 4    Muslim women \nclaimed, that the Muslim ‘perso...
# ..                                                 ...
# 157  If a 340 decision is taken without any princip...
# 158  (See Dicey — “Law of the \nConstitution” — 10t...
# 159  And the \nConstitutional law of 1975 has under...
# 160  We \nmay not therefore rely wholly on Dicey’s ...
# 161  To sum up, ‘procedure’ in \nArticle 21 means f...
#
#                                                   Next
# 0    Laws of Southeast Asian States  (i) – (iii) \n...
# 1    Part -6 Judicial pronouncements, on the subjec...
# 2                                      14 6-15 7 \nVI.
# 3    During the course of hearing, it was submitted...
# 4    It is essential to \nunderstand, the backgroun...
# ..                                                 ...
# 157  “Law has reached its finest moments”, \nstated...
# 158  Where discretion, is \nabsolute, man has alway...
# 159  But \nso much, I suppose, can be said with \nr...
# 160  70-73)] \nThe International Commission of Juri...
# 161  As \nArticle 22 specifically spells out \nthe ...
#
# [162 rows x 3 columns]

# %%
concatenated_sen = pd.DataFrame(output_df['Previous'].astype(str) + ' ' + output_df['Sentence'].astype(str) + ' ' + output_df['Next'].astype(str), columns=['concat'])

# %%
print(concatenated_sen['concat'].iloc[0])
# Out:
# Part -5 Abrogation of the practice of ‘talaq -e-biddat’ by
# legislation, the world over, in Islamic, as well
# as, non-Islamic States  28 - 29
# A. Laws of Arab States  (i) – (xiii)
# B. Laws of Southeast Asian States  (i) – (iii)
# C.  Laws of Sub -continental States  (i) – (ii)
# 6.

# %%
concatenated_sen.to_csv('sentences_final_concatenated_talaq.csv', index=False)

# %%
import csv

# %%
def create_person_id_map(file_path):
    person_id_map = {}

    with open(file_path, 'r') as csvfile:
        reader = csv.reader(csvfile)
        header = next(reader)
        
        for row in reader:
            person_id_list = row[0]
            person = person_id_list.strip()
            person_id = row[1].strip()
            person_id_map[person] = person_id

    return person_id_map

def create_location_id_map(file_path):
    location_id_map = {}

    with open(file_path, 'r') as csvfile:
        reader = csv.reader(csvfile)
        header = next(reader)
        
        for row in reader:
            location_id_list = row[0]
            location = location_id_list.strip()
            location_id = row[1].strip()
            location_id_map[location] = location_id

    return location_id_map

def create_time_id_map(file_path):
    time_id_map = {}

    with open(file_path, 'r') as csvfile:
        reader = csv.reader(csvfile)
        header = next(reader)
        
        for row in reader:
            time_id_list = row[0].split(',')
            time = time_id_list.strip()
            time_id = row[1].strip()
            time_id_map[time] = time_id

    return time_id_map

def create_event_id_map(file_path):
    event_id_map = {}

    with open(file_path, 'r') as csvfile:
        reader = csv.reader(csvfile)
        header = next(reader)
        
        for row in reader:
            event_id_list = row[0].split(',')
            event = event_id_list.strip()
            event_id = row[1].strip()
            event_id_map[event] = event_id

    return event_id_map

def create_other_id_map(file_path):
    other_id_map = {}

    with open(file_path, 'r') as csvfile:
        reader = csv.reader(csvfile)
        header = next(reader)
        
        for row in reader:
            other_id_list = row[0].split(',')
            other = other_id_list.strip()
            other_id = row[1].strip()
            other_id_map[other] = other_id

    return other_id_map

# %%
file_path_person = '/Users/Desktop/ACM CONFERENCE WORK/Entities/Talaq Case/person.csv'
file_path_location = '/Users/Desktop/ACM CONFERENCE WORK/Entities/Talaq Case/location.csv'
file_path_time = '/Users/Desktop/ACM CONFERENCE WORK/Entities/Talaq Case/time.csv'
file_path_event = '/Users/Desktop/ACM CONFERENCE WORK/Entities/Talaq Case/event.csv'
file_path_other = '/Users/Desktop/ACM CONFERENCE WORK/Entities/Talaq Case/activity.csv'
person_id_map = create_person_id_map(file_path_person)
location_id_map = create_location_id_map(file_path_location)
time_id_map = create_location_id_map(file_path_time)
event_id_map = create_location_id_map(file_path_event)
other_id_map = create_location_id_map(file_path_other)

# %%
def generate_ngrams(text, n=6):
    words = text.split()
    ngrams = []
    for j in range(n, 0, -1):
        for i in range(len(words)):
            if i + j <= len(words):
                ngrams.append(' '.join(words[i:i+j]))
    return ngrams

# %%
def preprocess_text(text):
    text = text.replace("'s", "")
    text = text.replace(".", "")
    text = text.replace(";", "")
#     text = text.replace("-", "")
    text = text.replace("!", "")
    text = text.replace("?", "")
#     text = text.replace("/", "")
    text = text.replace("@", "")
    text = text.replace("#", "")
    text = text.replace(",", "")
    return text

# %%
def replace_entities(text):
    text = text.lower()
    ngrams = generate_ngrams(text)
    replaced_text = text

    for ngram in ngrams:
        original = ngram.lower()
        
        if original in person_id_map:
            entity_id = person_id_map[original]
            replaced_text = replaced_text.replace(ngram, entity_id)
        else:
            preprocessed_ngram = preprocess_text(ngram.lower())
            if preprocessed_ngram in person_id_map:
                entity_id = person_id_map[preprocessed_ngram]
                replaced_text = replaced_text.replace(ngram, entity_id)
            else:
                if original in location_id_map:
                    entity_id = location_id_map[original]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif preprocessed_ngram in location_id_map:
                    entity_id = location_id_map[preprocessed_ngram]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif original in time_id_map:
                    entity_id = time_id_map[original]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif preprocessed_ngram in time_id_map:
                    entity_id = time_id_map[preprocessed_ngram]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif original in event_id_map:
                    entity_id = event_id_map[original]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif preprocessed_ngram in event_id_map:
                    entity_id = event_id_map[preprocessed_ngram]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif original in other_id_map:
                    entity_id = other_id_map[original]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif preprocessed_ngram in other_id_map:
                    entity_id = other_id_map[preprocessed_ngram]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                    
    return replaced_text

# %%
with open('sentences_final_concatenated_talaq.csv', 'r', encoding='latin-1') as csvfile:
     reader = csv.reader(csvfile)
     next(reader)
     ref_sen = []
     for row in reader:
         sentence = row[0]
         ref_sen.append(sentence)

# %%
from IPython.display import HTML, display
import html

CSS = """
<style>
.annotated { font-family: Inter, Arial; line-height:1.6; }
.entity {
  display: inline-block;
  position: relative;
  padding: 2px 6px;
  margin: 0 2px;
  border-radius: 6px;
  font-weight: 600;
}
.entity .label {
  display: block;
  font-size: 10px;
  text-transform: uppercase;
  letter-spacing: .6px;
  margin-top: 2px;
  opacity: 0.9;
}
.badge {
  opacity: 0.9;
  padding: 1px 5px;
  border-radius: 6px;
  font-size: 10px;
  font-weight: 700;
  display:inline-block;
}
</style>
"""

# A palette of colors to cycle through for labels
PALETTE = {
    "PERSON":    ("#ffe8e6", "#c23b3b"),
    "LOCATION":  ("#e8f7ff", "#1e90ff"),
    "TIME":      ("#fff8e6", "#d98e00"),
    "EVENT":     ("#f0e9ff", "#7a4bb2"),
    "OTHER":     ("#e6fff2", "#0f9d58"),
    # fallback
    "DEFAULT":   ("#f2f2f2", "#333")
}

def highlight_html_from_spans(original_text, spans):
    """
    Given original_text (string) and spans (list of dicts with start,end,label,text),
    produce HTML with colored chips and small label below each entity.
    Safe when some spans have start=None (not located).
    """
    parts = []
    last = 0

    # Only consider spans that actually have start offsets for inline placement
    inline_spans = [s for s in spans if s.get('start') is not None]
    inline_spans = sorted(inline_spans, key=lambda x: int(x['start']))  # safe: all starts are ints

    for s in inline_spans:
        # If there's text between last and this entity, add it escaped
        if s['start'] > last:
            parts.append(html.escape(original_text[last:s['start']]))

        label = s.get('label', 'DEFAULT').upper()
        bg, fg = PALETTE.get(label, PALETTE['DEFAULT'])
        ent_html = (
            f"<span class='entity' style='background:{bg}; color:{fg};'>"
            f"{html.escape(s['text'])}"
            f"<span class='label' style='color:{fg};'>{html.escape(label)}</span>"
            f"</span>"
        )
        parts.append(ent_html)
        last = s['end'] if s.get('end') is not None else last

    # Add any remaining tail text
    if last < len(original_text):
        parts.append(html.escape(original_text[last:]))

    # Spans that could not be located in the original (start is None)
    not_located = [s for s in spans if s.get('start') is None]

    html_sentence = "<div class='annotated normal-text'>" + "".join(parts) + "</div>"

    if not_located:
        chips = " ".join(
            f"<span class='entity' style='background:{PALETTE.get(s['label'],PALETTE['DEFAULT'])[0]}; color:{PALETTE.get(s['label'],PALETTE['DEFAULT'])[1]}; margin-right:6px'>"
            f"{html.escape(s['text'])}"
            f"<span class='label' style='color:inherit'>{html.escape(s['label'])}</span>"
            f"</span>"
            for s in not_located
        )
        html_sentence += "<div style='margin-top:6px;'>" + chips + "</div>"

    return CSS + html_sentence

# %%
# ---------------------------
# Intermediate visualization cell
# ---------------------------

from IPython.display import HTML, display
import re

# Reuse your generate_ngrams function and the person/location/time/event/other id maps:
# - generate_ngrams(text)
# - person_id_map, location_id_map, time_id_map, event_id_map, other_id_map
# These are from your notebook already.

def detect_entities_in_sentence(text):
    """
    Return list of detected entities as dicts:
      {'id': 'P12', 'label': 'PERSON', 'text': 'John Doe'}
    Detection is done by checking n-grams against your *_id_map dictionaries.
    """
    detected = []
    seen_ids = set()
    ngrams = generate_ngrams(text, n=6)  # reuse your ngram generator

    # lower-case keys for safer matching (your maps may already be lowercase)
    person_keys = {k.lower(): v for k, v in person_id_map.items()}
    location_keys = {k.lower(): v for k, v in location_id_map.items()}
    time_keys = {k.lower(): v for k, v in time_id_map.items()}
    event_keys = {k.lower(): v for k, v in event_id_map.items()}
    other_keys = {k.lower(): v for k, v in other_id_map.items()}

    for ng in ngrams:
        candidate = ng.strip()
        lower_cand = candidate.lower()
        if not lower_cand:
            continue

        if lower_cand in person_keys:
            idval = person_keys[lower_cand]
            if idval not in seen_ids:
                detected.append({'id': idval, 'label': 'PERSON', 'text': candidate})
                seen_ids.add(idval)
        elif lower_cand in location_keys:
            idval = location_keys[lower_cand]
            if idval not in seen_ids:
                detected.append({'id': idval, 'label': 'LOCATION', 'text': candidate})
                seen_ids.add(idval)
        elif lower_cand in time_keys:
            idval = time_keys[lower_cand]
            if idval not in seen_ids:
                detected.append({'id': idval, 'label': 'TIME', 'text': candidate})
                seen_ids.add(idval)
        elif lower_cand in event_keys:
            idval = event_keys[lower_cand]
            if idval not in seen_ids:
                detected.append({'id': idval, 'label': 'EVENT', 'text': candidate})
                seen_ids.add(idval)
        elif lower_cand in other_keys:
            idval = other_keys[lower_cand]
            if idval not in seen_ids:
                detected.append({'id': idval, 'label': 'OTHER', 'text': candidate})
                seen_ids.add(idval)

    # Return in order found (shorter ngrams appear later due to your generator ordering — that's fine)
    return detected

def build_spans_from_detected(original_text, detected_entities):
    """
    For each detected entity dict {'id','label','text'}, attempt to find its first occurrence
    in the original_text (case-insensitive). Return list of spans {'start','end','label','text'}.
    If not found, span will have start=None (so renderer will put a chip below sentence).
    """
    spans = []
    cursor = 0
    for ent in detected_entities:
        ent_text = ent['text']
        label = ent['label']
        # try find from cursor
        if ent_text and ent_text.strip():
            pat = re.escape(ent_text)
            m = re.search(pat, original_text[cursor:], flags=re.IGNORECASE)
            if m:
                start = cursor + m.start()
                end = cursor + m.end()
                spans.append({'start': start, 'end': end, 'label': label, 'text': original_text[start:end]})
                cursor = end
                continue

        # fallback if not found
        spans.append({'start': None, 'end': None, 'label': label, 'text': ent['id']})  # show ID as fallback
    return spans

# Iterate through ref_sen, find one sentence with >1 detected entity, visualize it
chosen_index = None
chosen_sentence = None
chosen_detected = None

for i, sent in enumerate(ref_sen):
    detected = detect_entities_in_sentence(sent)
    if len(detected) > 1:
        chosen_index = i
        chosen_sentence = sent
        chosen_detected = detected
        break

if chosen_index is None:
    print("No sentence found with more than one detected entity (as per current ID maps).")
else:
    print(f"Visualizing sentence index {chosen_index} (shows {len(chosen_detected)} entities):")
    print(chosen_sentence)
    # Build spans and render using the renderer you already have
    spans = build_spans_from_detected(chosen_sentence, chosen_detected)

    # The renderer cell you ran earlier defined `highlight_html_from_spans(original_text, spans)`
    # If you've run that cell, call it:
    try:
        display(HTML(highlight_html_from_spans(chosen_sentence, spans)))
    except NameError:
        # If renderer not defined, show a simple fallback HTML
        print("Renderer functions not found in this session. Showing simple fallback output:")
        chips = " ".join([f"[{e['label']}:{e['text']}]" for e in chosen_detected])
        display(HTML(f"<div><p>{html.escape(chosen_sentence)}</p><div style='margin-top:8px'>{chips}</div></div>"))
# Out:
# Visualizing sentence index 0 (shows 2 entities):
# Part -5 Abrogation of the practice of âtalaq -e-biddatâ by
# legislation, the world over, in Islamic, as well
# as, non-Islamic States  28 - 29
# A. Laws of Arab States  (i) â (xiii)
# B. Laws of Southeast Asian States  (i) â (iii)
# C.  Laws of Sub -continental States  (i) â (ii)
# 6.
# <style>
# .annotated { font-family: Inter, Arial; line-height:1.6; }
# .entity {
#   display: inline-block;
#   position: relative;
#   padding: 2px 6px;
#   margin: 0 2px;
#   border-radius: 6px;
#   font-weight: 600;
# }
# .entity .label {
#   display: block;
#   font-size: 10px;
#   text-transform: uppercase;
#   letter-spacing: .6px;
#   margin-top: 2px;
#   opacity: 0.9;
# }
# .badge {
#   opacity: 0.9;
#   padding: 1px 5px;
#   border-radius: 6px;
#   font-size: 10px;
#   font-weight: 700;
#   display:inline-block;
# }
# </style>
# <div class='annotated normal-text'>Part -5 Abrogation of the practice of âtalaq -e-biddatâ by
# legislation, the world over, in Islamic, as well
# as, non-Islamic States  28 - 29
# A. Laws of Arab States  (i) â (xiii)
# B. Laws of <span class='entity' style='background:#e8f7ff; color:#1e90ff;'>Southeast Asian States<span class='label' style='color:#1e90ff;'>LOCATION</span></span>  (i) â (iii)
# C.  Laws of Sub -continental States  (i) â (ii)
# 6.</div><div style='margin-top:6px;'><span class='entity' style='background:#e8f7ff; color:#1e90ff; margin-right:6px'>L29<span class='label' style='color:inherit'>LOCATION</span></span></div>

# %%
# ---------------------------
# Show top-5 sentences with >1 detected entity (distinct color per entity)
# ---------------------------

from IPython.display import HTML, display
import re
import hashlib
import html

# deterministic color generator per entity id/text
def color_for_entity(key):
    """
    Return (bg_color, fg_color) for a given entity key (string).
    Deterministic via md5 hash -> hue.
    bg: light; fg: darker for contrast.
    """
    h = int(hashlib.md5(key.encode('utf-8')).hexdigest()[:8], 16) % 360
    # use HSL for pleasant distinct colors
    bg = f"hsl({h} 80% 92%)"
    fg = f"hsl({h} 55% 20%)"
    return bg, fg

# Reuse detect_entities_in_sentence from your previous cell (or paste again here if not present)
def detect_entities_in_sentence(text):
    detected = []
    seen_ids = set()
    ngrams = generate_ngrams(text, n=6)

    person_keys = {k.lower(): v for k, v in person_id_map.items()}
    location_keys = {k.lower(): v for k, v in location_id_map.items()}
    time_keys = {k.lower(): v for k, v in time_id_map.items()}
    event_keys = {k.lower(): v for k, v in event_id_map.items()}
    other_keys = {k.lower(): v for k, v in other_id_map.items()}

    for ng in ngrams:
        candidate = ng.strip()
        lower_cand = candidate.lower()
        if not lower_cand:
            continue

        if lower_cand in person_keys:
            idval = person_keys[lower_cand]
            if idval not in seen_ids:
                detected.append({'id': idval, 'label': 'PERSON', 'text': candidate})
                seen_ids.add(idval)
        elif lower_cand in location_keys:
            idval = location_keys[lower_cand]
            if idval not in seen_ids:
                detected.append({'id': idval, 'label': 'LOCATION', 'text': candidate})
                seen_ids.add(idval)
        elif lower_cand in time_keys:
            idval = time_keys[lower_cand]
            if idval not in seen_ids:
                detected.append({'id': idval, 'label': 'TIME', 'text': candidate})
                seen_ids.add(idval)
        elif lower_cand in event_keys:
            idval = event_keys[lower_cand]
            if idval not in seen_ids:
                detected.append({'id': idval, 'label': 'EVENT', 'text': candidate})
                seen_ids.add(idval)
        elif lower_cand in other_keys:
            idval = other_keys[lower_cand]
            if idval not in seen_ids:
                detected.append({'id': idval, 'label': 'OTHER', 'text': candidate})
                seen_ids.add(idval)

    return detected

def build_spans_from_detected_with_colors(original_text, detected_entities):
    """
    Like build_spans_from_detected, but attaches bg/fg colors for each span using color_for_entity.
    Returns spans list with entries:
      {'start': int|None, 'end': int|None, 'label': str, 'text': str, 'bg':str, 'fg':str}
    """
    spans = []
    cursor = 0
    for ent in detected_entities:
        ent_text = ent['text']
        label = ent['label']
        ent_key = ent['id'] if 'id' in ent else ent_text  # prefer canonical id for color hashing
        bg, fg = color_for_entity(ent_key)

        # try to find ent_text in original from cursor
        if ent_text and ent_text.strip():
            pat = re.escape(ent_text)
            m = re.search(pat, original_text[cursor:], flags=re.IGNORECASE)
            if m:
                start = cursor + m.start()
                end = cursor + m.end()
                spans.append({'start': start, 'end': end, 'label': label, 'text': original_text[start:end], 'bg': bg, 'fg': fg})
                cursor = end
                continue

        # fallback: not found inline
        spans.append({'start': None, 'end': None, 'label': label, 'text': ent['id'], 'bg': bg, 'fg': fg})
    return spans

# Replace the renderer to respect per-span colors (if you already have a renderer, keep it; below is a small inline renderer)
def highlight_html_from_spans_with_colors(original_text, spans):
    """
    Build HTML using per-span bg/fg when available. Falls back to label-based palette if not provided.
    This returns a full HTML string (with CSS header included).
    """
    CSS_local = """
    <style>
    .annotated { font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, "Helvetica Neue", Arial; line-height:1.6; }
    .entity { display: inline-block; position: relative; padding: 3px 6px; margin: 0 3px; border-radius: 8px; font-weight: 600; vertical-align: middle; }
    .entity .label { display:block; font-size:10px; text-transform:uppercase; letter-spacing:.5px; margin-top:3px; opacity:0.95; }
    .normal-text { white-space: pre-wrap; }
    </style>
    """
    parts = []
    last = 0
    inline_spans = [s for s in spans if s.get('start') is not None]
    inline_spans = sorted(inline_spans, key=lambda x: int(x['start']))

    for s in inline_spans:
        if s['start'] > last:
            parts.append(html.escape(original_text[last:s['start']]))
        bg = s.get('bg')
        fg = s.get('fg')
        label = s.get('label', 'DEFAULT').upper()
        text = s.get('text', '')
        # Build entity html using the provided colors
        ent_html = (
            f"<span class='entity' style='background:{bg}; color:{fg};'>"
            f"{html.escape(text)}"
            f"<span class='label' style='color:{fg};'>{html.escape(label)}</span>"
            f"</span>"
        )
        parts.append(ent_html)
        last = s['end'] if s.get('end') is not None else last

    if last < len(original_text):
        parts.append(html.escape(original_text[last:]))

    not_located = [s for s in spans if s.get('start') is None]
    html_sentence = "<div class='annotated normal-text'>" + "".join(parts) + "</div>"

    if not_located:
        chips = " ".join(
            f"<span class='entity' style='background:{s.get('bg')}; color:{s.get('fg')}; margin-right:6px'>"
            f"{html.escape(s.get('text'))}<span class='label' style='color:inherit'>{html.escape(s.get('label'))}</span></span>"
            for s in not_located
        )
        html_sentence += "<div style='margin-top:6px;'>" + chips + "</div>"

    return CSS_local + html_sentence

# collect all sentences with >1 detected entity
candidates = []
for i, sent in enumerate(ref_sen):
    detected = detect_entities_in_sentence(sent)
    if len(detected) > 1:
        candidates.append({'index': i, 'sentence': sent, 'detected': detected, 'count': len(detected)})

if not candidates:
    print("No sentence found with more than one detected entity.")
else:
    # sort by descending entity count, then by original order
    candidates = sorted(candidates, key=lambda x: (-x['count'], x['index']))
    topk = candidates[:5]  # top 5

    for item in topk:
        idx = item['index']
        sent = item['sentence']
        detected = item['detected']
        print(f"\n--- Sentence index {idx} — detected {len(detected)} entities ---\n{sent}\n")
        spans = build_spans_from_detected_with_colors(sent, detected)
        html_out = highlight_html_from_spans_with_colors(sent, spans)
        display(HTML(html_out))
# Out:
# --- Sentence index 136 — detected 4 entities ---
# In A. S. Parveen Akthar  v. The Union of India 60 , the
# High Court of Madras was posed with the question on  the
# validity and constitutionality of Section 2 of the 1937 Act in so
# far as it recognises triple talaq as a valid form o f divorce. The
# Court referred to the provisions of the Quran, opin ions of
# various eminent scholars of Islamic Law and previou s judicial
# pronouncements including Shamim Ara  and came to the
# following conclusion:
#
# â45.Thus, the law with regard to talaq, as declared
# by the apex Court, is that talaq must be for a
# reasonable cause and must be preceded by
# attempt at reconciliation between the husband
# and the wife by two arbiters one chosen by wife's
# family and the other from husband's family and it
# is only if their attempts fail, talaq may be effect ed. XXXX
# 48.Having regard to the law now declared by the
# apex Court in the case of Shamim Ara , 2002 AIR
# SCW 4162, talaq, in whatever form, must be for a
# reasonable cause, and must be preceded by
# attempts for reconciliation by arbiters chosen
# from the families of each of the spouses, the
#
# 60  2003-1-L.W.
#     <style>
#     .annotated { font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, "Helvetica Neue", Arial; line-height:1.6; }
#     .entity { display: inline-block; position: relative; padding: 3px 6px; margin: 0 3px; border-radius: 8px; font-weight: 600; vertical-align: middle; }
#     .entity .label { display:block; font-size:10px; text-transform:uppercase; letter-spacing:.5px; margin-top:3px; opacity:0.95; }
#     .normal-text { white-space: pre-wrap; }
#     </style>
#     <div class='annotated normal-text'>In A. S. Parveen Akthar  v. The Union of India 60 , the
# High Court of Madras was posed with the question on  the
# validity and constitutionality of Section 2 of the 1937 Act in so
# far as it recognises <span class='entity' style='background:hsl(13 80% 92%); color:hsl(13 55% 20%);'>triple talaq<span class='label' style='color:hsl(13 55% 20%);'>EVENT</span></span> as a valid form o f divorce. The
# Court referred to the provisions of the Quran, opin ions of
# various eminent scholars of Islamic Law and previou s judicial
# pronouncements including <span class='entity' style='background:hsl(107 80% 92%); color:hsl(107 55% 20%);'>Shamim Ara<span class='label' style='color:hsl(107 55% 20%);'>PERSON</span></span>  and came to the
# following conclusion:
#
# â45.Thus, the law with regard to talaq, as declared
# by the apex Court, is that talaq must be for a
# reasonable cause and must be preceded by
# attempt at reconciliation between the husband
# and the wife by two arbiters one chosen by wife&#x27;s
# family and the other from husband&#x27;s family and it
# is only if their attempts fail, talaq may be effect ed. XXXX
# 48.Having regard to the law now declared by the
# apex Court in the case of Shamim Ara , 2002 AIR
# SCW 4162, talaq, in whatever form, must be for a
# reasonable cause, and must be preceded by
# attempts for reconciliation by arbiters chosen
# from the families of each of the spouses, the
#
# 60  2003-1-L.W.</div><div style='margin-top:6px;'><span class='entity' style='background:hsl(13 80% 92%); color:hsl(13 55% 20%); margin-right:6px'>L14<span class='label' style='color:inherit'>LOCATION</span></span> <span class='entity' style='background:hsl(229 80% 92%); color:hsl(229 55% 20%); margin-right:6px'>L27<span class='label' style='color:inherit'>LOCATION</span></span></div>
# --- Sentence index 133 — detected 3 entities ---
# The above view has been endorsed by various High Co urts,
# finally culminating in Shamim Ara  by this Court which has since
#
# 50  Verses from the Holy Quran as extracted above are taken from âThe Holy Qurâanâ
# translated by Abdullah Yusuf Ali which was agreed t o be a fair translation by all parties. 51 Similar observations were made by the High Court of  Gauhati through Baharul Islam, J. in
# Jiauddin Ahmed v. Anwara Begum (1981) 1 Gau LR 358 wherein he noted that âthough
# marriage under Muslim Law is only a civil contract yet the rights and responsibilities
# consequent upon it are of such importance to the we lfare of humanity, that a high degree
# of sanctity is attached to it. But in spite of the sacredness of the character of the marriage-
# tie, Islam recognizes the necessity, in exceptional  circumstances, of keeping the way open
# for its dissolution â.
#     <style>
#     .annotated { font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, "Helvetica Neue", Arial; line-height:1.6; }
#     .entity { display: inline-block; position: relative; padding: 3px 6px; margin: 0 3px; border-radius: 8px; font-weight: 600; vertical-align: middle; }
#     .entity .label { display:block; font-size:10px; text-transform:uppercase; letter-spacing:.5px; margin-top:3px; opacity:0.95; }
#     .normal-text { white-space: pre-wrap; }
#     </style>
#     <div class='annotated normal-text'>The above view has been endorsed by various High Co urts,
# finally culminating in Shamim Ara  by this Court which has since
#
# 50  Verses from the Holy Quran as extracted above are taken from âThe Holy Qurâanâ
# translated by <span class='entity' style='background:hsl(152 80% 92%); color:hsl(152 55% 20%);'>Abdullah Yusuf Ali<span class='label' style='color:hsl(152 55% 20%);'>PERSON</span></span> which was agreed t o be a fair translation by all parties. 51 Similar observations were made by the High Court of  Gauhati through Baharul Islam, J. in
# Jiauddin Ahmed v. Anwara Begum (1981) 1 Gau LR 358 wherein he noted that âthough
# marriage under Muslim Law is only a civil contract yet the rights and responsibilities
# consequent upon it are of such importance to the we lfare of humanity, that a high degree
# of sanctity is attached to it. But in spite of the sacredness of the character of the marriage-
# tie, Islam recognizes the necessity, in exceptional  circumstances, of keeping the way open
# for its dissolution â.</div><div style='margin-top:6px;'><span class='entity' style='background:hsl(107 80% 92%); color:hsl(107 55% 20%); margin-right:6px'>P51<span class='label' style='color:inherit'>PERSON</span></span> <span class='entity' style='background:hsl(255 80% 92%); color:hsl(255 55% 20%); margin-right:6px'>P55<span class='label' style='color:inherit'>PERSON</span></span></div>
# --- Sentence index 0 — detected 2 entities ---
# Part -5 Abrogation of the practice of âtalaq -e-biddatâ by
# legislation, the world over, in Islamic, as well
# as, non-Islamic States  28 - 29
# A. Laws of Arab States  (i) â (xiii)
# B. Laws of Southeast Asian States  (i) â (iii)
# C.  Laws of Sub -continental States  (i) â (ii)
# 6.
#     <style>
#     .annotated { font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, "Helvetica Neue", Arial; line-height:1.6; }
#     .entity { display: inline-block; position: relative; padding: 3px 6px; margin: 0 3px; border-radius: 8px; font-weight: 600; vertical-align: middle; }
#     .entity .label { display:block; font-size:10px; text-transform:uppercase; letter-spacing:.5px; margin-top:3px; opacity:0.95; }
#     .normal-text { white-space: pre-wrap; }
#     </style>
#     <div class='annotated normal-text'>Part -5 Abrogation of the practice of âtalaq -e-biddatâ by
# legislation, the world over, in Islamic, as well
# as, non-Islamic States  28 - 29
# A. Laws of Arab States  (i) â (xiii)
# B. Laws of <span class='entity' style='background:hsl(226 80% 92%); color:hsl(226 55% 20%);'>Southeast Asian States<span class='label' style='color:hsl(226 55% 20%);'>LOCATION</span></span>  (i) â (iii)
# C.  Laws of Sub -continental States  (i) â (ii)
# 6.</div><div style='margin-top:6px;'><span class='entity' style='background:hsl(53 80% 92%); color:hsl(53 55% 20%); margin-right:6px'>L29<span class='label' style='color:inherit'>LOCATION</span></span></div>
# --- Sentence index 1 — detected 2 entities ---
# Laws of Arab States  (i) â (xiii)
# B. Laws of Southeast Asian States  (i) â (iii)
# C.  Laws of Sub -continental States  (i) â (ii)
# 6. Part -6 Judicial pronouncements, on the subject of
# âtalaq-e-biddatâ  30 - 34
# 7.
#     <style>
#     .annotated { font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, "Helvetica Neue", Arial; line-height:1.6; }
#     .entity { display: inline-block; position: relative; padding: 3px 6px; margin: 0 3px; border-radius: 8px; font-weight: 600; vertical-align: middle; }
#     .entity .label { display:block; font-size:10px; text-transform:uppercase; letter-spacing:.5px; margin-top:3px; opacity:0.95; }
#     .normal-text { white-space: pre-wrap; }
#     </style>
#     <div class='annotated normal-text'>Laws of Arab States  (i) â (xiii)
# B. Laws of <span class='entity' style='background:hsl(226 80% 92%); color:hsl(226 55% 20%);'>Southeast Asian States<span class='label' style='color:hsl(226 55% 20%);'>LOCATION</span></span>  (i) â (iii)
# C.  Laws of Sub -continental States  (i) â (ii)
# 6. Part -6 Judicial pronouncements, on the subject of
# âtalaq-e-biddatâ  30 - 34
# 7.</div><div style='margin-top:6px;'><span class='entity' style='background:hsl(53 80% 92%); color:hsl(53 55% 20%); margin-right:6px'>L29<span class='label' style='color:inherit'>LOCATION</span></span></div>
# --- Sentence index 3 — detected 2 entities ---
# The petitioner has sought a declaration , that the âtalaq-e-
# biddatâ pronounced by her husband on 10.10.2015 be declared as void ab
# initio . It is also her contention, that such a divorce which abruptly,
# unilaterally and irrevocably terminates the ties of matr imony, purportedly
# under Section 2 of the Muslim Personal Law (Shariat) A pplication Act, 1937
# (hereinafter referred to as, the Shariat Act), be decl ared unconstitutional. During the course of hearing, it was submitted, that the  âtalaq-e-biddatâ
# (-triple talaq), pronounced by her husband is not vali d, as it is not a part of
# âShariatâ (Muslim âpersonal lawâ).
#     <style>
#     .annotated { font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, "Helvetica Neue", Arial; line-height:1.6; }
#     .entity { display: inline-block; position: relative; padding: 3px 6px; margin: 0 3px; border-radius: 8px; font-weight: 600; vertical-align: middle; }
#     .entity .label { display:block; font-size:10px; text-transform:uppercase; letter-spacing:.5px; margin-top:3px; opacity:0.95; }
#     .normal-text { white-space: pre-wrap; }
#     </style>
#     <div class='annotated normal-text'>The petitioner has sought a declaration , that the âtalaq-e-
# biddatâ pronounced by her husband on <span class='entity' style='background:hsl(130 80% 92%); color:hsl(130 55% 20%);'>10.10.2015<span class='label' style='color:hsl(130 55% 20%);'>TIME</span></span> be declared as void ab
# initio . It is also her contention, that such a <span class='entity' style='background:hsl(51 80% 92%); color:hsl(51 55% 20%);'>divorce<span class='label' style='color:hsl(51 55% 20%);'>EVENT</span></span> which abruptly,
# unilaterally and irrevocably terminates the ties of matr imony, purportedly
# under Section 2 of the Muslim Personal Law (Shariat) A pplication Act, 1937
# (hereinafter referred to as, the Shariat Act), be decl ared unconstitutional. During the course of hearing, it was submitted, that the  âtalaq-e-biddatâ
# (-triple talaq), pronounced by her husband is not vali d, as it is not a part of
# âShariatâ (Muslim âpersonal lawâ).</div>

# %%
# final_sentences = []

# for sen in ref_sen:
#      s = replace_entities(sen)
#      final_sentences.append(s)

# %%
with open('cleaned_sentences_talaq.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Sentences'])
#      for sen in final_sentences:
    for sen in final_sentences:
        writer.writerow([sen])

# %% [markdown]
# ## Matrix Creation

# %%
# with the sentences
import pandas as pd
import csv
import re

# Load the CSV files
time_df = pd.read_csv(file_path_time)
location_df = pd.read_csv(file_path_location)
event_df = pd.read_csv(file_path_event)
person_df = pd.read_csv(file_path_person)
activity_df = pd.read_csv(file_path_other)

location_ID = location_df['Id'].tolist()
location_df = location_df['Location'].tolist()

time_ID = time_df['Id'].tolist()
time_df = time_df['Time'].tolist()

# event_ID = event_df['ID'].tolist()
# event_df = event_df['Event'].tolist()

# person_ID = person_df['ID'].tolist()
# person_df = person_df['Person'].tolist()

# activity_ID = activity_df['ID'].tolist()
# activity_df = activity_df['Others'].tolist()

event_ID_map = dict(zip(event_df['Id'], event_df['Event']))
person_ID_map = dict(zip(person_df['Id'], person_df['Person']))
activity_ID_map = dict(zip(activity_df['Id'], activity_df['Activity']))

matrix = {}

# %%
sentences = []
with open('cleaned_sentences_talaq.csv', 'r', encoding='latin-1') as csvfile:
    reader = csv.reader(csvfile)
    next(reader)
    for row in reader:
        sentence = row[0]
        sentences.append(sentence)

# %%
for s in sentences:
    pattern = r'([PTLEA]\d+)'
    matches = re.findall(pattern, s)

    persons = []
    time = []
    location = []
    event = []
    activity = []

    for match in matches:
        if match[0] == 'P':
            persons.append(person_ID_map.get(match, 'Unknown Person'))
        elif match[0] == 'L':
             location.append(location_ID.index(match))
        elif match[0] == 'E':
            event.append(event_ID_map.get(match, 'Unknown Event'))
        elif match[0] == 'A':
            activity.append(activity_ID_map.get(match, 'Unknown Activity'))
        elif match[0] == 'T':
            time.append(time_ID.index(match))

    if location and time:
        for loc_index in location:
            loc_key = location_df[loc_index]
            for time_index in time:
                time_key = time_df[time_index]
                if time_key not in matrix:
                    matrix[time_key] = {}
                if loc_key not in matrix[time_key]:
                    matrix[time_key][loc_key] = []
                matrix[time_key][loc_key].extend([(entity, s) for entity in (persons + event + activity)])
    elif location:
        for loc_index in location:
            loc_key = location_df[loc_index]
            if loc_key not in matrix:
                matrix[loc_key] = {}
            if 'NULL' not in matrix:
                matrix['NULL'] = {}
            if loc_key not in matrix["NULL"]:
                matrix["NULL"][loc_key] = []
            matrix["NULL"][loc_key].extend([(entity, s) for entity in (persons + event + activity)])
    elif time:
        for time_index in time:
            time_key = time_df[time_index]
            if time_key not in matrix:
                matrix[time_key] = {}
            if 'NULL' not in matrix[time_key]:
                matrix[time_key]['NULL'] = []
            matrix[time_key]["NULL"].extend([(entity, s) for entity in (persons + event + activity)])
    else:
        if 'NULL' not in matrix:
            matrix['NULL'] = {}
        if 'NULL' not in matrix['NULL']:
            matrix['NULL']['NULL'] = []
        matrix["NULL"]["NULL"].extend([(entity, s) for entity in (persons + event + activity)])

matrix_df = pd.DataFrame.from_dict(matrix, orient='index')

# %%
matrix_df.to_csv('matrix_with_sen_talaq.csv')

# %%
import networkx as nx

# %%
df = pd.read_csv('matrix_with_sen_talaq.csv')

# %%
df.rename(columns={'Unnamed: 0': 'Time'}, inplace=True)

# %%
import ast
from tabulate import tabulate
import pandas as pd

def show_10x10_entity_matrix(df, max_entities=6):
    # Take EXACT first 10 rows and first 10 columns
    sub = df.iloc[:10, :10].copy()

    # Convert each cell into entity-only listing
    def extract_entities(cell):
        if pd.isnull(cell) or cell == "":
            return ""
        try:
            items = ast.literal_eval(cell)
            ents = [e for e, _ in items]   # keep only entity IDs
            if len(ents) > max_entities:
                ents = ents[:max_entities] + ["..."]
            return ", ".join(ents)
        except:
            return str(cell)

    # Apply to all non-Time columns
    for col in sub.columns:
        if col != "Time":
            sub[col] = sub[col].apply(extract_entities)

    print(tabulate(sub, headers="keys", tablefmt="github", showindex=False))
    return sub


# RUN IT
show_10x10_entity_matrix(df)
# Out:
# | Time       | NULL                                                                                                   |
# |------------|--------------------------------------------------------------------------------------------------------|
# | nan        | dissolution of marriage, khula, mubaraat, dissolution of marriage, dissolution of marriage, khula, ... |
# | 10.10.2015 | divorce                                                                                                |
# | one year   | divorce, divorce                                                                                       |
# | 1400 years |                                                                                                        |
#          Time                                               NULL
# 0         NaN  dissolution of marriage, khula, mubaraat, diss...
# 1  10.10.2015                                            divorce
# 2    one year                                   divorce, divorce
# 3  1400 years

# %%
G = nx.Graph()

for index, row in df.iterrows():
    time = row['Time']
    for location in df.columns:
        if location == 'Time':
            continue
        # Convert the tuple to a string and add it as a node
        G.add_node(f"{time}, {location}")

# %%
import ast

# %%
final = set()

# Update the final set with only the entities
for value in pd.unique(df.drop(columns='Time').values.ravel()):
    if pd.notnull(value):
        value_list = ast.literal_eval(value)
        entity_list = [entity for entity, sentence in value_list]
        final.update(entity_list)

# %%
G.add_nodes_from(final)

# %%
for index, row in df.iterrows():
    time = row['Time']
    for location in df.columns:
        if location == 'Time':
            continue
        if pd.notnull(row[location]):
            value_list = ast.literal_eval(row[location])
            entity_list = [entity for entity, sentence in value_list]
            for entity in entity_list:
                if entity in final:
                    # Convert the tuples to strings and add them as an edge
                    G.add_edge(f"{time}, {location}", entity)

# %%
for node in list(G.nodes):
    if not list(G.neighbors(node)):
        G.remove_node(node)

# %%
for node1 in G.nodes:
    # Check if node1 can be split into a pair
    if ', ' in node1:
        parts1 = node1.split(", ")
        if len(parts1) == 2:  # Ensure it splits into exactly two parts
            time1, location1 = parts1
            for node2 in G.nodes:
                # Check if node2 can be split into a pair
                if ', ' in node2:
                    parts2 = node2.split(", ")
                    if len(parts2) == 2:  # Ensure it splits into exactly two parts
                        time2, location2 = parts2
                        # Add edge if the time or location matches
                        if time1 == time2 or location1 == location2:
                            G.add_edge(node1, node2)

# %%
degree_dict = dict(G.degree(G.nodes()))
nx.set_node_attributes(G, degree_dict, 'degree')

# %%
# Create a dictionary to store the sentences for each node
sentences_dict = {}

# Create a dictionary to store the sentences for each edge i.e. between two nodes
edge_sentences_dict = {}

# Update the sentences_dict and edge_sentences_dict
for index, row in df.iterrows():
    time = row['Time']
    for location in df.columns:
        if location == 'Time':
            continue
        if pd.notnull(row[location]):
            value_list = ast.literal_eval(row[location])
            for entity, sentence in value_list:
                if entity in final:
                    # Add the sentence to the sentences_dict for the entity
                    if entity not in sentences_dict:
                        sentences_dict[entity] = set()
                    sentences_dict[entity].add(sentence)

                    # Add the sentence to the sentences_dict for the (time, location) node
                    time_location_node = f"{time}, {location}"
                    if time_location_node not in sentences_dict:
                        sentences_dict[time_location_node] = set()
                    sentences_dict[time_location_node].add(sentence)

                    # Add the sentence to the edge_sentences_dict for the edge
                    edge = (time_location_node, entity)
                    if edge not in edge_sentences_dict:
                        edge_sentences_dict[edge] = set()
                    edge_sentences_dict[edge].add(sentence)

# Convert the sets back to lists if needed
for node, sentences in sentences_dict.items():
    sentences_dict[node] = list(sentences)

for edge, sentences in edge_sentences_dict.items():
    edge_sentences_dict[edge] = list(sentences)

# %%
pip install node2vec
# Out:
# Requirement already satisfied: node2vec in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (0.5.0)
# Requirement already satisfied: gensim<5.0.0,>=4.3.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from node2vec) (4.4.0)
# Requirement already satisfied: joblib<2.0.0,>=1.4.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from node2vec) (1.4.2)
# Requirement already satisfied: networkx<4.0.0,>=3.1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from node2vec) (3.4.2)
# Requirement already satisfied: numpy<2.0.0,>=1.24.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from node2vec) (1.26.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from node2vec) (4.67.1)
# Requirement already satisfied: scipy>=1.7.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from gensim<5.0.0,>=4.3.0->node2vec) (1.15.1)
# Requirement already satisfied: smart_open>=1.8.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from gensim<5.0.0,>=4.3.0->node2vec) (7.5.0)
# Requirement already satisfied: wrapt in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from smart_open>=1.8.1->gensim<5.0.0,>=4.3.0->node2vec) (2.0.1)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from node2vec import Node2Vec

# Create a Node2Vec instance
node2vec = Node2Vec(G, dimensions=64, walk_length=30, num_walks=200, workers=4)

# Generate embeddings
model = node2vec.fit(window=10, min_count=1, batch_words=4)
# Out:
# Computing transition probabilities:   0%|          | 0/8 [00:00<?, ?it/s]
# Generating walks (CPU: 1): 100%|██████████| 50/50 [00:00<00:00, 1332.29it/s]
# Generating walks (CPU: 2): 100%|██████████| 50/50 [00:00<00:00, 1332.69it/s]
# Generating walks (CPU: 3): 100%|██████████| 50/50 [00:00<00:00, 1330.33it/s]
# Generating walks (CPU: 4): 100%|██████████| 50/50 [00:00<00:00, 1313.96it/s]

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Get the node embeddings
node_embeddings = {node: model.wv[node] for node in G.nodes}

# Compute cosine similarity matrix
similarity_matrix = cosine_similarity(list(node_embeddings.values()))

# %%
from sklearn.cluster import DBSCAN

# Initialize DBSCAN
dbscan = DBSCAN(eps=0.5, min_samples=3)  # Adjust parameters as needed

# Fit and predict clusters
labels = dbscan.fit_predict(similarity_matrix)

# %%
cluster_colors = [
    'rgb(31, 119, 180)',  # Blue
    'rgb(255, 127, 14)',  # Orange
    'rgb(44, 160, 44)',   # Green
    'rgb(214, 39, 40)',   # Red
    'rgb(148, 103, 189)', # Purple
    'rgb(140, 86, 75)',   # Brown
    'rgb(227, 119, 194)', # Pink
    'rgb(127, 127, 127)', # Gray
    'rgb(188, 189, 34)',  # Olive
    'rgb(23, 190, 207)',  # Teal
    'rgb(255, 187, 120)', # Peach
    'rgb(214, 39, 40)',   # Maroon
    'rgb(77, 175, 74)',   # Light Green
    'rgb(152, 78, 163)',  # Plum
    'rgb(255, 152, 150)'  # Salmon
]

# %%
import networkx as nx
import plotly.graph_objs as go

# Assuming 'G' is your graph and 'labels' is the list of labels
# Renumber clusters from 1 to 7 if needed, otherwise ensure you have clusters numbered 1 to 7
unique_labels = list(set(labels))
label_mapping = {label: idx+1 for idx, label in enumerate(unique_labels)}

def draw_subgraph_plotly(subgraph, cluster_id, cluster_color):
    pos = nx.spring_layout(subgraph, seed=42)  # Fixed seed for reproducibility
    
    # Extract the node positions
    x_nodes = [pos[node][0] for node in subgraph.nodes()]
    y_nodes = [pos[node][1] for node in subgraph.nodes()]

    # Extract the edges
    edge_x = []
    edge_y = []
    for edge in subgraph.edges():
        x0, y0 = pos[edge[0]]
        x1, y1 = pos[edge[1]]
        edge_x.extend([x0, x1, None])
        edge_y.extend([y0, y1, None])

    # Edge trace
    edge_trace = go.Scatter(
        x=edge_x, y=edge_y,
        line=dict(width=1, color='gray'),
        hoverinfo='none',
        mode='lines')

    # Node trace
    node_trace = go.Scatter(
        x=x_nodes, y=y_nodes,
        mode='markers+text',
        text=[f'{node}' for node in subgraph.nodes()],
        textposition="top center",
        marker=dict(
            showscale=False,
            color=cluster_color,  # Assign the cluster color
            size=20,
            line=dict(width=2, color='black')
        ),
        hoverinfo='text'
    )

    # Create figure
    fig = go.Figure(data=[edge_trace, node_trace],
                    layout=go.Layout(
                        title=f'Cluster {cluster_id}',
                        showlegend=False,
                        hovermode='closest',
                        margin=dict(b=20, l=5, r=5, t=40),
                        xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                        yaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                        height=600,
                        width=600,
                        paper_bgcolor='white',
                        plot_bgcolor='white'
                    ))

    fig.show()

# Iterate over each cluster and draw the subgraph
for original_cluster_id in set(labels):
    cluster_id = label_mapping[original_cluster_id]
    cluster_color = cluster_colors[cluster_id - 1]  # Assign a unique color to each cluster
    cluster_nodes = [node for node, label in zip(G.nodes, labels) if label == original_cluster_id]
    subgraph = G.subgraph(cluster_nodes)
    draw_subgraph_plotly(subgraph, cluster_id, cluster_color)

# %%
# # Initialize lists for nodes and links
# nodes = []
# links = []

# # Add nodes to the list
# for node, sentences in sentences_dict.items():
#     nodes.append({
#         "id": node,
#         "group": 1,  # Update this as needed
#         "size": len(sentences)  # The size could be based on the number of sentences
#     })

# # Add links to the list
# for edge, sentences in edge_sentences_dict.items():
#     source, target = edge
#     links.append({
#         "source": source,
#         "target": target,
#         "value": len(sentences)  # The value could be based on the number of sentences
#     })

# # Combine nodes and links into a single dictionary
# graph_data = {
#     "nodes": nodes,
#     "links": links
# }

# %%
# import os

# os.environ['METIS_DLL'] = '/Users/.local/lib/libmetis.dylib'

# %%
# import metis

# %%
# edgecuts, parts = metis.part_graph(G)

# %%
import json

# Create a mapping from nodes to integers
node_to_int = {node: i for i, node in enumerate(G.nodes)}

# %%
degree_dict = dict(G.degree(G.nodes()))
nx.set_node_attributes(G, degree_dict, 'degree')

data = nx.node_link_data(G)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/networkx/readwrite/json_graph/node_link.py:142: FutureWarning:
#
#
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.

# %%
import numpy as np

# %%
labels = labels.astype(np.int32)

# %%
graph_data = {
    "nodes": [{"name": str(node), "n": degree_dict[node], "grp": int(labels[i]), "id": str(node)} for i, node in enumerate(G.nodes())],
    "links": [{"source": str(link_data['source']), "target": str(link_data['target']), "value": 1} for link_data in data['links']]
}

# %%
json_data = json.dumps(graph_data)
with open('data_talaq.json', 'w') as f:
    f.write(json_data)

# %%
# from collections import defaultdict

# # Create a dictionary where keys are part numbers and values are lists of nodes
# part_dict = defaultdict(list)
# for node, part in enumerate(parts):
#     part_dict[part].append(node)

# # Print the number of parts
# print("Number of parts:", len(part_dict))

# # Print the nodes in each part
# for part, nodes in part_dict.items():
#     print("Part", part, ":", nodes)

# %%
# Assuming you have already created clusters using DBSCAN and have 'labels' and 'G' available

# Initialize an empty dictionary to store sentences for each cluster
cluster_sentences_dict = {}

# Iterate over each cluster
for original_cluster_id in set(labels):
    cluster_id = label_mapping[original_cluster_id]
    cluster_nodes = [node for node, label in zip(G.nodes, labels) if label == original_cluster_id]
    
    # Initialize a set to store sentences for this cluster
    cluster_sentences = set()
    
    # Iterate over nodes in the cluster
    for node in cluster_nodes:
        # Assuming 'node' contains the relevant information (e.g., entity, time, location)
        # Extract sentences associated with this node and add them to the cluster_sentences set
        if node in sentences_dict:
            cluster_sentences.update(sentences_dict[node])
    
    # Store the cluster_sentences set in the cluster_sentences_dict
    cluster_sentences_dict[cluster_id] = cluster_sentences

# %%
sentences_dict
# Out:
# {'dissolution of marriage': ['xxx  xxx  xxx \n5. E2 by court in certain circu mstances.-the \ndistrict judge may, on petition made by a muslim marrie d woman, \ndissolve a marriage on any ground recognized by mus lim personal law \n(shariat).Ã¢Â\x80Â\x9d \n \na close examination of section 2, extracted above, lea ves no room for any \ndoubt, that custom and usage, as it existed amongst musli ms, were sought 30 to be expressly done away with, to the extent the same w ere contrary to \nmuslim Ã¢Â\x80Â\x98personal lawÃ¢Â\x80Â\x99. section 2 also mandated, that m uslim Ã¢Â\x80Â\x98personal lawÃ¢Â\x80Â\x99 \n(shariat) would be exclusively adopted as Ã¢Â\x80Â\x9cÃ¢Â\x80Â¦ the rul e of decision Ã¢Â\x80Â¦Ã¢Â\x80Â\x9d in \nmatters of intestate succession, special property of fe males, including all \nquestions pertaining to Ã¢Â\x80Â\x9cÃ¢Â\x80Â¦ personal property inherite d or obtained under \ncontract or gift or any other provision of Ã¢Â\x80Â\x98personal la wÃ¢Â\x80Â\x99, marriage, \nE2, including talaq, ila, zihar , lian, E3 and \nE4 maintenance, dower, gifts, trusts and trust pro perties, and wakfs \nÃ¢Â\x80Â¦Ã¢Â\x80Â\x9d.',
#   'we have already enumerated the relevant provisio ns of the shariat \nact (-for details, refer to part-4 Ã¢Â\x80Â\x93 legislation in in dia, in the field of muslim \nÃ¢Â\x80Â\x98personal lawÃ¢Â\x80Â\x99). a perusal of section 2 thereof (ex tracted in paragraph 23 \nabove) reveals, that on the questions/subjects of intesta te succession, \nspecial property of females, including personal pro perty inherited or \nobtained under contract or gift or any other provision of Ã¢Â\x80Â\x98personal lawÃ¢Â\x80Â\x99, \nmarriage, E2 including talaq, ila, zihar, lian, E3 and \nE4 maintenance, dower, guardianship, gifts, trus ts and trust \nproperties, and wakfs, Ã¢Â\x80Â\x9cÃ¢Â\x80Â¦ the rule of decision Ã¢Â\x80Â¦Ã¢Â\x80Â\x9d, wh ere the parties are \nmuslims, shall be Ã¢Â\x80Â\x9cÃ¢Â\x80Â¦ the muslim personal law Ã¢Â\x80Â\x93 shar iat. the submission \nof the learned counsel representing the petitioners, in  support of the instant \ncontention was, that since the Ã¢Â\x80Â\x9crule of the decisionÃ¢Â\x80Â\x9d inter alia  with reference \nto Ã¢Â\x80Â\x98talaqÃ¢Â\x80Â\x99 (-Ã¢Â\x80Â\x98talaq-e-biddatÃ¢Â\x80Â\x99), was thereafter to be reg ulated in terms of the \nshariat act, what was Ã¢Â\x80Â\x98personal lawÃ¢Â\x80Â\x99 (-prior to the abo ve enactment), came \nto be transformed into Ã¢Â\x80Â\x98statutory lawÃ¢Â\x80Â\x99.',
#   'application of personal law to muslims. Ã¢Â\x80Â\x93 \nnotwithstanding any custom or usage to the \ncontrary, in all questions (save questions relating  \nto agricultural land) regarding intestate \nsuccession, special property of females, including \npersonal property inherited or obtained under \ncontract or gift or any other provision of personal  \nlaw, marriage, E2 including \ntalaq , ila, zihar, lian, E3 and E4 , \nmaintenance, dower, guardianship, gifts, trusts \nand trust properties, and wakfs  (other than \ncharities and charitable institutions and charitabl e \nand religious endowments) the rule of decision in  \ncases where the parties are muslims shall be \nmuslim personal law ( shariat ). (emphasis supplied) \n \n4.',
#   'sections 2, 3 and 5 of the shariat act are releva nt and are extracted \nhereunder: \nÃ¢Â\x80Â\x9c2. application of personal law to muslims.- notwithsta nding any \ncustoms or usage to the contrary, in all questions  (save questions \nrelating to agricultural land) regarding intestate succe ssion, special \nproperty of females, including personal property in herited or obtained \nunder contract or gift or any other provision of perso nal law, marriage, \nE2 including talaq, ila, zihar , lian, E3 and \nE4 , maintenance, dower, guardianship, gifts, trusts and trust \nproperties, and wakfs (other than charities and charita ble institutions \nand charitable and religious endowments) the rule of d ecision in cases \nwhere the parties are muslims shall be the muslim pers onal law \n(shariat).Ã¢Â\x80Â\x9d \n3. power to make a declaration.- (1) any person who s atisfies the \nprescribed authority- \n(a) that he is a muslim, and  \n(b) that he is competent to contract within the meaning o f section 11 of \nthe contract act, 1872 (9 of 1872), and  \n(c) that he is a resident of the territories to which thi s act extends, \nmay by declaration in the prescribed form and filed before the prescribed \nauthority declare that he desires to obtain the benefit of  the provisions of \nthis section, and thereafter the provisions of section 2  shall apply to the \ndeclarant and all his minor children and their descen dants as if in \naddition to the matters enumerated therein adoption, w ills and legacies \nwere also specified.'],
#  'nan, NULL': ['for their personal relations, they follow the muslim Ã¢Â\x80Â\x98personal \nlawÃ¢Â\x80Â\x99 Ã¢Â\x80Â\x93 Ã¢Â\x80Â\x98shariatÃ¢Â\x80Â\x99. the muslim personal law (shariat)  application act, 1937, \nas already noticed above provided, Ã¢Â\x80Â\x9cthe rule of deci sionÃ¢Â\x80Â\x9d in matters \npertaining, inter alia, to marriage, dissolution of mar riage including talaq, \nila, zihar, lian, E3 and E4 would be the mus lim Ã¢Â\x80Â\x98personal lawÃ¢Â\x80Â\x99 Ã¢Â\x80Â\x93 \nÃ¢Â\x80Â\x98shariatÃ¢Â\x80Â\x99, and not, any custom or usage to the contrary. it is therefore, that \nby a statutory intervention, customs and usages in conf lict with muslim \nÃ¢Â\x80Â\x98personal lawÃ¢Â\x80Â\x99, were done away with, in connection wi th Ã¢Â\x80Â\x98personal lawÃ¢Â\x80Â\x99 \nmatters, in relation to muslims.',
#   'application of personal law to muslims. Ã¢Â\x80Â\x93 \nnotwithstanding any custom or usage to the \ncontrary, in all questions (save questions relating  \nto agricultural land) regarding intestate \nsuccession, special property of females, including \npersonal property inherited or obtained under \ncontract or gift or any other provision of personal  \nlaw, marriage, E2 including \ntalaq , ila, zihar, lian, E3 and E4 , \nmaintenance, dower, guardianship, gifts, trusts \nand trust properties, and wakfs  (other than \ncharities and charitable institutions and charitabl e \nand religious endowments) the rule of decision in  \ncases where the parties are muslims shall be \nmuslim personal law ( shariat ). (emphasis supplied) \n \n4.',
#   'finally, many muslim countries, \nincluding algeria, egypt, jordan, morocco, sudan, s yria, and yemen, have implemented laws that \nuphold the notion that a triple talak counts as onl y one talak. personal law in islamic countries, tah ir \nmahmood, academy of law and religion: new delhi (19 87). 3  4  \n5  \n6 see supra, fn 25 & 26, for the opinion of the hanaf i madhab that E8 is sinful.',
#   'but rather it require a state \nintervention by way of legislation to regulate triple ta laq in india. therefore, settlement of law relating to talaq is necessa ry and further \ndiscussion is to be treated as an allude for the state to consider for \npossible reforms of E9 law of muslim in this c ountry . the empirical \nresearch placed herein justifies such course of acti on to remind the state \nfor action.',
#   'the emphasis \nwas that a talaq would be valid only if it is effecte d in accordance with \nthe muslim law. in ilr 5, rangoon 18, their lordships of the privy co uncil observed: \nÃ¢Â\x80Â\x9caccording to that law (the muslim law), a husband ca n effect a E9 \nwhenever he desires.Ã¢Â\x80Â\x9d \nbut the privy council has not said that the E9 need  not be duly \neffected or that procedure enjoined by the quran need  not be followed. 8.',
#   'we have already enumerated the relevant provisio ns of the shariat \nact (-for details, refer to part-4 Ã¢Â\x80Â\x93 legislation in in dia, in the field of muslim \nÃ¢Â\x80Â\x98personal lawÃ¢Â\x80Â\x99). a perusal of section 2 thereof (ex tracted in paragraph 23 \nabove) reveals, that on the questions/subjects of intesta te succession, \nspecial property of females, including personal pro perty inherited or \nobtained under contract or gift or any other provision of Ã¢Â\x80Â\x98personal lawÃ¢Â\x80Â\x99, \nmarriage, E2 including talaq, ila, zihar, lian, E3 and \nE4 maintenance, dower, guardianship, gifts, trus ts and trust \nproperties, and wakfs, Ã¢Â\x80Â\x9cÃ¢Â\x80Â¦ the rule of decision Ã¢Â\x80Â¦Ã¢Â\x80Â\x9d, wh ere the parties are \nmuslims, shall be Ã¢Â\x80Â\x9cÃ¢Â\x80Â¦ the muslim personal law Ã¢Â\x80Â\x93 shar iat. the submission \nof the learned counsel representing the petitioners, in  support of the instant \ncontention was, that since the Ã¢Â\x80Â\x9crule of the decisionÃ¢Â\x80Â\x9d inter alia  with reference \nto Ã¢Â\x80Â\x98talaqÃ¢Â\x80Â\x99 (-Ã¢Â\x80Â\x98talaq-e-biddatÃ¢Â\x80Â\x99), was thereafter to be reg ulated in terms of the \nshariat act, what was Ã¢Â\x80Â\x98personal lawÃ¢Â\x80Â\x99 (-prior to the abo ve enactment), came \nto be transformed into Ã¢Â\x80Â\x98statutory lawÃ¢Â\x80Â\x99.',
#   'to this , the \ncounter argument of the other side is that muslim 305 personal laws are not being attacked as such. what  is \nthe subject matter of attack in these matters is a \nstatute, namely, the muslim personal law ( shariat ) \napplication act, 1937 (hereinafter referred to as t he \nÃ¢Â\x80Â\x9c1937 actÃ¢Â\x80Â\x9d). according to them, E8 is \nspecifically sanctioned by statutory law vide  section 2 \nof the 1937 act and what is sought for is a declara tion \nthat section 2 of the 1937 act is constitutionally invalid \nto the aforesaid extent.',
#   'muslims of the sunni sect constitute its majo rity. on the issue in \nhand, it has enacted the following legislation: \ncode of personal status 1956 \nlaw 13-8 of 1956 as amended by law 7 of 1981 \nÃ¢Â\x80Â\x9carticle 31. (1) a decree of E9 shall be given: (i) with the mutual \nconsent of the parties; or (ii) at the instance of either party on the ground \nof injury; or (iii) if the husband insists on divor ce or the wife demands it.',
#   'muslims of the sunni sect constitute its majo rity. on the issue in \nhand, it has enacted the following legislation:  \ncode of family law 1984 \nlaw no.84-11 of 1984 as amended in 2005 \nÃ¢Â\x80Â\x9carticle 49. E9 cannot be established except by a judgment of the \ncourt, preceded by an attempt at reconciliation for a period not exceeding \nthree months.Ã¢Â\x80Â\x9d \n \n(ii)  egypt : is a secular state.',
#   "their lordships are of opinion that the pronoun cement of the triple \ntalak by ghiyas-ud-din constituted an immediately eff ective E9 , and, \nwhile they are satisfied that the high court were not justi fied in such a \nconclusion on the evidence in the present case, they a re of opinion that \nthe validity and effectiveness of the E9 would no t be affected by \nghiyas-ud-dinÃ¢Â\x80Â\x99s mental intention that it should not be a genuine E9, \nas such a view is contrary to all authority. a talak a ctually pronounced \nunder compulsion or in jest is valid and effective : baillieÃ¢Â\x80Â\x99s digest, 2nd \nedn., p. 208; ameer ali's mohammedan law, 3rd edn.,  vol. ii, p. 518; \nhamilton's hedaya, vol.",
#   'muslims of the sunni sect constitute its majo rity. on the issue in \nhand, it has the following legislation in place: \nlaw on talaq 1935 \njudicial proclamation no.4 of 1935 \nÃ¢Â\x80Â\x9carticle 1. a E9 uttered in a state of intoxicatio n or under duress \nshall be invalid and ineffective.',
#   'in morocco and indonesia, \nE9 proceedings take place in a secular court, pr ocedures of mediation \nand reconciliation are encouraged, and men and women  are considered \nequal in matters of family and E9. in indonesia , E9 is a judicial \nprocess, where those marrying under islamic law, ca n approach the \nreligious court for a E9, while others can appro ach district courts for \nthe same. in iran and sri lanka, E9 can be gra nted by a qazi and/or a \ncourt, only after reconciliation efforts have failed.',
#   'christians constitute its major ity. on \nthe issue in hand, it has the following legislation in  place: \ncode of muslim personal law 1977 \ndecree no.1083 of 1977 \nÃ¢Â\x80Â\x9carticle 46. (1) a E9 by talaq may be effected by the husband in a \nsingle repudiation of his wife during her tuhr [non- menstrual period] \nwithin which he has totally abstained from carnal rela tions with her.',
#   'abrogation of the practice of Ã¢Â\x80Â\x98talaq-e-biddatÃ¢Â\x80Â\x99 by legis lation, the world over, in  \nislamic, as well as, non-islamic states : \n \n28. Ã¢Â\x80Â\x98muslim law in india and abroadÃ¢Â\x80Â\x99, by tahir mahm ood and saif \nmahmood (universal law publishing co. pvt. ltd., new delhi, 2012 edition), \nrecords the following position about the abrogation of the practice of Ã¢Â\x80Â\x98talaq-\ne-biddatÃ¢Â\x80Â\x99 as a means of E9 through statutory ena ctments, the world \nover.',
#   '311 9. this then leads us to the forms of E9 \nrecognized in islamic law. mulla (supra), at pages \n393-395,  puts it thus:  \nÃ¢Â\x80Â\x9cs.',
#   "in ilr 30 madras 22  precisely held \nwas that impropriety of the husband's conduct would in no way affect \nthe legal validity of a E9 duly effected by the h usband. the emphasis \nwas that a talaq would be valid only if it is effecte d in accordance with \nthe muslim law. in ilr 5, rangoon 18, their lordships of the privy co uncil observed: \nÃ¢Â\x80Â\x9caccording to that law (the muslim law), a husband ca n effect a E9 \nwhenever he desires.Ã¢Â\x80Â\x9d \nbut the privy council has not said that the E9 need  not be duly \neffected or that procedure enjoined by the quran need  not be followed.",
#   '(2) if the \nphrase just quoted was intended to have such a wide op eration as \ncutting at even the essentials guaranteed by article 25(1 ), there would \nhave been no need for the special provision as to Ã¢Â\x80Â\x9ct hrowing open of \nhindu religious institutionsÃ¢Â\x80Â\x9d to all classes and secti ons of hindus since \nthe legislation contemplated by this provision would be par excellence \none of social reform.Ã¢Â\x80Â\x9d \n \n73. it was pointed out, that in the counter-affidavit dated august 2016, \nfiled on behalf of the muslim personal law board, i. e., respondent no.3 to \nthis petition, the practices of E8 (as well as, Ã¢Â\x80Â\x98nikah halalaÃ¢Â\x80Â\x99 and \npolygamy) have been referred to as Ã¢Â\x80Â\x9cundesirableÃ¢Â\x80Â\x9d. i t was accordingly \n                                                 \n28  air 1962 sc 853 120 submitted, that no Ã¢Â\x80Â\x9cundesirableÃ¢Â\x80Â\x9d practice can be conferr ed the status of an \nÃ¢Â\x80Â\x9cessential practiceÃ¢Â\x80Â\x9d, much less one that forms the subs tratum of the \nconcerned religion.',
#   '117. if the muslim personal law (shariat) application act, 1937, had \nincorporated the manner in which questions regarding i ntestate succession, \nspecial property of females including personal prop erty inherited or 180 obtained under contract or gift or matters such as marria ge, dissolution of \nmarriage, including talaq, ila, jihar, lian, E3 a nd E4 \nmaintenance, dower, guardianship, gifts, trusts and tr ust properties, and \nwakfs (-as in section 2 thereof), had to be dealt with, as per muslim \nÃ¢Â\x80Â\x98personal lawÃ¢Â\x80Â\x99 Ã¢Â\x80Â\x93 Ã¢Â\x80Â\x98shariatÃ¢Â\x80Â\x99 according to the petitioner s, it would be quite a \ndifferent matter. all the same, the shariat act did not describe how the \nabove questions and subjects had to be dealt with.',
#   'i n a \nprivy council decision in 1932, 5 years before the 1937 \nact, namely rashid ahmad v.  anisa khatun , (1931-\n32) 59 ia  21: air 1932 pc 25, the privy council was \nsquarely called upon to adjudicate upon a triple ta laq. lord thankerton speaking for the privy council put it \nthus: \nÃ¢Â\x80Â\x9cthere is nothing in the case to suggest \nthat the parties are not sunni mahomedans \ngoverned by the ordinary hanafi law, and, \nin the opinion of their lordships, the law of \nE9 applicable in such a case is \ncorrectly stated by sir r.k wilson, in his \ndigest of anglo-muhammadan law, 5th \ned., at p. 136, as follows: Ã¢Â\x80Â\x9cthe E9 \ncalled talak  may be either irrevocable ( bain ) \nor revocable ( raja ). a talak bain , while it \nalways operates as an immediate and \ncomplete dissolution of the marriage bond, \ndiffers as to one of its ulterior effects \naccording to the form in which it is \npronounced.',
#   'muslims of the sunni sect constitute its majo rity. on the issue in \nhand, it has enacted the following legislation: \nfamily law 1984 \nlaw 10 of 1984 as amended by law 15 of 1984 \nÃ¢Â\x80Â\x9carticle 28. E9 is termination of the marriage bo nd.',
#   'muslims constitute its majority,  which is \nestimated to be 54% (27% shia, and 27% sunni). on th e issue in hand, it \nhas enacted the following legislation: \nfamily rights law 1962 \nlaw of 16 july 1962 \nÃ¢Â\x80Â\x9carticle 104. a E9 by a drunk person shall have  no effect.',
#   'reference to tafs ir ibn kathir was \nstated to be improper, as he belonged to the ahl-e-hadit h/salafi school, 198 which school does not accept E8 it was subm itted, that dr. tahir \nmahmood was a professor of law at the delhi universit y, and his views \nmust be treated as personal to him, and could not be elevated to the \nposition of Ã¢Â\x80Â\x98hadithsÃ¢Â\x80Â\x99. it was pointed out, that sheikh yu suf al-qaradawi, \nwas a follower of ahl-e-hadith school, and therefor e, his views could not be \ntaken into consideration.',
#   'sections 2, 3 and 5 of the shariat act are releva nt and are extracted \nhereunder: \nÃ¢Â\x80Â\x9c2. application of personal law to muslims.- notwithsta nding any \ncustoms or usage to the contrary, in all questions  (save questions \nrelating to agricultural land) regarding intestate succe ssion, special \nproperty of females, including personal property in herited or obtained \nunder contract or gift or any other provision of perso nal law, marriage, \nE2 including talaq, ila, zihar , lian, E3 and \nE4 , maintenance, dower, guardianship, gifts, trusts and trust \nproperties, and wakfs (other than charities and charita ble institutions \nand charitable and religious endowments) the rule of d ecision in cases \nwhere the parties are muslims shall be the muslim pers onal law \n(shariat).Ã¢Â\x80Â\x9d \n3. power to make a declaration.- (1) any person who s atisfies the \nprescribed authority- \n(a) that he is a muslim, and  \n(b) that he is competent to contract within the meaning o f section 11 of \nthe contract act, 1872 (9 of 1872), and  \n(c) that he is a resident of the territories to which thi s act extends, \nmay by declaration in the prescribed form and filed before the prescribed \nauthority declare that he desires to obtain the benefit of  the provisions of \nthis section, and thereafter the provisions of section 2  shall apply to the \ndeclarant and all his minor children and their descen dants as if in \naddition to the matters enumerated therein adoption, w ills and legacies \nwere also specified.',
#   "the only thing to be further considered in this \ncase is whether the E9 alleged to have been \neffected by the husband by pronouncement of \ntalaq on 23-7-1999 is proved or not. the mere \npronouncement of talaq three times even in the \npresence of the wife is not sufficient to effect a \nE9 under mohammadan law. as held by the \nsupreme court in shamim ara's  case [2002 (3) klt \n537 (sc)], there should be an attempt of mediation \nby two mediators; one on the side of the husband \nand the other on the side of the wife and only in \ncase it was a failure that the husband is entitled to \npronounce talaq to E9 the wifeÃ¢Â\x80Â¦ Ã¢Â\x80Â\x9d \n                                                 \n64  2005 (4) klt 565 296 (emphasis supplied) \n \n21.",
#   'muslims of 40 the shia sect constitute its majority. on the issue in hand, it has the \nfollowing legislation in place: \nlaw of personal status 2005 \nfederal law no.28 of 2005 \nÃ¢Â\x80Â\x9carticle 140(1). if a husband E9s his wife aft er consummation of a \nvalid marriage by his unilateral action and without an y move for E9 \nfrom her side, she will be entitled to compensation bes ides maintenance \nfor iddat.',
#   'in both countries muslims of the sunni sect constitute the \nmajority. on the issue in hand, it has the following legislation in place: \nmuslim family laws ordinance 1961 \nordinance viii of 1961 amended in bangladesh by ord inance 114 of \n1985 \n(bangladesh changes noted below relevant provisions) \nÃ¢Â\x80Â\x9csection 7. (1)  any man who wishes to E9 his wi fe shall, as soon as \nmay be after the pronouncement of talaq in any form w hatsoever, give \nthe chairman a notice in writing of his having done s o, and shall supply \na copy thereof to the wife .',
#   'in the case of ahmed kasim molla v. khatun bibi repor ted in ilr cal \n833, which has so long been regarded as a leading c ase on the law of \nE9 justice costello held: \nÃ¢Â\x80Â\x9cupon that point (E9), there are a number of author ities and i have \ncarefully considered this point as dealt with in the very early authorities \nto see whether i am in agreement with the mere recent dec isions of the \ncourts. i regret that i have to come to the conclusion tha t at the law \nstands at present, any mohamedan may E9 his wife at his mere \nwhim and caprice.Ã¢Â\x80Â\x9d 56 following macnaghten, j. who held: "there is no occasi on for any \nparticular cause for E9 and mere whim is suffi cient,\'\' and batchelor, \nj, in case of sarabai v. babiabai (ilr 30 bombay 53 7) costello, j. held:Ã¢Â\x80Â\x94 \nÃ¢Â\x80Â\x9cit is good in law, though bad in theology.Ã¢Â\x80Â\x9d \nameer ali, in his treatise on mahomedan law has obse rved: \nÃ¢Â\x80Â\x9cthe prophet pronounced talaq to be a most destable thing  before the \nalmighty god of all permitted things. if \'talaq\' is given without any reason it is stupidity  and ingratitude to \ngod.Ã¢Â\x80Â\x9d \nthe learned author in the same book has also observed  \nÃ¢Â\x80Â\x9cthe author of the multeka (ibrohim halebi) is more c oncise.',
#   'it is \nsubmitted that he belonged to \nthe ahl-e-hadith/salafi school, \nwhich school does not recognize \nE8 (iii) dr. tahir mahmood \n(referred in para 6 of the \njudgment) he was a professor of law, delhi \nuniversity. he wrote a book entitled Ã¢Â\x80Â\x9cmuslim \nlaw in india and abroadÃ¢Â\x80Â\x9d and \nother books.',
#   'xxx  xxx  xxx \n5. E2 by court in certain circu mstances.-the \ndistrict judge may, on petition made by a muslim marrie d woman, \ndissolve a marriage on any ground recognized by mus lim personal law \n(shariat).Ã¢Â\x80Â\x9d \n \na close examination of section 2, extracted above, lea ves no room for any \ndoubt, that custom and usage, as it existed amongst musli ms, were sought 30 to be expressly done away with, to the extent the same w ere contrary to \nmuslim Ã¢Â\x80Â\x98personal lawÃ¢Â\x80Â\x99. section 2 also mandated, that m uslim Ã¢Â\x80Â\x98personal lawÃ¢Â\x80Â\x99 \n(shariat) would be exclusively adopted as Ã¢Â\x80Â\x9cÃ¢Â\x80Â¦ the rul e of decision Ã¢Â\x80Â¦Ã¢Â\x80Â\x9d in \nmatters of intestate succession, special property of fe males, including all \nquestions pertaining to Ã¢Â\x80Â\x9cÃ¢Â\x80Â¦ personal property inherite d or obtained under \ncontract or gift or any other provision of Ã¢Â\x80Â\x98personal la wÃ¢Â\x80Â\x99, marriage, \nE2, including talaq, ila, zihar , lian, E3 and \nE4 maintenance, dower, gifts, trusts and trust pro perties, and wakfs \nÃ¢Â\x80Â¦Ã¢Â\x80Â\x9d.',
#   'the statement of objects and reasons of the bill , delineates the \npurpose that was sought to be achieved through the enactm ent. relevant \npart thereof, is reproduced hereunder:- \nÃ¢Â\x80Â\x9cstatement of objects and reasons \nthe object of indian E9 bill is to place the m atrimonial law \nadministered by the high courts, in the exercise of  their original \njurisdiction, on the same footing as the matrimonia l law administered \nby the court for E9 and matrimonial causes in england . the 9th section of the act of parliament for establ ishing high courts of \njudicature in india (24 and 25 vic., c.104) provide s that the high courts \nshall exercise such matrimonial jurisdiction as her  majesty by letters \npatent shall grant and direct.',
#   'application of personal law to \nmuslims. - notwithstanding any custom or \nusage to the contrary, in all questions (save \nquestions relating to agricultural land) \nregarding intestate succession, special \nproperty of females, including personal \nproperly inherited or obtained under \ncontract or gift or any other provision of \npersonal law, marriage, dissolution of \nmarriage, including talaq , ila , zihar , lian , \nE3  and E4 , maintenance, dower, \nguardianship, gifts, trusts and trust \nproperties, and wakfs  (other than charities \nand charitable institutions and charitable \nand religious endowments) the rule of \ndecision in cases where the parties are \nmuslims shall be the muslim personal law \n(shariat ).Ã¢Â\x80Â\x9d \n \n13. a word as to the meaning of the expression \nÃ¢Â\x80Â\x9cshariatÃ¢Â\x80Â\x9d.',
#   'muslims of the sunni sect const itute its \nmajority. on the issue in hand, it has enacted the fol lowing legislation: \ncode of personal status 1953 \nlaw 59 of 1953 as amended by law 34 of 1975 \nÃ¢Â\x80Â\x9carticle 89. no E9 shall take place when the man is drunk, out of his \nsenses, or under duress.',
#   'the first-named of the \nabove methods is called ahsan  (best), the 327 second hasan  (good), the third and fourth \nare said to be bidaat  (sinful), but are, \nnevertheless, regarded by sunni lawyers \nas legally valid.Ã¢Â\x80Â\x9d  \n                                                       (at page \n26) \nthe privy council went on to state: \nÃ¢Â\x80Â\x9ctheir lordships are of opinion that the \npronouncement of the triple talak by \nghiyas-ud-din constituted an immediately \neffective E9 and, while they are \nsatisfied that the high court were not \njustified in such a conclusion on the \nevidence in the present case, they are of \nopinion that the validity and effectiveness of \nthe E9 would not be affected by \nghiyas-ud-dinÃ¢Â\x80Â\x99s mental intention that it \nshould not be a genuine E9 as such a \nview is contrary to all authority. a talak \nactually pronounced under compulsion or in \njest is valid and effective: baillieÃ¢Â\x80Â\x99s digest, \n2nd ed., p. 208; ameer aliÃ¢Â\x80Â\x99s mohammedan \nlaw, 3rd ed., vol. ii., p. 518; hamiltonÃ¢Â\x80Â\x99s \nhedaya, vol.',
#   'in common law systems, personal law refers to the l aw of \nthe personÃ¢Â\x80Â\x99s domicile. in civil-law systems, it refer s to the law of the \nindividualÃ¢Â\x80Â\x99s nationality (and so is sometimes called  lex patriae).Ã¢Â\x80Â\x9d \nreference was also made to the definition of the term Ã¢Â\x80Â\x98personal lawÃ¢Â\x80Â\x99 in \nÃ¢Â\x80Â\x98conflict of laws 188Ã¢Â\x80Â\x99 (7 th  edition, 1974) by r.h. graveson, who defined the \nterm as under: \nÃ¢Â\x80Â\x9cthe idea of the personal law is based on the concept ion of man as a \nsocial being, so that those transactions of his daily l ife which affect him \nmost closely in a personal sense, such as marriage, E9 legitimacy, \nmany kinds of capacity, and succession, may be gove rned universally by \nthat system of law deemed most suitable and adequate fo r the purpose  \nÃ¢Â\x80Â¦Ã¢Â\x80Â\x9d \nbased on the cumulative definition of the term Ã¢Â\x80Â\x98persona l lawÃ¢Â\x80Â\x99, it was \nsubmitted, that the evolution of the matters of faith relati ng to religious \npractices, must necessarily be judged in the context of practices adopted by \nthe concerned community, with reference to each indiv idual aspect of \nÃ¢Â\x80Â\x98personal lawÃ¢Â\x80Â\x99. it was conceded, on behalf of the a implb, that Ã¢Â\x80Â\x98personal \nlawsÃ¢Â\x80Â\x99 were per se  subservient to legislation, and as such, Ã¢Â\x80Â\x98personal la wsÃ¢Â\x80Â\x99 \nwere liable to be considered as mandatory, with refer ence to numerous \naspects of an individualÃ¢Â\x80Â\x99s life, only in the absence  of legislation.',
#   'muslims of the sunni sect constitute its m ajority. on the \nissue in hand, it has the following legislation in pl ace: \n(a) law of marriage 1974 \nlaw 1 of 1974 \nÃ¢Â\x80Â\x9carticle 38. a E9 shall be effected only in the  court and the court \nshall not permit a E9 before attempting reconcili ation between the \nparties.',
#   'muslims of the sunni sect constit ute its majority. on \nthe issue in hand, it has the following legislation in  place: \nislamic family law act 1984 \nact 304 of 1984 \nÃ¢Â\x80Â\x9carticle 47. (1) a husband or a wife who desires a d ivorce shall present \nan application for E9 to the court in the prescrib ed form \naccompanied by a statutory declaration containing  (a) particulars of the \nmarriage and the name, ages and sex of the children, if any, of the \nmarriage; (b) particulars of the facts giving the court jurisdiction under \nsection 45; (c) particulars of any previous matrimonia l proceedings \nbetween the parties, including the place of the proceed ings; (d) a \nstatement as to the reasons for desiring E9 ; (e) a statement as to \nwhether any, and if so, what steps have been taken to e ffect \nreconciliation ; (f) the terms of any agreement regarding maintenanc e and \nhabitation of the wife and the children of the marriage , if any, and the \ndivision of any assets acquired through the joint effo rt of the parties, if \nany, or where no such agreement has been reached, the  applicantÃ¢Â\x80Â\x99s \nproposals regarding those matters; and (g) particular s of the order \nsought.',
#   'we will need  to determine, the legal \nsanctity of Ã¢Â\x80Â\x98talaq-e-biddatÃ¢Â\x80Â\x99 Ã¢Â\x80Â\x93 E8 this will  enable us to ascertain, \nwhether the practice of talaq has a legislative sanction,  because it is the \npetitionerÃ¢Â\x80Â\x99s case, that it is so through express legislati on (-the muslim \npersonal law (shariat) application act, 1937). but the stance adopted on \nbehalf of those contesting the petitionerÃ¢Â\x80Â\x99s claim is, tha t its stature is that of \nÃ¢Â\x80Â\x98personal lawÃ¢Â\x80Â\x99, and on that account, the practice of Ã¢Â\x80Â\x98 talaq-e-biddatÃ¢Â\x80Â\x99 has a \nconstitutional protection.',
#   "in a. s. parveen akthar  v. the union of india 60 , the \nhigh court of madras was posed with the question on  the \nvalidity and constitutionality of section 2 of the 1937 act in so \nfar as it recognises E8 as a valid form o f E9 the \ncourt referred to the provisions of the quran, opin ions of \nvarious eminent scholars of islamic law and previou s judicial \npronouncements including shamim ara  and came to the \nfollowing conclusion:  \n \nÃ¢Â\x80Â\x9c45.thus, the law with regard to talaq, as declared  \nby the apex court, is that talaq must be for a \nreasonable cause and must be preceded by \nattempt at reconciliation between the husband \nand the wife by two arbiters one chosen by wife's \nfamily and the other from husband's family and it \nis only if their attempts fail, talaq may be effect ed. xxxx \n48.having regard to the law now declared by the \napex court in the case of shamim ara , 2002 air \nscw 4162, talaq, in whatever form, must be for a \nreasonable cause, and must be preceded by \nattempts for reconciliation by arbiters chosen \nfrom the families of each of the spouses, the \n                                                 \n60  2003-1-l.w.",
#   'registration of marriage and E9 unde r the assam \nmuslim marriages and E9s registration act, 1935 i s voluntary, and \nunilateral. mere registration of E9 (or marriage ) even if proved, will \nnot render valid E9 which is otherwise invalid under muslim law.Ã¢Â\x80Â\x9d \n \na perusal of the conclusion recorded by the high co urt, through the \nabove observations, leaves no room for any doubt, t hat the Ã¢Â\x80Â\x98talaq-e-biddatÃ¢Â\x80Â\x99 \npronounced by the husband without reasonable cause,  and without being \npreceded by attempts of reconciliation, and without  the involvement of \narbitrators with due representation on behalf of th e husband and wife, 54 would not lead to a valid E9. the high court also concluded, that the \npetitioner Ã¢Â\x80Â\x93 jiauddin ahmed, had mainly alleged tha t he had pronounced \ntalaq, but had not established the factum of divorc e by adducing any \ncogent evidence.',
#   'the majority of iraqÃ¢Â\x80Â\x99s muslims is shias. on the iss ue in hand, it has \nenacted the following legislation: \ncode of personal status 1959 \nlaw 188 of 1959 as amended by law 90 of 1987 \nÃ¢Â\x80Â\x9carticle 35. no E9 shall be effective when pron ounced by the \npersons mentioned below: \n(a)  one who is intoxicated, insane or imbecile, und er duress, or not in \nhis senses due to anger, sudden calamity, old age or  sickness; \n(b) a person in death-sickness or in a condition whic h in all probabilities \nis fatal and of which he actually dies, survived by h is wife.Ã¢Â\x80Â\x9d \n   xxx   xxx   xxx \narticle 37.'],
#  'khula': ['for their personal relations, they follow the muslim Ã¢Â\x80Â\x98personal \nlawÃ¢Â\x80Â\x99 Ã¢Â\x80Â\x93 Ã¢Â\x80Â\x98shariatÃ¢Â\x80Â\x99. the muslim personal law (shariat)  application act, 1937, \nas already noticed above provided, Ã¢Â\x80Â\x9cthe rule of deci sionÃ¢Â\x80Â\x9d in matters \npertaining, inter alia, to marriage, dissolution of mar riage including talaq, \nila, zihar, lian, E3 and E4 would be the mus lim Ã¢Â\x80Â\x98personal lawÃ¢Â\x80Â\x99 Ã¢Â\x80Â\x93 \nÃ¢Â\x80Â\x98shariatÃ¢Â\x80Â\x99, and not, any custom or usage to the contrary. it is therefore, that \nby a statutory intervention, customs and usages in conf lict with muslim \nÃ¢Â\x80Â\x98personal lawÃ¢Â\x80Â\x99, were done away with, in connection wi th Ã¢Â\x80Â\x98personal lawÃ¢Â\x80Â\x99 \nmatters, in relation to muslims.',
#   'application of personal law to muslims. Ã¢Â\x80Â\x93 \nnotwithstanding any custom or usage to the \ncontrary, in all questions (save questions relating  \nto agricultural land) regarding intestate \nsuccession, special property of females, including \npersonal property inherited or obtained under \ncontract or gift or any other provision of personal  \nlaw, marriage, E2 including \ntalaq , ila, zihar, lian, E3 and E4 , \nmaintenance, dower, guardianship, gifts, trusts \nand trust properties, and wakfs  (other than \ncharities and charitable institutions and charitabl e \nand religious endowments) the rule of decision in  \ncases where the parties are muslims shall be \nmuslim personal law ( shariat ). (emphasis supplied) \n \n4.',
#   'sections 2, 3 and 5 of the shariat act are releva nt and are extracted \nhereunder: \nÃ¢Â\x80Â\x9c2. application of personal law to muslims.- notwithsta nding any \ncustoms or usage to the contrary, in all questions  (save questions \nrelating to agricultural land) regarding intestate succe ssion, special \nproperty of females, including personal property in herited or obtained \nunder contract or gift or any other provision of perso nal law, marriage, \nE2 including talaq, ila, zihar , lian, E3 and \nE4 , maintenance, dower, guardianship, gifts, trusts and trust \nproperties, and wakfs (other than charities and charita ble institutions \nand charitable and religious endowments) the rule of d ecision in cases \nwhere the parties are muslims shall be the muslim pers onal law \n(shariat).Ã¢Â\x80Â\x9d \n3. power to make a declaration.- (1) any person who s atisfies the \nprescribed authority- \n(a) that he is a muslim, and  \n(b) that he is competent to contract within the meaning o f section 11 of \nthe contract act, 1872 (9 of 1872), and  \n(c) that he is a resident of the territories to which thi s act extends, \nmay by declaration in the prescribed form and filed before the prescribed \nauthority declare that he desires to obtain the benefit of  the provisions of \nthis section, and thereafter the provisions of section 2  shall apply to the \ndeclarant and all his minor children and their descen dants as if in \naddition to the matters enumerated therein adoption, w ills and legacies \nwere also specified.',
#   'application of personal law to \nmuslims. - notwithstanding any custom or \nusage to the contrary, in all questions (save \nquestions relating to agricultural land) \nregarding intestate succession, special \nproperty of females, including personal \nproperly inherited or obtained under \ncontract or gift or any other provision of \npersonal law, marriage, dissolution of \nmarriage, including talaq , ila , zihar , lian , \nE3  and E4 , maintenance, dower, \nguardianship, gifts, trusts and trust \nproperties, and wakfs  (other than charities \nand charitable institutions and charitable \nand religious endowments) the rule of \ndecision in cases where the parties are \nmuslims shall be the muslim personal law \n(shariat ).Ã¢Â\x80Â\x9d \n \n13. a word as to the meaning of the expression \nÃ¢Â\x80Â\x9cshariatÃ¢Â\x80Â\x9d.',
#   'xxx  xxx  xxx \n5. E2 by court in certain circu mstances.-the \ndistrict judge may, on petition made by a muslim marrie d woman, \ndissolve a marriage on any ground recognized by mus lim personal law \n(shariat).Ã¢Â\x80Â\x9d \n \na close examination of section 2, extracted above, lea ves no room for any \ndoubt, that custom and usage, as it existed amongst musli ms, were sought 30 to be expressly done away with, to the extent the same w ere contrary to \nmuslim Ã¢Â\x80Â\x98personal lawÃ¢Â\x80Â\x99. section 2 also mandated, that m uslim Ã¢Â\x80Â\x98personal lawÃ¢Â\x80Â\x99 \n(shariat) would be exclusively adopted as Ã¢Â\x80Â\x9cÃ¢Â\x80Â¦ the rul e of decision Ã¢Â\x80Â¦Ã¢Â\x80Â\x9d in \nmatters of intestate succession, special property of fe males, including all \nquestions pertaining to Ã¢Â\x80Â\x9cÃ¢Â\x80Â¦ personal property inherite d or obtained under \ncontract or gift or any other provision of Ã¢Â\x80Â\x98personal la wÃ¢Â\x80Â\x99, marriage, \nE2, including talaq, ila, zihar , lian, E3 and \nE4 maintenance, dower, gifts, trusts and trust pro perties, and wakfs \nÃ¢Â\x80Â¦Ã¢Â\x80Â\x9d.',
#   '117. if the muslim personal law (shariat) application act, 1937, had \nincorporated the manner in which questions regarding i ntestate succession, \nspecial property of females including personal prop erty inherited or 180 obtained under contract or gift or matters such as marria ge, dissolution of \nmarriage, including talaq, ila, jihar, lian, E3 a nd E4 \nmaintenance, dower, guardianship, gifts, trusts and tr ust properties, and \nwakfs (-as in section 2 thereof), had to be dealt with, as per muslim \nÃ¢Â\x80Â\x98personal lawÃ¢Â\x80Â\x99 Ã¢Â\x80Â\x93 Ã¢Â\x80Â\x98shariatÃ¢Â\x80Â\x99 according to the petitioner s, it would be quite a \ndifferent matter. all the same, the shariat act did not describe how the \nabove questions and subjects had to be dealt with.',
#   'we have already enumerated the relevant provisio ns of the shariat \nact (-for details, refer to part-4 Ã¢Â\x80Â\x93 legislation in in dia, in the field of muslim \nÃ¢Â\x80Â\x98personal lawÃ¢Â\x80Â\x99). a perusal of section 2 thereof (ex tracted in paragraph 23 \nabove) reveals, that on the questions/subjects of intesta te succession, \nspecial property of females, including personal pro perty inherited or \nobtained under contract or gift or any other provision of Ã¢Â\x80Â\x98personal lawÃ¢Â\x80Â\x99, \nmarriage, E2 including talaq, ila, zihar, lian, E3 and \nE4 maintenance, dower, guardianship, gifts, trus ts and trust \nproperties, and wakfs, Ã¢Â\x80Â\x9cÃ¢Â\x80Â¦ the rule of decision Ã¢Â\x80Â¦Ã¢Â\x80Â\x9d, wh ere the parties are \nmuslims, shall be Ã¢Â\x80Â\x9cÃ¢Â\x80Â¦ the muslim personal law Ã¢Â\x80Â\x93 shar iat. the submission \nof the learned counsel representing the petitioners, in  support of the instant \ncontention was, that since the Ã¢Â\x80Â\x9crule of the decisionÃ¢Â\x80Â\x9d inter alia  with reference \nto Ã¢Â\x80Â\x98talaqÃ¢Â\x80Â\x99 (-Ã¢Â\x80Â\x98talaq-e-biddatÃ¢Â\x80Â\x99), was thereafter to be reg ulated in terms of the \nshariat act, what was Ã¢Â\x80Â\x98personal lawÃ¢Â\x80Â\x99 (-prior to the abo ve enactment), came \nto be transformed into Ã¢Â\x80Â\x98statutory lawÃ¢Â\x80Â\x99.'],
#  'mubaraat': ['for their personal relations, they follow the muslim Ã¢Â\x80Â\x98personal \nlawÃ¢Â\x80Â\x99 Ã¢Â\x80Â\x93 Ã¢Â\x80Â\x98shariatÃ¢Â\x80Â\x99. the muslim personal law (shariat)  application act, 1937, \nas already noticed above provided, Ã¢Â\x80Â\x9cthe rule of deci sionÃ¢Â\x80Â\x9d in matters \npertaining, inter alia, to marriage, dissolution of mar riage including talaq, \nila, zihar, lian, E3 and E4 would be the mus lim Ã¢Â\x80Â\x98personal lawÃ¢Â\x80Â\x99 Ã¢Â\x80Â\x93 \nÃ¢Â\x80Â\x98shariatÃ¢Â\x80Â\x99, and not, any custom or usage to the contrary. it is therefore, that \nby a statutory intervention, customs and usages in conf lict with muslim \nÃ¢Â\x80Â\x98personal lawÃ¢Â\x80Â\x99, were done away with, in connection wi th Ã¢Â\x80Â\x98personal lawÃ¢Â\x80Â\x99 \nmatters, in relation to muslims.',
#   'application of personal law to muslims. Ã¢Â\x80Â\x93 \nnotwithstanding any custom or usage to the \ncontrary, in all questions (save questions relating  \nto agricultural land) regarding intestate \nsuccession, special property of females, including \npersonal property inherited or obtained under \ncontract or gift or any other provision of personal  \nlaw, marriage, E2 including \ntalaq , ila, zihar, lian, E3 and E4 , \nmaintenance, dower, guardianship, gifts, trusts \nand trust properties, and wakfs  (other than \ncharities and charitable institutions and charitabl e \nand religious endowments) the rule of decision in  \ncases where the parties are muslims shall be \nmuslim personal law ( shariat ). (emphasis supplied) \n \n4.',
#   'sections 2, 3 and 5 of the shariat act are releva nt and are extracted \nhereunder: \nÃ¢Â\x80Â\x9c2. application of personal law to muslims.- notwithsta nding any \ncustoms or usage to the contrary, in all questions  (save questions \nrelating to agricultural land) regarding intestate succe ssion, special \nproperty of females, including personal property in herited or obtained \nunder contract or gift or any other provision of perso nal law, marriage, \nE2 including talaq, ila, zihar , lian, E3 and \nE4 , maintenance, dower, guardianship, gifts, trusts and trust \nproperties, and wakfs (other than charities and charita ble institutions \nand charitable and religious endowments) the rule of d ecision in cases \nwhere the parties are muslims shall be the muslim pers onal law \n(shariat).Ã¢Â\x80Â\x9d \n3. power to make a declaration.- (1) any person who s atisfies the \nprescribed authority- \n(a) that he is a muslim, and  \n(b) that he is competent to contract within the meaning o f section 11 of \nthe contract act, 1872 (9 of 1872), and  \n(c) that he is a resident of the territories to which thi s act extends, \nmay by declaration in the prescribed form and filed before the prescribed \nauthority declare that he desires to obtain the benefit of  the provisions of \nthis section, and thereafter the provisions of section 2  shall apply to the \ndeclarant and all his minor children and their descen dants as if in \naddition to the matters enumerated therein adoption, w ills and legacies \nwere also specified.',
#   'application of personal law to \nmuslims. - notwithstanding any custom or \nusage to the contrary, in all questions (save \nquestions relating to agricultural land) \nregarding intestate succession, special \nproperty of females, including personal \nproperly inherited or obtained under \ncontract or gift or any other provision of \npersonal law, marriage, dissolution of \nmarriage, including talaq , ila , zihar , lian , \nE3  and E4 , maintenance, dower, \nguardianship, gifts, trusts and trust \nproperties, and wakfs  (other than charities \nand charitable institutions and charitable \nand religious endowments) the rule of \ndecision in cases where the parties are \nmuslims shall be the muslim personal law \n(shariat ).Ã¢Â\x80Â\x9d \n \n13. a word as to the meaning of the expression \nÃ¢Â\x80Â\x9cshariatÃ¢Â\x80Â\x9d.',
#   'xxx  xxx  xxx \n5. E2 by court in certain circu mstances.-the \ndistrict judge may, on petition made by a muslim marrie d woman, \ndissolve a marriage on any ground recognized by mus lim personal law \n(shariat).Ã¢Â\x80Â\x9d \n \na close examination of section 2, extracted above, lea ves no room for any \ndoubt, that custom and usage, as it existed amongst musli ms, were sought 30 to be expressly done away with, to the extent the same w ere contrary to \nmuslim Ã¢Â\x80Â\x98personal lawÃ¢Â\x80Â\x99. section 2 also mandated, that m uslim Ã¢Â\x80Â\x98personal lawÃ¢Â\x80Â\x99 \n(shariat) would be exclusively adopted as Ã¢Â\x80Â\x9cÃ¢Â\x80Â¦ the rul e of decision Ã¢Â\x80Â¦Ã¢Â\x80Â\x9d in \nmatters of intestate succession, special property of fe males, including all \nquestions pertaining to Ã¢Â\x80Â\x9cÃ¢Â\x80Â¦ personal property inherite d or obtained under \ncontract or gift or any other provision of Ã¢Â\x80Â\x98personal la wÃ¢Â\x80Â\x99, marriage, \nE2, including talaq, ila, zihar , lian, E3 and \nE4 maintenance, dower, gifts, trusts and trust pro perties, and wakfs \nÃ¢Â\x80Â¦Ã¢Â\x80Â\x9d.',
#   '117. if the muslim personal law (shariat) application act, 1937, had \nincorporated the manner in which questions regarding i ntestate succession, \nspecial property of females including personal prop erty inherited or 180 obtained under contract or gift or matters such as marria ge, dissolution of \nmarriage, including talaq, ila, jihar, lian, E3 a nd E4 \nmaintenance, dower, guardianship, gifts, trusts and tr ust properties, and \nwakfs (-as in section 2 thereof), had to be dealt with, as per muslim \nÃ¢Â\x80Â\x98personal lawÃ¢Â\x80Â\x99 Ã¢Â\x80Â\x93 Ã¢Â\x80Â\x98shariatÃ¢Â\x80Â\x99 according to the petitioner s, it would be quite a \ndifferent matter. all the same, the shariat act did not describe how the \nabove questions and subjects had to be dealt with.',
#   'we have already enumerated the relevant provisio ns of the shariat \nact (-for details, refer to part-4 Ã¢Â\x80Â\x93 legislation in in dia, in the field of muslim \nÃ¢Â\x80Â\x98personal lawÃ¢Â\x80Â\x99). a perusal of section 2 thereof (ex tracted in paragraph 23 \nabove) reveals, that on the questions/subjects of intesta te succession, \nspecial property of females, including personal pro perty inherited or \nobtained under contract or gift or any other provision of Ã¢Â\x80Â\x98personal lawÃ¢Â\x80Â\x99, \nmarriage, E2 including talaq, ila, zihar, lian, E3 and \nE4 maintenance, dower, guardianship, gifts, trus ts and trust \nproperties, and wakfs, Ã¢Â\x80Â\x9cÃ¢Â\x80Â¦ the rule of decision Ã¢Â\x80Â¦Ã¢Â\x80Â\x9d, wh ere the parties are \nmuslims, shall be Ã¢Â\x80Â\x9cÃ¢Â\x80Â¦ the muslim personal law Ã¢Â\x80Â\x93 shar iat. the submission \nof the learned counsel representing the petitioners, in  support of the instant \ncontention was, that since the Ã¢Â\x80Â\x9crule of the decisionÃ¢Â\x80Â\x9d inter alia  with reference \nto Ã¢Â\x80Â\x98talaqÃ¢Â\x80Â\x99 (-Ã¢Â\x80Â\x98talaq-e-biddatÃ¢Â\x80Â\x99), was thereafter to be reg ulated in terms of the \nshariat act, what was Ã¢Â\x80Â\x98personal lawÃ¢Â\x80Â\x99 (-prior to the abo ve enactment), came \nto be transformed into Ã¢Â\x80Â\x98statutory lawÃ¢Â\x80Â\x99.'],
#  'divorce': ['but rather it require a state \nintervention by way of legislation to regulate triple ta laq in india. therefore, settlement of law relating to talaq is necessa ry and further \ndiscussion is to be treated as an allude for the state to consider for \npossible reforms of E9 law of muslim in this c ountry . the empirical \nresearch placed herein justifies such course of acti on to remind the state \nfor action.',
# ...
#   'the first-named of the \nabove methods is called ahsan  (best), the 327 second hasan  (good), the third and fourth \nare said to be bidaat  (sinful), but are, \nnevertheless, regarded by sunni lawyers \nas legally valid.Ã¢Â\x80Â\x9d  \n                                                       (at page \n26) \nthe privy council went on to state: \nÃ¢Â\x80Â\x9ctheir lordships are of opinion that the \npronouncement of the triple talak by \nghiyas-ud-din constituted an immediately \neffective E9 and, while they are \nsatisfied that the high court were not \njustified in such a conclusion on the \nevidence in the present case, they are of \nopinion that the validity and effectiveness of \nthe E9 would not be affected by \nghiyas-ud-dinÃ¢Â\x80Â\x99s mental intention that it \nshould not be a genuine E9 as such a \nview is contrary to all authority. a talak \nactually pronounced under compulsion or in \njest is valid and effective: baillieÃ¢Â\x80Â\x99s digest, \n2nd ed., p. 208; ameer aliÃ¢Â\x80Â\x99s mohammedan \nlaw, 3rd ed., vol. ii., p. 518; hamiltonÃ¢Â\x80Â\x99s \nhedaya, vol.',
#   'in common law systems, personal law refers to the l aw of \nthe personÃ¢Â\x80Â\x99s domicile. in civil-law systems, it refer s to the law of the \nindividualÃ¢Â\x80Â\x99s nationality (and so is sometimes called  lex patriae).Ã¢Â\x80Â\x9d \nreference was also made to the definition of the term Ã¢Â\x80Â\x98personal lawÃ¢Â\x80Â\x99 in \nÃ¢Â\x80Â\x98conflict of laws 188Ã¢Â\x80Â\x99 (7 th  edition, 1974) by r.h. graveson, who defined the \nterm as under: \nÃ¢Â\x80Â\x9cthe idea of the personal law is based on the concept ion of man as a \nsocial being, so that those transactions of his daily l ife which affect him \nmost closely in a personal sense, such as marriage, E9 legitimacy, \nmany kinds of capacity, and succession, may be gove rned universally by \nthat system of law deemed most suitable and adequate fo r the purpose  \nÃ¢Â\x80Â¦Ã¢Â\x80Â\x9d \nbased on the cumulative definition of the term Ã¢Â\x80Â\x98persona l lawÃ¢Â\x80Â\x99, it was \nsubmitted, that the evolution of the matters of faith relati ng to religious \npractices, must necessarily be judged in the context of practices adopted by \nthe concerned community, with reference to each indiv idual aspect of \nÃ¢Â\x80Â\x98personal lawÃ¢Â\x80Â\x99. it was conceded, on behalf of the a implb, that Ã¢Â\x80Â\x98personal \nlawsÃ¢Â\x80Â\x99 were per se  subservient to legislation, and as such, Ã¢Â\x80Â\x98personal la wsÃ¢Â\x80Â\x99 \nwere liable to be considered as mandatory, with refer ence to numerous \naspects of an individualÃ¢Â\x80Â\x99s life, only in the absence  of legislation.',
#   'muslims of the sunni sect constitute its m ajority. on the \nissue in hand, it has the following legislation in pl ace: \n(a) law of marriage 1974 \nlaw 1 of 1974 \nÃ¢Â\x80Â\x9carticle 38. a E9 shall be effected only in the  court and the court \nshall not permit a E9 before attempting reconcili ation between the \nparties.',
#   'muslims of the sunni sect constit ute its majority. on \nthe issue in hand, it has the following legislation in  place: \nislamic family law act 1984 \nact 304 of 1984 \nÃ¢Â\x80Â\x9carticle 47. (1) a husband or a wife who desires a d ivorce shall present \nan application for E9 to the court in the prescrib ed form \naccompanied by a statutory declaration containing  (a) particulars of the \nmarriage and the name, ages and sex of the children, if any, of the \nmarriage; (b) particulars of the facts giving the court jurisdiction under \nsection 45; (c) particulars of any previous matrimonia l proceedings \nbetween the parties, including the place of the proceed ings; (d) a \nstatement as to the reasons for desiring E9 ; (e) a statement as to \nwhether any, and if so, what steps have been taken to e ffect \nreconciliation ; (f) the terms of any agreement regarding maintenanc e and \nhabitation of the wife and the children of the marriage , if any, and the \ndivision of any assets acquired through the joint effo rt of the parties, if \nany, or where no such agreement has been reached, the  applicantÃ¢Â\x80Â\x99s \nproposals regarding those matters; and (g) particular s of the order \nsought.',
#   "in a. s. parveen akthar  v. the union of india 60 , the \nhigh court of madras was posed with the question on  the \nvalidity and constitutionality of section 2 of the 1937 act in so \nfar as it recognises E8 as a valid form o f E9 the \ncourt referred to the provisions of the quran, opin ions of \nvarious eminent scholars of islamic law and previou s judicial \npronouncements including shamim ara  and came to the \nfollowing conclusion:  \n \nÃ¢Â\x80Â\x9c45.thus, the law with regard to talaq, as declared  \nby the apex court, is that talaq must be for a \nreasonable cause and must be preceded by \nattempt at reconciliation between the husband \nand the wife by two arbiters one chosen by wife's \nfamily and the other from husband's family and it \nis only if their attempts fail, talaq may be effect ed. xxxx \n48.having regard to the law now declared by the \napex court in the case of shamim ara , 2002 air \nscw 4162, talaq, in whatever form, must be for a \nreasonable cause, and must be preceded by \nattempts for reconciliation by arbiters chosen \nfrom the families of each of the spouses, the \n                                                 \n60  2003-1-l.w.",
#   '(2) a wife may also present a petition for the dissolu tion of her marriage \nby a decree of E9 on the ground-  \n(i) in the case of any marriage solemnized before the  commencement of \nthis act, that the husband had married again before such  \ncommencement or that any other wife of the husband marr ied before \nsuch commencement was alive at the time of the solemniz ation of the \nmarriage of the petitioner:  \nprovided that in either case the other wife is alive at the time of the \npresentation of the petition; or \n(ii)that the husband has, since the solemnization of the  marriage, been \nguilty of rape, sodomy or bestiality ; or  \n(iii) that in a suit under section 18 of the hindu adop tions and \nmaintenance act, 1956 (78 of 1956), or in a proceedin g under section \n125 of the code of criminal procedure, 1973, (2 of 1 974) or under \ncorresponding section 488 of the code of criminal pr ocedure, 1898 (5 of \n1898), a decree  or order, as the case may be, has been passed again st \nthe husband awarding maintenance to the wife notwithstan ding that she \nwas living apart and that since the passing of such dec ree or order , \ncohabitation between the parties has not been resumed f or T26 or \nupwards; or  \n(iv) that her marriage (whether consummated or not) wa s solemnized \nbefore she attained the age of fifteen years and she  has repudiated the \nmarriage after attaining that age but before attaining th e age of eighteen \nyears. explanation.- this clause applies whether the marriage  was solemnized \nbefore or after the commencement of the marriage laws (amendment) \nact, 1976 (68 of 1976).Ã¢Â\x80Â\x9d \nby subsequent amendments, section 13b was introduced, w hich provides \nfor E9 by mutual consent. 182.',
#   'registration of marriage and E9 unde r the assam \nmuslim marriages and E9s registration act, 1935 i s voluntary, and \nunilateral. mere registration of E9 (or marriage ) even if proved, will \nnot render valid E9 which is otherwise invalid under muslim law.Ã¢Â\x80Â\x9d \n \na perusal of the conclusion recorded by the high co urt, through the \nabove observations, leaves no room for any doubt, t hat the Ã¢Â\x80Â\x98talaq-e-biddatÃ¢Â\x80Â\x99 \npronounced by the husband without reasonable cause,  and without being \npreceded by attempts of reconciliation, and without  the involvement of \narbitrators with due representation on behalf of th e husband and wife, 54 would not lead to a valid E9. the high court also concluded, that the \npetitioner Ã¢Â\x80Â\x93 jiauddin ahmed, had mainly alleged tha t he had pronounced \ntalaq, but had not established the factum of divorc e by adducing any \ncogent evidence.',
#   'the majority of iraqÃ¢Â\x80Â\x99s muslims is shias. on the iss ue in hand, it has \nenacted the following legislation: \ncode of personal status 1959 \nlaw 188 of 1959 as amended by law 90 of 1987 \nÃ¢Â\x80Â\x9carticle 35. no E9 shall be effective when pron ounced by the \npersons mentioned below: \n(a)  one who is intoxicated, insane or imbecile, und er duress, or not in \nhis senses due to anger, sudden calamity, old age or  sickness; \n(b) a person in death-sickness or in a condition whic h in all probabilities \nis fatal and of which he actually dies, survived by h is wife.Ã¢Â\x80Â\x9d \n   xxx   xxx   xxx \narticle 37.'],
#  'triple talaq': ['to this , the \ncounter argument of the other side is that muslim 305 personal laws are not being attacked as such. what  is \nthe subject matter of attack in these matters is a \nstatute, namely, the muslim personal law ( shariat ) \napplication act, 1937 (hereinafter referred to as t he \nÃ¢Â\x80Â\x9c1937 actÃ¢Â\x80Â\x9d). according to them, E8 is \nspecifically sanctioned by statutory law vide  section 2 \nof the 1937 act and what is sought for is a declara tion \nthat section 2 of the 1937 act is constitutionally invalid \nto the aforesaid extent.',
#   'reference to tafs ir ibn kathir was \nstated to be improper, as he belonged to the ahl-e-hadit h/salafi school, 198 which school does not accept E8 it was subm itted, that dr. tahir \nmahmood was a professor of law at the delhi universit y, and his views \nmust be treated as personal to him, and could not be elevated to the \nposition of Ã¢Â\x80Â\x98hadithsÃ¢Â\x80Â\x99. it was pointed out, that sheikh yu suf al-qaradawi, \nwas a follower of ahl-e-hadith school, and therefor e, his views could not be \ntaken into consideration.',
#   'it is \nsubmitted that he belonged to \nthe ahl-e-hadith/salafi school, \nwhich school does not recognize \nE8 (iii) dr. tahir mahmood \n(referred in para 6 of the \njudgment) he was a professor of law, delhi \nuniversity. he wrote a book entitled Ã¢Â\x80Â\x9cmuslim \nlaw in india and abroadÃ¢Â\x80Â\x9d and \nother books.',
#   'we will need  to determine, the legal \nsanctity of Ã¢Â\x80Â\x98talaq-e-biddatÃ¢Â\x80Â\x99 Ã¢Â\x80Â\x93 E8 this will  enable us to ascertain, \nwhether the practice of talaq has a legislative sanction,  because it is the \npetitionerÃ¢Â\x80Â\x99s case, that it is so through express legislati on (-the muslim \npersonal law (shariat) application act, 1937). but the stance adopted on \nbehalf of those contesting the petitionerÃ¢Â\x80Â\x99s claim is, tha t its stature is that of \nÃ¢Â\x80Â\x98personal lawÃ¢Â\x80Â\x99, and on that account, the practice of Ã¢Â\x80Â\x98 talaq-e-biddatÃ¢Â\x80Â\x99 has a \nconstitutional protection.',
#   'finally, many muslim countries, \nincluding algeria, egypt, jordan, morocco, sudan, s yria, and yemen, have implemented laws that \nuphold the notion that a triple talak counts as onl y one talak. personal law in islamic countries, tah ir \nmahmood, academy of law and religion: new delhi (19 87). 3  4  \n5  \n6 see supra, fn 25 & 26, for the opinion of the hanaf i madhab that E8 is sinful.',
#   "in a. s. parveen akthar  v. the union of india 60 , the \nhigh court of madras was posed with the question on  the \nvalidity and constitutionality of section 2 of the 1937 act in so \nfar as it recognises E8 as a valid form o f E9 the \ncourt referred to the provisions of the quran, opin ions of \nvarious eminent scholars of islamic law and previou s judicial \npronouncements including shamim ara  and came to the \nfollowing conclusion:  \n \nÃ¢Â\x80Â\x9c45.thus, the law with regard to talaq, as declared  \nby the apex court, is that talaq must be for a \nreasonable cause and must be preceded by \nattempt at reconciliation between the husband \nand the wife by two arbiters one chosen by wife's \nfamily and the other from husband's family and it \nis only if their attempts fail, talaq may be effect ed. xxxx \n48.having regard to the law now declared by the \napex court in the case of shamim ara , 2002 air \nscw 4162, talaq, in whatever form, must be for a \nreasonable cause, and must be preceded by \nattempts for reconciliation by arbiters chosen \nfrom the families of each of the spouses, the \n                                                 \n60  2003-1-l.w.",
#   '(2) if the \nphrase just quoted was intended to have such a wide op eration as \ncutting at even the essentials guaranteed by article 25(1 ), there would \nhave been no need for the special provision as to Ã¢Â\x80Â\x9ct hrowing open of \nhindu religious institutionsÃ¢Â\x80Â\x9d to all classes and secti ons of hindus since \nthe legislation contemplated by this provision would be par excellence \none of social reform.Ã¢Â\x80Â\x9d \n \n73. it was pointed out, that in the counter-affidavit dated august 2016, \nfiled on behalf of the muslim personal law board, i. e., respondent no.3 to \nthis petition, the practices of E8 (as well as, Ã¢Â\x80Â\x98nikah halalaÃ¢Â\x80Â\x99 and \npolygamy) have been referred to as Ã¢Â\x80Â\x9cundesirableÃ¢Â\x80Â\x9d. i t was accordingly \n                                                 \n28  air 1962 sc 853 120 submitted, that no Ã¢Â\x80Â\x9cundesirableÃ¢Â\x80Â\x9d practice can be conferr ed the status of an \nÃ¢Â\x80Â\x9cessential practiceÃ¢Â\x80Â\x9d, much less one that forms the subs tratum of the \nconcerned religion.'],
#  '10.10.2015, NULL': ['the petitioner has sought a declaration , that the Ã¢Â\x80Â\x98talaq-e-\nbiddatÃ¢Â\x80Â\x99 pronounced by her husband on T1 be declared as void ab \ninitio . it is also her contention, that such a E9 which abruptly, \nunilaterally and irrevocably terminates the ties of matr imony, purportedly \nunder section 2 of the muslim personal law (shariat) a pplication act, 1937 \n(hereinafter referred to as, the shariat act), be decl ared unconstitutional. during the course of hearing, it was submitted, that the  Ã¢Â\x80Â\x98talaq-e-biddatÃ¢Â\x80Â\x99      \n(-triple talaq), pronounced by her husband is not vali d, as it is not a part of \nÃ¢Â\x80Â\x98shariatÃ¢Â\x80Â\x99 (muslim Ã¢Â\x80Â\x98personal lawÃ¢Â\x80Â\x99).'],
#  'one year, NULL': ['(2) a wife may also present a petition for the dissolu tion of her marriage \nby a decree of E9 on the ground-  \n(i) in the case of any marriage solemnized before the  commencement of \nthis act, that the husband had married again before such  \ncommencement or that any other wife of the husband marr ied before \nsuch commencement was alive at the time of the solemniz ation of the \nmarriage of the petitioner:  \nprovided that in either case the other wife is alive at the time of the \npresentation of the petition; or \n(ii)that the husband has, since the solemnization of the  marriage, been \nguilty of rape, sodomy or bestiality ; or  \n(iii) that in a suit under section 18 of the hindu adop tions and \nmaintenance act, 1956 (78 of 1956), or in a proceedin g under section \n125 of the code of criminal procedure, 1973, (2 of 1 974) or under \ncorresponding section 488 of the code of criminal pr ocedure, 1898 (5 of \n1898), a decree  or order, as the case may be, has been passed again st \nthe husband awarding maintenance to the wife notwithstan ding that she \nwas living apart and that since the passing of such dec ree or order , \ncohabitation between the parties has not been resumed f or T26 or \nupwards; or  \n(iv) that her marriage (whether consummated or not) wa s solemnized \nbefore she attained the age of fifteen years and she  has repudiated the \nmarriage after attaining that age but before attaining th e age of eighteen \nyears. explanation.- this clause applies whether the marriage  was solemnized \nbefore or after the commencement of the marriage laws (amendment) \nact, 1976 (68 of 1976).Ã¢Â\x80Â\x9d \nby subsequent amendments, section 13b was introduced, w hich provides \nfor E9 by mutual consent. 182.']}

# %%
with open("output.txt", "w") as f:
    f.write(str(sentences_dict))
