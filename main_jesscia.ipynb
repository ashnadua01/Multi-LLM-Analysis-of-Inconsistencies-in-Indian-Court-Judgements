# %%
import PyPDF2

# %%
def pdf_to_txt(pdf_file_path, txt_file_path):
    with open(pdf_file_path, 'rb') as pdf_file:
        pdf_reader = PyPDF2.PdfReader(pdf_file)
        
        text = ""
        for page_num in range(len(pdf_reader.pages)):
            page = pdf_reader.pages[page_num]
            text += page.extract_text().rstrip()

    with open(txt_file_path, 'w', encoding='utf-8') as txt_file:
        txt_file.write(text)

# %%
# Example usage
pdf_to_txt("/Users/Desktop/flow/jessica.pdf", "jessica.txt")
# Out:
# incorrect startxref pointer(1)

# %%
# import pandas as pd
# import nltk
# nltk.download('punkt')  # Download the required NLTK data

# %%
def find_related_sentences(sentences, keyword):
    related_sentences = []

    for i, sentence in enumerate(sentences):
        if keyword in sentence:
            prev_sentence = sentences[i - 1].strip() if i > 0 else None
            next_sentence = sentences[i + 1].strip() if i < len(sentences) - 1 else None
            related_sentences.append({
                "Sentence": sentence.strip(),
                "Previous": prev_sentence,
                "Next": next_sentence
            })

    return related_sentences

# %%
# with open("/Users/Desktop/flow/jessic_txt.txt", "r") as file:
#     text = file.read()

# # Tokenize into sentences using nltk.sent_tokenize()
# sentences = nltk.sent_tokenize(text)

# keyword = "Jessica"
# result = []

# related_sentences = find_related_sentences(sentences, keyword)
# result.extend(related_sentences)

# # Create a DataFrame with columns "Sentence," "Previous," and "Next"
# output_df = pd.DataFrame(result, columns=["Sentence", "Previous", "Next"])

# # Save results to a new CSV
# output_df.to_csv("output_sentences.csv", index=False)

# %%
encodings_to_try = ['utf-8', 'latin1', 'utf-16', 'ISO-8859-1']

# Try reading the CSV file with different encodings
for encoding in encodings_to_try:
    try:
        output_df = pd.read_csv("output_sentences.csv", encoding=encoding)
        print("CSV file read successfully with encoding:", encoding)
        break  # Exit loop if successful
    except UnicodeDecodeError:
        print("Failed to read CSV file with encoding:", encoding)
        continue  # Try next encoding
# Out:
# Failed to read CSV file with encoding: utf-8
# CSV file read successfully with encoding: latin1

# %%
# output_df

# %%
concatenated_sen = pd.DataFrame(output_df['Previous'].astype(str) + ' ' + output_df['Sentence'].astype(str) + ' ' + output_df['Next'].astype(str), columns=['concat'])

# %%
print(concatenated_sen['concat'].iloc[0])
# Out:
# On night intervening 29-30.04.1999, a Thursday Party was going on at Qutub Colonnade at Once upon a time restaurant also called Tamarind Cafe. The liquor was being served by the bartenders, namely, Jessica Lal (since deceased) and one Shyan Munshi (PW-2). At about 2.00 a.m., Sidhartha Vashisht  Manu Sharma (appellant in Crl. A. No. 179 of 2007) along with his friends came there and asked for two drinks.

# %%
concatenated_sen.to_csv('sentences_final.csv', index=False)

# %%
import csv

# %%
def create_person_id_map(file_path):
    person_id_map = {}

    with open(file_path, 'r') as csvfile:
        reader = csv.reader(csvfile)
        header = next(reader)
        
        for row in reader:
            person_id_list = row[0]
            person = person_id_list.strip()
            person_id = row[1].strip()
            person_id_map[person] = person_id

    return person_id_map

def create_location_id_map(file_path):
    location_id_map = {}

    with open(file_path, 'r') as csvfile:
        reader = csv.reader(csvfile)
        header = next(reader)
        
        for row in reader:
            location_id_list = row[0]
            location = location_id_list.strip()
            location_id = row[1].strip()
            location_id_map[location] = location_id

    return location_id_map

def create_time_id_map(file_path):
    time_id_map = {}

    with open(file_path, 'r') as csvfile:
        reader = csv.reader(csvfile)
        header = next(reader)
        
        for row in reader:
            time_id_list = row[0].split(',')
            time = time_id_list.strip()
            time_id = row[1].strip()
            time_id_map[time] = time_id

    return time_id_map

def create_event_id_map(file_path):
    event_id_map = {}

    with open(file_path, 'r') as csvfile:
        reader = csv.reader(csvfile)
        header = next(reader)
        
        for row in reader:
            event_id_list = row[0].split(',')
            event = event_id_list.strip()
            event_id = row[1].strip()
            event_id_map[event] = event_id

    return event_id_map

def create_other_id_map(file_path):
    other_id_map = {}

    with open(file_path, 'r') as csvfile:
        reader = csv.reader(csvfile)
        header = next(reader)
        
        for row in reader:
            other_id_list = row[0].split(',')
            other = other_id_list.strip()
            other_id = row[1].strip()
            other_id_map[other] = other_id

    return other_id_map

# %%
file_path_person = 'person.csv'
file_path_location = 'location.csv'
file_path_time = 'time.csv'
file_path_event = 'event.csv'
file_path_other = 'other.csv'
person_id_map = create_person_id_map(file_path_person)
location_id_map = create_location_id_map(file_path_location)
time_id_map = create_location_id_map(file_path_time)
event_id_map = create_location_id_map(file_path_event)
other_id_map = create_location_id_map(file_path_other)

# %%
def generate_ngrams(text, n=6):
    words = text.split()
    ngrams = []
    for j in range(n, 0, -1):
        for i in range(len(words)):
            if i + j <= len(words):
                ngrams.append(' '.join(words[i:i+j]))
    return ngrams

# %%
def preprocess_text(text):
    text = text.replace("'s", "")
    text = text.replace(".", "")
    text = text.replace(";", "")
#     text = text.replace("-", "")
    text = text.replace("!", "")
    text = text.replace("?", "")
#     text = text.replace("/", "")
    text = text.replace("@", "")
    text = text.replace("#", "")
    text = text.replace(",", "")
    return text

# %%
def replace_entities(text):
    text = text.lower()
    ngrams = generate_ngrams(text)
    replaced_text = text

    for ngram in ngrams:
        original = ngram.lower()
        
        if original in person_id_map:
            entity_id = person_id_map[original]
            replaced_text = replaced_text.replace(ngram, entity_id)
        else:
            preprocessed_ngram = preprocess_text(ngram.lower())
            if preprocessed_ngram in person_id_map:
                entity_id = person_id_map[preprocessed_ngram]
                replaced_text = replaced_text.replace(ngram, entity_id)
            else:
                if original in location_id_map:
                    entity_id = location_id_map[original]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif preprocessed_ngram in location_id_map:
                    entity_id = location_id_map[preprocessed_ngram]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif original in time_id_map:
                    entity_id = time_id_map[original]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif preprocessed_ngram in time_id_map:
                    entity_id = time_id_map[preprocessed_ngram]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif original in event_id_map:
                    entity_id = event_id_map[original]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif preprocessed_ngram in event_id_map:
                    entity_id = event_id_map[preprocessed_ngram]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif original in other_id_map:
                    entity_id = other_id_map[original]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                elif preprocessed_ngram in other_id_map:
                    entity_id = other_id_map[preprocessed_ngram]
                    replaced_text = replaced_text.replace(ngram, entity_id)
                    
    return replaced_text

# %%
with open('sentences_final.csv', 'r', encoding='latin-1') as csvfile:
     reader = csv.reader(csvfile)
     next(reader)
     ref_sen = []
     for row in reader:
         sentence = row[0]
         ref_sen.append(sentence)

# %%
final_sentences = []

for sen in ref_sen:
     s = replace_entities(sen)
     final_sentences.append(s)

# %%
with open('cleaned_sentences.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Sentences'])
#      for sen in final_sentences:
    for sen in final_sentences:
        writer.writerow([sen])

# %% [markdown]
# ## Matrix Creation

# %%
# with the sentences
import pandas as pd
import csv
import re

# Load the CSV files
time_df = pd.read_csv('time.csv')
location_df = pd.read_csv('location.csv')
event_df = pd.read_csv('event.csv')
person_df = pd.read_csv('person.csv')
activity_df = pd.read_csv('other.csv')

location_ID = location_df['ID'].tolist()
location_df = location_df['Location'].tolist()

time_ID = time_df['ID'].tolist()
time_df = time_df['Time'].tolist()

# event_ID = event_df['ID'].tolist()
# event_df = event_df['Event'].tolist()

# person_ID = person_df['ID'].tolist()
# person_df = person_df['Person'].tolist()

# activity_ID = activity_df['ID'].tolist()
# activity_df = activity_df['Others'].tolist()

event_ID_map = dict(zip(event_df['ID'], event_df['Event']))
person_ID_map = dict(zip(person_df['ID'], person_df['Person']))
activity_ID_map = dict(zip(activity_df['ID'], activity_df['Activity']))

matrix = {}

# %%
sentences = []
with open('cleaned_sentences.csv', 'r', encoding='latin-1') as csvfile:
    reader = csv.reader(csvfile)
    next(reader)
    for row in reader:
        sentence = row[0]
        sentences.append(sentence)

# %%
for s in sentences:
    pattern = r'([PTLEA]\d+)'
    matches = re.findall(pattern, s)

    persons = []
    time = []
    location = []
    event = []
    activity = []

    for match in matches:
        if match[0] == 'P':
            persons.append(person_ID_map.get(match, 'Unknown Person'))
        elif match[0] == 'L':
             location.append(location_ID.index(match))
        elif match[0] == 'E':
            event.append(event_ID_map.get(match, 'Unknown Event'))
        elif match[0] == 'A':
            activity.append(activity_ID_map.get(match, 'Unknown Activity'))
        elif match[0] == 'T':
            time.append(time_ID.index(match))

    if location and time:
        for loc_index in location:
            loc_key = location_df[loc_index]
            for time_index in time:
                time_key = time_df[time_index]
                if time_key not in matrix:
                    matrix[time_key] = {}
                if loc_key not in matrix[time_key]:
                    matrix[time_key][loc_key] = []
                matrix[time_key][loc_key].extend([(entity, s) for entity in (persons + event + activity)])
    elif location:
        for loc_index in location:
            loc_key = location_df[loc_index]
            if loc_key not in matrix:
                matrix[loc_key] = {}
            if 'NULL' not in matrix:
                matrix['NULL'] = {}
            if loc_key not in matrix["NULL"]:
                matrix["NULL"][loc_key] = []
            matrix["NULL"][loc_key].extend([(entity, s) for entity in (persons + event + activity)])
    elif time:
        for time_index in time:
            time_key = time_df[time_index]
            if time_key not in matrix:
                matrix[time_key] = {}
            if 'NULL' not in matrix[time_key]:
                matrix[time_key]['NULL'] = []
            matrix[time_key]["NULL"].extend([(entity, s) for entity in (persons + event + activity)])
    else:
        if 'NULL' not in matrix:
            matrix['NULL'] = {}
        if 'NULL' not in matrix['NULL']:
            matrix['NULL']['NULL'] = []
        matrix["NULL"]["NULL"].extend([(entity, s) for entity in (persons + event + activity)])

matrix_df = pd.DataFrame.from_dict(matrix, orient='index')

# %%
matrix_df.to_csv('matrix_with_sen.csv')

# %%
import networkx as nx

# %%
df = pd.read_csv('matrix_with_sen.csv')

# %%
df.rename(columns={'Unnamed: 0': 'Time'}, inplace=True)

# %%
df.head()
# Out:
#           Time                                    qutub colonnade  \
# 0     thursday  [('jessica lal', 'on night intervening 29-30.0...
# 1          NaN  [('jessica lal', 'she was at the L3 on that ev...
# 2      morning  [('jessica lal', 'P14 was rushed to L6 from wh...
# 3  two minutes  [('jessica lal', 'he reached the scene of occu...
# 4   02.17 a.m.  [('jessica lal', 'he reached the scene of occu...
#
#                          once upon a time restaurant  \
# 0  [('jessica lal', 'on night intervening 29-30.0...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        tamarind cafe  \
# 0  [('jessica lal', 'on night intervening 29-30.0...
# 1  [('jessica lal', 'the bar counter was located ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                 NULL  \
# 0  [('jessica lal', 'i had purchased four coupons...
# 1  [('jessica lal', 'the waiter did not serve him...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         oberoi hotel  \
# 0  [('jessica lal', 'P14 (since deceased) and P15...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                       tamarind court  \
# 0  [('jessica lal', 'i had known P14 for about fi...
# 1  [('jessica lal', 'the bar counter was located ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                      ashlok hospital  \
# 0                                                NaN
# 1  [('jessica lal', 'on refusal to serve liquor, ...
# 2  [('beena ramani', 'P17 (pw-20), who was presen...
# 3                                                NaN
# 4                                                NaN
#
#                                      apollo hospital  \
# 0                                                NaN
# 1  [('jessica lal', 'on refusal to serve liquor, ...
# 2  [('beena ramani', 'P17 (pw-20), who was presen...
# 3                                                NaN
# 4                                                NaN
#
#                                             mehrauli  \
# 0                                                NaN
# 1  [('jessica lal', 'at  about 4.00 a.m., fir no....
# 2  [('jessica lal', 'P14 was rushed to L6 from wh...
# 3  [('jessica lal', 'he reached the scene of occu...
# 4  [('jessica lal', 'he reached the scene of occu...
#
#                                               punjab  \
# 0                                                NaN
# 1  [('ram jethmalani', 'mr. P65 further submitted...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                            rajasthan  \
# 0                                                NaN
# 1  [('rup singh', 'it is well settled that when p...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   piccadilly sugar industries bhadson kurukshetra chandigarh samalkha okhla  \
# 0                         NaN     NaN         NaN        NaN      NaN   NaN
# 1                         NaN     NaN         NaN        NaN      NaN   NaN
# 2                         NaN     NaN         NaN        NaN      NaN   NaN
# 3                         NaN     NaN         NaN        NaN      NaN   NaN
# 4                         NaN     NaN         NaN        NaN      NaN   NaN
#
#   delhi ghaziabad
# 0   NaN       NaN
# 1   NaN       NaN
# 2   NaN       NaN
# 3   NaN       NaN
# 4   NaN       NaN

# %%
G = nx.Graph()

for index, row in df.iterrows():
    time = row['Time']
    for location in df.columns:
        if location == 'Time':
            continue
        # Convert the tuple to a string and add it as a node
        G.add_node(f"{time}, {location}")

# %%
import ast

# %%
final = set()

# Update the final set with only the entities
for value in pd.unique(df.drop(columns='Time').values.ravel()):
    if pd.notnull(value):
        value_list = ast.literal_eval(value)
        entity_list = [entity for entity, sentence in value_list]
        final.update(entity_list)

# %%
G.add_nodes_from(final)

# %%
for index, row in df.iterrows():
    time = row['Time']
    for location in df.columns:
        if location == 'Time':
            continue
        if pd.notnull(row[location]):
            value_list = ast.literal_eval(row[location])
            entity_list = [entity for entity, sentence in value_list]
            for entity in entity_list:
                if entity in final:
                    # Convert the tuples to strings and add them as an edge
                    G.add_edge(f"{time}, {location}", entity)

# %%
for node in list(G.nodes):
    if not list(G.neighbors(node)):
        G.remove_node(node)

# %%
for node1 in G.nodes:
    # Check if the node string can be split into a pair
    if ', ' in node1:
        # Split the string back into a tuple
        time1, location1 = node1.split(", ")
        for node2 in G.nodes:
            # Check if the node string can be split into a pair
            if ', ' in node2:
                # Split the string back into a tuple
                time2, location2 = node2.split(", ")
                if time1 == time2 or location1 == location2:
                    G.add_edge(node1, node2)

# %%
degree_dict = dict(G.degree(G.nodes()))
nx.set_node_attributes(G, degree_dict, 'degree')

# %%
# Create a dictionary to store the sentences for each node
sentences_dict = {}

# Create a dictionary to store the sentences for each edge i.e. between two nodes
edge_sentences_dict = {}

# Update the sentences_dict and edge_sentences_dict
for index, row in df.iterrows():
    time = row['Time']
    for location in df.columns:
        if location == 'Time':
            continue
        if pd.notnull(row[location]):
            value_list = ast.literal_eval(row[location])
            for entity, sentence in value_list:
                if entity in final:
                    # Add the sentence to the sentences_dict for the entity
                    if entity not in sentences_dict:
                        sentences_dict[entity] = set()
                    sentences_dict[entity].add(sentence)

                    # Add the sentence to the sentences_dict for the (time, location) node
                    time_location_node = f"{time}, {location}"
                    if time_location_node not in sentences_dict:
                        sentences_dict[time_location_node] = set()
                    sentences_dict[time_location_node].add(sentence)

                    # Add the sentence to the edge_sentences_dict for the edge
                    edge = (time_location_node, entity)
                    if edge not in edge_sentences_dict:
                        edge_sentences_dict[edge] = set()
                    edge_sentences_dict[edge].add(sentence)

# Convert the sets back to lists if needed
for node, sentences in sentences_dict.items():
    sentences_dict[node] = list(sentences)

for edge, sentences in edge_sentences_dict.items():
    edge_sentences_dict[edge] = list(sentences)

# %%
from node2vec import Node2Vec

# Create a Node2Vec instance
node2vec = Node2Vec(G, dimensions=64, walk_length=30, num_walks=200, workers=4)

# Generate embeddings
model = node2vec.fit(window=10, min_count=1, batch_words=4)
# Out:
# Computing transition probabilities:   0%|          | 0/82 [00:00<?, ?it/s]
# Generating walks (CPU: 3): 100%|██████████| 50/50 [00:00<00:00, 59.33it/s]
# Generating walks (CPU: 1): 100%|██████████| 50/50 [00:00<00:00, 58.41it/s]
# Generating walks (CPU: 4): 100%|██████████| 50/50 [00:00<00:00, 58.25it/s]
# Generating walks (CPU: 2): 100%|██████████| 50/50 [00:00<00:00, 56.67it/s]

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Get the node embeddings
node_embeddings = {node: model.wv[node] for node in G.nodes}

# Compute cosine similarity matrix
similarity_matrix = cosine_similarity(list(node_embeddings.values()))

# %%
from sklearn.cluster import DBSCAN

# Initialize DBSCAN
dbscan = DBSCAN(eps=0.8, min_samples=5)  # Adjust parameters as needed

# Fit and predict clusters
labels = dbscan.fit_predict(similarity_matrix)

# %%
cluster_colors = [
    'rgb(31, 119, 180)',  # Blue
    'rgb(255, 127, 14)',  # Orange
    'rgb(44, 160, 44)',   # Green
    'rgb(214, 39, 40)',   # Red
    'rgb(148, 103, 189)', # Purple
    'rgb(140, 86, 75)',   # Brown
    'rgb(227, 119, 194)'  # Pink
]

# %%
import networkx as nx
import plotly.graph_objs as go

# Assuming 'G' is your graph and 'labels' is the list of labels
# Renumber clusters from 1 to 7 if needed, otherwise ensure you have clusters numbered 1 to 7
unique_labels = list(set(labels))
label_mapping = {label: idx+1 for idx, label in enumerate(unique_labels)}

def draw_subgraph_plotly(subgraph, cluster_id, cluster_color):
    pos = nx.spring_layout(subgraph, seed=42)  # Fixed seed for reproducibility
    
    # Extract the node positions
    x_nodes = [pos[node][0] for node in subgraph.nodes()]
    y_nodes = [pos[node][1] for node in subgraph.nodes()]

    # Extract the edges
    edge_x = []
    edge_y = []
    for edge in subgraph.edges():
        x0, y0 = pos[edge[0]]
        x1, y1 = pos[edge[1]]
        edge_x.extend([x0, x1, None])
        edge_y.extend([y0, y1, None])

    # Edge trace
    edge_trace = go.Scatter(
        x=edge_x, y=edge_y,
        line=dict(width=1, color='gray'),
        hoverinfo='none',
        mode='lines')

    # Node trace
    node_trace = go.Scatter(
        x=x_nodes, y=y_nodes,
        mode='markers+text',
        text=[f'{node}' for node in subgraph.nodes()],
        textposition="top center",
        marker=dict(
            showscale=False,
            color=cluster_color,  # Assign the cluster color
            size=20,
            line=dict(width=2, color='black')
        ),
        hoverinfo='text'
    )

    # Create figure
    fig = go.Figure(data=[edge_trace, node_trace],
                    layout=go.Layout(
                        title=f'Cluster {cluster_id}',
                        titlefont=dict(size=16),
                        showlegend=False,
                        hovermode='closest',
                        margin=dict(b=20, l=5, r=5, t=40),
                        xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                        yaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                        height=600,
                        width=600,
                        paper_bgcolor='white',
                        plot_bgcolor='white'
                    ))

    fig.show()

# Iterate over each cluster and draw the subgraph
for original_cluster_id in set(labels):
    cluster_id = label_mapping[original_cluster_id]
    cluster_color = cluster_colors[cluster_id - 1]  # Assign a unique color to each cluster
    cluster_nodes = [node for node, label in zip(G.nodes, labels) if label == original_cluster_id]
    subgraph = G.subgraph(cluster_nodes)
    draw_subgraph_plotly(subgraph, cluster_id, cluster_color)

# %%
pip install -U kaleido
# Out:
# Requirement already satisfied: kaleido in /opt/homebrew/lib/python3.11/site-packages (0.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# # Initialize lists for nodes and links
# nodes = []
# links = []

# # Add nodes to the list
# for node, sentences in sentences_dict.items():
#     nodes.append({
#         "id": node,
#         "group": 1,  # Update this as needed
#         "size": len(sentences)  # The size could be based on the number of sentences
#     })

# # Add links to the list
# for edge, sentences in edge_sentences_dict.items():
#     source, target = edge
#     links.append({
#         "source": source,
#         "target": target,
#         "value": len(sentences)  # The value could be based on the number of sentences
#     })

# # Combine nodes and links into a single dictionary
# graph_data = {
#     "nodes": nodes,
#     "links": links
# }

# %%
# import os

# os.environ['METIS_DLL'] = '/Users/.local/lib/libmetis.dylib'

# %%
# import metis

# %%
# edgecuts, parts = metis.part_graph(G)

# %%
import json

# Create a mapping from nodes to integers
node_to_int = {node: i for i, node in enumerate(G.nodes)}

# %%
degree_dict = dict(G.degree(G.nodes()))
nx.set_node_attributes(G, degree_dict, 'degree')

data = nx.node_link_data(G)

# %%
import numpy as np

# %%
labels = labels.astype(np.int32)

# %%
graph_data = {
    "nodes": [{"name": str(node), "n": degree_dict[node], "grp": int(labels[i]), "id": str(node)} for i, node in enumerate(G.nodes())],
    "links": [{"source": str(link_data['source']), "target": str(link_data['target']), "value": 1} for link_data in data['links']]
}

# %%
json_data = json.dumps(graph_data)
with open('data.json', 'w') as f:
    f.write(json_data)

# %%
# from collections import defaultdict

# # Create a dictionary where keys are part numbers and values are lists of nodes
# part_dict = defaultdict(list)
# for node, part in enumerate(parts):
#     part_dict[part].append(node)

# # Print the number of parts
# print("Number of parts:", len(part_dict))

# # Print the nodes in each part
# for part, nodes in part_dict.items():
#     print("Part", part, ":", nodes)

# %%
# Assuming you have already created clusters using DBSCAN and have 'labels' and 'G' available

# Initialize an empty dictionary to store sentences for each cluster
cluster_sentences_dict = {}

# Iterate over each cluster
for original_cluster_id in set(labels):
    cluster_id = label_mapping[original_cluster_id]
    cluster_nodes = [node for node, label in zip(G.nodes, labels) if label == original_cluster_id]
    
    # Initialize a set to store sentences for this cluster
    cluster_sentences = set()
    
    # Iterate over nodes in the cluster
    for node in cluster_nodes:
        # Assuming 'node' contains the relevant information (e.g., entity, time, location)
        # Extract sentences associated with this node and add them to the cluster_sentences set
        if node in sentences_dict:
            cluster_sentences.update(sentences_dict[node])
    
    # Store the cluster_sentences set in the cluster_sentences_dict
    cluster_sentences_dict[cluster_id] = cluster_sentences

# %%
sentences_dict
# Out:
# {'jessica lal': ['he reached the scene of occurrence within T66 at around T77 and reported back at T78 it is relevant to refer the message received that is ex pw 12/d-1 which states: from e-43 (pcr van), a party hosted by malini and beena was going on in L3 hotel situated at the road which leads towards L8 where a person had demanded whiskey from P14 but she (P14) said that the restaurant had already been closed. at this the aforesaid person had fired shot at P14, which had hit her on her chest.',
#   'the appellant/accused has relied on the testimony of pw-7 to show that the cartridges sold to appellant/accused had kf marking is wholly unwarranted. the prosecution has established that the appellant/accused was the holder of a .22 bore pistol; he was witnessed by P17 as the perpetrator of the crime; a mutilated .22 lead was recovered from the skull of the deceased; two empties of .22 make with mark c were found at the spot; a .22 live cartridge with mark c was found in the tata safari of the appellant/accused which was found abandoned at noida and for which no theft report was lodged; that his prior and subsequent conduct of having got the tata safari removed from the spot, of absconding; refusal to tip without having any basis; that he even denied his presence at the spot, clearly prove beyond reasonable doubt leaving no manner of doubt that he is guilty of the offence of murdering P14 by using firearm and destroying evidence thereafter. it is pointed out by the state that when the accused P2 was arrested on 06.05.1999, the police filed an application dated T30 for police remand of the accused for recovery of pistol. ',
#   'P14 and P16 (pw-6), who were also present there, tried to make him understand that the party was over and there was no liquor available with them. on refusal to serve liquor, the appellant took out a pistol and fired one shot at the roof and another at P14 which hit near her left eye as a result of which she fell down. P17 (pw-20), who was present there, stopped the appellant and questioned him as to why he had shot P14 and demanded the weapon from him but he did not hand over the pistol and fled away.',
#   'at this the aforesaid person had fired shot at P14 which had hit her on her chest. P14 has been admitted in L6 safdarjung enclave and the person who had fired shot has fled from there. one person has fled after firing (at someone) 35 years, stout body 5 4 r/f fat, t-shirt of white colour.',
#   'it is also relevant to note that she mentioned that P14 was standing with the people at the far end and she saw her falling down. she also informed that P15 pw-2 said that P14 had been shot. it is relevant to point out that she was shouting to the guests to call the doctor or to take P14 for treatment, she reached the gate where her husband was standing and she told him that this was the man who had shot P14 and to see in which car he gets into.',
#   'on inspection of the site, two empty cartridges were seized and, in the meantime, a supplementary statement of pw-2 was also recorded by pw-100. at about 5.45 a.m., pw-100 received an information by ct. P42 intimating him about the death of P14 at L7 charge under section 302 ipc/201/120 b ipc and under section 27 of the arms act has been framed against the accused P1  P2 charge under section 201/120b ipc has been framed against accused P5 P3  P4  and P6 charge under section 212 ipc has been framed against P7 P8 P9  P10 and P11 and charge under section 201/212 ipc against P12',
#   'the scrutiny of the entire evidence of pw-6 clearly shows that her evidence is not only relevant but also admissible. coming to the cause of death, dr. P71 pw-9, who conducted post-mortem on the body of deceased P14 has stated that on T8 at about T114 7 sheets of papers i.e. inquest papers, request of post-mortem, inquest report, copy of fir, brief facts of the case, were submitted to him along with the dead body. he informed that the cause of death to the best of his knowledge and belief was head injury due to firearm, injury was ante-mortem in nature.',
#   'a moment  later  she  heard  another  shot. jessica  lal  was standing with people at the far end and she saw her falling. it is pertinent to note that as per the scaled site plan, the point at which P17 pw-20 was standing was only four feet from the point at which the shot was fired at P14.',
#   't that time, i saw some people rushing in and some people rushing out of the restaurant and they were shouting goli lag gai, P14 ko goli lag gai. i knew P14 before the incident, P24 was the manager of the restaurant. i was coming downstairs, and on hearing the noise, i went to restaurant.',
#   'on the other hand, his evidence supported by other witnesses clearly proves the presence of accused nos. 1-4 at the place of occurrence. he asserted the presence of P14 P15 and the claim of whisky by a fair complexion man who exchanged niceties with him and introduced him as P2 we do not find any valid reason to hold that he is a planted witness, though he was not an eye-witness to the actual shooting incident  but his own statement proves that immediately on hearing the noise he peeped and noticed P14 lying on the floor of L73',
#   'it is also clear from his evidence that at around 1.45 a.m., he heard a noise emerging from L73 to the effect that P14 had been shot. it is also clear that on hearing that P14 had been shot, he ran towards L73 though according to him he could not go inside yet peeped and saw P14 lying on the floor. since the high court has accepted his evidence which was not acceptable by the trial court, we analyzed his entire statement with great care.',
#   'P14 (since deceased) and P15 (complainant) were serving liquor on that night at the bar counter. i had known P14 for about five or six years whereas shyan was introduced to me by P14 about a week before T9 i.e. on the previous T115 party apart from the above assertion, he also informed the court that P14 (since deceased) was working with L16 and was also a model by profession.',
#   'at that time, that gentleman took out a pistol from the dub of the pant and fired a shot in the air. there was another gentleman on the other side of the counter, who fired a shot at P14 and she fell down. that gentleman was also wearing light colored clothes.',
#   'P14 was rushed to L6 from where she was shifted to L7 on 30.04.1999, in the early T83 hours, P14 was declared brought dead at L7 on the night intervening 29/30.04.1999 at 2.20 a.m., dd entry no. 41 a (ex. pw-13/a) was recorded at police station L8 which disclosed a shooting incident at h- 5/6 L3',
#   'P14 was removed on a stature for medical treatment. i returned to the restaurant at about T71 police met me there in the restaurant.',
#   'P127 had left at about T70 from there. when i saw P14 lying on the floor, i also saw that she had some injury on the left forehead, from which blood was coming out. there was also blood on the floor, where P14 was lying.',
#   'he also identified other persons who accompanied P2 and P4 it is also clear from his evidence that at around 1.45 a.m., he heard a noise emerging from L73 to the effect that P14 had been shot. it is also clear that on hearing that P14 had been shot, he ran towards L73 though according to him he could not go inside yet peeped and saw P14 lying on the floor.',
#   'we had a proper staff to run the restaurant and occasionally any of our friends could reach out and help the thursdays parties. P14 and P15 were friends of my daughter malini and were helping her on that night. the date was 29th of april, T10',
#   'therefore to contend that sanjay mehtani was deliberately not examined by the prosecution is absolutely baseless and not founded on the basis of the record. the conduct of absconding:\n\n99) from the testimony of pw-20 and pw-24, it is proved beyond reasonable doubt that accused sidharth vashisht  P2 after committing the murder of P14 fled away from the scene of occurrence.  it is further proved from the testimony of pw-100, pw-101, pw-87 P35 pw-85 and pw-80 that from afternoon of T8 search was made for the black tata safari bearing regn. no. ch-01-w-6535 and for sidharth vashisht  P2, director of L36 at L30 L34 L10 his farmhouse at L39 and L35 L2',
#   'i was coming downstairs, and on hearing the noise, i went to restaurant. i saw P14 lying on the floor. some guests, P17 and P24 were present there.',
#   'it is the submission of the learned senior counsel for the appellant-manu sharma that the statement of P20 pw-70 ought to have been used for the purpose of registration of fir instead of P15 pw-2. it was demonstrated that P20 had made two calls on 100 on coming to know by other persons that P14 has been shot inside the cafe. as against this, P15 pw-2 was very much within the vicinity of the place of occurrence and, therefore, the statement of P15 was used for the purpose of registration of fir.',
#   'it is relevant to refer the message received that is ex pw 12/d-1 which states: from e-43 (pcr van), a party hosted by malini and beena was going on in L3 hotel situated at the road which leads towards L8 where a person had demanded whiskey from P14 but she (P14) said that the restaurant had already been closed. at this the aforesaid person had fired shot at P14, which had hit her on her chest. P14 has been admitted in L6 safdarjung enclave and the person who had fired shot has fled from there.',
#   'thereafter, P25 brought a sheet of cloth. P24 P17 and i wrapped the said P14 in the bed-sheet. we took/carried her to an esteem car, parked outside.',
#   'therefore, it can never be alleged that there was no way in which the said witness could have had any doubt as to the identity of P2 thereafter, she accosted P2 till the gate of L3 where she told P18 pw-24 that this was the man who had shot P14 and that he should see in which car he i.e. P2 gets into and after that P17 pw-20 came back to the spot.',
#   'if we analyze her evidence along with the sketch/map of the occurrence, when she mounted steps of the restaurant, she heard a shot, a moment later, she heard another shot. it is also relevant to note that she mentioned that P14 was standing with the people at the far end and she saw her falling down. she also informed that P15 pw-2 said that P14 had been shot.',
#   'he was chubby and fair and i asked him as to who he was. why are you here and why he shot P14 i also asked him to give me his gun.',
#   'i saw a few people standing next to the counter and i heard a shot, a moment later i heard another shot. P14 was standing with people at the far end and i saw her falling down. it is also relevant that on noticing P15 she asked him why are you here and why he shot P14?.',
#   'she also informed that P15 pw-2 said that P14 had been shot. it is relevant to point out that she was shouting to the guests to call the doctor or to take P14 for treatment, she reached the gate where her husband was standing and she told him that this was the man who had shot P14 and to see in which car he gets into. if we read her entire evidence she refers only P2',
#   'P14 was standing with people at the far end and i saw her falling down. it is also relevant that on noticing P15 she asked him why are you here and why he shot P14?. her statement clearly proves the prosecution case that she had herself seen P2 shooting P14.',
#   'i had told the police in L7 that it was P2 who was with the similar description as was discussed amongst friends on which police had told me that they would call me. a close scrutiny of pw-1s evidence clearly shows that P14 was friendly with him having known him for 5- 6 years. he also went to the house of parents of P14 twice i.e. on 30th april and 1st may T10 to pay condolence.',
#   'the occurrence took place at about 1.30 or 1.45 am. t that time, i saw some people rushing in and some people rushing out of the restaurant and they were shouting goli lag gai, P14 ko goli lag gai. i knew P14 before the incident, P24 was the manager of the restaurant.',
#   'a moment later, i heard another shot. P14 was standing with people at the far end and i saw her falling down. there was a door to my right.',
#   'P25 is an electrician in L3 we removed P14 in a car to the L6 mrs. P17 P23 waiter, myself and driver were in that car, apart from P14.',
#   'alcohol and food was being sold there on coupons. i had met P14 on that night in the party. i had acquaintance with her from before.',
#   'he asserted the presence of P14 P15 and the claim of whisky by a fair complexion man who exchanged niceties with him and introduced him as P2 we do not find any valid reason to hold that he is a planted witness, though he was not an eye-witness to the actual shooting incident  but his own statement proves that immediately on hearing the noise he peeped and noticed P14 lying on the floor of L73 to this extent, the evidence of pw-1 is acceptable and the high court has rightly believed and relied on his version.',
#   'since the present statement about another gentleman who fired a shot at P14 and she fell down was not the one earlier made to the police, after getting permission from the court, the public prosecutor cross-examined him. he stated it is correct that P17 and other lifted jessica from the spot and carried her to the hospital ashlok. i went there later.',
#   'it is pointed out by the learned solicitor general that the courts below ought to have drawn an adverse inference from the said facts but have failed to do  so. thus this evidence coupled with the testimony of P15 pw-2, that the person in white t-shirt who was asking for whisky took out a pistol from dub of his pant and fired a shot in the air and the other witnesses pws 1,6, 20 and 24 that the person in white t-shirt was P2 a positive inference beyond reasonable  doubt has to be drawn that P2 fired from his .22 bore pistol which resulted in the death of P14 on the fateful night of 29/30.04.1999. mr. P65 learned senior counsel, appearing for the accused pointed out that no question has been put to the accused in his examination under section 313 cr.p.c. with reference to the pistol and shooting by him for this.',
#   'she was at the L3 on that evening. P14 was also there. P17 pw-20 and P15 pw-2, were also there.',
#   'i rushed towards her and we both went inside the cafe. we saw, P14 lying on the floor, near the counter. P25 P76 surender and wiplub, members of the staff and one-two guests also reached the spot.',
#   'i had purchased four coupons of rs. 100/- each on that day. P14 (since deceased) and P15 (complainant) were serving liquor on that night at the bar counter. i had known P14 for about five or six years whereas shyan was introduced to me by P14 about a week before T9 i.e. on the previous T115 party',
#   'in the meantime, i was shouting instructions to the guests to call hospital or to take P14 i reached the gate my husband was standing there and i told him that this was the man who had shot P14 and to see in which car he gets into. that person who was told to be seen by my husband was with some friends at the time of occurrence inside the cafe.',
#   'that gentleman was also wearing light colored clothes. since the present statement about another gentleman who fired a shot at P14 and she fell down was not the one earlier made to the police, after getting permission from the court, the public prosecutor cross-examined him. he stated it is correct that P17 and other lifted jessica from the spot and carried her to the hospital ashlok.',
#   'the testimony of pw-23 further corroborates the testimony of pw-6. as rightly pointed out by the state that it was a case where the deceased P14 was murdered for a row over the drink. it was also pointed out on the side of the appellant- P2 that the evidence of P16 pw-6 and P18 pw-24 does not corroborate the statement of P17 pw-20.',
#   'we left and reached L6 P14 was removed on a stature for medical treatment. i returned to the restaurant at about T71',
#   'on the same night, at about 1 oclock (midnight), he went to the bar counter to have his third drink. he informed the court that on the suggestion of P14 that the liquor was getting over he handed over all the remaining coupons and purchased two pegs of whisky. while holding both the glasses of whisky, he came in the company of his friends.',
#   'P14 was standing with people at the far end and i saw her falling down. it is also relevant that on noticing P15 she asked him why are you here and why he shot P14?. her statement clearly proves the prosecution case that she had herself seen P2 shooting P14. as rightly observed by the high court, if the evidence of P17 is analyzed in depth, it is clear that she not only asserted the presence of P2 at the scene  of occurrence and heard two shots one by one but also asked a pertinent question to P15 that why he (P2) shot P14.',
#   'alcohol was never served in the restaurant but were served only in the courtyard on T115 parties. she further deposed i knew P14 P15 we had a proper staff to run the restaurant and occasionally any of our friends could reach out and help the T115s parties.',
#   'based on the statement of P20 pw-70, that he saw her screaming out, the defence has sought to discredit pw-6s, statement. it is relevant to note that it is the case of pw-6 that she came to know when she was in the courtyard, P15 came running towards her and sanjay mehtani, screaming that P14 had been shot. thereafter, pw-6 fainted, thus, in the process, if pw-70 saw her screaming in the courtyard, it cannot be said that there is any contradiction in the statement of pw-6 and pw-70.',
#   'he was a few steps ahead of me and i could not catch him. in the meantime, i was shouting instructions to the guests to call hospital or to take P14 i reached the gate my husband was standing there and i told him that this was the man who had shot P14 and to see in which car he gets into.',
#   'her statement clearly proves the prosecution case that she had herself seen P2 shooting P14 as rightly observed by the high court, if the evidence of P17 is analyzed in depth, it is clear that she not only asserted the presence of P2 at the scene  of occurrence and heard two shots one by one but also asked a pertinent question to P15 that why he (P2) shot P14 whether she has to be treated as an eye-witness to the occurrence or not is to be discussed at later point of time by analyzing her entire evidence.',
#   'P25 P76 surender and wiplub, members of the staff and one-two guests also reached the spot. there was scratched on the forehead of P14 P25 pw-3, brought a bed-sheet.',
#   'i had known P14 for about five or six years whereas shyan was introduced to me by P14 about a week before T9 i.e. on the previous T115 party apart from the above assertion, he also informed the court that P14 (since deceased) was working with L16 and was also a model by profession. he described the location of L17 and L73',
#   'there was commotion. all the people who were with P14 earlier, started coming out. the companion of shyan was wearing white t-shirt.',
#   'in the absence of rebuttal evidence, there is no reason to reject the evidence of pw-83 as well as ex. pw-12/d-1 in those circumstances, the entire premise of the defence argument that it was not a person in white t-shirt, stocky and fair, who shot at P14 over a row over the drink and fled away from the spot and this was a planted and concocted story of the prosecution to rope in P2 and make escape good of the tall sikh gentleman is wholly erroneous and without any basis. evaluation  of  evidence  throwing  light  on  the  actual incident:  it is the stand of the defence that the testimony of P23 pw 46 and P24 pw-47 belies the fact that P17 pw-20 had seen actual shooting  as the witness says that they both entered together.',
#   'on refusal to serve liquor, the appellant took out a pistol and fired one shot at the roof and another at P14 which hit near her left eye as a result of which she fell down. P17 (pw-20), who was present there, stopped the appellant and questioned him as to why he had shot P14 and demanded the weapon from him but he did not hand over the pistol and fled away. P14 was rushed to L6 from where she was shifted to L7',
#   'P16 pw-6, P17 pw-20 and P18 pw-24 were frequently shown the photograph of the appellant and he was paraded before them. the finding of the high court that P1  P2 took out his pistol and first fired at the ceiling and then at P14 is based on no evidence. three ballistic experts have concurred that empty cartridges have been fired from two different weapons.',
#   'at  about 4.00 a.m., fir no. 287/99 was registered at the police station, L8 in the meantime, P14 had been shifted to L7 when si P33 came back to the spot along with pw-2, pw 30 informed them about the lifting of one black tata safari from the spot.',
#   'there was miniature bar counter outside in the open space where liquor was being served. besides P14 and malini there were other few persons who were helping in serving liquor. on that night, i did go inside the L73',
#   'jessica  lal  was standing with people at the far end and she saw her falling. t is pertinent to note that as per the scaled site plan, the point at which P17 pw-20 was standing was only four feet from the point at which the shot was fired at P14. therefore, it can never be alleged that there was no way in which the said witness could have had any doubt as to the identity of P2  ',
#   'it could be swung open and P15 came out with another person who was either ahead of him or behind him. P15 said that P14 had been shot. i told P15 to call the police or doctor or ambulance and i stopped the man accompanying them.',
#   'he also mentioned the presence of P2 his evidence further shows that immediately after the shot P17 and others were carrying P14 to the L6 in other words, his evidence proves the presence of accused-manu sharma at the scene of offence.',
#   'the waiter did not serve him liquor as the party was over. P14 and P16 (pw-6), who were also present there, tried to make him understand that the party was over and there was no liquor available with them. on refusal to serve liquor, the appellant took out a pistol and fired one shot at the roof and another at P14 which hit near her left eye as a result of which she fell down.',
#   'on night intervening 29-30.04.1999, a T115 party was going on at L3 at L4 also called L73 the liquor was being served by the bartenders, namely, P14 (since deceased) and one P15 (pw-2). at about 2.00 a.m., P1  P2 (appellant in crl. a. no. 179 of 2007) along with his friends came there and asked for two drinks.',
#   'the bar counter was located in L17 open area between the two doors of the L73 but since it was summer nobody was using the bar counter giving preference to the bar counter located outside. he also stated that P14 was wearing blue denim shorts and white half sleeved shirt on that night. on the same night, at about 1 oclock (midnight), he went to the bar counter to have his third drink.',
#   'it is well settled that when pressure is built inside the cartridge case, which results in the pushing out of the bullet from the barrel, there is difference in the marks to the extent that it may be either clear or unclear and flattened or deepened thus no opinion can be rendered on account of this dissimilarity in the absence of the weapon of offence and test firing. further once the report of P72 is rendered inadmissible the two gun theory of the defence becomes wholly inadmissible and what remains is that the two empties found at the spot are .22 bore cartridges, that the live bullet found in the tata safari is a .22 cartridge and that the gun belonging to the appellant is a .22 bore pistol which was used for the commission of the crime of murder of P14 the prosecution obtained another opinion from fsl L56 and the queries made are as under: 1. please examine and opine the bore of the two empty cartridges present in the sealed parcel.',
#   'a close scrutiny of pw-1s evidence clearly shows that P14 was friendly with him having known him for 5- 6 years. he also went to the house of parents of P14 twice i.e. on 30th april and 1st may T10 to pay condolence. further, in categorical terms, he asserted and identified the presence of P2 at the scene of offence.',
#   'in those circumstances, the defence cannot take advantage out of a portion of statement of pw-47. it is relevant to mention that P23 pw-46 also stated that when the occurrence took place he was present on the stairs leading to terrace and that time he saw people rushing in and some people rushing out of the restaurant who were also shouting goli lag gai, P14 ko goli lag gai. he came downstairs after hearing the noise and went to the restaurant, thus it is evident that this witness did not hear the shots of the fire but only realized about the occurrence after people were rushing in and rushing out shouting.',
#   'we removed P14 in a car to the L6 mrs. P17 P23 waiter, myself and driver were in that car, apart from P14. i came out of my office, immediately, after hearing the shots of firing.',
#   'mr. P65 further submitted that due to the pressure by the prosecution for registering a case under the L14 excise act against P16 pw-6, P17 pw-20 and P18 pw-24, virtually, they were pressurized to yield to the case of prosecution. while stoutly denying the said allegation, mr. P68 submitted that the registration of case under the L14 excise act has nothing to do with their evidence in the case of death of P14 he also submitted that ultimately they were fined, the said action cannot be construed as a threat to them or keeping the sword hanging for taking action either under section 201 ipc or the L14 excise act.',
#   'when i saw P14 lying on the floor, i also saw that she had some injury on the left forehead, from which blood was coming out. there was also blood on the floor, where P14 was lying. jitender raj pw 47 was working as a manager-cum- supervisor.',
#   'P17 (pw-20), who was present there, stopped the appellant and questioned him as to why he had shot P14 and demanded the weapon from him but he did not hand over the pistol and fled away. P14 was rushed to L6 from where she was shifted to L7 on 30.04.1999, in the early T83 hours, P14 was declared brought dead at L7'],
#  'thursday, qutub colonnade': ['on night intervening 29-30.04.1999, a T115 party was going on at L3 at L4 also called L73 the liquor was being served by the bartenders, namely, P14 (since deceased) and one P15 (pw-2). at about 2.00 a.m., P1  P2 (appellant in crl. a. no. 179 of 2007) along with his friends came there and asked for two drinks.'],
#  'shyan munshi': ['it is also relevant to note that she mentioned that P14 was standing with the people at the far end and she saw her falling down. she also informed that P15 pw-2 said that P14 had been shot. it is relevant to point out that she was shouting to the guests to call the doctor or to take P14 for treatment, she reached the gate where her husband was standing and she told him that this was the man who had shot P14 and to see in which car he gets into.',
#   'it was on the other side of the courtyard and i was standing next to speaker (amplifier) after about a minute and a half/two minutes, P15 came running to me and sanjay mehtani and he was screaming that jessica had been shot. i just passed out after hearing about it and fainted.',
#   'on the other hand, his evidence supported by other witnesses clearly proves the presence of accused nos. 1-4 at the place of occurrence. he asserted the presence of P14 P15 and the claim of whisky by a fair complexion man who exchanged niceties with him and introduced him as P2 we do not find any valid reason to hold that he is a planted witness, though he was not an eye-witness to the actual shooting incident  but his own statement proves that immediately on hearing the noise he peeped and noticed P14 lying on the floor of L73',
#   'P14 (since deceased) and P15 (complainant) were serving liquor on that night at the bar counter. i had known P14 for about five or six years whereas shyan was introduced to me by P14 about a week before T9 i.e. on the previous T115 party apart from the above assertion, he also informed the court that P14 (since deceased) was working with L16 and was also a model by profession.',
#   'we had a proper staff to run the restaurant and occasionally any of our friends could reach out and help the thursdays parties. P14 and P15 were friends of my daughter malini and were helping her on that night. the date was 29th of april, T10',
#   'it is the submission of the learned senior counsel for the appellant-manu sharma that the statement of P20 pw-70 ought to have been used for the purpose of registration of fir instead of P15 pw-2. it was demonstrated that P20 had made two calls on 100 on coming to know by other persons that P14 has been shot inside the cafe. as against this, P15 pw-2 was very much within the vicinity of the place of occurrence and, therefore, the statement of P15 was used for the purpose of registration of fir.',
#   'if we analyze her evidence along with the sketch/map of the occurrence, when she mounted steps of the restaurant, she heard a shot, a moment later, she heard another shot. it is also relevant to note that she mentioned that P14 was standing with the people at the far end and she saw her falling down. she also informed that P15 pw-2 said that P14 had been shot.',
#   'i saw a few people standing next to the counter and i heard a shot, a moment later i heard another shot. P14 was standing with people at the far end and i saw her falling down. it is also relevant that on noticing P15 she asked him why are you here and why he shot P14?.',
#   'P14 was standing with people at the far end and i saw her falling down. it is also relevant that on noticing P15 she asked him why are you here and why he shot P14?. her statement clearly proves the prosecution case that she had herself seen P2 shooting P14.',
#   'she also informed that P15 pw-2 said that P14 had been shot. it is relevant to point out that she was shouting to the guests to call the doctor or to take P14 for treatment, she reached the gate where her husband was standing and she told him that this was the man who had shot P14 and to see in which car he gets into. if we read her entire evidence she refers only P2',
#   'it is pointed out by the learned solicitor general that the courts below ought to have drawn an adverse inference from the said facts but have failed to do  so. thus this evidence coupled with the testimony of P15 pw-2, that the person in white t-shirt who was asking for whisky took out a pistol from dub of his pant and fired a shot in the air and the other witnesses pws 1,6, 20 and 24 that the person in white t-shirt was P2 a positive inference beyond reasonable  doubt has to be drawn that P2 fired from his .22 bore pistol which resulted in the death of P14 on the fateful night of 29/30.04.1999. mr. P65 learned senior counsel, appearing for the accused pointed out that no question has been put to the accused in his examination under section 313 cr.p.c. with reference to the pistol and shooting by him for this.',
#   'he asserted the presence of P14 P15 and the claim of whisky by a fair complexion man who exchanged niceties with him and introduced him as P2 we do not find any valid reason to hold that he is a planted witness, though he was not an eye-witness to the actual shooting incident  but his own statement proves that immediately on hearing the noise he peeped and noticed P14 lying on the floor of L73 to this extent, the evidence of pw-1 is acceptable and the high court has rightly believed and relied on his version.',
#   'she was at the L3 on that evening. P14 was also there. P17 pw-20 and P15 pw-2, were also there.',
#   'i had purchased four coupons of rs. 100/- each on that day. P14 (since deceased) and P15 (complainant) were serving liquor on that night at the bar counter. i had known P14 for about five or six years whereas shyan was introduced to me by P14 about a week before T9 i.e. on the previous T115 party',
#   'i was facing opposite side of the entrance door of the restaurant and then i heard two pop shots like balloon. i turned towards the restaurant door from where i had heard the sound and within a few seconds P15 came running and said to me someone shot jessica. i immediately went to the restaurant.',
#   'ans. it is false and incorrect. it is further in evidence of pw-20 that the companion of P15 (you P2) was wearing t-shirt and she asked you P2 as to why you were here and why you shot jessica and she also asked you to give her your gun as she thought you were having the gun. what you have to say in this regard?',
#   'P14 was standing with people at the far end and i saw her falling down. it is also relevant that on noticing P15 she asked him why are you here and why he shot P14?. her statement clearly proves the prosecution case that she had herself seen P2 shooting P14. as rightly observed by the high court, if the evidence of P17 is analyzed in depth, it is clear that she not only asserted the presence of P2 at the scene  of occurrence and heard two shots one by one but also asked a pertinent question to P15 that why he (P2) shot P14.',
#   'the witness touched siddhartha vashist as the person who was being followed by beena his evidence makes it clear that at the relevant time on hearing the shot, P15 pw-2 came running shouting that someone shot jessica. he reached the door of the restaurant.',
#   'alcohol was never served in the restaurant but were served only in the courtyard on T115 parties. she further deposed i knew P14 P15 we had a proper staff to run the restaurant and occasionally any of our friends could reach out and help the T115s parties.',
#   'based on the statement of P20 pw-70, that he saw her screaming out, the defence has sought to discredit pw-6s, statement. it is relevant to note that it is the case of pw-6 that she came to know when she was in the courtyard, P15 came running towards her and sanjay mehtani, screaming that P14 had been shot. thereafter, pw-6 fainted, thus, in the process, if pw-70 saw her screaming in the courtyard, it cannot be said that there is any contradiction in the statement of pw-6 and pw-70.',
#   'her statement clearly proves the prosecution case that she had herself seen P2 shooting P14 as rightly observed by the high court, if the evidence of P17 is analyzed in depth, it is clear that she not only asserted the presence of P2 at the scene  of occurrence and heard two shots one by one but also asked a pertinent question to P15 that why he (P2) shot P14 whether she has to be treated as an eye-witness to the occurrence or not is to be discussed at later point of time by analyzing her entire evidence.',
#   'it could be swung open and P15 came out with another person who was either ahead of him or behind him. P15 said that P14 had been shot. i told P15 to call the police or doctor or ambulance and i stopped the man accompanying them.',
#   'on night intervening 29-30.04.1999, a T115 party was going on at L3 at L4 also called L73 the liquor was being served by the bartenders, namely, P14 (since deceased) and one P15 (pw-2). at about 2.00 a.m., P1  P2 (appellant in crl. a. no. 179 of 2007) along with his friends came there and asked for two drinks.'],
#  'sidhartha vashisht': ['on inspection of the site, two empty cartridges were seized and, in the meantime, a supplementary statement of pw-2 was also recorded by pw-100. at about 5.45 a.m., pw-100 received an information by ct. P42 intimating him about the death of P14 at L7 charge under section 302 ipc/201/120 b ipc and under section 27 of the arms act has been framed against the accused P1  P2 charge under section 201/120b ipc has been framed against accused P5 P3  P4  and P6 charge under section 212 ipc has been framed against P7 P8 P9  P10 and P11 and charge under section 201/212 ipc against P12',
#   'on night intervening 29-30.04.1999, a T115 party was going on at L3 at L4 also called L73 the liquor was being served by the bartenders, namely, P14 (since deceased) and one P15 (pw-2). at about 2.00 a.m., P1  P2 (appellant in crl. a. no. 179 of 2007) along with his friends came there and asked for two drinks.',
#   'P16 pw-6, P17 pw-20 and P18 pw-24 were frequently shown the photograph of the appellant and he was paraded before them. the finding of the high court that P1  P2 took out his pistol and first fired at the ceiling and then at P14 is based on no evidence. three ballistic experts have concurred that empty cartridges have been fired from two different weapons.'],
#  'manu sharma': ['the appellant/accused has relied on the testimony of pw-7 to show that the cartridges sold to appellant/accused had kf marking is wholly unwarranted. the prosecution has established that the appellant/accused was the holder of a .22 bore pistol; he was witnessed by P17 as the perpetrator of the crime; a mutilated .22 lead was recovered from the skull of the deceased; two empties of .22 make with mark c were found at the spot; a .22 live cartridge with mark c was found in the tata safari of the appellant/accused which was found abandoned at noida and for which no theft report was lodged; that his prior and subsequent conduct of having got the tata safari removed from the spot, of absconding; refusal to tip without having any basis; that he even denied his presence at the spot, clearly prove beyond reasonable doubt leaving no manner of doubt that he is guilty of the offence of murdering P14 by using firearm and destroying evidence thereafter. it is pointed out by the state that when the accused P2 was arrested on 06.05.1999, the police filed an application dated T30 for police remand of the accused for recovery of pistol. ',
#   'on inspection of the site, two empty cartridges were seized and, in the meantime, a supplementary statement of pw-2 was also recorded by pw-100. at about 5.45 a.m., pw-100 received an information by ct. P42 intimating him about the death of P14 at L7 charge under section 302 ipc/201/120 b ipc and under section 27 of the arms act has been framed against the accused P1  P2 charge under section 201/120b ipc has been framed against accused P5 P3  P4  and P6 charge under section 212 ipc has been framed against P7 P8 P9  P10 and P11 and charge under section 201/212 ipc against P12',
#   'the said claim of the prosecution cannot be rejected as unreasonable. in the earlier part of our judgment, we have noted that pw-20 has categorically stated that she heard the two shots, saw the people inside and jessica falling down, which shows that she had witnessed the entire incident as is evident from the relevant portion of her testimony extracted in paragraphs supra. P16 in categorical terms informed the court about P2 asking about the whisky, his misbehaviour immediately before the shooting and also identified the same person in white t-shirt asking for the whisky and misbehaving with her as P2.',
#   'on the other hand, his evidence supported by other witnesses clearly proves the presence of accused nos. 1-4 at the place of occurrence. he asserted the presence of P14 P15 and the claim of whisky by a fair complexion man who exchanged niceties with him and introduced him as P2 we do not find any valid reason to hold that he is a planted witness, though he was not an eye-witness to the actual shooting incident  but his own statement proves that immediately on hearing the noise he peeped and noticed P14 lying on the floor of L73',
#   'therefore to contend that sanjay mehtani was deliberately not examined by the prosecution is absolutely baseless and not founded on the basis of the record. the conduct of absconding:\n\n99) from the testimony of pw-20 and pw-24, it is proved beyond reasonable doubt that accused sidharth vashisht  P2 after committing the murder of P14 fled away from the scene of occurrence.  it is further proved from the testimony of pw-100, pw-101, pw-87 P35 pw-85 and pw-80 that from afternoon of T8 search was made for the black tata safari bearing regn. no. ch-01-w-6535 and for sidharth vashisht  P2, director of L36 at L30 L34 L10 his farmhouse at L39 and L35 L2',
#   'he also identified other persons who accompanied P2 and P4 it is also clear from his evidence that at around 1.45 a.m., he heard a noise emerging from L73 to the effect that P14 had been shot. it is also clear that on hearing that P14 had been shot, he ran towards L73 though according to him he could not go inside yet peeped and saw P14 lying on the floor.',
#   'therefore, it can never be alleged that there was no way in which the said witness could have had any doubt as to the identity of P2 thereafter, she accosted P2 till the gate of L3 where she told P18 pw-24 that this was the man who had shot P14 and that he should see in which car he i.e. P2 gets into and after that P17 pw-20 came back to the spot.',
#   'P14 was standing with people at the far end and i saw her falling down. it is also relevant that on noticing P15 she asked him why are you here and why he shot P14?. her statement clearly proves the prosecution case that she had herself seen P2 shooting P14.',
#   'she also informed that P15 pw-2 said that P14 had been shot. it is relevant to point out that she was shouting to the guests to call the doctor or to take P14 for treatment, she reached the gate where her husband was standing and she told him that this was the man who had shot P14 and to see in which car he gets into. if we read her entire evidence she refers only P2',
#   'i had told the police in L7 that it was P2 who was with the similar description as was discussed amongst friends on which police had told me that they would call me. a close scrutiny of pw-1s evidence clearly shows that P14 was friendly with him having known him for 5- 6 years. he also went to the house of parents of P14 twice i.e. on 30th april and 1st may T10 to pay condolence.',
#   'it is pointed out by the learned solicitor general that the courts below ought to have drawn an adverse inference from the said facts but have failed to do  so. thus this evidence coupled with the testimony of P15 pw-2, that the person in white t-shirt who was asking for whisky took out a pistol from dub of his pant and fired a shot in the air and the other witnesses pws 1,6, 20 and 24 that the person in white t-shirt was P2 a positive inference beyond reasonable  doubt has to be drawn that P2 fired from his .22 bore pistol which resulted in the death of P14 on the fateful night of 29/30.04.1999. mr. P65 learned senior counsel, appearing for the accused pointed out that no question has been put to the accused in his examination under section 313 cr.p.c. with reference to the pistol and shooting by him for this.',
#   'he asserted the presence of P14 P15 and the claim of whisky by a fair complexion man who exchanged niceties with him and introduced him as P2 we do not find any valid reason to hold that he is a planted witness, though he was not an eye-witness to the actual shooting incident  but his own statement proves that immediately on hearing the noise he peeped and noticed P14 lying on the floor of L73 to this extent, the evidence of pw-1 is acceptable and the high court has rightly believed and relied on his version.',
#   'the testimony of pw-23 further corroborates the testimony of pw-6. as rightly pointed out by the state that it was a case where the deceased P14 was murdered for a row over the drink. it was also pointed out on the side of the appellant- P2 that the evidence of P16 pw-6 and P18 pw-24 does not corroborate the statement of P17 pw-20.',
#   'ans. it is false and incorrect. it is further in evidence of pw-20 that the companion of P15 (you P2) was wearing t-shirt and she asked you P2 as to why you were here and why you shot jessica and she also asked you to give her your gun as she thought you were having the gun. what you have to say in this regard?',
#   'P14 was standing with people at the far end and i saw her falling down. it is also relevant that on noticing P15 she asked him why are you here and why he shot P14?. her statement clearly proves the prosecution case that she had herself seen P2 shooting P14. as rightly observed by the high court, if the evidence of P17 is analyzed in depth, it is clear that she not only asserted the presence of P2 at the scene  of occurrence and heard two shots one by one but also asked a pertinent question to P15 that why he (P2) shot P14.',
#   'her statement clearly proves the prosecution case that she had herself seen P2 shooting P14 as rightly observed by the high court, if the evidence of P17 is analyzed in depth, it is clear that she not only asserted the presence of P2 at the scene  of occurrence and heard two shots one by one but also asked a pertinent question to P15 that why he (P2) shot P14 whether she has to be treated as an eye-witness to the occurrence or not is to be discussed at later point of time by analyzing her entire evidence.',
#   'in the absence of rebuttal evidence, there is no reason to reject the evidence of pw-83 as well as ex. pw-12/d-1 in those circumstances, the entire premise of the defence argument that it was not a person in white t-shirt, stocky and fair, who shot at P14 over a row over the drink and fled away from the spot and this was a planted and concocted story of the prosecution to rope in P2 and make escape good of the tall sikh gentleman is wholly erroneous and without any basis. evaluation  of  evidence  throwing  light  on  the  actual incident:  it is the stand of the defence that the testimony of P23 pw 46 and P24 pw-47 belies the fact that P17 pw-20 had seen actual shooting  as the witness says that they both entered together.',
#   'P16 pw-6, P17 pw-20 and P18 pw-24 were frequently shown the photograph of the appellant and he was paraded before them. the finding of the high court that P1  P2 took out his pistol and first fired at the ceiling and then at P14 is based on no evidence. three ballistic experts have concurred that empty cartridges have been fired from two different weapons.',
#   'jessica  lal  was standing with people at the far end and she saw her falling. t is pertinent to note that as per the scaled site plan, the point at which P17 pw-20 was standing was only four feet from the point at which the shot was fired at P14. therefore, it can never be alleged that there was no way in which the said witness could have had any doubt as to the identity of P2  ',
#   'he also mentioned the presence of P2 his evidence further shows that immediately after the shot P17 and others were carrying P14 to the L6 in other words, his evidence proves the presence of accused-manu sharma at the scene of offence.',
#   'on night intervening 29-30.04.1999, a T115 party was going on at L3 at L4 also called L73 the liquor was being served by the bartenders, namely, P14 (since deceased) and one P15 (pw-2). at about 2.00 a.m., P1  P2 (appellant in crl. a. no. 179 of 2007) along with his friends came there and asked for two drinks.',
#   'a close scrutiny of pw-1s evidence clearly shows that P14 was friendly with him having known him for 5- 6 years. he also went to the house of parents of P14 twice i.e. on 30th april and 1st may T10 to pay condolence. further, in categorical terms, he asserted and identified the presence of P2 at the scene of offence.'],
#  'thursday, once upon a time restaurant': ['on night intervening 29-30.04.1999, a T115 party was going on at L3 at L4 also called L73 the liquor was being served by the bartenders, namely, P14 (since deceased) and one P15 (pw-2). at about 2.00 a.m., P1  P2 (appellant in crl. a. no. 179 of 2007) along with his friends came there and asked for two drinks.'],
# ...
#  '02.35 a.m., mehrauli': ['he reached the scene of occurrence within T66 at around T77 and reported back at T78 it is relevant to refer the message received that is ex pw 12/d-1 which states: from e-43 (pcr van), a party hosted by malini and beena was going on in L3 hotel situated at the road which leads towards L8 where a person had demanded whiskey from P14 but she (P14) said that the restaurant had already been closed. at this the aforesaid person had fired shot at P14, which had hit her on her chest.'],
#  '29.04.1999, tamarind cafe': ['i had known P14 for about five or six years whereas shyan was introduced to me by P14 about a week before T9 i.e. on the previous T115 party apart from the above assertion, he also informed the court that P14 (since deceased) was working with L16 and was also a model by profession. he described the location of L17 and L73'],
#  '29.04.1999, NULL': ['i had purchased four coupons of rs. 100/- each on that day. P14 (since deceased) and P15 (complainant) were serving liquor on that night at the bar counter. i had known P14 for about five or six years whereas shyan was introduced to me by P14 about a week before T9 i.e. on the previous T115 party'],
#  '29.04.1999, oberoi hotel': ['i had known P14 for about five or six years whereas shyan was introduced to me by P14 about a week before T9 i.e. on the previous T115 party apart from the above assertion, he also informed the court that P14 (since deceased) was working with L16 and was also a model by profession. he described the location of L17 and L73',
#   'P14 (since deceased) and P15 (complainant) were serving liquor on that night at the bar counter. i had known P14 for about five or six years whereas shyan was introduced to me by P14 about a week before T9 i.e. on the previous T115 party apart from the above assertion, he also informed the court that P14 (since deceased) was working with L16 and was also a model by profession.'],
#  '29.04.1999, tamarind court': ['i had known P14 for about five or six years whereas shyan was introduced to me by P14 about a week before T9 i.e. on the previous T115 party apart from the above assertion, he also informed the court that P14 (since deceased) was working with L16 and was also a model by profession. he described the location of L17 and L73'],
#  '1999, NULL': ['we had a proper staff to run the restaurant and occasionally any of our friends could reach out and help the thursdays parties. P14 and P15 were friends of my daughter malini and were helping her on that night. the date was 29th of april, T10',
#   'a close scrutiny of pw-1s evidence clearly shows that P14 was friendly with him having known him for 5- 6 years. he also went to the house of parents of P14 twice i.e. on 30th april and 1st may T10 to pay condolence. further, in categorical terms, he asserted and identified the presence of P2 at the scene of offence.'],
#  '1999, apollo hospital': ['i had told the police in L7 that it was P2 who was with the similar description as was discussed amongst friends on which police had told me that they would call me. a close scrutiny of pw-1s evidence clearly shows that P14 was friendly with him having known him for 5- 6 years. he also went to the house of parents of P14 twice i.e. on 30th april and 1st may T10 to pay condolence.'],
#  '3/3.15 a.m., NULL': ['P14 was removed on a stature for medical treatment. i returned to the restaurant at about T71 police met me there in the restaurant.'],
#  '3/3.15 a.m., ashlok hospital': ['we left and reached L6 P14 was removed on a stature for medical treatment. i returned to the restaurant at about T71'],
#  'george': ['P127 had left at about T70 from there. when i saw P14 lying on the floor, i also saw that she had some injury on the left forehead, from which blood was coming out. there was also blood on the floor, where P14 was lying.'],
#  '12.30 or 12.45 a.m., NULL': ['P127 had left at about T70 from there. when i saw P14 lying on the floor, i also saw that she had some injury on the left forehead, from which blood was coming out. there was also blood on the floor, where P14 was lying.'],
#  'r.k. sharma': ['the scrutiny of the entire evidence of pw-6 clearly shows that her evidence is not only relevant but also admissible. coming to the cause of death, dr. P71 pw-9, who conducted post-mortem on the body of deceased P14 has stated that on T8 at about T114 7 sheets of papers i.e. inquest papers, request of post-mortem, inquest report, copy of fir, brief facts of the case, were submitted to him along with the dead body. he informed that the cause of death to the best of his knowledge and belief was head injury due to firearm, injury was ante-mortem in nature.'],
#  '30.04.1999, NULL': ['the scrutiny of the entire evidence of pw-6 clearly shows that her evidence is not only relevant but also admissible. coming to the cause of death, dr. P71 pw-9, who conducted post-mortem on the body of deceased P14 has stated that on T8 at about T114 7 sheets of papers i.e. inquest papers, request of post-mortem, inquest report, copy of fir, brief facts of the case, were submitted to him along with the dead body. he informed that the cause of death to the best of his knowledge and belief was head injury due to firearm, injury was ante-mortem in nature.'],
#  '30.04.1999, piccadilly sugar industries': ['therefore to contend that sanjay mehtani was deliberately not examined by the prosecution is absolutely baseless and not founded on the basis of the record. the conduct of absconding:\n\n99) from the testimony of pw-20 and pw-24, it is proved beyond reasonable doubt that accused sidharth vashisht  P2 after committing the murder of P14 fled away from the scene of occurrence.  it is further proved from the testimony of pw-100, pw-101, pw-87 P35 pw-85 and pw-80 that from afternoon of T8 search was made for the black tata safari bearing regn. no. ch-01-w-6535 and for sidharth vashisht  P2, director of L36 at L30 L34 L10 his farmhouse at L39 and L35 L2'],
#  'raman lamba': ['therefore to contend that sanjay mehtani was deliberately not examined by the prosecution is absolutely baseless and not founded on the basis of the record. the conduct of absconding:\n\n99) from the testimony of pw-20 and pw-24, it is proved beyond reasonable doubt that accused sidharth vashisht  P2 after committing the murder of P14 fled away from the scene of occurrence.  it is further proved from the testimony of pw-100, pw-101, pw-87 P35 pw-85 and pw-80 that from afternoon of T8 search was made for the black tata safari bearing regn. no. ch-01-w-6535 and for sidharth vashisht  P2, director of L36 at L30 L34 L10 his farmhouse at L39 and L35 L2'],
#  '30.04.1999, bhadson': ['therefore to contend that sanjay mehtani was deliberately not examined by the prosecution is absolutely baseless and not founded on the basis of the record. the conduct of absconding:\n\n99) from the testimony of pw-20 and pw-24, it is proved beyond reasonable doubt that accused sidharth vashisht  P2 after committing the murder of P14 fled away from the scene of occurrence.  it is further proved from the testimony of pw-100, pw-101, pw-87 P35 pw-85 and pw-80 that from afternoon of T8 search was made for the black tata safari bearing regn. no. ch-01-w-6535 and for sidharth vashisht  P2, director of L36 at L30 L34 L10 his farmhouse at L39 and L35 L2'],
#  '30.04.1999, kurukshetra': ['therefore to contend that sanjay mehtani was deliberately not examined by the prosecution is absolutely baseless and not founded on the basis of the record. the conduct of absconding:\n\n99) from the testimony of pw-20 and pw-24, it is proved beyond reasonable doubt that accused sidharth vashisht  P2 after committing the murder of P14 fled away from the scene of occurrence.  it is further proved from the testimony of pw-100, pw-101, pw-87 P35 pw-85 and pw-80 that from afternoon of T8 search was made for the black tata safari bearing regn. no. ch-01-w-6535 and for sidharth vashisht  P2, director of L36 at L30 L34 L10 his farmhouse at L39 and L35 L2'],
#  '30.04.1999, chandigarh': ['therefore to contend that sanjay mehtani was deliberately not examined by the prosecution is absolutely baseless and not founded on the basis of the record. the conduct of absconding:\n\n99) from the testimony of pw-20 and pw-24, it is proved beyond reasonable doubt that accused sidharth vashisht  P2 after committing the murder of P14 fled away from the scene of occurrence.  it is further proved from the testimony of pw-100, pw-101, pw-87 P35 pw-85 and pw-80 that from afternoon of T8 search was made for the black tata safari bearing regn. no. ch-01-w-6535 and for sidharth vashisht  P2, director of L36 at L30 L34 L10 his farmhouse at L39 and L35 L2'],
#  '30.04.1999, samalkha': ['therefore to contend that sanjay mehtani was deliberately not examined by the prosecution is absolutely baseless and not founded on the basis of the record. the conduct of absconding:\n\n99) from the testimony of pw-20 and pw-24, it is proved beyond reasonable doubt that accused sidharth vashisht  P2 after committing the murder of P14 fled away from the scene of occurrence.  it is further proved from the testimony of pw-100, pw-101, pw-87 P35 pw-85 and pw-80 that from afternoon of T8 search was made for the black tata safari bearing regn. no. ch-01-w-6535 and for sidharth vashisht  P2, director of L36 at L30 L34 L10 his farmhouse at L39 and L35 L2'],
#  '30.04.1999, okhla': ['therefore to contend that sanjay mehtani was deliberately not examined by the prosecution is absolutely baseless and not founded on the basis of the record. the conduct of absconding:\n\n99) from the testimony of pw-20 and pw-24, it is proved beyond reasonable doubt that accused sidharth vashisht  P2 after committing the murder of P14 fled away from the scene of occurrence.  it is further proved from the testimony of pw-100, pw-101, pw-87 P35 pw-85 and pw-80 that from afternoon of T8 search was made for the black tata safari bearing regn. no. ch-01-w-6535 and for sidharth vashisht  P2, director of L36 at L30 L34 L10 his farmhouse at L39 and L35 L2'],
#  '30.04.1999, delhi': ['therefore to contend that sanjay mehtani was deliberately not examined by the prosecution is absolutely baseless and not founded on the basis of the record. the conduct of absconding:\n\n99) from the testimony of pw-20 and pw-24, it is proved beyond reasonable doubt that accused sidharth vashisht  P2 after committing the murder of P14 fled away from the scene of occurrence.  it is further proved from the testimony of pw-100, pw-101, pw-87 P35 pw-85 and pw-80 that from afternoon of T8 search was made for the black tata safari bearing regn. no. ch-01-w-6535 and for sidharth vashisht  P2, director of L36 at L30 L34 L10 his farmhouse at L39 and L35 L2'],
#  '11:20 a.m., NULL': ['the scrutiny of the entire evidence of pw-6 clearly shows that her evidence is not only relevant but also admissible. coming to the cause of death, dr. P71 pw-9, who conducted post-mortem on the body of deceased P14 has stated that on T8 at about T114 7 sheets of papers i.e. inquest papers, request of post-mortem, inquest report, copy of fir, brief facts of the case, were submitted to him along with the dead body. he informed that the cause of death to the best of his knowledge and belief was head injury due to firearm, injury was ante-mortem in nature.'],
#  '07.05.1999, NULL': ['the appellant/accused has relied on the testimony of pw-7 to show that the cartridges sold to appellant/accused had kf marking is wholly unwarranted. the prosecution has established that the appellant/accused was the holder of a .22 bore pistol; he was witnessed by P17 as the perpetrator of the crime; a mutilated .22 lead was recovered from the skull of the deceased; two empties of .22 make with mark c were found at the spot; a .22 live cartridge with mark c was found in the tata safari of the appellant/accused which was found abandoned at noida and for which no theft report was lodged; that his prior and subsequent conduct of having got the tata safari removed from the spot, of absconding; refusal to tip without having any basis; that he even denied his presence at the spot, clearly prove beyond reasonable doubt leaving no manner of doubt that he is guilty of the offence of murdering P14 by using firearm and destroying evidence thereafter. it is pointed out by the state that when the accused P2 was arrested on 06.05.1999, the police filed an application dated T30 for police remand of the accused for recovery of pistol. '],
#  'bd dubey': ['the same was taken into possession by L2 police on T25 after taking appropriate orders from the magistrate L51 recovery of tata safari with live bullet and broken glass pieces at noida: 47) pw-91 si P38 in his evidence has stated that information was received that the vehicle involved in jessical lal murder case was parked at ntpc township. they reached ntpc township at about T82 on T81 and found a safari vehicle parked there bearing no. ch-01-w-6535'],
#  '03.05.1999, delhi': ['the same was taken into possession by L2 police on T25 after taking appropriate orders from the magistrate L51 recovery of tata safari with live bullet and broken glass pieces at noida: 47) pw-91 si P38 in his evidence has stated that information was received that the vehicle involved in jessical lal murder case was parked at ntpc township. they reached ntpc township at about T82 on T81 and found a safari vehicle parked there bearing no. ch-01-w-6535'],
#  '03.05.1999, ghaziabad': ['the same was taken into possession by L2 police on T25 after taking appropriate orders from the magistrate L51 recovery of tata safari with live bullet and broken glass pieces at noida: 47) pw-91 si P38 in his evidence has stated that information was received that the vehicle involved in jessical lal murder case was parked at ntpc township. they reached ntpc township at about T82 on T81 and found a safari vehicle parked there bearing no. ch-01-w-6535'],
#  '06.30 p.m., delhi': ['the same was taken into possession by L2 police on T25 after taking appropriate orders from the magistrate L51 recovery of tata safari with live bullet and broken glass pieces at noida: 47) pw-91 si P38 in his evidence has stated that information was received that the vehicle involved in jessical lal murder case was parked at ntpc township. they reached ntpc township at about T82 on T81 and found a safari vehicle parked there bearing no. ch-01-w-6535'],
#  '06.30 p.m., ghaziabad': ['the same was taken into possession by L2 police on T25 after taking appropriate orders from the magistrate L51 recovery of tata safari with live bullet and broken glass pieces at noida: 47) pw-91 si P38 in his evidence has stated that information was received that the vehicle involved in jessical lal murder case was parked at ntpc township. they reached ntpc township at about T82 on T81 and found a safari vehicle parked there bearing no. ch-01-w-6535'],
#  '02.05.99, delhi': ['the same was taken into possession by L2 police on T25 after taking appropriate orders from the magistrate L51 recovery of tata safari with live bullet and broken glass pieces at noida: 47) pw-91 si P38 in his evidence has stated that information was received that the vehicle involved in jessical lal murder case was parked at ntpc township. they reached ntpc township at about T82 on T81 and found a safari vehicle parked there bearing no. ch-01-w-6535'],
#  '02.05.99, ghaziabad': ['the same was taken into possession by L2 police on T25 after taking appropriate orders from the magistrate L51 recovery of tata safari with live bullet and broken glass pieces at noida: 47) pw-91 si P38 in his evidence has stated that information was received that the vehicle involved in jessical lal murder case was parked at ntpc township. they reached ntpc township at about T82 on T81 and found a safari vehicle parked there bearing no. ch-01-w-6535']}

# %%
import pandas as pd

data = {
    "Law/Scheme": [
        "Electoral Bond Scheme",
        "Unlimited Corporate Funding",
        "Non-Disclosure of Contributions",
        "Section 154 (Companies Act)",
        "Sections 11 & 137 (IT & RPA)",
        "Section 31(3) (RBI Act)",
        "Sec. 182 (Companies Act)",
        "Sec. 29C (RPA)",
        "Sec. 13A (IT Act)",
        "Sec. 2 (FCRA)"
    ],
    "Argument For": [
        "Incentivizes political donations through banking channels (reducing black money). Protects donor privacy.",
        "Simplifies regulations, discourages shell companies.",
        "Protects donors from retribution and encourages contributions.",
        "Aligns company disclosure requirements with RPA (after EBS changes).",
        "Facilitate implementation of EBS.",
        "Enables the issuance of Electoral Bonds.",
        "Post-amendment: Aligns company disclosures with RPA (after EBS changes). Pre-amendment: Transparency, accountability for corporate donations.",
        "Transparency of political party funding (pre-amendment).",
        "Tax exemption for political parties encourages legitimate funding.",
        "(Amendment not directly challenged in ADR, but its relationship to EBS was a concern): Attempts to regulate foreign contributions."
    ],
    "Argument Against": [
        "Anonymizes contributions, hindering transparency and accountability. Enables quid pro quo arrangements and corruption. Not the least restrictive means of achieving stated goals. Disproportionately benefits ruling parties.",
        "Allows undue corporate influence on elections and policy. Creates uneven playing field for smaller parties and independent candidates. Harms the principle of 'one person, one vote.'",
        "Violates voters' right to information about political funding, hindering informed decision-making.",
        "Further reduces transparency of corporate political donations, making it harder to track influence.",
        "Directly enable the anonymity of EBS donations, undermining transparency in electoral funding.",
        "Allows a new form of bearer instrument, raising concerns about money laundering and misuse.",
        "Post-amendment: Removes cap on corporate funding, enabling undue influence, violating Art. 14 (equality). Post-amendment: Reduces transparency by removing requirement to disclose recipient party. Pre-amendment: Cap on donations seen as potentially encouraging shell companies.",
        "Post-amendment: EBS exception guts transparency by shielding significant contributions from disclosure, violating Art. 19(1)(a).",
        "Post-amendment: EBS exception creates a loophole for not recording contributions, enabling black money and violating transparency.",
        "Concerns about loopholes allowing foreign corporate influence through Indian subsidiaries, especially given EBS anonymity."
    ]
}

df = pd.DataFrame(data)
df
# Out:
#                         Law/Scheme  \
# 0            Electoral Bond Scheme
# 1      Unlimited Corporate Funding
# 2  Non-Disclosure of Contributions
# 3      Section 154 (Companies Act)
# 4     Sections 11 & 137 (IT & RPA)
# 5          Section 31(3) (RBI Act)
# 6         Sec. 182 (Companies Act)
# 7                   Sec. 29C (RPA)
# 8                Sec. 13A (IT Act)
# 9                    Sec. 2 (FCRA)
#
#                                         Argument For  \
# 0  Incentivizes political donations through banki...
# 1  Simplifies regulations, discourages shell comp...
# 2  Protects donors from retribution and encourage...
# 3  Aligns company disclosure requirements with RP...
# 4                  Facilitate implementation of EBS.
# 5           Enables the issuance of Electoral Bonds.
# 6  Post-amendment: Aligns company disclosures wit...
# 7  Transparency of political party funding (pre-a...
# 8  Tax exemption for political parties encourages...
# 9  (Amendment not directly challenged in ADR, but...
#
#                                     Argument Against
# 0  Anonymizes contributions, hindering transparen...
# 1  Allows undue corporate influence on elections ...
# 2  Violates voters' right to information about po...
# 3  Further reduces transparency of corporate poli...
# 4  Directly enable the anonymity of EBS donations...
# 5  Allows a new form of bearer instrument, raisin...
# 6  Post-amendment: Removes cap on corporate fundi...
# 7  Post-amendment: EBS exception guts transparenc...
# 8  Post-amendment: EBS exception creates a loopho...
# 9  Concerns about loopholes allowing foreign corp...
